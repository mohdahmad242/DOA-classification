# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 300
no_doa = 6

# %%
root_dataset_path =  ("/content/drive/MyDrive/DOA/{}/{}/DOA{}".format(nq_type, no_samples, no_doa))

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_{}_0_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, nq_type, no_samples)
# Out:
# 2021-07-01 00:26:48,963 - Data prepration started
# 2021-07-01 00:27:20,216 - Dividing your dataset into 3 channel
# 2021-07-01 00:33:42,075 - Creating Train dataloader
# 2021-07-01 00:33:48,355 - Creating Validation dataloader
# 2021-07-01 00:33:49,462 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 6, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 35

weights_dir = root_dataset_path

autoencoder = ResNet34()
cross_criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
  classification_model = autoencoder.cuda()
  optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-5)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=5, verbose=True)
# Out:
# Tesla P100-PCIE-16GB

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
mae_res
# Out:
# {0: [], 10: [], 20: [], 30: [], 40: [], 'training': []}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))

                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/35], Training Loss: 4.6556, Training Accuracy: 3.0576, Training MAE: 0.24360977113246918
# SNR [0dB], Validation Loss: 4.5624, Validation Accuracy: 3.5678, Validation MAE: 0.31370922923088074
# SNR [10dB], Validation Loss: 3.6907, Validation Accuracy: 9.8211, Validation MAE: 0.17038461565971375
# SNR [20dB], Validation Loss: 3.3632, Validation Accuracy: 13.2500, Validation MAE: 0.12435692548751831
# SNR [30dB], Validation Loss: 3.3002, Validation Accuracy: 14.1322, Validation MAE: 0.1186361238360405
# SNR [40dB], Validation Loss: 3.2934, Validation Accuracy: 13.9711, Validation MAE: 0.11766204982995987
#
#
# Epoch [2/35], Training Loss: 3.0267, Training Accuracy: 17.1729, Training MAE: 0.10581047087907791
# SNR [0dB], Validation Loss: 4.1550, Validation Accuracy: 6.9256, Validation MAE: 0.23181933164596558
# SNR [10dB], Validation Loss: 3.1327, Validation Accuracy: 18.5133, Validation MAE: 0.1303451657295227
# SNR [20dB], Validation Loss: 2.5944, Validation Accuracy: 28.1478, Validation MAE: 0.09881004691123962
# SNR [30dB], Validation Loss: 2.4468, Validation Accuracy: 31.7033, Validation MAE: 0.09488337486982346
# SNR [40dB], Validation Loss: 2.4255, Validation Accuracy: 32.6556, Validation MAE: 0.09414847195148468
#
#
# Epoch [3/35], Training Loss: 2.6831, Training Accuracy: 25.3453, Training MAE: 0.10036667436361313
# SNR [0dB], Validation Loss: 3.9610, Validation Accuracy: 8.1433, Validation MAE: 0.17148970067501068
# SNR [10dB], Validation Loss: 2.9259, Validation Accuracy: 21.6233, Validation MAE: 0.10707306116819382
# SNR [20dB], Validation Loss: 2.2939, Validation Accuracy: 34.4933, Validation MAE: 0.08624099940061569
# SNR [30dB], Validation Loss: 2.0921, Validation Accuracy: 40.1167, Validation MAE: 0.08264829218387604
# SNR [40dB], Validation Loss: 2.0621, Validation Accuracy: 41.1833, Validation MAE: 0.08183115720748901
#
#
# Epoch [4/35], Training Loss: 2.4965, Training Accuracy: 31.0411, Training MAE: 0.09443260729312897
# SNR [0dB], Validation Loss: 3.8868, Validation Accuracy: 8.9911, Validation MAE: 0.1571885049343109
# SNR [10dB], Validation Loss: 2.7976, Validation Accuracy: 23.6567, Validation MAE: 0.0958499163389206
# SNR [20dB], Validation Loss: 2.1242, Validation Accuracy: 39.5644, Validation MAE: 0.07753834873437881
# SNR [30dB], Validation Loss: 1.8874, Validation Accuracy: 47.3178, Validation MAE: 0.0737592950463295
# SNR [40dB], Validation Loss: 1.8421, Validation Accuracy: 49.1022, Validation MAE: 0.07366801798343658
#
#
# Epoch [5/35], Training Loss: 2.3994, Training Accuracy: 34.2262, Training MAE: 0.0888582095503807
# SNR [0dB], Validation Loss: 3.8718, Validation Accuracy: 9.2544, Validation MAE: 0.15837886929512024
# SNR [10dB], Validation Loss: 2.7918, Validation Accuracy: 24.7878, Validation MAE: 0.10142765939235687
# SNR [20dB], Validation Loss: 2.1113, Validation Accuracy: 41.7311, Validation MAE: 0.08204557001590729
# SNR [30dB], Validation Loss: 1.8613, Validation Accuracy: 50.0311, Validation MAE: 0.07762490957975388
# SNR [40dB], Validation Loss: 1.8162, Validation Accuracy: 52.1656, Validation MAE: 0.0775543674826622
#
#
# Epoch [6/35], Training Loss: 2.3358, Training Accuracy: 36.3623, Training MAE: 0.08643366396427155
# SNR [0dB], Validation Loss: 3.8055, Validation Accuracy: 9.6144, Validation MAE: 0.1322309821844101
# SNR [10dB], Validation Loss: 2.7247, Validation Accuracy: 25.7211, Validation MAE: 0.07955457270145416
# SNR [20dB], Validation Loss: 2.0045, Validation Accuracy: 43.8689, Validation MAE: 0.06518479436635971
# SNR [30dB], Validation Loss: 1.7211, Validation Accuracy: 53.1689, Validation MAE: 0.06339472532272339
# SNR [40dB], Validation Loss: 1.6633, Validation Accuracy: 55.9833, Validation MAE: 0.06325483322143555
#
#
# Epoch [7/35], Training Loss: 2.2914, Training Accuracy: 37.8424, Training MAE: 0.08473242074251175
# SNR [0dB], Validation Loss: 3.8118, Validation Accuracy: 9.7400, Validation MAE: 0.1394200325012207
# SNR [10dB], Validation Loss: 2.7338, Validation Accuracy: 25.5989, Validation MAE: 0.08674582093954086
# SNR [20dB], Validation Loss: 2.0357, Validation Accuracy: 43.3622, Validation MAE: 0.06951449811458588
# SNR [30dB], Validation Loss: 1.7454, Validation Accuracy: 53.0956, Validation MAE: 0.06608419865369797
# SNR [40dB], Validation Loss: 1.6850, Validation Accuracy: 55.6267, Validation MAE: 0.06530378013849258
#
#
# Epoch [8/35], Training Loss: 2.2550, Training Accuracy: 39.0359, Training MAE: 0.08388932794332504
# SNR [0dB], Validation Loss: 3.8111, Validation Accuracy: 9.7067, Validation MAE: 0.1329527646303177
# SNR [10dB], Validation Loss: 2.7509, Validation Accuracy: 26.2178, Validation MAE: 0.08125611394643784
# SNR [20dB], Validation Loss: 2.0371, Validation Accuracy: 45.2244, Validation MAE: 0.06469085067510605
# SNR [30dB], Validation Loss: 1.7314, Validation Accuracy: 55.4667, Validation MAE: 0.062299713492393494
# SNR [40dB], Validation Loss: 1.6665, Validation Accuracy: 58.3833, Validation MAE: 0.06174871698021889
#
#
# Epoch [9/35], Training Loss: 2.2282, Training Accuracy: 39.9142, Training MAE: 0.08331125229597092
# SNR [0dB], Validation Loss: 4.1082, Validation Accuracy: 9.5533, Validation MAE: 0.12793219089508057
# SNR [10dB], Validation Loss: 3.2148, Validation Accuracy: 24.8967, Validation MAE: 0.0740964263677597
# SNR [20dB], Validation Loss: 2.5461, Validation Accuracy: 42.0467, Validation MAE: 0.05786290019750595
# SNR [30dB], Validation Loss: 2.2146, Validation Accuracy: 51.3256, Validation MAE: 0.054742470383644104
# SNR [40dB], Validation Loss: 2.1500, Validation Accuracy: 53.2711, Validation MAE: 0.05469575524330139
#
#
# Epoch [10/35], Training Loss: 2.2072, Training Accuracy: 40.6072, Training MAE: 0.08276988565921783
# SNR [0dB], Validation Loss: 3.7975, Validation Accuracy: 10.0644, Validation MAE: 0.13710469007492065
# SNR [10dB], Validation Loss: 2.7434, Validation Accuracy: 26.5889, Validation MAE: 0.08524471521377563
# SNR [20dB], Validation Loss: 1.9914, Validation Accuracy: 46.0733, Validation MAE: 0.06835120916366577
# SNR [30dB], Validation Loss: 1.6627, Validation Accuracy: 56.8778, Validation MAE: 0.06450052559375763
# SNR [40dB], Validation Loss: 1.5958, Validation Accuracy: 59.7067, Validation MAE: 0.06402693688869476
#
#
# Epoch [11/35], Training Loss: 2.1844, Training Accuracy: 41.3204, Training MAE: 0.08177963644266129
# SNR [0dB], Validation Loss: 3.7853, Validation Accuracy: 10.0800, Validation MAE: 0.13357116281986237
# SNR [10dB], Validation Loss: 2.7379, Validation Accuracy: 26.8533, Validation MAE: 0.0831775963306427
# SNR [20dB], Validation Loss: 2.0136, Validation Accuracy: 46.0667, Validation MAE: 0.06724479049444199
# SNR [30dB], Validation Loss: 1.6761, Validation Accuracy: 56.4156, Validation MAE: 0.06386706233024597
# SNR [40dB], Validation Loss: 1.6022, Validation Accuracy: 59.4211, Validation MAE: 0.06349990516901016
#
#
# Epoch [12/35], Training Loss: 2.1666, Training Accuracy: 41.9222, Training MAE: 0.08077030628919601
# SNR [0dB], Validation Loss: 3.7727, Validation Accuracy: 10.0222, Validation MAE: 0.13518863916397095
# SNR [10dB], Validation Loss: 2.7214, Validation Accuracy: 27.2200, Validation MAE: 0.08569512516260147
# SNR [20dB], Validation Loss: 1.9598, Validation Accuracy: 47.6044, Validation MAE: 0.0695546418428421
# SNR [30dB], Validation Loss: 1.6069, Validation Accuracy: 59.1256, Validation MAE: 0.06553009897470474
# SNR [40dB], Validation Loss: 1.5333, Validation Accuracy: 61.9711, Validation MAE: 0.06516002118587494
#
#
# Epoch [13/35], Training Loss: 2.1518, Training Accuracy: 42.4131, Training MAE: 0.08103205263614655
# SNR [0dB], Validation Loss: 3.7714, Validation Accuracy: 9.8889, Validation MAE: 0.1279919147491455
# SNR [10dB], Validation Loss: 2.7457, Validation Accuracy: 27.2156, Validation MAE: 0.07681628316640854
# SNR [20dB], Validation Loss: 2.0434, Validation Accuracy: 48.0489, Validation MAE: 0.05992145091295242
# SNR [30dB], Validation Loss: 1.7052, Validation Accuracy: 60.0067, Validation MAE: 0.05552353709936142
# SNR [40dB], Validation Loss: 1.6202, Validation Accuracy: 63.7833, Validation MAE: 0.054913174360990524
#
#
# Epoch [14/35], Training Loss: 2.1368, Training Accuracy: 42.8290, Training MAE: 0.08020202815532684
# SNR [0dB], Validation Loss: 3.7567, Validation Accuracy: 10.1289, Validation MAE: 0.13373415172100067
# SNR [10dB], Validation Loss: 2.7043, Validation Accuracy: 27.1211, Validation MAE: 0.08212439715862274
# SNR [20dB], Validation Loss: 1.9992, Validation Accuracy: 47.1733, Validation MAE: 0.06572498381137848
# SNR [30dB], Validation Loss: 1.6609, Validation Accuracy: 58.1111, Validation MAE: 0.06219489872455597
# SNR [40dB], Validation Loss: 1.5750, Validation Accuracy: 61.4644, Validation MAE: 0.06187764182686806
#
#
# Epoch [15/35], Training Loss: 2.1395, Training Accuracy: 42.8465, Training MAE: 0.08051445335149765
# SNR [0dB], Validation Loss: 3.8027, Validation Accuracy: 10.0333, Validation MAE: 0.15235891938209534
# SNR [10dB], Validation Loss: 2.7388, Validation Accuracy: 26.9922, Validation MAE: 0.10039406269788742
# SNR [20dB], Validation Loss: 1.9918, Validation Accuracy: 46.7933, Validation MAE: 0.08274417370557785
# SNR [30dB], Validation Loss: 1.6533, Validation Accuracy: 58.5900, Validation MAE: 0.07869736850261688
# SNR [40dB], Validation Loss: 1.5811, Validation Accuracy: 61.8244, Validation MAE: 0.07832645624876022
#
#
# Epoch [16/35], Training Loss: 2.1150, Training Accuracy: 43.5689, Training MAE: 0.0802852213382721
# SNR [0dB], Validation Loss: 3.8083, Validation Accuracy: 10.2267, Validation MAE: 0.11978880316019058
# SNR [10dB], Validation Loss: 2.7717, Validation Accuracy: 27.3022, Validation MAE: 0.0709959864616394
# SNR [20dB], Validation Loss: 2.0329, Validation Accuracy: 48.2422, Validation MAE: 0.05546141788363457
# SNR [30dB], Validation Loss: 1.6603, Validation Accuracy: 60.5178, Validation MAE: 0.051455482840538025
# SNR [40dB], Validation Loss: 1.5725, Validation Accuracy: 64.3944, Validation MAE: 0.05044363811612129
#
#
# Epoch [17/35], Training Loss: 2.1059, Training Accuracy: 43.8376, Training MAE: 0.07885124534368515
# SNR [0dB], Validation Loss: 3.7767, Validation Accuracy: 10.2989, Validation MAE: 0.1310306340456009
# SNR [10dB], Validation Loss: 2.7253, Validation Accuracy: 27.4233, Validation MAE: 0.08129548281431198
# SNR [20dB], Validation Loss: 1.9697, Validation Accuracy: 48.6622, Validation MAE: 0.06615804135799408
# SNR [30dB], Validation Loss: 1.5951, Validation Accuracy: 61.3578, Validation MAE: 0.061733417212963104
# SNR [40dB], Validation Loss: 1.5064, Validation Accuracy: 65.0044, Validation MAE: 0.06190912798047066
#
#
# Epoch [18/35], Training Loss: 2.0947, Training Accuracy: 44.1753, Training MAE: 0.07951150834560394
# SNR [0dB], Validation Loss: 3.7718, Validation Accuracy: 10.2989, Validation MAE: 0.13928242027759552
# SNR [10dB], Validation Loss: 2.7280, Validation Accuracy: 27.2156, Validation MAE: 0.08773001283407211
# SNR [20dB], Validation Loss: 1.9854, Validation Accuracy: 46.9656, Validation MAE: 0.06990188360214233
# SNR [30dB], Validation Loss: 1.6273, Validation Accuracy: 58.3333, Validation MAE: 0.06421130895614624
# SNR [40dB], Validation Loss: 1.5483, Validation Accuracy: 61.9467, Validation MAE: 0.06386218965053558
#
#
# Epoch [19/35], Training Loss: 2.0842, Training Accuracy: 44.4785, Training MAE: 0.07882137596607208
# SNR [0dB], Validation Loss: 3.7354, Validation Accuracy: 10.3011, Validation MAE: 0.13275499641895294
# SNR [10dB], Validation Loss: 2.7035, Validation Accuracy: 27.3267, Validation MAE: 0.08522360026836395
# SNR [20dB], Validation Loss: 1.9949, Validation Accuracy: 47.9767, Validation MAE: 0.06916752457618713
# SNR [30dB], Validation Loss: 1.6345, Validation Accuracy: 60.2689, Validation MAE: 0.06426477432250977
# SNR [40dB], Validation Loss: 1.5384, Validation Accuracy: 64.1522, Validation MAE: 0.06344831734895706
#
#
# Epoch [20/35], Training Loss: 2.0852, Training Accuracy: 44.5093, Training MAE: 0.0789426863193512
# SNR [0dB], Validation Loss: 3.7837, Validation Accuracy: 10.4022, Validation MAE: 0.1274021565914154
# SNR [10dB], Validation Loss: 2.7495, Validation Accuracy: 28.0311, Validation MAE: 0.07767938822507858
# SNR [20dB], Validation Loss: 2.0032, Validation Accuracy: 49.5233, Validation MAE: 0.0614938847720623
# SNR [30dB], Validation Loss: 1.6072, Validation Accuracy: 62.9200, Validation MAE: 0.056693024933338165
# SNR [40dB], Validation Loss: 1.5019, Validation Accuracy: 67.4222, Validation MAE: 0.055597733706235886
#
#
# Epoch [21/35], Training Loss: 2.0680, Training Accuracy: 44.9516, Training MAE: 0.07822678983211517
# SNR [0dB], Validation Loss: 3.7761, Validation Accuracy: 10.2444, Validation MAE: 0.12145853042602539
# SNR [10dB], Validation Loss: 2.7677, Validation Accuracy: 27.4922, Validation MAE: 0.07168951630592346
# SNR [20dB], Validation Loss: 2.0822, Validation Accuracy: 48.8067, Validation MAE: 0.05597151443362236
# SNR [30dB], Validation Loss: 1.7474, Validation Accuracy: 61.3656, Validation MAE: 0.05266069248318672
# SNR [40dB], Validation Loss: 1.6611, Validation Accuracy: 65.2667, Validation MAE: 0.051631879061460495
#
#
# Epoch [22/35], Training Loss: 2.0606, Training Accuracy: 45.1891, Training MAE: 0.0779731422662735
# SNR [0dB], Validation Loss: 3.7641, Validation Accuracy: 10.2056, Validation MAE: 0.1302129477262497
# SNR [10dB], Validation Loss: 2.7275, Validation Accuracy: 27.8689, Validation MAE: 0.07992194592952728
# SNR [20dB], Validation Loss: 1.9769, Validation Accuracy: 49.2000, Validation MAE: 0.06368836015462875
# SNR [30dB], Validation Loss: 1.5895, Validation Accuracy: 62.0156, Validation MAE: 0.05667524412274361
# SNR [40dB], Validation Loss: 1.4917, Validation Accuracy: 65.8556, Validation MAE: 0.05605495348572731
#
#
# Epoch [23/35], Training Loss: 2.0544, Training Accuracy: 45.3412, Training MAE: 0.07799351215362549
# SNR [0dB], Validation Loss: 3.7587, Validation Accuracy: 10.1656, Validation MAE: 0.12639650702476501
# SNR [10dB], Validation Loss: 2.7280, Validation Accuracy: 27.8911, Validation MAE: 0.07592882961034775
# SNR [20dB], Validation Loss: 1.9871, Validation Accuracy: 49.1789, Validation MAE: 0.06016917526721954
# SNR [30dB], Validation Loss: 1.5971, Validation Accuracy: 62.0322, Validation MAE: 0.05590115487575531
# SNR [40dB], Validation Loss: 1.4941, Validation Accuracy: 65.9378, Validation MAE: 0.05443187057971954
#
#
# Epoch [24/35], Training Loss: 2.0415, Training Accuracy: 45.7212, Training MAE: 0.07790648192167282
# SNR [0dB], Validation Loss: 3.7816, Validation Accuracy: 10.1122, Validation MAE: 0.13549302518367767
# SNR [10dB], Validation Loss: 2.7564, Validation Accuracy: 27.2600, Validation MAE: 0.08682871609926224
# SNR [20dB], Validation Loss: 2.0254, Validation Accuracy: 48.5144, Validation MAE: 0.0709872841835022
# SNR [30dB], Validation Loss: 1.6421, Validation Accuracy: 61.4800, Validation MAE: 0.06754449754953384
# SNR [40dB], Validation Loss: 1.5400, Validation Accuracy: 65.8211, Validation MAE: 0.06710726022720337
#
#
# Criterion is changed to focal loss
# Epoch [25/35], Training Loss: 1.5396, Training Accuracy: 45.8380, Training MAE: 0.0774020254611969
# SNR [0dB], Validation Loss: 3.5526, Validation Accuracy: 10.1100, Validation MAE: 0.12870827317237854
# SNR [10dB], Validation Loss: 2.3347, Validation Accuracy: 27.7444, Validation MAE: 0.07899587601423264
# SNR [20dB], Validation Loss: 1.4507, Validation Accuracy: 49.4322, Validation MAE: 0.06237700581550598
# SNR [30dB], Validation Loss: 1.0007, Validation Accuracy: 63.2256, Validation MAE: 0.05792232230305672
# SNR [40dB], Validation Loss: 0.8763, Validation Accuracy: 67.7044, Validation MAE: 0.05674780160188675
#
#
# Criterion is changed to focal loss
# Epoch [26/35], Training Loss: 1.5235, Training Accuracy: 46.2382, Training MAE: 0.07707896828651428
# SNR [0dB], Validation Loss: 3.5611, Validation Accuracy: 10.2411, Validation MAE: 0.12935152649879456
# SNR [10dB], Validation Loss: 2.3309, Validation Accuracy: 27.8467, Validation MAE: 0.07796750962734222
# SNR [20dB], Validation Loss: 1.3979, Validation Accuracy: 49.6133, Validation MAE: 0.060442641377449036
# SNR [30dB], Validation Loss: 0.9418, Validation Accuracy: 62.9456, Validation MAE: 0.0546647310256958
# SNR [40dB], Validation Loss: 0.8338, Validation Accuracy: 67.1511, Validation MAE: 0.05435749143362045
#
#
# Criterion is changed to focal loss
# Epoch [27/35], Training Loss: 1.5115, Training Accuracy: 46.5198, Training MAE: 0.07692158222198486
# SNR [0dB], Validation Loss: 3.5691, Validation Accuracy: 10.0989, Validation MAE: 0.13415765762329102
# SNR [10dB], Validation Loss: 2.3566, Validation Accuracy: 27.4300, Validation MAE: 0.08508456498384476
# SNR [20dB], Validation Loss: 1.4397, Validation Accuracy: 49.0867, Validation MAE: 0.06855285167694092
# SNR [30dB], Validation Loss: 0.9665, Validation Accuracy: 62.2711, Validation MAE: 0.0620151087641716
# SNR [40dB], Validation Loss: 0.8494, Validation Accuracy: 66.4911, Validation MAE: 0.061704907566308975
#
#
# Criterion is changed to focal loss
# Epoch [28/35], Training Loss: 1.4995, Training Accuracy: 46.7706, Training MAE: 0.07680289447307587
# SNR [0dB], Validation Loss: 3.5861, Validation Accuracy: 10.0556, Validation MAE: 0.12704411149024963
# SNR [10dB], Validation Loss: 2.3863, Validation Accuracy: 27.8567, Validation MAE: 0.07683666795492172
# SNR [20dB], Validation Loss: 1.4822, Validation Accuracy: 50.1167, Validation MAE: 0.06088178977370262
# SNR [30dB], Validation Loss: 1.0151, Validation Accuracy: 63.7844, Validation MAE: 0.05615999549627304
# SNR [40dB], Validation Loss: 0.9003, Validation Accuracy: 67.8311, Validation MAE: 0.055446475744247437
#
#
# Criterion is changed to focal loss
# Epoch [29/35], Training Loss: 1.4867, Training Accuracy: 47.0351, Training MAE: 0.0766906812787056
# SNR [0dB], Validation Loss: 3.5569, Validation Accuracy: 10.0111, Validation MAE: 0.13013529777526855
# SNR [10dB], Validation Loss: 2.3184, Validation Accuracy: 27.5000, Validation MAE: 0.07826434075832367
# SNR [20dB], Validation Loss: 1.4179, Validation Accuracy: 49.7256, Validation MAE: 0.060835160315036774
# SNR [30dB], Validation Loss: 0.9622, Validation Accuracy: 63.1133, Validation MAE: 0.05554434284567833
# SNR [40dB], Validation Loss: 0.8422, Validation Accuracy: 67.7600, Validation MAE: 0.05431894585490227
#
#
# Criterion is changed to focal loss
# Epoch [30/35], Training Loss: 1.4732, Training Accuracy: 47.3332, Training MAE: 0.07616965472698212
# SNR [0dB], Validation Loss: 3.5652, Validation Accuracy: 9.9044, Validation MAE: 0.13094750046730042
# SNR [10dB], Validation Loss: 2.2995, Validation Accuracy: 27.6322, Validation MAE: 0.08145551383495331
# SNR [20dB], Validation Loss: 1.3501, Validation Accuracy: 49.3944, Validation MAE: 0.0651567354798317
# SNR [30dB], Validation Loss: 0.8840, Validation Accuracy: 62.6622, Validation MAE: 0.060713030397892
# SNR [40dB], Validation Loss: 0.7746, Validation Accuracy: 67.0411, Validation MAE: 0.06025883927941322
#
#
# Criterion is changed to focal loss
# Epoch [31/35], Training Loss: 1.4618, Training Accuracy: 47.5715, Training MAE: 0.07501712441444397
# SNR [0dB], Validation Loss: 3.5780, Validation Accuracy: 10.0200, Validation MAE: 0.13710135221481323
# SNR [10dB], Validation Loss: 2.3461, Validation Accuracy: 27.5944, Validation MAE: 0.08781611174345016
# SNR [20dB], Validation Loss: 1.4424, Validation Accuracy: 49.5678, Validation MAE: 0.07140550017356873
# SNR [30dB], Validation Loss: 0.9870, Validation Accuracy: 63.3667, Validation MAE: 0.06740140169858932
# SNR [40dB], Validation Loss: 0.8712, Validation Accuracy: 67.9644, Validation MAE: 0.06662282347679138
# Epoch    31: reducing learning rate of group 0 to 5.0000e-05.
#
#
# Criterion is changed to focal loss
# Epoch [32/35], Training Loss: 1.3186, Training Accuracy: 51.3785, Training MAE: 0.07660453766584396
# SNR [0dB], Validation Loss: 3.5543, Validation Accuracy: 9.9511, Validation MAE: 0.14088650047779083
# SNR [10dB], Validation Loss: 2.2489, Validation Accuracy: 28.0867, Validation MAE: 0.09039882570505142
# SNR [20dB], Validation Loss: 1.2664, Validation Accuracy: 51.8767, Validation MAE: 0.07360184192657471
# SNR [30dB], Validation Loss: 0.7563, Validation Accuracy: 67.7344, Validation MAE: 0.06871401518583298
# SNR [40dB], Validation Loss: 0.6083, Validation Accuracy: 73.7911, Validation MAE: 0.06783498823642731
#
#
# Criterion is changed to focal loss
# Epoch [33/35], Training Loss: 1.2898, Training Accuracy: 51.9989, Training MAE: 0.07591723650693893
# SNR [0dB], Validation Loss: 3.5607, Validation Accuracy: 9.9633, Validation MAE: 0.13974454998970032
# SNR [10dB], Validation Loss: 2.2551, Validation Accuracy: 28.0878, Validation MAE: 0.0893966406583786
# SNR [20dB], Validation Loss: 1.2660, Validation Accuracy: 51.9844, Validation MAE: 0.07197470217943192
# SNR [30dB], Validation Loss: 0.7475, Validation Accuracy: 67.8100, Validation MAE: 0.06565456837415695
# SNR [40dB], Validation Loss: 0.5951, Validation Accuracy: 73.9611, Validation MAE: 0.0643911212682724
#
#
# Criterion is changed to focal loss
# Epoch [34/35], Training Loss: 1.2776, Training Accuracy: 52.2900, Training MAE: 0.07438810914754868
# SNR [0dB], Validation Loss: 3.5669, Validation Accuracy: 9.9500, Validation MAE: 0.12726300954818726
# SNR [10dB], Validation Loss: 2.2496, Validation Accuracy: 28.1111, Validation MAE: 0.07620261609554291
# SNR [20dB], Validation Loss: 1.2534, Validation Accuracy: 52.0256, Validation MAE: 0.059863463044166565
# SNR [30dB], Validation Loss: 0.7355, Validation Accuracy: 67.8244, Validation MAE: 0.05477407947182655
# SNR [40dB], Validation Loss: 0.5814, Validation Accuracy: 73.8678, Validation MAE: 0.05317801982164383
#
#
# Criterion is changed to focal loss

# %% [markdown]
# # Results

# %% [markdown]
# ##DOA7

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-7 ====
# = MAE =_= Acc =
# 0.7067   9.72
# 0.2283   27.91
# 0.0871   52.70
# 0.0440   71.16
# 0.0378   77.29

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()

# %% [markdown]
# ##DOA 5

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-5 ====
# = MAE =_= Acc =
# 0.4580   12.11
# 0.1535   33.11
# 0.0600   59.30
# 0.0314   76.33
# 0.0291   79.60

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(max(acc_res[0])), "  {:.4f}".format(mae_res[0][acc_res[0].index(max(acc_res[0]))]))
print("{:.4f}".format(max(acc_res[10])), "  {:.4f}".format(mae_res[10][acc_res[10].index(max(acc_res[10]))]))
print("{:.4f}".format(max(acc_res[20])), "  {:.4f}".format(mae_res[20][acc_res[20].index(max(acc_res[20]))]))
print("{:.4f}".format(max(acc_res[30])), "  {:.4f}".format(mae_res[30][acc_res[30].index(max(acc_res[30]))]))
print("{:.4f}".format(max(acc_res[40])), "  {:.4f}".format(mae_res[40][acc_res[40].index(max(acc_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-5 ====
# = MAE =_= Acc =
# 12.2467   0.4581
# 33.2560   0.1623
# 61.1880   0.0896
# 81.4693   0.0414
# 88.8440   0.0338

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## DOA 5 (Unet + resnet)

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(max(acc_res[0])), "  {:.4f}".format(mae_res[0][acc_res[0].index(max(acc_res[0]))]))
print("{:.4f}".format(max(acc_res[10])), "  {:.4f}".format(mae_res[10][acc_res[10].index(max(acc_res[10]))]))
print("{:.4f}".format(max(acc_res[20])), "  {:.4f}".format(mae_res[20][acc_res[20].index(max(acc_res[20]))]))
print("{:.4f}".format(max(acc_res[30])), "  {:.4f}".format(mae_res[30][acc_res[30].index(max(acc_res[30]))]))
print("{:.4f}".format(max(acc_res[40])), "  {:.4f}".format(mae_res[40][acc_res[40].index(max(acc_res[40]))]))

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
