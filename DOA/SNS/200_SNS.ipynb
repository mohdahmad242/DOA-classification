# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("/content/drive/MyDrive/DOA/SNS/200/DOA5")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_0_5_200.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_5_200.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_5_200.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_5_200.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_5_200.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 200)
# Out:
# 2021-06-21 12:28:18,529 - Data prepration started
# 2021-06-21 12:28:51,239 - Dividing your dataset into 3 channel
# 2021-06-21 12:33:16,756 - Creating Train dataloader
# 2021-06-21 12:33:19,722 - Creating Validation dataloader
# 2021-06-21 12:33:20,346 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((5, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.7)
        self.dropout1 = nn.Dropout(0.6)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 5, 181])

# %%
num_epochs = 60
doa = 5
weights_dir = root_dataset_path

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# Tesla P100-PCIE-16GB

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(64*len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*64*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*128*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_200_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/DOA_{}_200_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 4.9847, Training Accuracy: 1.1394, Training MAE: 1.3639013352304161
# SNR [0dB], Validation Loss: 4.3410, Validation Accuracy: 3.4307, Validation MAE: 0.7055622454115554
# SNR [10dB], Validation Loss: 3.8576, Validation Accuracy: 5.5947, Validation MAE: 0.36595406288041954
# SNR [20dB], Validation Loss: 3.7386, Validation Accuracy: 5.8880, Validation MAE: 0.2825302579829572
# SNR [30dB], Validation Loss: 3.7196, Validation Accuracy: 6.2080, Validation MAE: 0.26748247143927334
# SNR [40dB], Validation Loss: 3.7153, Validation Accuracy: 6.0507, Validation MAE: 0.26312301011330647
#
#
# Epoch [2/60], Training Loss: 2.9932, Training Accuracy: 13.0776, Training MAE: 0.24726046019578693
# SNR [0dB], Validation Loss: 3.8746, Validation Accuracy: 8.1133, Validation MAE: 0.5206103245856354
# SNR [10dB], Validation Loss: 2.8244, Validation Accuracy: 17.7333, Validation MAE: 0.1946401816649499
# SNR [20dB], Validation Loss: 2.4179, Validation Accuracy: 23.6040, Validation MAE: 0.11043761412585448
# SNR [30dB], Validation Loss: 2.3249, Validation Accuracy: 25.1147, Validation MAE: 0.09614700873209102
# SNR [40dB], Validation Loss: 2.3072, Validation Accuracy: 25.6707, Validation MAE: 0.09338640673284015
#
#
# Epoch [3/60], Training Loss: 2.3860, Training Accuracy: 23.4440, Training MAE: 0.18666111334577348
# SNR [0dB], Validation Loss: 3.7567, Validation Accuracy: 9.1987, Validation MAE: 0.4763009615834816
# SNR [10dB], Validation Loss: 2.5999, Validation Accuracy: 23.5027, Validation MAE: 0.1703478351203296
# SNR [20dB], Validation Loss: 2.0069, Validation Accuracy: 36.1973, Validation MAE: 0.07949012079782751
# SNR [30dB], Validation Loss: 1.8399, Validation Accuracy: 41.5587, Validation MAE: 0.0615123724131473
# SNR [40dB], Validation Loss: 1.8093, Validation Accuracy: 42.8000, Validation MAE: 0.05813907552205263
#
#
# Epoch [4/60], Training Loss: 2.1615, Training Accuracy: 29.6234, Training MAE: 0.1706245798742285
# SNR [0dB], Validation Loss: 3.7011, Validation Accuracy: 9.6813, Validation MAE: 0.4654275476402285
# SNR [10dB], Validation Loss: 2.5301, Validation Accuracy: 25.2293, Validation MAE: 0.16810811522614477
# SNR [20dB], Validation Loss: 1.8220, Validation Accuracy: 40.3000, Validation MAE: 0.08126675309017699
# SNR [30dB], Validation Loss: 1.5915, Validation Accuracy: 47.5827, Validation MAE: 0.06309294234010675
# SNR [40dB], Validation Loss: 1.5493, Validation Accuracy: 49.2093, Validation MAE: 0.0624725659003652
#
#
# Epoch [5/60], Training Loss: 2.0254, Training Accuracy: 34.0489, Training MAE: 0.1618016656946925
# SNR [0dB], Validation Loss: 3.6784, Validation Accuracy: 9.9747, Validation MAE: 0.46127256180353965
# SNR [10dB], Validation Loss: 2.5378, Validation Accuracy: 26.2787, Validation MAE: 0.16387009551456128
# SNR [20dB], Validation Loss: 1.8204, Validation Accuracy: 44.2373, Validation MAE: 0.07551802895870399
# SNR [30dB], Validation Loss: 1.5451, Validation Accuracy: 53.6213, Validation MAE: 0.056198570207884636
# SNR [40dB], Validation Loss: 1.4951, Validation Accuracy: 55.2440, Validation MAE: 0.05200590820769735
#
#
# Epoch [6/60], Training Loss: 1.9234, Training Accuracy: 37.6712, Training MAE: 0.15585591110721028
# SNR [0dB], Validation Loss: 3.6364, Validation Accuracy: 9.8813, Validation MAE: 0.4832765386506227
# SNR [10dB], Validation Loss: 2.4364, Validation Accuracy: 27.5787, Validation MAE: 0.16488332826107313
# SNR [20dB], Validation Loss: 1.5869, Validation Accuracy: 48.9507, Validation MAE: 0.06713453389830508
# SNR [30dB], Validation Loss: 1.2373, Validation Accuracy: 60.5707, Validation MAE: 0.04507605463994756
# SNR [40dB], Validation Loss: 1.1650, Validation Accuracy: 63.6667, Validation MAE: 0.03869561464088398
#
#
# Epoch [7/60], Training Loss: 1.8465, Training Accuracy: 40.4099, Training MAE: 0.1516918693600195
# SNR [0dB], Validation Loss: 3.6617, Validation Accuracy: 9.8347, Validation MAE: 0.49946594952710927
# SNR [10dB], Validation Loss: 2.4350, Validation Accuracy: 27.5960, Validation MAE: 0.16338286590504728
# SNR [20dB], Validation Loss: 1.6051, Validation Accuracy: 47.5533, Validation MAE: 0.06530852022661297
# SNR [30dB], Validation Loss: 1.2518, Validation Accuracy: 58.0773, Validation MAE: 0.04547000831070325
# SNR [40dB], Validation Loss: 1.1773, Validation Accuracy: 60.8000, Validation MAE: 0.04022497424852514
#
#
# Epoch [8/60], Training Loss: 1.7880, Training Accuracy: 42.4714, Training MAE: 0.14913376877359047
# SNR [0dB], Validation Loss: 3.5938, Validation Accuracy: 10.1267, Validation MAE: 0.48276187494147393
# SNR [10dB], Validation Loss: 2.3259, Validation Accuracy: 28.4493, Validation MAE: 0.1645903320769735
# SNR [20dB], Validation Loss: 1.4481, Validation Accuracy: 51.0080, Validation MAE: 0.06396351776851765
# SNR [30dB], Validation Loss: 1.0402, Validation Accuracy: 64.0027, Validation MAE: 0.041996119720947654
# SNR [40dB], Validation Loss: 0.9462, Validation Accuracy: 67.2107, Validation MAE: 0.037803457720760374
#
#
# Epoch [9/60], Training Loss: 1.7431, Training Accuracy: 44.0878, Training MAE: 0.14671926748783923
# SNR [0dB], Validation Loss: 3.6273, Validation Accuracy: 9.9387, Validation MAE: 0.487914364640884
# SNR [10dB], Validation Loss: 2.3527, Validation Accuracy: 28.5373, Validation MAE: 0.16605238669351063
# SNR [20dB], Validation Loss: 1.4413, Validation Accuracy: 51.3613, Validation MAE: 0.0662164060305272
# SNR [30dB], Validation Loss: 1.0252, Validation Accuracy: 64.5187, Validation MAE: 0.04494290780972001
# SNR [40dB], Validation Loss: 0.9306, Validation Accuracy: 67.9867, Validation MAE: 0.04249139666635453
#
#
# Epoch [10/60], Training Loss: 1.7080, Training Accuracy: 45.2504, Training MAE: 0.14451137136955178
# SNR [0dB], Validation Loss: 3.6091, Validation Accuracy: 10.0987, Validation MAE: 0.4972086718091582
# SNR [10dB], Validation Loss: 2.3196, Validation Accuracy: 28.6533, Validation MAE: 0.16514413510160128
# SNR [20dB], Validation Loss: 1.3935, Validation Accuracy: 52.2400, Validation MAE: 0.061840850032774605
# SNR [30dB], Validation Loss: 0.9368, Validation Accuracy: 67.0560, Validation MAE: 0.0369464164481693
# SNR [40dB], Validation Loss: 0.8310, Validation Accuracy: 70.9067, Validation MAE: 0.031031258778911882
#
#
# Epoch [11/60], Training Loss: 1.6794, Training Accuracy: 46.2542, Training MAE: 0.14319738642253338
# SNR [0dB], Validation Loss: 3.5780, Validation Accuracy: 10.1907, Validation MAE: 0.4797653396853638
# SNR [10dB], Validation Loss: 2.3003, Validation Accuracy: 29.0907, Validation MAE: 0.16480139175016387
# SNR [20dB], Validation Loss: 1.3690, Validation Accuracy: 53.2387, Validation MAE: 0.06140702547054968
# SNR [30dB], Validation Loss: 0.9023, Validation Accuracy: 68.4213, Validation MAE: 0.03523599178293848
# SNR [40dB], Validation Loss: 0.7939, Validation Accuracy: 72.4893, Validation MAE: 0.033015658652495554
#
#
# Epoch [12/60], Training Loss: 1.6555, Training Accuracy: 47.0347, Training MAE: 0.14142134112049623
# SNR [0dB], Validation Loss: 3.5955, Validation Accuracy: 10.0867, Validation MAE: 0.5099194388519525
# SNR [10dB], Validation Loss: 2.2915, Validation Accuracy: 29.2213, Validation MAE: 0.1670970772076037
# SNR [20dB], Validation Loss: 1.3443, Validation Accuracy: 54.1187, Validation MAE: 0.06371368456784343
# SNR [30dB], Validation Loss: 0.8616, Validation Accuracy: 69.9213, Validation MAE: 0.03765604515872273
# SNR [40dB], Validation Loss: 0.7414, Validation Accuracy: 74.5880, Validation MAE: 0.031646148398726474
#
#
# Epoch [13/60], Training Loss: 1.6336, Training Accuracy: 47.7398, Training MAE: 0.14026251153266042
# SNR [0dB], Validation Loss: 3.5831, Validation Accuracy: 10.1760, Validation MAE: 0.4988488651793239
# SNR [10dB], Validation Loss: 2.2725, Validation Accuracy: 29.2640, Validation MAE: 0.16284369440022475
# SNR [20dB], Validation Loss: 1.3202, Validation Accuracy: 54.5227, Validation MAE: 0.05988022637887443
# SNR [30dB], Validation Loss: 0.8323, Validation Accuracy: 70.7507, Validation MAE: 0.03410607266597996
# SNR [40dB], Validation Loss: 0.7117, Validation Accuracy: 75.3960, Validation MAE: 0.02950848335518307
#
#
# Epoch [14/60], Training Loss: 1.6148, Training Accuracy: 48.3802, Training MAE: 0.1384426338017389
# SNR [0dB], Validation Loss: 3.5419, Validation Accuracy: 10.4173, Validation MAE: 0.4891141492649124
# SNR [10dB], Validation Loss: 2.2338, Validation Accuracy: 29.8573, Validation MAE: 0.160279520554359
# SNR [20dB], Validation Loss: 1.2785, Validation Accuracy: 55.7240, Validation MAE: 0.05816833856166308
# SNR [30dB], Validation Loss: 0.7788, Validation Accuracy: 72.3720, Validation MAE: 0.034600618035396574
# SNR [40dB], Validation Loss: 0.6489, Validation Accuracy: 77.1760, Validation MAE: 0.027282663404813185
#
#
# Epoch [15/60], Training Loss: 1.5990, Training Accuracy: 48.8883, Training MAE: 0.13790020099482456
# SNR [0dB], Validation Loss: 3.5537, Validation Accuracy: 10.2453, Validation MAE: 0.4857328050379249
# SNR [10dB], Validation Loss: 2.2556, Validation Accuracy: 29.5147, Validation MAE: 0.15911924103380468
# SNR [20dB], Validation Loss: 1.3232, Validation Accuracy: 54.4813, Validation MAE: 0.060120183303680116
# SNR [30dB], Validation Loss: 0.8359, Validation Accuracy: 70.5973, Validation MAE: 0.034520510464462965
# SNR [40dB], Validation Loss: 0.7079, Validation Accuracy: 75.5480, Validation MAE: 0.028374906358273246
#
#
# Epoch [16/60], Training Loss: 1.5826, Training Accuracy: 49.4166, Training MAE: 0.13622778325004306
# SNR [0dB], Validation Loss: 3.5641, Validation Accuracy: 10.1987, Validation MAE: 0.5072821074070606
# SNR [10dB], Validation Loss: 2.2387, Validation Accuracy: 29.6853, Validation MAE: 0.16561892791928085
# SNR [20dB], Validation Loss: 1.3055, Validation Accuracy: 54.6387, Validation MAE: 0.06052950007023129
# SNR [30dB], Validation Loss: 0.8211, Validation Accuracy: 70.5213, Validation MAE: 0.03364993503605206
# SNR [40dB], Validation Loss: 0.6967, Validation Accuracy: 75.1733, Validation MAE: 0.025949731950557168
#
#
# Epoch [17/60], Training Loss: 1.5690, Training Accuracy: 49.8396, Training MAE: 0.1352999578418347
# SNR [0dB], Validation Loss: 3.5493, Validation Accuracy: 10.0413, Validation MAE: 0.5128940268283547
# SNR [10dB], Validation Loss: 2.2247, Validation Accuracy: 29.6173, Validation MAE: 0.16864253148703062
# SNR [20dB], Validation Loss: 1.2634, Validation Accuracy: 55.5800, Validation MAE: 0.06316134469519617
# SNR [30dB], Validation Loss: 0.7476, Validation Accuracy: 72.7680, Validation MAE: 0.03796001498267628
# SNR [40dB], Validation Loss: 0.6040, Validation Accuracy: 77.9960, Validation MAE: 0.03255037632268939
#
#
# Epoch [18/60], Training Loss: 1.5558, Training Accuracy: 50.2258, Training MAE: 0.1341513974173496
# SNR [0dB], Validation Loss: 3.5448, Validation Accuracy: 10.1973, Validation MAE: 0.49976809041108716
# SNR [10dB], Validation Loss: 2.2226, Validation Accuracy: 29.8853, Validation MAE: 0.16678579162374754
# SNR [20dB], Validation Loss: 1.2608, Validation Accuracy: 55.8867, Validation MAE: 0.06313208165558573
# SNR [30dB], Validation Loss: 0.7532, Validation Accuracy: 72.8547, Validation MAE: 0.037709815994006926
# SNR [40dB], Validation Loss: 0.6126, Validation Accuracy: 78.0680, Validation MAE: 0.03350910665792677
#
#
# Epoch [19/60], Training Loss: 1.5423, Training Accuracy: 50.6633, Training MAE: 0.13281983790216642
# SNR [0dB], Validation Loss: 3.5353, Validation Accuracy: 10.3453, Validation MAE: 0.4982786016949153
# SNR [10dB], Validation Loss: 2.2108, Validation Accuracy: 29.8133, Validation MAE: 0.16201372143927334
# SNR [20dB], Validation Loss: 1.2712, Validation Accuracy: 54.9387, Validation MAE: 0.057708908839779006
# SNR [30dB], Validation Loss: 0.7695, Validation Accuracy: 71.3027, Validation MAE: 0.032693033640790334
# SNR [40dB], Validation Loss: 0.6174, Validation Accuracy: 76.4973, Validation MAE: 0.026303448941848488
#
#
# Epoch [20/60], Training Loss: 1.5295, Training Accuracy: 51.0373, Training MAE: 0.13149944447725956
# SNR [0dB], Validation Loss: 3.5286, Validation Accuracy: 10.2507, Validation MAE: 0.49537058713362675
# SNR [10dB], Validation Loss: 2.2170, Validation Accuracy: 29.6240, Validation MAE: 0.16019502352748385
# SNR [20dB], Validation Loss: 1.2651, Validation Accuracy: 55.5973, Validation MAE: 0.0574795597668321
# SNR [30dB], Validation Loss: 0.7509, Validation Accuracy: 72.5440, Validation MAE: 0.03252842904298155
# SNR [40dB], Validation Loss: 0.6080, Validation Accuracy: 77.5533, Validation MAE: 0.02480225500983238
#
#
# Epoch [21/60], Training Loss: 1.5175, Training Accuracy: 51.4075, Training MAE: 0.13020012233563308
# SNR [0dB], Validation Loss: 3.5276, Validation Accuracy: 10.3560, Validation MAE: 0.4948219051409308
# SNR [10dB], Validation Loss: 2.2098, Validation Accuracy: 29.9507, Validation MAE: 0.16338835272497426
# SNR [20dB], Validation Loss: 1.2501, Validation Accuracy: 56.0787, Validation MAE: 0.05870494955051971
# SNR [30dB], Validation Loss: 0.7240, Validation Accuracy: 73.8880, Validation MAE: 0.031463620189156286
# SNR [40dB], Validation Loss: 0.5790, Validation Accuracy: 79.6667, Validation MAE: 0.023741835611948685
#
#
# Epoch [22/60], Training Loss: 1.5065, Training Accuracy: 51.7136, Training MAE: 0.12872284469239723
# SNR [0dB], Validation Loss: 3.5211, Validation Accuracy: 10.4773, Validation MAE: 0.49682752071823205
# SNR [10dB], Validation Loss: 2.1942, Validation Accuracy: 30.0893, Validation MAE: 0.1621315051737054
# SNR [20dB], Validation Loss: 1.2296, Validation Accuracy: 56.7107, Validation MAE: 0.06005690198052252
# SNR [30dB], Validation Loss: 0.7027, Validation Accuracy: 74.2560, Validation MAE: 0.03240735321659331
# SNR [40dB], Validation Loss: 0.5526, Validation Accuracy: 79.9493, Validation MAE: 0.025000877891188312
#
#
# Epoch [23/60], Training Loss: 1.4942, Training Accuracy: 52.0648, Training MAE: 0.12742284660584133
# SNR [0dB], Validation Loss: 3.5108, Validation Accuracy: 10.2987, Validation MAE: 0.48247582872928174
# SNR [10dB], Validation Loss: 2.1910, Validation Accuracy: 29.7147, Validation MAE: 0.15697096813840247
# SNR [20dB], Validation Loss: 1.2379, Validation Accuracy: 55.8360, Validation MAE: 0.057278010581515125
# SNR [30dB], Validation Loss: 0.7277, Validation Accuracy: 72.7360, Validation MAE: 0.033545319669444705
# SNR [40dB], Validation Loss: 0.5702, Validation Accuracy: 78.0147, Validation MAE: 0.026491829759340762
#
#
# Epoch [24/60], Training Loss: 1.4838, Training Accuracy: 52.2943, Training MAE: 0.12627206336245372
# SNR [0dB], Validation Loss: 3.5211, Validation Accuracy: 10.1787, Validation MAE: 0.4895029819037363
# SNR [10dB], Validation Loss: 2.1862, Validation Accuracy: 30.0773, Validation MAE: 0.1592019091207042
# SNR [20dB], Validation Loss: 1.2194, Validation Accuracy: 56.6493, Validation MAE: 0.0579847129881075
# SNR [30dB], Validation Loss: 0.6869, Validation Accuracy: 74.4707, Validation MAE: 0.03253940268283547
# SNR [40dB], Validation Loss: 0.5327, Validation Accuracy: 80.1973, Validation MAE: 0.025570775587601836
#
#
# Epoch [25/60], Training Loss: 1.4703, Training Accuracy: 52.7242, Training MAE: 0.12460810792823088
# SNR [0dB], Validation Loss: 3.5199, Validation Accuracy: 10.3587, Validation MAE: 0.4902839392733402
# SNR [10dB], Validation Loss: 2.1987, Validation Accuracy: 29.7747, Validation MAE: 0.16249546422886038
# SNR [20dB], Validation Loss: 1.2479, Validation Accuracy: 55.8107, Validation MAE: 0.05819467529731248
# SNR [30dB], Validation Loss: 0.7249, Validation Accuracy: 74.1373, Validation MAE: 0.032349558713362675
# SNR [40dB], Validation Loss: 0.5721, Validation Accuracy: 80.0187, Validation MAE: 0.026190420451353124
#
#
# Epoch [26/60], Training Loss: 1.4579, Training Accuracy: 53.0565, Training MAE: 0.12306723946586624
# SNR [0dB], Validation Loss: 3.5212, Validation Accuracy: 10.2427, Validation MAE: 0.4940138794596872
# SNR [10dB], Validation Loss: 2.1966, Validation Accuracy: 29.8013, Validation MAE: 0.16286454431594719
# SNR [20dB], Validation Loss: 1.2440, Validation Accuracy: 56.1227, Validation MAE: 0.060766896479071075
# SNR [30dB], Validation Loss: 0.7215, Validation Accuracy: 74.2747, Validation MAE: 0.033789300262196835
# SNR [40dB], Validation Loss: 0.5704, Validation Accuracy: 79.6307, Validation MAE: 0.027307902776477197
#
#
# Epoch [27/60], Training Loss: 1.4449, Training Accuracy: 53.4056, Training MAE: 0.12169213349849961
# SNR [0dB], Validation Loss: 3.5183, Validation Accuracy: 10.3693, Validation MAE: 0.49192705894746697
# SNR [10dB], Validation Loss: 2.1879, Validation Accuracy: 29.9453, Validation MAE: 0.1635558836267441
# SNR [20dB], Validation Loss: 1.2266, Validation Accuracy: 56.3320, Validation MAE: 0.05971818229703156
# SNR [30dB], Validation Loss: 0.7086, Validation Accuracy: 73.8147, Validation MAE: 0.033343038908137466
# SNR [40dB], Validation Loss: 0.5612, Validation Accuracy: 79.1293, Validation MAE: 0.026209441427099914
#
#
# Epoch [28/60], Training Loss: 1.4325, Training Accuracy: 53.7236, Training MAE: 0.11982460165005436
# SNR [0dB], Validation Loss: 3.5428, Validation Accuracy: 10.0920, Validation MAE: 0.5078523708914693
# SNR [10dB], Validation Loss: 2.2088, Validation Accuracy: 29.4787, Validation MAE: 0.17113866876580205
# SNR [20dB], Validation Loss: 1.2505, Validation Accuracy: 56.0080, Validation MAE: 0.06584513121546962
# SNR [30dB], Validation Loss: 0.7261, Validation Accuracy: 73.8413, Validation MAE: 0.038942887325592285
# SNR [40dB], Validation Loss: 0.5723, Validation Accuracy: 79.9027, Validation MAE: 0.03289897228204888
#
#
# Epoch [29/60], Training Loss: 1.4178, Training Accuracy: 54.0504, Training MAE: 0.11743252353744235
# SNR [0dB], Validation Loss: 3.5369, Validation Accuracy: 10.1600, Validation MAE: 0.4959617005337578
# SNR [10dB], Validation Loss: 2.1978, Validation Accuracy: 29.3440, Validation MAE: 0.16601800262196834
# SNR [20dB], Validation Loss: 1.2289, Validation Accuracy: 56.0413, Validation MAE: 0.05966367988575709
# SNR [30dB], Validation Loss: 0.6894, Validation Accuracy: 74.0587, Validation MAE: 0.033644082428129975
# SNR [40dB], Validation Loss: 0.5293, Validation Accuracy: 79.7867, Validation MAE: 0.026964793637044668
#
#
# Epoch [30/60], Training Loss: 1.4056, Training Accuracy: 54.3463, Training MAE: 0.11555178476499163
# SNR [0dB], Validation Loss: 3.5353, Validation Accuracy: 10.1493, Validation MAE: 0.4930829490120798
# SNR [10dB], Validation Loss: 2.1908, Validation Accuracy: 29.8747, Validation MAE: 0.1632683742625714
# SNR [20dB], Validation Loss: 1.2185, Validation Accuracy: 56.3800, Validation MAE: 0.05850486351718326
# SNR [30dB], Validation Loss: 0.6849, Validation Accuracy: 74.2840, Validation MAE: 0.03218970935949059
# SNR [40dB], Validation Loss: 0.5290, Validation Accuracy: 79.6200, Validation MAE: 0.02424918356119487
#
#
# Epoch [31/60], Training Loss: 1.3908, Training Accuracy: 54.7113, Training MAE: 0.11334615046242953
# SNR [0dB], Validation Loss: 3.5401, Validation Accuracy: 10.1267, Validation MAE: 0.4902982050051503
# SNR [10dB], Validation Loss: 2.1900, Validation Accuracy: 29.5533, Validation MAE: 0.1623129360192902
# SNR [20dB], Validation Loss: 1.2125, Validation Accuracy: 56.6893, Validation MAE: 0.057161324211068454
# SNR [30dB], Validation Loss: 0.6555, Validation Accuracy: 75.5613, Validation MAE: 0.031782587320910195
# SNR [40dB], Validation Loss: 0.4834, Validation Accuracy: 82.0120, Validation MAE: 0.023595520413896433
#
#
# Epoch [32/60], Training Loss: 1.3759, Training Accuracy: 55.0801, Training MAE: 0.11113938525200474
# SNR [0dB], Validation Loss: 3.5481, Validation Accuracy: 10.0693, Validation MAE: 0.4916227233355183
# SNR [10dB], Validation Loss: 2.1865, Validation Accuracy: 29.6467, Validation MAE: 0.16398568452102258
# SNR [20dB], Validation Loss: 1.2014, Validation Accuracy: 56.7560, Validation MAE: 0.05881432016106377
# SNR [30dB], Validation Loss: 0.6474, Validation Accuracy: 75.8907, Validation MAE: 0.03241722949246184
# SNR [40dB], Validation Loss: 0.4801, Validation Accuracy: 82.2013, Validation MAE: 0.02536959219027999
#
#
# Epoch [33/60], Training Loss: 1.3592, Training Accuracy: 55.4760, Training MAE: 0.10878733087857866
# SNR [0dB], Validation Loss: 3.5670, Validation Accuracy: 10.0707, Validation MAE: 0.48438889994381495
# SNR [10dB], Validation Loss: 2.1901, Validation Accuracy: 29.8733, Validation MAE: 0.16114570652682836
# SNR [20dB], Validation Loss: 1.2011, Validation Accuracy: 56.9973, Validation MAE: 0.058000076083902986
# SNR [30dB], Validation Loss: 0.6543, Validation Accuracy: 75.7933, Validation MAE: 0.03143325978556045
# SNR [40dB], Validation Loss: 0.4891, Validation Accuracy: 81.7693, Validation MAE: 0.025037456690701378
#
#
# Epoch [34/60], Training Loss: 1.3443, Training Accuracy: 55.8886, Training MAE: 0.10669091367788083
# SNR [0dB], Validation Loss: 3.5888, Validation Accuracy: 10.1000, Validation MAE: 0.48528069107594346
# SNR [10dB], Validation Loss: 2.1927, Validation Accuracy: 29.8427, Validation MAE: 0.16231513074726098
# SNR [20dB], Validation Loss: 1.2098, Validation Accuracy: 56.6467, Validation MAE: 0.057962765708399665
# SNR [30dB], Validation Loss: 0.6622, Validation Accuracy: 75.3387, Validation MAE: 0.03271680986047383
# SNR [40dB], Validation Loss: 0.4940, Validation Accuracy: 81.2413, Validation MAE: 0.02369757526453788
#
#
# Epoch [35/60], Training Loss: 1.3266, Training Accuracy: 56.3006, Training MAE: 0.10430241027403016
# SNR [0dB], Validation Loss: 3.6029, Validation Accuracy: 9.9693, Validation MAE: 0.48888370282798016
# SNR [10dB], Validation Loss: 2.2047, Validation Accuracy: 29.5040, Validation MAE: 0.16271457123794364
# SNR [20dB], Validation Loss: 1.2084, Validation Accuracy: 56.6867, Validation MAE: 0.05836001147111153
# SNR [30dB], Validation Loss: 0.6558, Validation Accuracy: 75.7787, Validation MAE: 0.03257817621031932
# SNR [40dB], Validation Loss: 0.4833, Validation Accuracy: 81.8720, Validation MAE: 0.023817553726940725
#
#
# Epoch [36/60], Training Loss: 1.3099, Training Accuracy: 56.6911, Training MAE: 0.10174687047896834
# SNR [0dB], Validation Loss: 3.6237, Validation Accuracy: 9.8187, Validation MAE: 0.4990672406124169
# SNR [10dB], Validation Loss: 2.2113, Validation Accuracy: 29.3893, Validation MAE: 0.16567196717857477
# SNR [20dB], Validation Loss: 1.2286, Validation Accuracy: 56.1120, Validation MAE: 0.06111183455847926
# SNR [30dB], Validation Loss: 0.6943, Validation Accuracy: 74.5627, Validation MAE: 0.03409948848206761
# SNR [40dB], Validation Loss: 0.5286, Validation Accuracy: 80.8467, Validation MAE: 0.02470788170708868
#
#
# Epoch [37/60], Training Loss: 1.2926, Training Accuracy: 57.1010, Training MAE: 0.09954772264794043
# SNR [0dB], Validation Loss: 3.6608, Validation Accuracy: 9.9253, Validation MAE: 0.4930481991525424
# SNR [10dB], Validation Loss: 2.2198, Validation Accuracy: 29.5587, Validation MAE: 0.16519863751287575
# SNR [20dB], Validation Loss: 1.2123, Validation Accuracy: 56.6533, Validation MAE: 0.05999069435340388
# SNR [30dB], Validation Loss: 0.6442, Validation Accuracy: 75.9707, Validation MAE: 0.03265169959734057
# SNR [40dB], Validation Loss: 0.4616, Validation Accuracy: 82.6533, Validation MAE: 0.02493357290008428
#
#
# Epoch [38/60], Training Loss: 1.2755, Training Accuracy: 57.5303, Training MAE: 0.09685058538910718
# SNR [0dB], Validation Loss: 3.6851, Validation Accuracy: 9.8133, Validation MAE: 0.49953362030620846
# SNR [10dB], Validation Loss: 2.2235, Validation Accuracy: 29.4427, Validation MAE: 0.165395431454256
# SNR [20dB], Validation Loss: 1.2147, Validation Accuracy: 56.4627, Validation MAE: 0.05987291061897181
# SNR [30dB], Validation Loss: 0.6644, Validation Accuracy: 74.9467, Validation MAE: 0.032963716757187005
# SNR [40dB], Validation Loss: 0.4908, Validation Accuracy: 81.0893, Validation MAE: 0.02557882292349471
#
#
# Epoch [39/60], Training Loss: 1.2563, Training Accuracy: 57.9901, Training MAE: 0.09411194251181967
# SNR [0dB], Validation Loss: 3.6997, Validation Accuracy: 9.8667, Validation MAE: 0.49060327219308925
# SNR [10dB], Validation Loss: 2.2214, Validation Accuracy: 29.5280, Validation MAE: 0.1613004348487686
# SNR [20dB], Validation Loss: 1.1893, Validation Accuracy: 57.3613, Validation MAE: 0.058497547757280645
# SNR [30dB], Validation Loss: 0.6181, Validation Accuracy: 77.0200, Validation MAE: 0.031594938079408184
# SNR [40dB], Validation Loss: 0.4317, Validation Accuracy: 83.8400, Validation MAE: 0.023429452664107127
#
#
# Epoch [40/60], Training Loss: 1.2374, Training Accuracy: 58.4769, Training MAE: 0.09199397306702628
# SNR [0dB], Validation Loss: 3.7705, Validation Accuracy: 9.6680, Validation MAE: 0.5121558666541811
# SNR [10dB], Validation Loss: 2.2522, Validation Accuracy: 29.2493, Validation MAE: 0.16524545837625246
# SNR [20dB], Validation Loss: 1.2187, Validation Accuracy: 56.5493, Validation MAE: 0.05890869346380747
# SNR [30dB], Validation Loss: 0.6500, Validation Accuracy: 75.5280, Validation MAE: 0.03170028502200581
# SNR [40dB], Validation Loss: 0.4663, Validation Accuracy: 82.1227, Validation MAE: 0.022927591534787902
#
#
# Epoch [41/60], Training Loss: 1.2190, Training Accuracy: 58.9377, Training MAE: 0.08921173174179153
# SNR [0dB], Validation Loss: 3.7845, Validation Accuracy: 9.7187, Validation MAE: 0.5012520923073321
# SNR [10dB], Validation Loss: 2.2532, Validation Accuracy: 29.2267, Validation MAE: 0.1651946138449293
# SNR [20dB], Validation Loss: 1.2195, Validation Accuracy: 56.5693, Validation MAE: 0.05947639643225021
# SNR [30dB], Validation Loss: 0.6525, Validation Accuracy: 75.6520, Validation MAE: 0.03201303375784249
# SNR [40dB], Validation Loss: 0.4647, Validation Accuracy: 82.0800, Validation MAE: 0.024822739137559696
#
#
# Epoch [42/60], Training Loss: 1.2000, Training Accuracy: 59.3849, Training MAE: 0.08631738754980155
# SNR [0dB], Validation Loss: 3.8226, Validation Accuracy: 9.5880, Validation MAE: 0.5083889818803259
# SNR [10dB], Validation Loss: 2.2718, Validation Accuracy: 28.7707, Validation MAE: 0.16856315549208728
# SNR [20dB], Validation Loss: 1.2277, Validation Accuracy: 56.0387, Validation MAE: 0.05928472352280176
# SNR [30dB], Validation Loss: 0.6465, Validation Accuracy: 75.8013, Validation MAE: 0.031152700393295252
# SNR [40dB], Validation Loss: 0.4648, Validation Accuracy: 82.2520, Validation MAE: 0.024315756976308642
#
#
# Epoch [43/60], Training Loss: 1.1812, Training Accuracy: 59.8884, Training MAE: 0.0847141111719346
# SNR [0dB], Validation Loss: 3.8787, Validation Accuracy: 9.5760, Validation MAE: 0.5017502955567
# SNR [10dB], Validation Loss: 2.2792, Validation Accuracy: 29.1387, Validation MAE: 0.16844720069763086
# SNR [20dB], Validation Loss: 1.2295, Validation Accuracy: 56.7840, Validation MAE: 0.05932422862627587
# SNR [30dB], Validation Loss: 0.6698, Validation Accuracy: 75.2493, Validation MAE: 0.032847030386740333
# SNR [40dB], Validation Loss: 0.4815, Validation Accuracy: 81.4267, Validation MAE: 0.02507366970221931
#
#
# Epoch [44/60], Training Loss: 1.1613, Training Accuracy: 60.4225, Training MAE: 0.08212815385504912
# SNR [0dB], Validation Loss: 3.9162, Validation Accuracy: 9.6040, Validation MAE: 0.5064993210974811
# SNR [10dB], Validation Loss: 2.2960, Validation Accuracy: 29.2507, Validation MAE: 0.17019054628242344
# SNR [20dB], Validation Loss: 1.2254, Validation Accuracy: 56.6173, Validation MAE: 0.060842980382058244
# SNR [30dB], Validation Loss: 0.6466, Validation Accuracy: 76.0587, Validation MAE: 0.03191609993913288
# SNR [40dB], Validation Loss: 0.4580, Validation Accuracy: 82.5013, Validation MAE: 0.02342030796422886
#
#
# Epoch [45/60], Training Loss: 1.1428, Training Accuracy: 60.8437, Training MAE: 0.07953680197766927
# SNR [0dB], Validation Loss: 3.9485, Validation Accuracy: 9.2973, Validation MAE: 0.5054835278350033
# SNR [10dB], Validation Loss: 2.3110, Validation Accuracy: 28.5893, Validation MAE: 0.1701660384867497
# SNR [20dB], Validation Loss: 1.2310, Validation Accuracy: 56.2200, Validation MAE: 0.06165173763929207
# SNR [30dB], Validation Loss: 0.6381, Validation Accuracy: 76.2973, Validation MAE: 0.0323151746418204
# SNR [40dB], Validation Loss: 0.4475, Validation Accuracy: 83.1333, Validation MAE: 0.024522061405562318
#
#
# Epoch [46/60], Training Loss: 1.1235, Training Accuracy: 61.4008, Training MAE: 0.07716742001595646
# SNR [0dB], Validation Loss: 4.0388, Validation Accuracy: 9.4947, Validation MAE: 0.5037643242578893
# SNR [10dB], Validation Loss: 2.3314, Validation Accuracy: 28.7787, Validation MAE: 0.1673348394044386
# SNR [20dB], Validation Loss: 1.2368, Validation Accuracy: 56.1187, Validation MAE: 0.05965014572993726
# SNR [30dB], Validation Loss: 0.6484, Validation Accuracy: 75.8227, Validation MAE: 0.03167760616630771
# SNR [40dB], Validation Loss: 0.4568, Validation Accuracy: 82.5160, Validation MAE: 0.0238614482863564
#
#
# Epoch [47/60], Training Loss: 1.1058, Training Accuracy: 61.8326, Training MAE: 0.07531692977909704
# SNR [0dB], Validation Loss: 4.1267, Validation Accuracy: 9.4693, Validation MAE: 0.503365981131192
# SNR [10dB], Validation Loss: 2.3553, Validation Accuracy: 28.7907, Validation MAE: 0.16800606037550334
# SNR [20dB], Validation Loss: 1.2342, Validation Accuracy: 56.5613, Validation MAE: 0.06023906440209757
# SNR [30dB], Validation Loss: 0.6292, Validation Accuracy: 76.6720, Validation MAE: 0.033227084113681055
# SNR [40dB], Validation Loss: 0.4316, Validation Accuracy: 83.5013, Validation MAE: 0.02451803773761588
#
#
# Epoch [48/60], Training Loss: 1.0859, Training Accuracy: 62.3909, Training MAE: 0.07323936104277712
# SNR [0dB], Validation Loss: 4.1183, Validation Accuracy: 9.3893, Validation MAE: 0.5059766100524393
# SNR [10dB], Validation Loss: 2.3598, Validation Accuracy: 28.9133, Validation MAE: 0.16989535537035302
# SNR [20dB], Validation Loss: 1.2504, Validation Accuracy: 56.2107, Validation MAE: 0.06177976343758779
# SNR [30dB], Validation Loss: 0.6714, Validation Accuracy: 75.1653, Validation MAE: 0.0335416617894934
# SNR [40dB], Validation Loss: 0.4881, Validation Accuracy: 81.1493, Validation MAE: 0.024251744077160783
#
#
# Epoch [49/60], Training Loss: 1.0678, Training Accuracy: 62.8608, Training MAE: 0.07081174382560704
# SNR [0dB], Validation Loss: 4.1800, Validation Accuracy: 9.4453, Validation MAE: 0.506756835846053
# SNR [10dB], Validation Loss: 2.3785, Validation Accuracy: 28.7027, Validation MAE: 0.1699502235696226
# SNR [20dB], Validation Loss: 1.2487, Validation Accuracy: 56.3253, Validation MAE: 0.06007263086431314
# SNR [30dB], Validation Loss: 0.6644, Validation Accuracy: 75.4093, Validation MAE: 0.032588418274182976
# SNR [40dB], Validation Loss: 0.4791, Validation Accuracy: 81.6667, Validation MAE: 0.025529441544152074
#
#
# Epoch [50/60], Training Loss: 1.0491, Training Accuracy: 63.3808, Training MAE: 0.0690479305270041
# SNR [0dB], Validation Loss: 4.2743, Validation Accuracy: 9.4093, Validation MAE: 0.5058485842541437
# SNR [10dB], Validation Loss: 2.4178, Validation Accuracy: 28.6093, Validation MAE: 0.1730140638168368
# SNR [20dB], Validation Loss: 1.2561, Validation Accuracy: 56.4693, Validation MAE: 0.061007219191871895
# SNR [30dB], Validation Loss: 0.6496, Validation Accuracy: 76.0507, Validation MAE: 0.034061446530574024
# SNR [40dB], Validation Loss: 0.4520, Validation Accuracy: 82.7920, Validation MAE: 0.0264684193276524
#
#
# Epoch [51/60], Training Loss: 1.0312, Training Accuracy: 63.8906, Training MAE: 0.0669988554692472
# SNR [0dB], Validation Loss: 4.2909, Validation Accuracy: 9.2960, Validation MAE: 0.5021255940397041
# SNR [10dB], Validation Loss: 2.4267, Validation Accuracy: 28.6253, Validation MAE: 0.17058193943721323
# SNR [20dB], Validation Loss: 1.2608, Validation Accuracy: 56.5893, Validation MAE: 0.060697396759996254
# SNR [30dB], Validation Loss: 0.6376, Validation Accuracy: 76.6040, Validation MAE: 0.033193797406124166
# SNR [40dB], Validation Loss: 0.4354, Validation Accuracy: 83.2507, Validation MAE: 0.02429783336454724
#
#
# Epoch [52/60], Training Loss: 1.0134, Training Accuracy: 64.3934, Training MAE: 0.06516528985350506
# SNR [0dB], Validation Loss: 4.3849, Validation Accuracy: 9.3480, Validation MAE: 0.5164110784015358
# SNR [10dB], Validation Loss: 2.4542, Validation Accuracy: 28.6040, Validation MAE: 0.1699535156615788
# SNR [20dB], Validation Loss: 1.2631, Validation Accuracy: 56.2147, Validation MAE: 0.06054010792209008
# SNR [30dB], Validation Loss: 0.6369, Validation Accuracy: 76.4440, Validation MAE: 0.03186488961981459
# SNR [40dB], Validation Loss: 0.4380, Validation Accuracy: 83.3120, Validation MAE: 0.02289284167525049
#
#
# Epoch [53/60], Training Loss: 0.9947, Training Accuracy: 64.9087, Training MAE: 0.0636284770607169
# SNR [0dB], Validation Loss: 4.4234, Validation Accuracy: 9.2067, Validation MAE: 0.5153027407762899
# SNR [10dB], Validation Loss: 2.4800, Validation Accuracy: 28.3707, Validation MAE: 0.1719825416705684
# SNR [20dB], Validation Loss: 1.2754, Validation Accuracy: 56.6440, Validation MAE: 0.060560957837812526
# SNR [30dB], Validation Loss: 0.6422, Validation Accuracy: 76.6067, Validation MAE: 0.032913603801854104
# SNR [40dB], Validation Loss: 0.4344, Validation Accuracy: 83.3933, Validation MAE: 0.023969721532915066
#
#
# Epoch [54/60], Training Loss: 0.9766, Training Accuracy: 65.4321, Training MAE: 0.06174889519401076
# SNR [0dB], Validation Loss: 4.5197, Validation Accuracy: 9.1467, Validation MAE: 0.5170051181056279
# SNR [10dB], Validation Loss: 2.5165, Validation Accuracy: 28.2120, Validation MAE: 0.1730393031885008
# SNR [20dB], Validation Loss: 1.2821, Validation Accuracy: 55.9680, Validation MAE: 0.0627842172722165
# SNR [30dB], Validation Loss: 0.6494, Validation Accuracy: 75.9440, Validation MAE: 0.03476302790523457
# SNR [40dB], Validation Loss: 0.4512, Validation Accuracy: 82.9800, Validation MAE: 0.025216692808315386
#
#
# Epoch [55/60], Training Loss: 0.9605, Training Accuracy: 65.9508, Training MAE: 0.06021904983357196
# SNR [0dB], Validation Loss: 4.6122, Validation Accuracy: 9.2827, Validation MAE: 0.5089043771654649
# SNR [10dB], Validation Loss: 2.5403, Validation Accuracy: 28.3933, Validation MAE: 0.17316550004682085
# SNR [20dB], Validation Loss: 1.2858, Validation Accuracy: 56.0493, Validation MAE: 0.0639115758732091
# SNR [30dB], Validation Loss: 0.6457, Validation Accuracy: 76.2733, Validation MAE: 0.032120209640415766
# SNR [40dB], Validation Loss: 0.4493, Validation Accuracy: 83.0093, Validation MAE: 0.02390644020975747
#
#
# Epoch [56/60], Training Loss: 0.9433, Training Accuracy: 66.4463, Training MAE: 0.058392906613112416
# SNR [0dB], Validation Loss: 4.6639, Validation Accuracy: 9.2427, Validation MAE: 0.5089749742485251
# SNR [10dB], Validation Loss: 2.5732, Validation Accuracy: 28.1960, Validation MAE: 0.16929217096638263
# SNR [20dB], Validation Loss: 1.3089, Validation Accuracy: 55.7787, Validation MAE: 0.06094613259668508
# SNR [30dB], Validation Loss: 0.6770, Validation Accuracy: 75.2293, Validation MAE: 0.03272229668040079
# SNR [40dB], Validation Loss: 0.4793, Validation Accuracy: 81.6627, Validation MAE: 0.024207849517745107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-a90cb20edcf7> in <module>()
#      79         print("\n")
#      80
# ---> 81 train()
#      82 print("Training Complete")
#
# <ipython-input-16-a90cb20edcf7> in train()
#      15             auto_outputs = torch.transpose(enn, 2, 3)
#      16             auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
# ---> 17             losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
#      18             losss.backward()
#      19             optimizer.step()
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format((mae_res[0][30])), "  {:.2f}".format(acc_res[0][mae_res[0].index((mae_res[0][30]))]))
print("{:.4f}".format((mae_res[10][30])), "  {:.2f}".format(acc_res[10][mae_res[10].index((mae_res[10][30]))]))
print("{:.4f}".format((mae_res[20][30])), "  {:.2f}".format(acc_res[20][mae_res[20].index((mae_res[20][30]))]))
print("{:.4f}".format((mae_res[30][30])), "  {:.2f}".format(acc_res[30][mae_res[30].index((mae_res[30][30]))]))
print("{:.4f}".format((mae_res[40][30])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-5 ====
# = MAE =_= Acc =
# 0.4903   10.13
# 0.1623   29.55
# 0.0572   56.69
# 0.0318   75.56
# 0.0236   83.31

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-5 ====
# = MAE =_= Acc =
# 0.4613   9.97
# 0.1570   29.71
# 0.0572   56.69
# 0.0312   75.80
# 0.0229   83.31

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()
