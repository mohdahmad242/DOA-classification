# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("/content/drive/MyDrive/DOA/SNS/200/DOA4")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_0_4_200.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_4_200.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_4_200.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_4_200.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_4_200.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 200)
# Out:
# 2021-06-22 00:12:42,035 - Data prepration started
# 2021-06-22 00:13:09,364 - Dividing your dataset into 3 channel
# 2021-06-22 00:17:25,872 - Creating Train dataloader
# 2021-06-22 00:17:30,036 - Creating Validation dataloader
# 2021-06-22 00:17:30,667 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((4, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.7)
        self.dropout1 = nn.Dropout(0.6)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 4, 181])

# %%
num_epochs = 40
doa = 4
weights_dir = root_dataset_path

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# Tesla P100-PCIE-16GB

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(64*len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*64*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*128*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_200_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/DOA_{}_200_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/40], Training Loss: 5.2215, Training Accuracy: 0.5553, Training MAE: 1.422800004638022
# SNR [0dB], Validation Loss: 5.1951, Validation Accuracy: 0.5617, Validation MAE: 1.5767821922698755
# SNR [10dB], Validation Loss: 5.1950, Validation Accuracy: 0.5417, Validation MAE: 1.5774567053328963
# SNR [20dB], Validation Loss: 5.1949, Validation Accuracy: 0.5867, Validation MAE: 1.573619589263976
# SNR [30dB], Validation Loss: 5.1950, Validation Accuracy: 0.5833, Validation MAE: 1.5807107553375783
# SNR [40dB], Validation Loss: 5.1952, Validation Accuracy: 0.5783, Validation MAE: 1.5792691848487685
#
#
# Epoch [2/40], Training Loss: 4.3514, Training Accuracy: 3.9485, Training MAE: 0.8662158486623778
# SNR [0dB], Validation Loss: 4.0098, Validation Accuracy: 6.0567, Validation MAE: 0.4675619205918157
# SNR [10dB], Validation Loss: 3.2884, Validation Accuracy: 11.2850, Validation MAE: 0.19029974131472985
# SNR [20dB], Validation Loss: 3.0944, Validation Accuracy: 13.1667, Validation MAE: 0.1266873800215376
# SNR [30dB], Validation Loss: 3.0615, Validation Accuracy: 13.1733, Validation MAE: 0.11921323391703342
# SNR [40dB], Validation Loss: 3.0590, Validation Accuracy: 13.3917, Validation MAE: 0.11871612803165091
#
#
# Epoch [3/40], Training Loss: 2.6921, Training Accuracy: 17.1491, Training MAE: 0.17785886748234847
# SNR [0dB], Validation Loss: 3.7668, Validation Accuracy: 8.5850, Validation MAE: 0.4780289440724787
# SNR [10dB], Validation Loss: 2.6915, Validation Accuracy: 19.2483, Validation MAE: 0.15957757339170334
# SNR [20dB], Validation Loss: 2.2767, Validation Accuracy: 25.8533, Validation MAE: 0.08411185211630302
# SNR [30dB], Validation Loss: 2.1876, Validation Accuracy: 27.3383, Validation MAE: 0.07218460295907857
# SNR [40dB], Validation Loss: 2.1847, Validation Accuracy: 27.6900, Validation MAE: 0.0745783195992134
#
#
# Epoch [4/40], Training Loss: 2.2801, Training Accuracy: 25.9044, Training MAE: 0.1526433138439345
# SNR [0dB], Validation Loss: 3.6797, Validation Accuracy: 9.4067, Validation MAE: 0.44188470069763086
# SNR [10dB], Validation Loss: 2.5309, Validation Accuracy: 22.4633, Validation MAE: 0.14690009305646595
# SNR [20dB], Validation Loss: 2.0054, Validation Accuracy: 32.2500, Validation MAE: 0.06940315104410526
# SNR [30dB], Validation Loss: 1.8742, Validation Accuracy: 35.1567, Validation MAE: 0.056293675086618596
# SNR [40dB], Validation Loss: 1.8674, Validation Accuracy: 35.8417, Validation MAE: 0.05713169538346287
#
#
# Epoch [5/40], Training Loss: 2.0850, Training Accuracy: 31.8269, Training MAE: 0.14272583684062093
# SNR [0dB], Validation Loss: 3.6378, Validation Accuracy: 9.9817, Validation MAE: 0.4578290336173799
# SNR [10dB], Validation Loss: 2.4140, Validation Accuracy: 25.4150, Validation MAE: 0.1477651816649499
# SNR [20dB], Validation Loss: 1.7661, Validation Accuracy: 39.0283, Validation MAE: 0.06784745470081469
# SNR [30dB], Validation Loss: 1.5851, Validation Accuracy: 43.6350, Validation MAE: 0.05220965212098511
# SNR [40dB], Validation Loss: 1.5710, Validation Accuracy: 44.2567, Validation MAE: 0.05251142721696788
#
#
# Epoch [6/40], Training Loss: 1.9587, Training Accuracy: 36.0915, Training MAE: 0.13689910055647947
# SNR [0dB], Validation Loss: 3.5712, Validation Accuracy: 10.3500, Validation MAE: 0.44056896127914597
# SNR [10dB], Validation Loss: 2.3393, Validation Accuracy: 27.2850, Validation MAE: 0.15145012992789586
# SNR [20dB], Validation Loss: 1.6208, Validation Accuracy: 43.6417, Validation MAE: 0.07045808362206199
# SNR [30dB], Validation Loss: 1.3932, Validation Accuracy: 50.1450, Validation MAE: 0.05722936077816275
# SNR [40dB], Validation Loss: 1.3711, Validation Accuracy: 50.9417, Validation MAE: 0.05765477221649967
#
#
# Epoch [7/40], Training Loss: 1.8699, Training Accuracy: 39.2172, Training MAE: 0.13170009612976813
# SNR [0dB], Validation Loss: 3.5519, Validation Accuracy: 10.3700, Validation MAE: 0.44781339252270813
# SNR [10dB], Validation Loss: 2.3078, Validation Accuracy: 28.4383, Validation MAE: 0.14501518751755782
# SNR [20dB], Validation Loss: 1.5251, Validation Accuracy: 48.1667, Validation MAE: 0.060818838374379625
# SNR [30dB], Validation Loss: 1.2620, Validation Accuracy: 57.1500, Validation MAE: 0.04318054124918064
# SNR [40dB], Validation Loss: 1.2303, Validation Accuracy: 58.3883, Validation MAE: 0.04131904614196086
#
#
# Epoch [8/40], Training Loss: 1.8010, Training Accuracy: 41.6421, Training MAE: 0.12817588825403217
# SNR [0dB], Validation Loss: 3.5168, Validation Accuracy: 10.9183, Validation MAE: 0.42867975407341513
# SNR [10dB], Validation Loss: 2.2850, Validation Accuracy: 28.7217, Validation MAE: 0.14691289563629553
# SNR [20dB], Validation Loss: 1.4771, Validation Accuracy: 48.0633, Validation MAE: 0.0642495639807098
# SNR [30dB], Validation Loss: 1.1798, Validation Accuracy: 56.7250, Validation MAE: 0.04593785115647533
# SNR [40dB], Validation Loss: 1.1478, Validation Accuracy: 58.0417, Validation MAE: 0.0460355165511752
#
#
# Epoch [9/40], Training Loss: 1.7518, Training Accuracy: 43.3621, Training MAE: 0.12487936982798137
# SNR [0dB], Validation Loss: 3.4995, Validation Accuracy: 10.8567, Validation MAE: 0.4336775154508849
# SNR [10dB], Validation Loss: 2.2661, Validation Accuracy: 29.5450, Validation MAE: 0.14877146443955427
# SNR [20dB], Validation Loss: 1.4400, Validation Accuracy: 50.1617, Validation MAE: 0.06718391527764772
# SNR [30dB], Validation Loss: 1.1188, Validation Accuracy: 60.2883, Validation MAE: 0.04950903935293567
# SNR [40dB], Validation Loss: 1.0753, Validation Accuracy: 61.6500, Validation MAE: 0.048826844742017046
#
#
# Epoch [10/40], Training Loss: 1.7135, Training Accuracy: 44.6318, Training MAE: 0.12301890940341309
# SNR [0dB], Validation Loss: 3.5025, Validation Accuracy: 10.6233, Validation MAE: 0.40837266773574304
# SNR [10dB], Validation Loss: 2.2701, Validation Accuracy: 29.2983, Validation MAE: 0.14051197150950465
# SNR [20dB], Validation Loss: 1.4159, Validation Accuracy: 51.0017, Validation MAE: 0.06181524487311546
# SNR [30dB], Validation Loss: 1.0639, Validation Accuracy: 61.7133, Validation MAE: 0.04427388156662609
# SNR [40dB], Validation Loss: 1.0145, Validation Accuracy: 63.6183, Validation MAE: 0.044190116115741175
#
#
# Epoch [11/40], Training Loss: 1.6799, Training Accuracy: 45.8279, Training MAE: 0.1206648661920216
# SNR [0dB], Validation Loss: 3.4799, Validation Accuracy: 10.9550, Validation MAE: 0.4345115120797827
# SNR [10dB], Validation Loss: 2.2253, Validation Accuracy: 30.3483, Validation MAE: 0.14410218068171177
# SNR [20dB], Validation Loss: 1.3489, Validation Accuracy: 52.9717, Validation MAE: 0.059129629412866376
# SNR [30dB], Validation Loss: 0.9800, Validation Accuracy: 64.6883, Validation MAE: 0.03862209125386272
# SNR [40dB], Validation Loss: 0.9243, Validation Accuracy: 66.9567, Validation MAE: 0.03700201622342916
#
#
# Epoch [12/40], Training Loss: 1.6514, Training Accuracy: 46.7522, Training MAE: 0.11896885536941534
# SNR [0dB], Validation Loss: 3.4536, Validation Accuracy: 11.0000, Validation MAE: 0.44280648644536
# SNR [10dB], Validation Loss: 2.2095, Validation Accuracy: 30.2333, Validation MAE: 0.15148305084745764
# SNR [20dB], Validation Loss: 1.3379, Validation Accuracy: 52.9900, Validation MAE: 0.06397156510441053
# SNR [30dB], Validation Loss: 0.9596, Validation Accuracy: 66.0450, Validation MAE: 0.041502305927521306
# SNR [40dB], Validation Loss: 0.8940, Validation Accuracy: 68.6050, Validation MAE: 0.040715130162000186
#
#
# Epoch [13/40], Training Loss: 1.6275, Training Accuracy: 47.5476, Training MAE: 0.11748377836160932
# SNR [0dB], Validation Loss: 3.4633, Validation Accuracy: 10.9767, Validation MAE: 0.41883603333645475
# SNR [10dB], Validation Loss: 2.2391, Validation Accuracy: 30.1367, Validation MAE: 0.14991894138027906
# SNR [20dB], Validation Loss: 1.3514, Validation Accuracy: 53.5517, Validation MAE: 0.06582318393576178
# SNR [30dB], Validation Loss: 0.9513, Validation Accuracy: 66.3583, Validation MAE: 0.04396296177076505
# SNR [40dB], Validation Loss: 0.8866, Validation Accuracy: 68.7050, Validation MAE: 0.04609111632643506
#
#
# Epoch [14/40], Training Loss: 1.6064, Training Accuracy: 48.2688, Training MAE: 0.1158585077756545
# SNR [0dB], Validation Loss: 3.4237, Validation Accuracy: 11.3767, Validation MAE: 0.38135739535537033
# SNR [10dB], Validation Loss: 2.1720, Validation Accuracy: 30.9117, Validation MAE: 0.13140092412679089
# SNR [20dB], Validation Loss: 1.2773, Validation Accuracy: 54.7867, Validation MAE: 0.05247082474950838
# SNR [30dB], Validation Loss: 0.8698, Validation Accuracy: 68.2617, Validation MAE: 0.03178112416892968
# SNR [40dB], Validation Loss: 0.7941, Validation Accuracy: 71.3467, Validation MAE: 0.030899940888659987
#
#
# Epoch [15/40], Training Loss: 1.5857, Training Accuracy: 48.9383, Training MAE: 0.11479401150229489
# SNR [0dB], Validation Loss: 3.4288, Validation Accuracy: 11.3267, Validation MAE: 0.4001032985298249
# SNR [10dB], Validation Loss: 2.2026, Validation Accuracy: 30.7967, Validation MAE: 0.13681970748665606
# SNR [20dB], Validation Loss: 1.3607, Validation Accuracy: 54.2000, Validation MAE: 0.05251215879295814
# SNR [30dB], Validation Loss: 0.9707, Validation Accuracy: 66.8950, Validation MAE: 0.03294798787339639
# SNR [40dB], Validation Loss: 0.9019, Validation Accuracy: 69.4933, Validation MAE: 0.029527870118924993
#
#
# Epoch [16/40], Training Loss: 1.5688, Training Accuracy: 49.4747, Training MAE: 0.113475450928062
# SNR [0dB], Validation Loss: 3.4232, Validation Accuracy: 11.3983, Validation MAE: 0.3918046662842963
# SNR [10dB], Validation Loss: 2.1646, Validation Accuracy: 31.3000, Validation MAE: 0.13543885780503792
# SNR [20dB], Validation Loss: 1.2435, Validation Accuracy: 56.3517, Validation MAE: 0.058685562786777785
# SNR [30dB], Validation Loss: 0.8007, Validation Accuracy: 71.1750, Validation MAE: 0.03736378055061335
# SNR [40dB], Validation Loss: 0.7211, Validation Accuracy: 74.4550, Validation MAE: 0.036223253581796046
#
#
# Epoch [17/40], Training Loss: 1.5530, Training Accuracy: 49.9955, Training MAE: 0.11243937033961969
# SNR [0dB], Validation Loss: 3.4106, Validation Accuracy: 11.4833, Validation MAE: 0.3954475489278022
# SNR [10dB], Validation Loss: 2.1570, Validation Accuracy: 31.1817, Validation MAE: 0.13418896022567656
# SNR [20dB], Validation Loss: 1.2586, Validation Accuracy: 55.1100, Validation MAE: 0.0548272310141399
# SNR [30dB], Validation Loss: 0.8403, Validation Accuracy: 68.5133, Validation MAE: 0.03265974693323345
# SNR [40dB], Validation Loss: 0.7619, Validation Accuracy: 71.4517, Validation MAE: 0.03077959663826201
#
#
# Epoch [18/40], Training Loss: 1.5369, Training Accuracy: 50.4946, Training MAE: 0.11140890529366791
# SNR [0dB], Validation Loss: 3.4221, Validation Accuracy: 11.4050, Validation MAE: 0.3895587279941942
# SNR [10dB], Validation Loss: 2.1646, Validation Accuracy: 31.4600, Validation MAE: 0.13819653350032773
# SNR [20dB], Validation Loss: 1.2556, Validation Accuracy: 56.0950, Validation MAE: 0.05963368527015638
# SNR [30dB], Validation Loss: 0.8290, Validation Accuracy: 69.5417, Validation MAE: 0.039036529052345725
# SNR [40dB], Validation Loss: 0.7482, Validation Accuracy: 72.6417, Validation MAE: 0.03829507678621594
#
#
# Epoch [19/40], Training Loss: 1.5220, Training Accuracy: 50.9279, Training MAE: 0.11026325663195569
# SNR [0dB], Validation Loss: 3.4072, Validation Accuracy: 11.1567, Validation MAE: 0.38806558139807096
# SNR [10dB], Validation Loss: 2.1452, Validation Accuracy: 31.4383, Validation MAE: 0.1346860661110591
# SNR [20dB], Validation Loss: 1.2253, Validation Accuracy: 56.5767, Validation MAE: 0.05392848991010394
# SNR [30dB], Validation Loss: 0.7714, Validation Accuracy: 71.7083, Validation MAE: 0.031884276383556516
# SNR [40dB], Validation Loss: 0.6815, Validation Accuracy: 75.3283, Validation MAE: 0.028096175905983706
#
#
# Epoch [20/40], Training Loss: 1.5092, Training Accuracy: 51.3861, Training MAE: 0.10886345267678352
# SNR [0dB], Validation Loss: 3.4042, Validation Accuracy: 11.2717, Validation MAE: 0.3893699813887068
# SNR [10dB], Validation Loss: 2.1493, Validation Accuracy: 31.8717, Validation MAE: 0.13947752305927522
# SNR [20dB], Validation Loss: 1.2455, Validation Accuracy: 56.8350, Validation MAE: 0.05776267967506321
# SNR [30dB], Validation Loss: 0.7905, Validation Accuracy: 72.3033, Validation MAE: 0.032175809415675626
# SNR [40dB], Validation Loss: 0.6966, Validation Accuracy: 76.0217, Validation MAE: 0.030980048459593595
#
#
# Epoch [21/40], Training Loss: 1.4954, Training Accuracy: 51.7474, Training MAE: 0.10745085776371627
# SNR [0dB], Validation Loss: 3.3815, Validation Accuracy: 11.3800, Validation MAE: 0.38927597387395824
# SNR [10dB], Validation Loss: 2.1272, Validation Accuracy: 31.6633, Validation MAE: 0.13613568393576178
# SNR [20dB], Validation Loss: 1.2064, Validation Accuracy: 57.3417, Validation MAE: 0.05479101800262197
# SNR [30dB], Validation Loss: 0.7446, Validation Accuracy: 72.9183, Validation MAE: 0.03177051631707089
# SNR [40dB], Validation Loss: 0.6546, Validation Accuracy: 76.2300, Validation MAE: 0.028885546399475607
#
#
# Epoch [22/40], Training Loss: 1.4802, Training Accuracy: 52.2385, Training MAE: 0.1061950170795685
# SNR [0dB], Validation Loss: 3.3868, Validation Accuracy: 11.3567, Validation MAE: 0.3738437441473921
# SNR [10dB], Validation Loss: 2.1336, Validation Accuracy: 31.7233, Validation MAE: 0.13003177966101695
# SNR [20dB], Validation Loss: 1.2031, Validation Accuracy: 56.9733, Validation MAE: 0.05088476800262197
# SNR [30dB], Validation Loss: 0.7329, Validation Accuracy: 72.5717, Validation MAE: 0.029551646338608482
# SNR [40dB], Validation Loss: 0.6293, Validation Accuracy: 76.7683, Validation MAE: 0.026539016410712612
#
#
# Epoch [23/40], Training Loss: 1.4682, Training Accuracy: 52.5845, Training MAE: 0.10522823384533216
# SNR [0dB], Validation Loss: 3.3935, Validation Accuracy: 11.2817, Validation MAE: 0.3757473048740519
# SNR [10dB], Validation Loss: 2.1268, Validation Accuracy: 31.5533, Validation MAE: 0.12865751416331117
# SNR [20dB], Validation Loss: 1.1825, Validation Accuracy: 58.1867, Validation MAE: 0.04934772684708306
# SNR [30dB], Validation Loss: 0.7020, Validation Accuracy: 74.4867, Validation MAE: 0.028541705684052815
# SNR [40dB], Validation Loss: 0.5982, Validation Accuracy: 78.8450, Validation MAE: 0.02638026442082592
#
#
# Epoch [24/40], Training Loss: 1.4542, Training Accuracy: 53.0088, Training MAE: 0.10379554256955577
# SNR [0dB], Validation Loss: 3.3808, Validation Accuracy: 11.2050, Validation MAE: 0.38953897544245714
# SNR [10dB], Validation Loss: 2.1115, Validation Accuracy: 31.7167, Validation MAE: 0.1350551461981459
# SNR [20dB], Validation Loss: 1.1914, Validation Accuracy: 57.3850, Validation MAE: 0.052091868386553046
# SNR [30dB], Validation Loss: 0.7312, Validation Accuracy: 72.2300, Validation MAE: 0.029448128335986517
# SNR [40dB], Validation Loss: 0.6301, Validation Accuracy: 76.2133, Validation MAE: 0.027124277202921623
#
#
# Epoch [25/40], Training Loss: 1.4421, Training Accuracy: 53.3401, Training MAE: 0.10236465814657149
# SNR [0dB], Validation Loss: 3.3863, Validation Accuracy: 11.4183, Validation MAE: 0.38444684076224367
# SNR [10dB], Validation Loss: 2.1167, Validation Accuracy: 31.6517, Validation MAE: 0.1322583311873771
# SNR [20dB], Validation Loss: 1.2045, Validation Accuracy: 57.3517, Validation MAE: 0.052162099681618126
# SNR [30dB], Validation Loss: 0.7380, Validation Accuracy: 72.6467, Validation MAE: 0.030484771514186722
# SNR [40dB], Validation Loss: 0.6415, Validation Accuracy: 76.3833, Validation MAE: 0.029576885710272498
#
#
# Epoch [26/40], Training Loss: 1.4267, Training Accuracy: 53.8169, Training MAE: 0.10115432675469065
# SNR [0dB], Validation Loss: 3.3985, Validation Accuracy: 11.3350, Validation MAE: 0.38922842143459124
# SNR [10dB], Validation Loss: 2.1271, Validation Accuracy: 31.5583, Validation MAE: 0.13545275774885288
# SNR [20dB], Validation Loss: 1.1987, Validation Accuracy: 57.6450, Validation MAE: 0.05108704876392921
# SNR [30dB], Validation Loss: 0.7076, Validation Accuracy: 74.4367, Validation MAE: 0.030379058783593968
# SNR [40dB], Validation Loss: 0.6027, Validation Accuracy: 78.8033, Validation MAE: 0.026052152589193744
#
#
# Epoch [27/40], Training Loss: 1.4116, Training Accuracy: 54.2061, Training MAE: 0.09932680564649037
# SNR [0dB], Validation Loss: 3.3981, Validation Accuracy: 11.1550, Validation MAE: 0.38026368924992976
# SNR [10dB], Validation Loss: 2.1114, Validation Accuracy: 31.9817, Validation MAE: 0.1319741139151606
# SNR [20dB], Validation Loss: 1.1596, Validation Accuracy: 58.6467, Validation MAE: 0.04919116958516715
# SNR [30dB], Validation Loss: 0.6631, Validation Accuracy: 75.4850, Validation MAE: 0.027748677310609607
# SNR [40dB], Validation Loss: 0.5521, Validation Accuracy: 79.9717, Validation MAE: 0.022606429675063208
#
#
# Epoch [28/40], Training Loss: 1.3962, Training Accuracy: 54.6419, Training MAE: 0.09813917040550872
# SNR [0dB], Validation Loss: 3.4018, Validation Accuracy: 11.1217, Validation MAE: 0.38445415652214626
# SNR [10dB], Validation Loss: 2.1060, Validation Accuracy: 31.9100, Validation MAE: 0.13068032177638356
# SNR [20dB], Validation Loss: 1.1664, Validation Accuracy: 58.4633, Validation MAE: 0.05285856002434685
# SNR [30dB], Validation Loss: 0.6853, Validation Accuracy: 74.7533, Validation MAE: 0.029855616162562038
# SNR [40dB], Validation Loss: 0.5813, Validation Accuracy: 78.6900, Validation MAE: 0.025662588374379625
#
#
# Epoch [29/40], Training Loss: 1.3803, Training Accuracy: 55.0745, Training MAE: 0.09612874119919702
# SNR [0dB], Validation Loss: 3.4231, Validation Accuracy: 10.9933, Validation MAE: 0.39382747389736866
# SNR [10dB], Validation Loss: 2.1246, Validation Accuracy: 31.6217, Validation MAE: 0.13247524346848955
# SNR [20dB], Validation Loss: 1.1754, Validation Accuracy: 58.3183, Validation MAE: 0.05072126076879858
# SNR [30dB], Validation Loss: 0.6668, Validation Accuracy: 75.5283, Validation MAE: 0.02781488493772825
# SNR [40dB], Validation Loss: 0.5515, Validation Accuracy: 80.2783, Validation MAE: 0.024322706948216127
#
#
# Epoch [30/40], Training Loss: 1.3642, Training Accuracy: 55.5362, Training MAE: 0.0944600671494092
# SNR [0dB], Validation Loss: 3.4266, Validation Accuracy: 11.0850, Validation MAE: 0.3838264643225021
# SNR [10dB], Validation Loss: 2.1195, Validation Accuracy: 31.5900, Validation MAE: 0.133834511658395
# SNR [20dB], Validation Loss: 1.1624, Validation Accuracy: 58.6550, Validation MAE: 0.051102777647719824
# SNR [30dB], Validation Loss: 0.6545, Validation Accuracy: 75.7800, Validation MAE: 0.02810349166588632
# SNR [40dB], Validation Loss: 0.5406, Validation Accuracy: 80.5400, Validation MAE: 0.025244858483940445
#
#
# Epoch [31/40], Training Loss: 1.3461, Training Accuracy: 56.0042, Training MAE: 0.09242930759945125
# SNR [0dB], Validation Loss: 3.4468, Validation Accuracy: 11.0400, Validation MAE: 0.37955515790336175
# SNR [10dB], Validation Loss: 2.1145, Validation Accuracy: 31.6717, Validation MAE: 0.13585805084745764
# SNR [20dB], Validation Loss: 1.1560, Validation Accuracy: 58.6700, Validation MAE: 0.05282161543683866
# SNR [30dB], Validation Loss: 0.6332, Validation Accuracy: 76.1083, Validation MAE: 0.029388870680775354
# SNR [40dB], Validation Loss: 0.5039, Validation Accuracy: 81.4100, Validation MAE: 0.024391475091300685
#
#
# Epoch [32/40], Training Loss: 1.3283, Training Accuracy: 56.5314, Training MAE: 0.09066583227331303
# SNR [0dB], Validation Loss: 3.4713, Validation Accuracy: 10.8300, Validation MAE: 0.3806580087086806
# SNR [10dB], Validation Loss: 2.1199, Validation Accuracy: 31.5450, Validation MAE: 0.13375111199550518
# SNR [20dB], Validation Loss: 1.1734, Validation Accuracy: 58.1383, Validation MAE: 0.054390114359958795
# SNR [30dB], Validation Loss: 0.6701, Validation Accuracy: 75.9467, Validation MAE: 0.03061206573649218
# SNR [40dB], Validation Loss: 0.5586, Validation Accuracy: 80.2733, Validation MAE: 0.028054841862533944
#
#
# Epoch [33/40], Training Loss: 1.3098, Training Accuracy: 56.9952, Training MAE: 0.0887465256430628
# SNR [0dB], Validation Loss: 3.4899, Validation Accuracy: 10.8133, Validation MAE: 0.3797376861129319
# SNR [10dB], Validation Loss: 2.1338, Validation Accuracy: 31.3300, Validation MAE: 0.13453060621312857
# SNR [20dB], Validation Loss: 1.1621, Validation Accuracy: 58.5800, Validation MAE: 0.05203919491525424
# SNR [30dB], Validation Loss: 0.6473, Validation Accuracy: 76.0967, Validation MAE: 0.027504330929862347
# SNR [40dB], Validation Loss: 0.5237, Validation Accuracy: 81.2367, Validation MAE: 0.0236858700486937
#
#
# Epoch [34/40], Training Loss: 1.2907, Training Accuracy: 57.4894, Training MAE: 0.08668711642725044
# SNR [0dB], Validation Loss: 3.5191, Validation Accuracy: 10.6950, Validation MAE: 0.3988925402659425
# SNR [10dB], Validation Loss: 2.1508, Validation Accuracy: 31.0450, Validation MAE: 0.13836186967412678
# SNR [20dB], Validation Loss: 1.2001, Validation Accuracy: 57.0733, Validation MAE: 0.054849178293847736
# SNR [30dB], Validation Loss: 0.7049, Validation Accuracy: 73.9033, Validation MAE: 0.03029200124075288
# SNR [40dB], Validation Loss: 0.5930, Validation Accuracy: 78.2050, Validation MAE: 0.025134756297406125
#
#
# Epoch [35/40], Training Loss: 1.2718, Training Accuracy: 58.0528, Training MAE: 0.08452918823797588
# SNR [0dB], Validation Loss: 3.5306, Validation Accuracy: 10.7167, Validation MAE: 0.39122598967599964
# SNR [10dB], Validation Loss: 2.1365, Validation Accuracy: 31.3217, Validation MAE: 0.13391791132128478
# SNR [20dB], Validation Loss: 1.1630, Validation Accuracy: 58.4800, Validation MAE: 0.05055226671504823
# SNR [30dB], Validation Loss: 0.6416, Validation Accuracy: 76.0150, Validation MAE: 0.02863315268283547
# SNR [40dB], Validation Loss: 0.5165, Validation Accuracy: 81.1500, Validation MAE: 0.025703190841839123
#
#
# Epoch [36/40], Training Loss: 1.2511, Training Accuracy: 58.5713, Training MAE: 0.08249077231179822
# SNR [0dB], Validation Loss: 3.5754, Validation Accuracy: 10.6417, Validation MAE: 0.3881303258732091
# SNR [10dB], Validation Loss: 2.1577, Validation Accuracy: 31.0017, Validation MAE: 0.13597181091394325
# SNR [20dB], Validation Loss: 1.1712, Validation Accuracy: 57.9017, Validation MAE: 0.05295220175110029
# SNR [30dB], Validation Loss: 0.6620, Validation Accuracy: 74.6667, Validation MAE: 0.029057466757187
# SNR [40dB], Validation Loss: 0.5303, Validation Accuracy: 79.7717, Validation MAE: 0.023753175039797732
#
#
# Epoch [37/40], Training Loss: 1.2302, Training Accuracy: 59.1856, Training MAE: 0.08049189916399131
# SNR [0dB], Validation Loss: 3.5938, Validation Accuracy: 10.6217, Validation MAE: 0.3961220619908231
# SNR [10dB], Validation Loss: 2.1711, Validation Accuracy: 30.8667, Validation MAE: 0.13492675461185505
# SNR [20dB], Validation Loss: 1.2046, Validation Accuracy: 57.3550, Validation MAE: 0.054436569435340386
# SNR [30dB], Validation Loss: 0.6965, Validation Accuracy: 75.1117, Validation MAE: 0.027900479328588818
# SNR [40dB], Validation Loss: 0.5688, Validation Accuracy: 80.2717, Validation MAE: 0.023689162140649873
#
#
# Epoch [38/40], Training Loss: 1.2099, Training Accuracy: 59.7229, Training MAE: 0.07857736314506984
# SNR [0dB], Validation Loss: 3.6486, Validation Accuracy: 10.4050, Validation MAE: 0.3971967471205169
# SNR [10dB], Validation Loss: 2.1799, Validation Accuracy: 30.5800, Validation MAE: 0.13923646877048412
# SNR [20dB], Validation Loss: 1.1826, Validation Accuracy: 57.8350, Validation MAE: 0.056452792864500424
# SNR [30dB], Validation Loss: 0.6447, Validation Accuracy: 76.2417, Validation MAE: 0.02999571296469707
# SNR [40dB], Validation Loss: 0.5090, Validation Accuracy: 81.9133, Validation MAE: 0.025349839638542936
#
#
# Epoch [39/40], Training Loss: 1.1897, Training Accuracy: 60.2192, Training MAE: 0.07658281864459938
# SNR [0dB], Validation Loss: 3.6860, Validation Accuracy: 10.3950, Validation MAE: 0.4029670527437026
# SNR [10dB], Validation Loss: 2.1843, Validation Accuracy: 30.9217, Validation MAE: 0.13881105733214721
# SNR [20dB], Validation Loss: 1.1749, Validation Accuracy: 58.2383, Validation MAE: 0.05558807004401161
# SNR [30dB], Validation Loss: 0.6426, Validation Accuracy: 76.3133, Validation MAE: 0.03095993011986141
# SNR [40dB], Validation Loss: 0.5146, Validation Accuracy: 81.4483, Validation MAE: 0.027770990378312575
#
#
# Epoch [40/40], Training Loss: 1.1677, Training Accuracy: 60.8642, Training MAE: 0.07407572590245927
# SNR [0dB], Validation Loss: 3.7260, Validation Accuracy: 10.4100, Validation MAE: 0.39332451540406405
# SNR [10dB], Validation Loss: 2.1975, Validation Accuracy: 30.7617, Validation MAE: 0.1348283576411649
# SNR [20dB], Validation Loss: 1.1860, Validation Accuracy: 57.4567, Validation MAE: 0.05438828541998315
# SNR [30dB], Validation Loss: 0.6647, Validation Accuracy: 75.7800, Validation MAE: 0.028975896034272874
# SNR [40dB], Validation Loss: 0.5329, Validation Accuracy: 81.2350, Validation MAE: 0.02339104492461841
#
#
# Training Complete

# %%
# SNS DOA-4 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-4 ====
# = MAE =_= Acc =
# 0.3738   11.36
# 0.1287   31.55
# 0.0492   58.65
# 0.0275   76.10
# 0.0226   79.97

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()
