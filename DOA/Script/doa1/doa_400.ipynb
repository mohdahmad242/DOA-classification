# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("../SNS_dataset/400/DOA1")

# %%
# root_dataset_path  = ("../SNS_dataset/400/DOA3")
data_list = [os.path.join(root_dataset_path, f) for f in listdir(root_dataset_path) if isfile(join(root_dataset_path, f))]
data_list = set(data_list)
# df = [sio.loadmat(path) for path in data_list]

# %%
data_list
# Out:
# {'../SNS_dataset/400/DOA1/SNR_SNS_00_1_400.mat',
#  '../SNS_dataset/400/DOA1/SNR_SNS_10_1_400.mat',
#  '../SNS_dataset/400/DOA1/SNR_SNS_20_1_400.mat',
#  '../SNS_dataset/400/DOA1/SNR_SNS_30_1_400.mat',
#  '../SNS_dataset/400/DOA1/SNR_SNS_40_1_400.mat'}

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_00_1_400.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_1_400.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_1_400.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_1_400.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_1_400.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 400)
# Out:
# 2021-06-18 06:47:34,393 - Data prepration started
# 2021-06-18 06:47:53,336 - Dividing your dataset into 3 channel
# 2021-06-18 06:54:08,367 - Creating Train dataloader
# 2021-06-18 06:54:10,144 - Creating Validation dataloader
# 2021-06-18 06:54:10,321 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((1, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.6)
        self.dropout = nn.Dropout(0.4)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        # print("Input ==> ", x.size())
        out = self.relu(self.bn1(self.conv1(x)))
        # print("F.relu(self.bn1(self.conv1(x))) ==> ", x.size())
        out = self.layer1(out)
        # print("layer1 ==> ", x.size())
        out = self.layer2(out)
        # print("layer2 ==> ", x.size())
        out = self.layer3(out)
        # print("layer3 ==> ", x.size())
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout(out)
#         print("layer4 ==>", out.size())
        out = self.adp_pool(out)
        
#         print("avg_pool2d ===>", out.size())
        # out = out.view(out.size(0), -1)
        # print("out.view ===>", out.size())
        out = self.linear(out)
        out = self.dropout(out)
        out = self.flat(out)
#         print("Out ===>", out.size())
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    model(image)

# %%
num_epochs = 60
doa = 1
weights_dir = "./doa_weights/"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(64*len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*64*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*128*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_400_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/DOA_{}_400_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 2.3497, Training Accuracy: 35.7191, Training MAE: 0.08338715328184781
# SNR [0dB], Validation Loss: 2.5022, Validation Accuracy: 28.7400, Validation MAE: 0.06776295767393951
# SNR [10dB], Validation Loss: 1.2465, Validation Accuracy: 62.5667, Validation MAE: 0.025628570090832473
# SNR [20dB], Validation Loss: 0.8449, Validation Accuracy: 76.7533, Validation MAE: 0.01437693136061429
# SNR [30dB], Validation Loss: 0.7802, Validation Accuracy: 79.5333, Validation MAE: 0.012108680002809251
# SNR [40dB], Validation Loss: 0.7616, Validation Accuracy: 80.3200, Validation MAE: 0.011668637044667104
#
#
# Epoch [2/60], Training Loss: 0.9600, Training Accuracy: 67.5355, Training MAE: 0.029216107705273036
# SNR [0dB], Validation Loss: 2.1766, Validation Accuracy: 35.5933, Validation MAE: 0.05747846240284671
# SNR [10dB], Validation Loss: 0.9505, Validation Accuracy: 70.5867, Validation MAE: 0.023403481716452852
# SNR [20dB], Validation Loss: 0.5003, Validation Accuracy: 86.6733, Validation MAE: 0.014565677966101694
# SNR [30dB], Validation Loss: 0.4056, Validation Accuracy: 90.9333, Validation MAE: 0.013516963784062178
# SNR [40dB], Validation Loss: 0.3892, Validation Accuracy: 91.7200, Validation MAE: 0.011703021116209383
#
#
# Epoch [3/60], Training Loss: 0.7585, Training Accuracy: 73.9654, Training MAE: 0.024430573592308286
# SNR [0dB], Validation Loss: 2.0492, Validation Accuracy: 38.9800, Validation MAE: 0.05245290113774698
# SNR [10dB], Validation Loss: 0.8809, Validation Accuracy: 71.9200, Validation MAE: 0.021125719870774416
# SNR [20dB], Validation Loss: 0.4418, Validation Accuracy: 86.1733, Validation MAE: 0.011998943604270063
# SNR [30dB], Validation Loss: 0.3656, Validation Accuracy: 88.7133, Validation MAE: 0.008532736562412211
# SNR [40dB], Validation Loss: 0.3455, Validation Accuracy: 89.3933, Validation MAE: 0.006166454021912164
#
#
# Epoch [4/60], Training Loss: 0.6663, Training Accuracy: 76.8659, Training MAE: 0.02303603420822099
# SNR [0dB], Validation Loss: 1.9071, Validation Accuracy: 42.0200, Validation MAE: 0.04927127715610076
# SNR [10dB], Validation Loss: 0.7601, Validation Accuracy: 75.5267, Validation MAE: 0.021282277132690326
# SNR [20dB], Validation Loss: 0.3313, Validation Accuracy: 90.0133, Validation MAE: 0.013485140228485813
# SNR [30dB], Validation Loss: 0.2437, Validation Accuracy: 93.5267, Validation MAE: 0.009864204864687705
# SNR [40dB], Validation Loss: 0.2245, Validation Accuracy: 94.2133, Validation MAE: 0.008824269594531323
#
#
# Epoch [5/60], Training Loss: 0.6128, Training Accuracy: 78.5075, Training MAE: 0.022148180543434766
# SNR [0dB], Validation Loss: 1.8429, Validation Accuracy: 42.3067, Validation MAE: 0.04839082545182133
# SNR [10dB], Validation Loss: 0.7211, Validation Accuracy: 76.8133, Validation MAE: 0.023984353052720293
# SNR [20dB], Validation Loss: 0.2816, Validation Accuracy: 91.9867, Validation MAE: 0.01472589310796891
# SNR [30dB], Validation Loss: 0.1799, Validation Accuracy: 96.2400, Validation MAE: 0.01284501123700721
# SNR [40dB], Validation Loss: 0.1618, Validation Accuracy: 97.0000, Validation MAE: 0.011244688758310703
#
#
# Epoch [6/60], Training Loss: 0.5775, Training Accuracy: 79.5461, Training MAE: 0.021643561655744784
# SNR [0dB], Validation Loss: 1.8080, Validation Accuracy: 44.4200, Validation MAE: 0.04604539282704373
# SNR [10dB], Validation Loss: 0.7047, Validation Accuracy: 77.2000, Validation MAE: 0.02168464392733402
# SNR [20dB], Validation Loss: 0.2698, Validation Accuracy: 91.6867, Validation MAE: 0.012828550777226331
# SNR [30dB], Validation Loss: 0.1649, Validation Accuracy: 96.0067, Validation MAE: 0.007193586712238974
# SNR [40dB], Validation Loss: 0.1410, Validation Accuracy: 97.2867, Validation MAE: 0.005882968325685926
#
#
# Epoch [7/60], Training Loss: 0.5470, Training Accuracy: 80.5412, Training MAE: 0.02099326363682498
# SNR [0dB], Validation Loss: 1.7566, Validation Accuracy: 43.9867, Validation MAE: 0.046694300730405466
# SNR [10dB], Validation Loss: 0.6920, Validation Accuracy: 76.8600, Validation MAE: 0.020688969004588446
# SNR [20dB], Validation Loss: 0.2678, Validation Accuracy: 91.1333, Validation MAE: 0.011937857009083248
# SNR [30dB], Validation Loss: 0.1678, Validation Accuracy: 94.3200, Validation MAE: 0.00861906252926304
# SNR [40dB], Validation Loss: 0.1456, Validation Accuracy: 95.1200, Validation MAE: 0.0068190198052252085
#
#
# Epoch [8/60], Training Loss: 0.5230, Training Accuracy: 81.2901, Training MAE: 0.020264361021978816
# SNR [0dB], Validation Loss: 1.7319, Validation Accuracy: 45.1267, Validation MAE: 0.04634131531510441
# SNR [10dB], Validation Loss: 0.6878, Validation Accuracy: 77.0933, Validation MAE: 0.022535466804007864
# SNR [20dB], Validation Loss: 0.3078, Validation Accuracy: 89.2333, Validation MAE: 0.017893251357805038
# SNR [30dB], Validation Loss: 0.2183, Validation Accuracy: 91.7067, Validation MAE: 0.015634144699878266
# SNR [40dB], Validation Loss: 0.2036, Validation Accuracy: 91.7533, Validation MAE: 0.015798017721696787
#
#
# Epoch [9/60], Training Loss: 0.4991, Training Accuracy: 82.1416, Training MAE: 0.019791433552325623
# SNR [0dB], Validation Loss: 1.7119, Validation Accuracy: 45.3600, Validation MAE: 0.048307791576926676
# SNR [10dB], Validation Loss: 0.6731, Validation Accuracy: 77.3667, Validation MAE: 0.023038059509317352
# SNR [20dB], Validation Loss: 0.2691, Validation Accuracy: 90.6267, Validation MAE: 0.01288561370446671
# SNR [30dB], Validation Loss: 0.1747, Validation Accuracy: 93.2800, Validation MAE: 0.010947668906264632
# SNR [40dB], Validation Loss: 0.1555, Validation Accuracy: 93.9600, Validation MAE: 0.009361612159378219
#
#
# Epoch [10/60], Training Loss: 0.4760, Training Accuracy: 82.8715, Training MAE: 0.01931749216527831
# SNR [0dB], Validation Loss: 1.7036, Validation Accuracy: 44.5733, Validation MAE: 0.04609696893435715
# SNR [10dB], Validation Loss: 0.6396, Validation Accuracy: 78.3800, Validation MAE: 0.02122082474950838
# SNR [20dB], Validation Loss: 0.2310, Validation Accuracy: 92.1667, Validation MAE: 0.014060158956831164
# SNR [30dB], Validation Loss: 0.1366, Validation Accuracy: 95.4000, Validation MAE: 0.01205015392358835
# SNR [40dB], Validation Loss: 0.1178, Validation Accuracy: 96.0667, Validation MAE: 0.012201224365577301
#
#
# Epoch [11/60], Training Loss: 0.4496, Training Accuracy: 83.7167, Training MAE: 0.018864271090105748
# SNR [0dB], Validation Loss: 1.6862, Validation Accuracy: 45.3267, Validation MAE: 0.04905655960295908
# SNR [10dB], Validation Loss: 0.6236, Validation Accuracy: 78.0867, Validation MAE: 0.024521695617567188
# SNR [20dB], Validation Loss: 0.2170, Validation Accuracy: 92.3333, Validation MAE: 0.013289809439086057
# SNR [30dB], Validation Loss: 0.1123, Validation Accuracy: 96.4733, Validation MAE: 0.008414952827980148
# SNR [40dB], Validation Loss: 0.0898, Validation Accuracy: 97.5800, Validation MAE: 0.005957223288697444
#
#
# Epoch [12/60], Training Loss: 0.4241, Training Accuracy: 84.6264, Training MAE: 0.018578411379668074
# SNR [0dB], Validation Loss: 1.7132, Validation Accuracy: 44.7133, Validation MAE: 0.04693096556325499
# SNR [10dB], Validation Loss: 0.6404, Validation Accuracy: 77.8400, Validation MAE: 0.021518941965539846
# SNR [20dB], Validation Loss: 0.2235, Validation Accuracy: 92.3067, Validation MAE: 0.01315154157692668
# SNR [30dB], Validation Loss: 0.1151, Validation Accuracy: 96.4867, Validation MAE: 0.010538352139713457
# SNR [40dB], Validation Loss: 0.0932, Validation Accuracy: 97.3667, Validation MAE: 0.009537921973031183
#
#
# Epoch [13/60], Training Loss: 0.3984, Training Accuracy: 85.5214, Training MAE: 0.018113335270348856
# SNR [0dB], Validation Loss: 1.7151, Validation Accuracy: 45.1533, Validation MAE: 0.05067151360146081
# SNR [10dB], Validation Loss: 0.6316, Validation Accuracy: 77.8600, Validation MAE: 0.021822911789493398
# SNR [20dB], Validation Loss: 0.2361, Validation Accuracy: 91.6333, Validation MAE: 0.013434295697162656
# SNR [30dB], Validation Loss: 0.1350, Validation Accuracy: 95.0133, Validation MAE: 0.01029071366701002
# SNR [40dB], Validation Loss: 0.1155, Validation Accuracy: 95.8333, Validation MAE: 0.009838965493023691
#
#
# Epoch [14/60], Training Loss: 0.3703, Training Accuracy: 86.4344, Training MAE: 0.017595535456535284
# SNR [0dB], Validation Loss: 1.7446, Validation Accuracy: 44.8867, Validation MAE: 0.050318893974154885
# SNR [10dB], Validation Loss: 0.6305, Validation Accuracy: 78.1400, Validation MAE: 0.02120948532165933
# SNR [20dB], Validation Loss: 0.2310, Validation Accuracy: 91.9333, Validation MAE: 0.01166644231669632
# SNR [30dB], Validation Loss: 0.1256, Validation Accuracy: 95.7400, Validation MAE: 0.007902118058807004
# SNR [40dB], Validation Loss: 0.1046, Validation Accuracy: 96.5733, Validation MAE: 0.006559310328682461
#
#
# Epoch [15/60], Training Loss: 0.3443, Training Accuracy: 87.3974, Training MAE: 0.01686187522930132
# SNR [0dB], Validation Loss: 1.8313, Validation Accuracy: 44.3600, Validation MAE: 0.05054275622717483
# SNR [10dB], Validation Loss: 0.6394, Validation Accuracy: 78.0200, Validation MAE: 0.021748291038486748
# SNR [20dB], Validation Loss: 0.2173, Validation Accuracy: 92.3933, Validation MAE: 0.011825194306583013
# SNR [30dB], Validation Loss: 0.1095, Validation Accuracy: 96.2533, Validation MAE: 0.008337405773012454
# SNR [40dB], Validation Loss: 0.0866, Validation Accuracy: 97.1000, Validation MAE: 0.006981429675063208
#
#
# Epoch [16/60], Training Loss: 0.3200, Training Accuracy: 88.2866, Training MAE: 0.016459077046074903
# SNR [0dB], Validation Loss: 1.8996, Validation Accuracy: 43.9600, Validation MAE: 0.05357074925086618
# SNR [10dB], Validation Loss: 0.6314, Validation Accuracy: 78.3400, Validation MAE: 0.021947279707837813
# SNR [20dB], Validation Loss: 0.1953, Validation Accuracy: 93.1133, Validation MAE: 0.01202601191590973
# SNR [30dB], Validation Loss: 0.0822, Validation Accuracy: 97.2467, Validation MAE: 0.0064627422979679746
# SNR [40dB], Validation Loss: 0.0609, Validation Accuracy: 97.9867, Validation MAE: 0.005116276687892125
#
#
# Epoch [17/60], Training Loss: 0.2975, Training Accuracy: 89.1838, Training MAE: 0.015325725382501636
# SNR [0dB], Validation Loss: 2.0098, Validation Accuracy: 43.4133, Validation MAE: 0.056228199035490214
# SNR [10dB], Validation Loss: 0.6660, Validation Accuracy: 77.5867, Validation MAE: 0.024640942503979774
# SNR [20dB], Validation Loss: 0.2115, Validation Accuracy: 92.4133, Validation MAE: 0.013241159635733683
# SNR [30dB], Validation Loss: 0.0939, Validation Accuracy: 96.8267, Validation MAE: 0.008869627305927521
# SNR [40dB], Validation Loss: 0.0714, Validation Accuracy: 97.6533, Validation MAE: 0.007282473195055717
#
#
# Epoch [18/60], Training Loss: 0.2751, Training Accuracy: 89.9442, Training MAE: 0.015158507006117197
# SNR [0dB], Validation Loss: 1.9923, Validation Accuracy: 43.5600, Validation MAE: 0.05333298705403128
# SNR [10dB], Validation Loss: 0.6527, Validation Accuracy: 77.8667, Validation MAE: 0.023830356306770297
# SNR [20dB], Validation Loss: 0.1962, Validation Accuracy: 93.0267, Validation MAE: 0.011827389034553798
# SNR [30dB], Validation Loss: 0.0783, Validation Accuracy: 97.2667, Validation MAE: 0.0070959213175390955
# SNR [40dB], Validation Loss: 0.0552, Validation Accuracy: 98.1667, Validation MAE: 0.005375986164434872
#
#
# Epoch [19/60], Training Loss: 0.2563, Training Accuracy: 90.5819, Training MAE: 0.014565339332673889
# SNR [0dB], Validation Loss: 2.1421, Validation Accuracy: 42.5400, Validation MAE: 0.05725313699784624
# SNR [10dB], Validation Loss: 0.6748, Validation Accuracy: 77.2867, Validation MAE: 0.02221357336829291
# SNR [20dB], Validation Loss: 0.2037, Validation Accuracy: 92.7133, Validation MAE: 0.011564753254050006
# SNR [30dB], Validation Loss: 0.0850, Validation Accuracy: 97.2600, Validation MAE: 0.007130305389081375
# SNR [40dB], Validation Loss: 0.0587, Validation Accuracy: 98.3533, Validation MAE: 0.005625087789118831
#
#
# Epoch [20/60], Training Loss: 0.2374, Training Accuracy: 91.2816, Training MAE: 0.013695879169332317
# SNR [0dB], Validation Loss: 2.1212, Validation Accuracy: 42.8667, Validation MAE: 0.056795536215937824
# SNR [10dB], Validation Loss: 0.6779, Validation Accuracy: 77.3600, Validation MAE: 0.023487978743328027
# SNR [20dB], Validation Loss: 0.2088, Validation Accuracy: 92.4267, Validation MAE: 0.012028206643880513
# SNR [30dB], Validation Loss: 0.0879, Validation Accuracy: 96.7400, Validation MAE: 0.007650455918157131
# SNR [40dB], Validation Loss: 0.0611, Validation Accuracy: 97.8867, Validation MAE: 0.005899428785466804
#
#
# Epoch [21/60], Training Loss: 0.2214, Training Accuracy: 91.8605, Training MAE: 0.013120520044990895
# SNR [0dB], Validation Loss: 2.2516, Validation Accuracy: 43.1200, Validation MAE: 0.05421270718232044
# SNR [10dB], Validation Loss: 0.6940, Validation Accuracy: 77.9733, Validation MAE: 0.022688366185972468
# SNR [20dB], Validation Loss: 0.2076, Validation Accuracy: 92.6667, Validation MAE: 0.012185861269781814
# SNR [30dB], Validation Loss: 0.0866, Validation Accuracy: 97.2267, Validation MAE: 0.00766179534600618
# SNR [40dB], Validation Loss: 0.0607, Validation Accuracy: 98.1867, Validation MAE: 0.006149261986141024
#
#
# Epoch [22/60], Training Loss: 0.2058, Training Accuracy: 92.4372, Training MAE: 0.012677412145877651
# SNR [0dB], Validation Loss: 2.3422, Validation Accuracy: 43.0067, Validation MAE: 0.057541012150014045
# SNR [10dB], Validation Loss: 0.7204, Validation Accuracy: 76.9867, Validation MAE: 0.02426710717295627
# SNR [20dB], Validation Loss: 0.2102, Validation Accuracy: 92.3200, Validation MAE: 0.012631391047850922
# SNR [30dB], Validation Loss: 0.0793, Validation Accuracy: 97.3733, Validation MAE: 0.0074573198567281585
# SNR [40dB], Validation Loss: 0.0511, Validation Accuracy: 98.4533, Validation MAE: 0.005617406241221088
#
#
# Epoch [23/60], Training Loss: 0.1921, Training Accuracy: 92.8955, Training MAE: 0.012061145354365688
# SNR [0dB], Validation Loss: 2.3863, Validation Accuracy: 42.6533, Validation MAE: 0.05758527249742485
# SNR [10dB], Validation Loss: 0.7385, Validation Accuracy: 77.0400, Validation MAE: 0.02508610649405375
# SNR [20dB], Validation Loss: 0.2631, Validation Accuracy: 90.0200, Validation MAE: 0.012857813816836783
# SNR [30dB], Validation Loss: 0.1716, Validation Accuracy: 92.4133, Validation MAE: 0.010949132058245154
# SNR [40dB], Validation Loss: 0.1564, Validation Accuracy: 92.7933, Validation MAE: 0.010197437728251709
#
#
# Epoch [24/60], Training Loss: 0.1798, Training Accuracy: 93.3532, Training MAE: 0.011410431369335478
# SNR [0dB], Validation Loss: 2.4870, Validation Accuracy: 43.3267, Validation MAE: 0.060312222001123704
# SNR [10dB], Validation Loss: 0.7395, Validation Accuracy: 77.3667, Validation MAE: 0.023203761471111528
# SNR [20dB], Validation Loss: 0.2047, Validation Accuracy: 92.8200, Validation MAE: 0.012390702547054967
# SNR [30dB], Validation Loss: 0.0743, Validation Accuracy: 97.3133, Validation MAE: 0.0073625807659893246
# SNR [40dB], Validation Loss: 0.0498, Validation Accuracy: 98.1067, Validation MAE: 0.006341300683584605
#
#
# Epoch [25/60], Training Loss: 0.1709, Training Accuracy: 93.6880, Training MAE: 0.010880568538320047
# SNR [0dB], Validation Loss: 2.4852, Validation Accuracy: 42.6533, Validation MAE: 0.06236758474576271
# SNR [10dB], Validation Loss: 0.7461, Validation Accuracy: 77.5533, Validation MAE: 0.025788053656709428
# SNR [20dB], Validation Loss: 0.2155, Validation Accuracy: 92.3267, Validation MAE: 0.015115457322783032
# SNR [30dB], Validation Loss: 0.0851, Validation Accuracy: 96.9333, Validation MAE: 0.009324667571870025
# SNR [40dB], Validation Loss: 0.0594, Validation Accuracy: 97.8333, Validation MAE: 0.009142505150294971
#
#
# Epoch [26/60], Training Loss: 0.1594, Training Accuracy: 94.0939, Training MAE: 0.010266680553001986
# SNR [0dB], Validation Loss: 2.6675, Validation Accuracy: 43.2067, Validation MAE: 0.05667884984549115
# SNR [10dB], Validation Loss: 0.7949, Validation Accuracy: 77.1133, Validation MAE: 0.026916875409682555
# SNR [20dB], Validation Loss: 0.2184, Validation Accuracy: 92.4867, Validation MAE: 0.013369917010019664
# SNR [30dB], Validation Loss: 0.1007, Validation Accuracy: 96.4000, Validation MAE: 0.008204624730780036
# SNR [40dB], Validation Loss: 0.0755, Validation Accuracy: 97.2200, Validation MAE: 0.006194253909542092
#
#
# Epoch [27/60], Training Loss: 0.1510, Training Accuracy: 94.3833, Training MAE: 0.009806973006295232
# SNR [0dB], Validation Loss: 2.7390, Validation Accuracy: 42.5267, Validation MAE: 0.06243013449293005
# SNR [10dB], Validation Loss: 0.8014, Validation Accuracy: 77.2467, Validation MAE: 0.025886450627399568
# SNR [20dB], Validation Loss: 0.2158, Validation Accuracy: 92.6467, Validation MAE: 0.013524645331959921
# SNR [30dB], Validation Loss: 0.0795, Validation Accuracy: 96.9467, Validation MAE: 0.007097018681524487
# SNR [40dB], Validation Loss: 0.0499, Validation Accuracy: 98.2067, Validation MAE: 0.005681419140368948
#
#
# Epoch [28/60], Training Loss: 0.1432, Training Accuracy: 94.6753, Training MAE: 0.00932865097614767
# SNR [0dB], Validation Loss: 2.6601, Validation Accuracy: 42.7467, Validation MAE: 0.05843097434216687
# SNR [10dB], Validation Loss: 0.8081, Validation Accuracy: 76.6667, Validation MAE: 0.0253410607266598
# SNR [20dB], Validation Loss: 0.2307, Validation Accuracy: 91.8267, Validation MAE: 0.012007356728158067
# SNR [30dB], Validation Loss: 0.0946, Validation Accuracy: 96.6333, Validation MAE: 0.008002343969472797
# SNR [40dB], Validation Loss: 0.0646, Validation Accuracy: 97.8867, Validation MAE: 0.006035501919655398
#
#
# Epoch [29/60], Training Loss: 0.1362, Training Accuracy: 94.9468, Training MAE: 0.008980968302550454
# SNR [0dB], Validation Loss: 2.7208, Validation Accuracy: 42.5200, Validation MAE: 0.059664411461747356
# SNR [10dB], Validation Loss: 0.8151, Validation Accuracy: 77.0200, Validation MAE: 0.025801587812529263
# SNR [20dB], Validation Loss: 0.2196, Validation Accuracy: 92.4733, Validation MAE: 0.01268808818709617
# SNR [30dB], Validation Loss: 0.0913, Validation Accuracy: 96.4600, Validation MAE: 0.008709777952055436
# SNR [40dB], Validation Loss: 0.0655, Validation Accuracy: 97.4467, Validation MAE: 0.006834382901020695
#
#
# Epoch [30/60], Training Loss: 0.1292, Training Accuracy: 95.2005, Training MAE: 0.008484551746600101
# SNR [0dB], Validation Loss: 2.8071, Validation Accuracy: 42.9200, Validation MAE: 0.061841581608764865
# SNR [10dB], Validation Loss: 0.8271, Validation Accuracy: 77.3133, Validation MAE: 0.0253769079501826
# SNR [20dB], Validation Loss: 0.2198, Validation Accuracy: 92.3333, Validation MAE: 0.011729357851858788
# SNR [30dB], Validation Loss: 0.0817, Validation Accuracy: 97.0600, Validation MAE: 0.00837508193651091
# SNR [40dB], Validation Loss: 0.0532, Validation Accuracy: 98.0600, Validation MAE: 0.006414824070605862
#
#
# Epoch [31/60], Training Loss: 0.1232, Training Accuracy: 95.4061, Training MAE: 0.008300980702500205
# SNR [0dB], Validation Loss: 2.8632, Validation Accuracy: 42.5067, Validation MAE: 0.0608627329337953
# SNR [10dB], Validation Loss: 0.8468, Validation Accuracy: 76.8400, Validation MAE: 0.02684957041857852
# SNR [20dB], Validation Loss: 0.2211, Validation Accuracy: 92.2733, Validation MAE: 0.01254287035302931
# SNR [30dB], Validation Loss: 0.0908, Validation Accuracy: 96.5200, Validation MAE: 0.008204258942784905
# SNR [40dB], Validation Loss: 0.0640, Validation Accuracy: 97.5200, Validation MAE: 0.006312403431969285
#
#
# Epoch [32/60], Training Loss: 0.1186, Training Accuracy: 95.5864, Training MAE: 0.007966413960321824
# SNR [0dB], Validation Loss: 2.8486, Validation Accuracy: 42.0200, Validation MAE: 0.061137439718138405
# SNR [10dB], Validation Loss: 0.8513, Validation Accuracy: 77.0333, Validation MAE: 0.026412087976402286
# SNR [20dB], Validation Loss: 0.2236, Validation Accuracy: 92.6067, Validation MAE: 0.011996383088304148
# SNR [30dB], Validation Loss: 0.0835, Validation Accuracy: 96.7800, Validation MAE: 0.010097943393576177
# SNR [40dB], Validation Loss: 0.0532, Validation Accuracy: 97.8533, Validation MAE: 0.008493963034928364
#
#
# Epoch [33/60], Training Loss: 0.1117, Training Accuracy: 95.8562, Training MAE: 0.007494877377350313
# SNR [0dB], Validation Loss: 3.1332, Validation Accuracy: 43.0400, Validation MAE: 0.06268838081749227
# SNR [10dB], Validation Loss: 0.9127, Validation Accuracy: 77.1067, Validation MAE: 0.02765247506789025
# SNR [20dB], Validation Loss: 0.2325, Validation Accuracy: 92.2467, Validation MAE: 0.013394059017698287
# SNR [30dB], Validation Loss: 0.0855, Validation Accuracy: 96.6333, Validation MAE: 0.007099213409495271
# SNR [40dB], Validation Loss: 0.0602, Validation Accuracy: 97.4067, Validation MAE: 0.005675932320441989
#
#
# Epoch [34/60], Training Loss: 0.1089, Training Accuracy: 95.9384, Training MAE: 0.007381136644035337
# SNR [0dB], Validation Loss: 2.9420, Validation Accuracy: 42.8067, Validation MAE: 0.05911499789306115
# SNR [10dB], Validation Loss: 0.8794, Validation Accuracy: 76.9600, Validation MAE: 0.02620102830321191
# SNR [20dB], Validation Loss: 0.2186, Validation Accuracy: 92.9600, Validation MAE: 0.01274588269032681
# SNR [30dB], Validation Loss: 0.0707, Validation Accuracy: 97.4467, Validation MAE: 0.007074339825826388
# SNR [40dB], Validation Loss: 0.0423, Validation Accuracy: 98.6200, Validation MAE: 0.004430789985017324
#
#
# Epoch [35/60], Training Loss: 0.1042, Training Accuracy: 96.1374, Training MAE: 0.007119662946820397
# SNR [0dB], Validation Loss: 2.9685, Validation Accuracy: 42.5667, Validation MAE: 0.05761746184099635
# SNR [10dB], Validation Loss: 0.8679, Validation Accuracy: 77.5133, Validation MAE: 0.02569477771795112
# SNR [20dB], Validation Loss: 0.2214, Validation Accuracy: 92.7467, Validation MAE: 0.014700653736304898
# SNR [30dB], Validation Loss: 0.0762, Validation Accuracy: 97.3267, Validation MAE: 0.0073750175578237665
# SNR [40dB], Validation Loss: 0.0467, Validation Accuracy: 98.3133, Validation MAE: 0.006012823063957299
#
#
# Epoch [36/60], Training Loss: 0.1012, Training Accuracy: 96.2624, Training MAE: 0.0068240670296109635
# SNR [0dB], Validation Loss: 3.0616, Validation Accuracy: 42.7200, Validation MAE: 0.06209946214533196
# SNR [10dB], Validation Loss: 0.9144, Validation Accuracy: 76.7600, Validation MAE: 0.02653682168274183
# SNR [20dB], Validation Loss: 0.2284, Validation Accuracy: 92.5733, Validation MAE: 0.012600299068264818
# SNR [30dB], Validation Loss: 0.0755, Validation Accuracy: 97.3267, Validation MAE: 0.007150057940818429
# SNR [40dB], Validation Loss: 0.0456, Validation Accuracy: 98.5000, Validation MAE: 0.00541549126790898
#
#
# Epoch [37/60], Training Loss: 0.0983, Training Accuracy: 96.3668, Training MAE: 0.00670213696349731
# SNR [0dB], Validation Loss: 2.9733, Validation Accuracy: 41.9000, Validation MAE: 0.06095674044854387
# SNR [10dB], Validation Loss: 0.9303, Validation Accuracy: 75.8333, Validation MAE: 0.028607181735181196
# SNR [20dB], Validation Loss: 0.2528, Validation Accuracy: 91.7333, Validation MAE: 0.0129547476355464
# SNR [30dB], Validation Loss: 0.0941, Validation Accuracy: 96.5867, Validation MAE: 0.007430251545088491
# SNR [40dB], Validation Loss: 0.0604, Validation Accuracy: 97.7867, Validation MAE: 0.005590337929581421
#
#
# Epoch [38/60], Training Loss: 0.0933, Training Accuracy: 96.5409, Training MAE: 0.006489604278960184
# SNR [0dB], Validation Loss: 3.0940, Validation Accuracy: 42.3867, Validation MAE: 0.06030892990916752
# SNR [10dB], Validation Loss: 0.9115, Validation Accuracy: 77.2267, Validation MAE: 0.0282274937962356
# SNR [20dB], Validation Loss: 0.2362, Validation Accuracy: 92.3000, Validation MAE: 0.014450088959640416
# SNR [30dB], Validation Loss: 0.0850, Validation Accuracy: 96.8800, Validation MAE: 0.008064162140649873
# SNR [40dB], Validation Loss: 0.0544, Validation Accuracy: 98.1267, Validation MAE: 0.006081225419046727
#
#
# Epoch [39/60], Training Loss: 0.0906, Training Accuracy: 96.6365, Training MAE: 0.006408217909670463
# SNR [0dB], Validation Loss: 3.0886, Validation Accuracy: 42.6800, Validation MAE: 0.05914352935668134
# SNR [10dB], Validation Loss: 0.9272, Validation Accuracy: 76.9533, Validation MAE: 0.026564255782376627
# SNR [20dB], Validation Loss: 0.2365, Validation Accuracy: 92.1733, Validation MAE: 0.013401740565596029
# SNR [30dB], Validation Loss: 0.0821, Validation Accuracy: 96.8600, Validation MAE: 0.007804452664107126
# SNR [40dB], Validation Loss: 0.0524, Validation Accuracy: 97.7067, Validation MAE: 0.007219923447888379
#
#
# Epoch [40/60], Training Loss: 0.0880, Training Accuracy: 96.7485, Training MAE: 0.006199506913772721
# SNR [0dB], Validation Loss: 3.1444, Validation Accuracy: 42.3200, Validation MAE: 0.06249890263601461
# SNR [10dB], Validation Loss: 0.9356, Validation Accuracy: 77.4400, Validation MAE: 0.02725632666916378
# SNR [20dB], Validation Loss: 0.2342, Validation Accuracy: 92.7733, Validation MAE: 0.013345775002341043
# SNR [30dB], Validation Loss: 0.0792, Validation Accuracy: 97.0333, Validation MAE: 0.0067440332662234296
# SNR [40dB], Validation Loss: 0.0504, Validation Accuracy: 97.7933, Validation MAE: 0.005784937142990916
#
#
# Epoch [41/60], Training Loss: 0.0855, Training Accuracy: 96.8313, Training MAE: 0.0061346291994898595
# SNR [0dB], Validation Loss: 3.1135, Validation Accuracy: 42.3867, Validation MAE: 0.061080376790898026
# SNR [10dB], Validation Loss: 0.9304, Validation Accuracy: 77.1000, Validation MAE: 0.027074895823578988
# SNR [20dB], Validation Loss: 0.2282, Validation Accuracy: 92.9800, Validation MAE: 0.013267862159378219
# SNR [30dB], Validation Loss: 0.0827, Validation Accuracy: 97.1067, Validation MAE: 0.007577298319131005
# SNR [40dB], Validation Loss: 0.0559, Validation Accuracy: 98.0267, Validation MAE: 0.004867906639198427
#
#
# Epoch [42/60], Training Loss: 0.0828, Training Accuracy: 96.9216, Training MAE: 0.005696174921236817
# SNR [0dB], Validation Loss: 3.1282, Validation Accuracy: 42.0467, Validation MAE: 0.060879924969566436
# SNR [10dB], Validation Loss: 0.9518, Validation Accuracy: 76.5933, Validation MAE: 0.026434035256110124
# SNR [20dB], Validation Loss: 0.2383, Validation Accuracy: 92.6133, Validation MAE: 0.013738265521116209
# SNR [30dB], Validation Loss: 0.0803, Validation Accuracy: 97.0533, Validation MAE: 0.007392209593594906
# SNR [40dB], Validation Loss: 0.0510, Validation Accuracy: 98.1200, Validation MAE: 0.005442193791553516
#
#
# Epoch [43/60], Training Loss: 0.0796, Training Accuracy: 97.0289, Training MAE: 0.005601516633236857
# SNR [0dB], Validation Loss: 3.2390, Validation Accuracy: 42.3800, Validation MAE: 0.0608352988341605
# SNR [10dB], Validation Loss: 0.9782, Validation Accuracy: 76.9333, Validation MAE: 0.026611442433748477
# SNR [20dB], Validation Loss: 0.2355, Validation Accuracy: 92.8533, Validation MAE: 0.013261277975465868
# SNR [30dB], Validation Loss: 0.0707, Validation Accuracy: 97.4467, Validation MAE: 0.007215168203951681
# SNR [40dB], Validation Loss: 0.0389, Validation Accuracy: 98.6000, Validation MAE: 0.005086647860286544
#
#
# Epoch [44/60], Training Loss: 0.0779, Training Accuracy: 97.0965, Training MAE: 0.0055821352122799855
# SNR [0dB], Validation Loss: 3.1947, Validation Accuracy: 42.4400, Validation MAE: 0.06036050601648094
# SNR [10dB], Validation Loss: 0.9832, Validation Accuracy: 76.4200, Validation MAE: 0.026146525891937448
# SNR [20dB], Validation Loss: 0.2495, Validation Accuracy: 92.2200, Validation MAE: 0.013015102654742953
# SNR [30dB], Validation Loss: 0.0777, Validation Accuracy: 97.2600, Validation MAE: 0.007108723897368667
# SNR [40dB], Validation Loss: 0.0450, Validation Accuracy: 98.4133, Validation MAE: 0.0056166746652308265
#
#
# Epoch [45/60], Training Loss: 0.0766, Training Accuracy: 97.1774, Training MAE: 0.005534923058748558
# SNR [0dB], Validation Loss: 3.3698, Validation Accuracy: 42.7133, Validation MAE: 0.06004812306863939
# SNR [10dB], Validation Loss: 1.0326, Validation Accuracy: 77.0133, Validation MAE: 0.026446837835939693
# SNR [20dB], Validation Loss: 0.2446, Validation Accuracy: 92.7333, Validation MAE: 0.013907991150856822
# SNR [30dB], Validation Loss: 0.0753, Validation Accuracy: 97.2200, Validation MAE: 0.008452628991478603
# SNR [40dB], Validation Loss: 0.0456, Validation Accuracy: 98.2533, Validation MAE: 0.006984355979024253
#
#
# Epoch [46/60], Training Loss: 0.0740, Training Accuracy: 97.2478, Training MAE: 0.005229083976070302
# SNR [0dB], Validation Loss: 3.3523, Validation Accuracy: 42.0867, Validation MAE: 0.06046109771514187
# SNR [10dB], Validation Loss: 1.0327, Validation Accuracy: 76.5800, Validation MAE: 0.027551883369229327
# SNR [20dB], Validation Loss: 0.2533, Validation Accuracy: 92.3333, Validation MAE: 0.014836361082498362
# SNR [30dB], Validation Loss: 0.0833, Validation Accuracy: 97.0667, Validation MAE: 0.007135060633018073
# SNR [40dB], Validation Loss: 0.0490, Validation Accuracy: 98.1467, Validation MAE: 0.00531124168929675
#
#
# Epoch [47/60], Training Loss: 0.0729, Training Accuracy: 97.2633, Training MAE: 0.005162659387814356
# SNR [0dB], Validation Loss: 3.3276, Validation Accuracy: 42.3800, Validation MAE: 0.06143775166214065
# SNR [10dB], Validation Loss: 1.0272, Validation Accuracy: 77.0533, Validation MAE: 0.02743592857477292
# SNR [20dB], Validation Loss: 0.2486, Validation Accuracy: 92.7333, Validation MAE: 0.013548787339638543
# SNR [30dB], Validation Loss: 0.0749, Validation Accuracy: 97.4067, Validation MAE: 0.007117137021256672
# SNR [40dB], Validation Loss: 0.0435, Validation Accuracy: 98.4133, Validation MAE: 0.004390919093548085
#
#
# Epoch [48/60], Training Loss: 0.0703, Training Accuracy: 97.3864, Training MAE: 0.005101564365348026
# SNR [0dB], Validation Loss: 3.1749, Validation Accuracy: 41.9533, Validation MAE: 0.06312769219964416
# SNR [10dB], Validation Loss: 0.9717, Validation Accuracy: 76.9133, Validation MAE: 0.02859620809532728
# SNR [20dB], Validation Loss: 0.2416, Validation Accuracy: 92.6667, Validation MAE: 0.01333882503043356
# SNR [30dB], Validation Loss: 0.0883, Validation Accuracy: 96.6733, Validation MAE: 0.006948874543496582
# SNR [40dB], Validation Loss: 0.0595, Validation Accuracy: 97.3933, Validation MAE: 0.005158708095327278
#
#
# Epoch [49/60], Training Loss: 0.0680, Training Accuracy: 97.4602, Training MAE: 0.004969430130588401
# SNR [0dB], Validation Loss: 3.3745, Validation Accuracy: 43.0400, Validation MAE: 0.06249414739207791
# SNR [10dB], Validation Loss: 1.0296, Validation Accuracy: 77.0667, Validation MAE: 0.027050022239910106
# SNR [20dB], Validation Loss: 0.2535, Validation Accuracy: 92.5867, Validation MAE: 0.01301912632268939
# SNR [30dB], Validation Loss: 0.0807, Validation Accuracy: 97.1733, Validation MAE: 0.008878406217810657
# SNR [40dB], Validation Loss: 0.0457, Validation Accuracy: 98.2867, Validation MAE: 0.007893704934919
#
#
# Epoch [50/60], Training Loss: 0.0676, Training Accuracy: 97.4887, Training MAE: 0.004844744288993287
# SNR [0dB], Validation Loss: 3.3681, Validation Accuracy: 42.1133, Validation MAE: 0.059763540008427755
# SNR [10dB], Validation Loss: 1.0498, Validation Accuracy: 76.9267, Validation MAE: 0.02683749941473921
# SNR [20dB], Validation Loss: 0.2559, Validation Accuracy: 92.8400, Validation MAE: 0.01393579103848675
# SNR [30dB], Validation Loss: 0.0764, Validation Accuracy: 97.3533, Validation MAE: 0.007635458610356775
# SNR [40dB], Validation Loss: 0.0431, Validation Accuracy: 98.4933, Validation MAE: 0.005550832826107313
#
#
# Epoch [51/60], Training Loss: 0.0645, Training Accuracy: 97.6118, Training MAE: 0.004699858093161434
# SNR [0dB], Validation Loss: 3.3865, Validation Accuracy: 41.7467, Validation MAE: 0.061822194845022944
# SNR [10dB], Validation Loss: 1.0457, Validation Accuracy: 76.8133, Validation MAE: 0.02626504120235977
# SNR [20dB], Validation Loss: 0.2409, Validation Accuracy: 92.7333, Validation MAE: 0.013755823344882479
# SNR [30dB], Validation Loss: 0.0750, Validation Accuracy: 97.4067, Validation MAE: 0.006551262992789587
# SNR [40dB], Validation Loss: 0.0406, Validation Accuracy: 98.5400, Validation MAE: 0.003919052579829572
#
#
# Epoch [52/60], Training Loss: 0.0635, Training Accuracy: 97.6548, Training MAE: 0.004736190133117475
# SNR [0dB], Validation Loss: 3.4521, Validation Accuracy: 42.3400, Validation MAE: 0.06209507268939039
# SNR [10dB], Validation Loss: 1.1308, Validation Accuracy: 75.7933, Validation MAE: 0.02574196436932297
# SNR [20dB], Validation Loss: 0.3059, Validation Accuracy: 91.2867, Validation MAE: 0.012505925765521116
# SNR [30dB], Validation Loss: 0.1150, Validation Accuracy: 96.1867, Validation MAE: 0.007380870165745857
# SNR [40dB], Validation Loss: 0.0832, Validation Accuracy: 97.3200, Validation MAE: 0.005093963620189156
#
#
# Epoch [53/60], Training Loss: 0.0627, Training Accuracy: 97.6541, Training MAE: 0.00466752972701808
# SNR [0dB], Validation Loss: 3.3035, Validation Accuracy: 42.4467, Validation MAE: 0.05960625117052158
# SNR [10dB], Validation Loss: 1.0440, Validation Accuracy: 77.1800, Validation MAE: 0.026378069692855135
# SNR [20dB], Validation Loss: 0.2545, Validation Accuracy: 92.7733, Validation MAE: 0.012379363119205919
# SNR [30dB], Validation Loss: 0.0726, Validation Accuracy: 97.5333, Validation MAE: 0.006524926257140182
# SNR [40dB], Validation Loss: 0.0396, Validation Accuracy: 98.5533, Validation MAE: 0.004700741525423728
#
#
# Epoch [54/60], Training Loss: 0.0613, Training Accuracy: 97.7240, Training MAE: 0.004617938767292751
# SNR [0dB], Validation Loss: 3.4056, Validation Accuracy: 42.8133, Validation MAE: 0.06036928492836408
# SNR [10dB], Validation Loss: 1.0436, Validation Accuracy: 77.1467, Validation MAE: 0.02502245938290102
# SNR [20dB], Validation Loss: 0.2562, Validation Accuracy: 92.3600, Validation MAE: 0.013725828729281768
# SNR [30dB], Validation Loss: 0.0747, Validation Accuracy: 97.4133, Validation MAE: 0.006845722328869744
# SNR [40dB], Validation Loss: 0.0409, Validation Accuracy: 98.5400, Validation MAE: 0.0048946091628429625
#
#
# Epoch [55/60], Training Loss: 0.0596, Training Accuracy: 97.7732, Training MAE: 0.00438767552729944
# SNR [0dB], Validation Loss: 3.3246, Validation Accuracy: 42.2667, Validation MAE: 0.06462669140368948
# SNR [10dB], Validation Loss: 1.0486, Validation Accuracy: 76.7200, Validation MAE: 0.027160490214439555
# SNR [20dB], Validation Loss: 0.2659, Validation Accuracy: 92.3733, Validation MAE: 0.013264570067422043
# SNR [30dB], Validation Loss: 0.0799, Validation Accuracy: 97.2000, Validation MAE: 0.00636141902331679
# SNR [40dB], Validation Loss: 0.0475, Validation Accuracy: 98.0600, Validation MAE: 0.0054454858835096915
#
#
# Epoch [56/60], Training Loss: 0.0582, Training Accuracy: 97.8122, Training MAE: 0.004487117425569104
# SNR [0dB], Validation Loss: 3.4464, Validation Accuracy: 42.6600, Validation MAE: 0.06145055424197022
# SNR [10dB], Validation Loss: 1.0886, Validation Accuracy: 76.6733, Validation MAE: 0.026631926561475793
# SNR [20dB], Validation Loss: 0.2698, Validation Accuracy: 92.3200, Validation MAE: 0.013398082685644724
# SNR [30dB], Validation Loss: 0.0832, Validation Accuracy: 97.0667, Validation MAE: 0.007669842681899054
# SNR [40dB], Validation Loss: 0.0455, Validation Accuracy: 98.3533, Validation MAE: 0.005679590200393295
#
#
# Epoch [57/60], Training Loss: 0.0576, Training Accuracy: 97.8671, Training MAE: 0.004498010538085441
# SNR [0dB], Validation Loss: 3.4692, Validation Accuracy: 42.5400, Validation MAE: 0.06334021502481506
# SNR [10dB], Validation Loss: 1.0820, Validation Accuracy: 76.8067, Validation MAE: 0.026440253652027342
# SNR [20dB], Validation Loss: 0.2641, Validation Accuracy: 92.6133, Validation MAE: 0.013439050941099354
# SNR [30dB], Validation Loss: 0.0716, Validation Accuracy: 97.5400, Validation MAE: 0.007943086314261634
# SNR [40dB], Validation Loss: 0.0365, Validation Accuracy: 98.7733, Validation MAE: 0.005787863446951961
#
#
# Epoch [58/60], Training Loss: 0.0563, Training Accuracy: 97.9045, Training MAE: 0.004300231651526887
# SNR [0dB], Validation Loss: 3.3714, Validation Accuracy: 42.4933, Validation MAE: 0.062038741338140274
# SNR [10dB], Validation Loss: 1.0527, Validation Accuracy: 76.7800, Validation MAE: 0.02886981751568499
# SNR [20dB], Validation Loss: 0.2565, Validation Accuracy: 92.5667, Validation MAE: 0.013831907247869651
# SNR [30dB], Validation Loss: 0.0775, Validation Accuracy: 97.3467, Validation MAE: 0.006417018798576646
# SNR [40dB], Validation Loss: 0.0397, Validation Accuracy: 98.4867, Validation MAE: 0.005939299676936043
#
#
# Epoch [59/60], Training Loss: 0.0550, Training Accuracy: 97.9527, Training MAE: 0.004498283515845397
# SNR [0dB], Validation Loss: 3.5417, Validation Accuracy: 42.3200, Validation MAE: 0.06106830578705871
# SNR [10dB], Validation Loss: 1.0996, Validation Accuracy: 76.9133, Validation MAE: 0.02663595022942223
# SNR [20dB], Validation Loss: 0.2703, Validation Accuracy: 92.3800, Validation MAE: 0.01323347808783594
# SNR [30dB], Validation Loss: 0.0746, Validation Accuracy: 97.5867, Validation MAE: 0.007022397930517839
# SNR [40dB], Validation Loss: 0.0377, Validation Accuracy: 98.6867, Validation MAE: 0.004498094976121359
#
#
# Epoch [60/60], Training Loss: 0.0546, Training Accuracy: 97.9718, Training MAE: 0.004397099759488395
# SNR [0dB], Validation Loss: 3.5005, Validation Accuracy: 42.0200, Validation MAE: 0.06398692820020602
# SNR [10dB], Validation Loss: 1.1103, Validation Accuracy: 76.5067, Validation MAE: 0.027583706924805693
# SNR [20dB], Validation Loss: 0.2834, Validation Accuracy: 92.1267, Validation MAE: 0.012880858460530012
# SNR [30dB], Validation Loss: 0.0916, Validation Accuracy: 96.7467, Validation MAE: 0.008698438524206386
# SNR [40dB], Validation Loss: 0.0559, Validation Accuracy: 97.8600, Validation MAE: 0.006427626650435434
#
#
# Training Complete

# %%
max(acc_res[0]), max(acc_res[10]), max(acc_res[20]), max(acc_res[30]), max(acc_res[40])
min(mae_res[0]), min(mae_res[10]), min(mae_res[20]), min(mae_res[30]), min(mae_res[40])

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - 5")
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(acc_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()

# %%
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-1 ====
# = MAE =_= Acc =
# 0.0460   44.42
# 0.0207   76.86
# 0.0116   92.71
# 0.0064   97.20
# 0.0039   98.54
