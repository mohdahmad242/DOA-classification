# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((2, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Sequential(nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1))

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        # print("Input ==> ", x.size())
        out = F.relu(self.bn1(self.conv1(x)))
        # print("F.relu(self.bn1(self.conv1(x))) ==> ", x.size())
        out = self.layer1(out)
        # print("layer1 ==> ", x.size())
        out = self.layer2(out)
        # print("layer2 ==> ", x.size())
        out = self.layer3(out)
        # print("layer3 ==> ", x.size())
        out = self.layer4(out)
#         print("layer4 ==>", out.size())
        out = self.adp_pool(out)
#         print("avg_pool2d ===>", out.size())
        # out = out.view(out.size(0), -1)
        # print("out.view ===>", out.size())
        out = self.linear(out)
        out = self.flat(out)
#         print("Out ===>", out.size())
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    model(image)

# %%
train_dataset_list = []
test_dataset_list = []

# %%
df1  = sio.loadmat("../SNS_dataset/DOA2/SNR_SNS_00_2.mat")
df2  = sio.loadmat("../SNS_dataset/DOA2/SNR_SNS_10_2.mat")
df3  = sio.loadmat("../SNS_dataset/DOA2/SNR_SNS_20_2.mat")
df4  = sio.loadmat("../SNS_dataset/DOA2/SNR_SNS_30_2.mat")
df5  = sio.loadmat("../SNS_dataset/DOA2/SNR_SNS_40_2.mat")
df = [df1, df2, df3, df4, df5]

# %%
from sklearn.model_selection import train_test_split
new_train_dataset_list = []
new_test_dataset_list = []
train_dataset_list_label = []
test_dataset_list_label = []
def create_dataset(df):
    data = np.transpose(df['SNS_data'], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    new_train_dataset_list.extend(X_train)
    new_test_dataset_list.append(X_test.tolist())
    train_dataset_list_label.extend(y_train)
    test_dataset_list_label.append(y_test.tolist())
    
for file in df:
    create_dataset(file)

# %%
del df
del df1
del df2
del df3
del df4
del df5

# %%
for idx, data in enumerate(new_train_dataset_list):
    new = np.zeros((3, 8, 10))
    for j in range(0, data.shape[0]):
        for k in range(0, data.shape[1]):
            new[0][j][k] = data[j][k].real
            new[1][j][k] = data[j][k].imag
            new[2][j][k] = cmath.phase(data[j][k])
    new_train_dataset_list[idx] = new
    
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new = np.zeros((3, 8, 10))
        for j in range(0, 8):
            for k in range(0, 10):
                new[0][j][k] = ndata[j][k].real
                new[1][j][k] = ndata[j][k].imag
                new[2][j][k] = cmath.phase(ndata[j][k])
        new_test_dataset_list[idx][i] = new

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample

    dataset = DOA_dataset(train, test)

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
doa2_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

# %%
del new_train_dataset_list
del train_dataset_list_label

# %%
test_dataset_list = []
for idx, data in enumerate(new_test_dataset_list):
    print(type(data))
    f = get_data(data, test_dataset_list_label[idx], 128, False)
    test_dataset_list.append(f)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
del new_test_dataset_list
del new

# %%
num_epochs = 50
doa = 2
weights_dir = "./doa_weights/"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
    print("Pre-trained available for DOA_{}_model.pth".format(doa))
    autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa2_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, 2))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa2_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))

        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa2_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa2_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, 2))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss
            torch.save( model, weights_dir+ "/SNS_DOA_{}_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( model, weights_dir+ "/DOA_{}_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/50], Training Loss: 2.9383, Training Accuracy: 18.3528, Training MAE: 10.702742298179484
# SNR [0dB], Validation Loss: 3.1393, Validation Accuracy: 14.6567, Validation MAE: 21.96961325966851
# SNR [10dB], Validation Loss: 1.9961, Validation Accuracy: 31.5867, Validation MAE: 9.358975559509318
# SNR [20dB], Validation Loss: 1.5234, Validation Accuracy: 43.1000, Validation MAE: 5.400412023597715
# SNR [30dB], Validation Loss: 1.4003, Validation Accuracy: 46.9433, Validation MAE: 4.954490120797828
# SNR [40dB], Validation Loss: 1.3806, Validation Accuracy: 47.6433, Validation MAE: 4.735977151418672
#
#
# Epoch [2/50], Training Loss: 1.7631, Training Accuracy: 40.8158, Training MAE: 4.406380587360786
# SNR [0dB], Validation Loss: 3.0322, Validation Accuracy: 15.4433, Validation MAE: 20.26027717951119
# SNR [10dB], Validation Loss: 1.8463, Validation Accuracy: 36.9767, Validation MAE: 8.591581608764866
# SNR [20dB], Validation Loss: 1.2505, Validation Accuracy: 53.3733, Validation MAE: 5.02612604176421
# SNR [30dB], Validation Loss: 1.0766, Validation Accuracy: 59.0433, Validation MAE: 4.363423541530106
# SNR [40dB], Validation Loss: 1.0500, Validation Accuracy: 59.4633, Validation MAE: 4.4321097481037555
#
#
# Epoch [3/50], Training Loss: 1.5174, Training Accuracy: 49.5958, Training MAE: 4.022304102840134
# SNR [0dB], Validation Loss: 2.9473, Validation Accuracy: 16.3467, Validation MAE: 19.804007865905046
# SNR [10dB], Validation Loss: 1.7618, Validation Accuracy: 39.4867, Validation MAE: 8.197958610356775
# SNR [20dB], Validation Loss: 1.0509, Validation Accuracy: 60.3900, Validation MAE: 3.788322876673846
# SNR [30dB], Validation Loss: 0.7900, Validation Accuracy: 68.6767, Validation MAE: 2.997658956831164
# SNR [40dB], Validation Loss: 0.7521, Validation Accuracy: 70.1500, Validation MAE: 2.7294222305459312
#
#
# Epoch [4/50], Training Loss: 1.4048, Training Accuracy: 53.4235, Training MAE: 3.848335428415976
# SNR [0dB], Validation Loss: 2.9212, Validation Accuracy: 16.7433, Validation MAE: 19.81852233355183
# SNR [10dB], Validation Loss: 1.7026, Validation Accuracy: 40.5333, Validation MAE: 8.321987077441708
# SNR [20dB], Validation Loss: 1.0029, Validation Accuracy: 62.1533, Validation MAE: 4.74229796797453
# SNR [30dB], Validation Loss: 0.7692, Validation Accuracy: 69.9600, Validation MAE: 3.8660923307425787
# SNR [40dB], Validation Loss: 0.7274, Validation Accuracy: 71.4600, Validation MAE: 4.0499578612229605
#
#
# Epoch [5/50], Training Loss: 1.3348, Training Accuracy: 55.7431, Training MAE: 3.760729637834946
# SNR [0dB], Validation Loss: 2.9010, Validation Accuracy: 16.9567, Validation MAE: 19.694587508193653
# SNR [10dB], Validation Loss: 1.6815, Validation Accuracy: 41.9300, Validation MAE: 8.223195055716827
# SNR [20dB], Validation Loss: 0.8966, Validation Accuracy: 67.0833, Validation MAE: 4.354199831444892
# SNR [30dB], Validation Loss: 0.5690, Validation Accuracy: 78.0600, Validation MAE: 3.3541061897181383
# SNR [40dB], Validation Loss: 0.5017, Validation Accuracy: 80.7200, Validation MAE: 3.310609607641165
#
#
# Epoch [6/50], Training Loss: 1.2867, Training Accuracy: 57.3781, Training MAE: 3.696734915612955
# SNR [0dB], Validation Loss: 2.8816, Validation Accuracy: 17.1300, Validation MAE: 19.15095046352655
# SNR [10dB], Validation Loss: 1.6551, Validation Accuracy: 42.8733, Validation MAE: 7.869463432905703
# SNR [20dB], Validation Loss: 0.9264, Validation Accuracy: 66.6167, Validation MAE: 3.4882011424290664
# SNR [30dB], Validation Loss: 0.6249, Validation Accuracy: 76.1567, Validation MAE: 2.5826856447232887
# SNR [40dB], Validation Loss: 0.5734, Validation Accuracy: 77.9700, Validation MAE: 2.41918718981178
#
#
# Epoch [7/50], Training Loss: 1.2528, Training Accuracy: 58.5198, Training MAE: 3.625142988350453
# SNR [0dB], Validation Loss: 2.8638, Validation Accuracy: 17.2333, Validation MAE: 19.265802041389644
# SNR [10dB], Validation Loss: 1.6382, Validation Accuracy: 43.0033, Validation MAE: 7.974295346006181
# SNR [20dB], Validation Loss: 0.8525, Validation Accuracy: 68.4400, Validation MAE: 3.6914973312107877
# SNR [30dB], Validation Loss: 0.5075, Validation Accuracy: 79.7700, Validation MAE: 2.5230358647813467
# SNR [40dB], Validation Loss: 0.4304, Validation Accuracy: 82.5600, Validation MAE: 2.422745575428411
#
#
# Epoch [8/50], Training Loss: 1.2242, Training Accuracy: 59.4089, Training MAE: 3.570437621306117
# SNR [0dB], Validation Loss: 2.8758, Validation Accuracy: 17.3700, Validation MAE: 19.028467084933045
# SNR [10dB], Validation Loss: 1.6434, Validation Accuracy: 43.5900, Validation MAE: 7.7031089053282145
# SNR [20dB], Validation Loss: 0.8583, Validation Accuracy: 69.1067, Validation MAE: 3.8624403033991945
# SNR [30dB], Validation Loss: 0.5101, Validation Accuracy: 79.7133, Validation MAE: 3.065034179230265
# SNR [40dB], Validation Loss: 0.4398, Validation Accuracy: 81.8200, Validation MAE: 3.0746792770858695
#
#
# Epoch [9/50], Training Loss: 1.2045, Training Accuracy: 60.1162, Training MAE: 3.5243427527472484
# SNR [0dB], Validation Loss: 2.8690, Validation Accuracy: 17.4533, Validation MAE: 20.19917595280457
# SNR [10dB], Validation Loss: 1.6310, Validation Accuracy: 44.3300, Validation MAE: 8.600383931079689
# SNR [20dB], Validation Loss: 0.8402, Validation Accuracy: 70.0767, Validation MAE: 3.6078752692199645
# SNR [30dB], Validation Loss: 0.4611, Validation Accuracy: 82.4800, Validation MAE: 2.4695664388051317
# SNR [40dB], Validation Loss: 0.3846, Validation Accuracy: 84.7800, Validation MAE: 2.2754471392452476
#
#
# Epoch [10/50], Training Loss: 1.1847, Training Accuracy: 60.7340, Training MAE: 3.4987966100425867
# SNR [0dB], Validation Loss: 2.8545, Validation Accuracy: 17.4733, Validation MAE: 19.093454443299933
# SNR [10dB], Validation Loss: 1.6165, Validation Accuracy: 44.1000, Validation MAE: 7.864687704841277
# SNR [20dB], Validation Loss: 0.8084, Validation Accuracy: 70.6100, Validation MAE: 3.458797640228486
# SNR [30dB], Validation Loss: 0.4356, Validation Accuracy: 83.6700, Validation MAE: 2.248899709710647
# SNR [40dB], Validation Loss: 0.3665, Validation Accuracy: 85.7867, Validation MAE: 2.034366513718513
#
#
# Epoch [11/50], Training Loss: 1.1681, Training Accuracy: 61.2865, Training MAE: 3.4395156157837508
# SNR [0dB], Validation Loss: 2.8689, Validation Accuracy: 17.3567, Validation MAE: 19.54995786122296
# SNR [10dB], Validation Loss: 1.6062, Validation Accuracy: 43.9067, Validation MAE: 7.799466242157505
# SNR [20dB], Validation Loss: 0.8016, Validation Accuracy: 70.4533, Validation MAE: 3.7671130255641914
# SNR [30dB], Validation Loss: 0.4303, Validation Accuracy: 83.2133, Validation MAE: 2.859069201236071
# SNR [40dB], Validation Loss: 0.3462, Validation Accuracy: 86.1967, Validation MAE: 2.539189062646315
#
#
# Epoch [12/50], Training Loss: 1.1521, Training Accuracy: 61.8571, Training MAE: 3.40862098083145
# SNR [0dB], Validation Loss: 2.8660, Validation Accuracy: 17.4067, Validation MAE: 19.987873396385428
# SNR [10dB], Validation Loss: 1.5890, Validation Accuracy: 43.7300, Validation MAE: 8.177966101694915
# SNR [20dB], Validation Loss: 0.7715, Validation Accuracy: 71.0267, Validation MAE: 3.4098698379998127
# SNR [30dB], Validation Loss: 0.4180, Validation Accuracy: 83.8833, Validation MAE: 2.273152916939788
# SNR [40dB], Validation Loss: 0.3315, Validation Accuracy: 87.5233, Validation MAE: 1.9608109373536848
#
#
# Epoch [13/50], Training Loss: 1.1368, Training Accuracy: 62.2867, Training MAE: 3.367858797808025
# SNR [0dB], Validation Loss: 2.8649, Validation Accuracy: 17.2733, Validation MAE: 19.644863751287573
# SNR [10dB], Validation Loss: 1.5958, Validation Accuracy: 43.6333, Validation MAE: 7.748852888847271
# SNR [20dB], Validation Loss: 0.7635, Validation Accuracy: 71.2967, Validation MAE: 3.530012173424478
# SNR [30dB], Validation Loss: 0.3909, Validation Accuracy: 84.7367, Validation MAE: 2.385897555950932
# SNR [40dB], Validation Loss: 0.3056, Validation Accuracy: 87.9567, Validation MAE: 2.3719917595280458
#
#
# Epoch [14/50], Training Loss: 1.1216, Training Accuracy: 62.7780, Training MAE: 3.352290018227635
# SNR [0dB], Validation Loss: 2.8892, Validation Accuracy: 17.0333, Validation MAE: 19.34979867028748
# SNR [10dB], Validation Loss: 1.6082, Validation Accuracy: 43.6300, Validation MAE: 8.159705964977995
# SNR [20dB], Validation Loss: 0.8219, Validation Accuracy: 69.4900, Validation MAE: 3.495832943159472
# SNR [30dB], Validation Loss: 0.4978, Validation Accuracy: 79.9733, Validation MAE: 2.5901301620001873
# SNR [40dB], Validation Loss: 0.4249, Validation Accuracy: 82.5333, Validation MAE: 2.488060679838936
#
#
# Epoch [15/50], Training Loss: 1.1045, Training Accuracy: 63.3378, Training MAE: 3.2982576843499407
# SNR [0dB], Validation Loss: 2.9004, Validation Accuracy: 17.1800, Validation MAE: 20.236913568686205
# SNR [10dB], Validation Loss: 1.5949, Validation Accuracy: 43.9000, Validation MAE: 8.443534038767675
# SNR [20dB], Validation Loss: 0.7635, Validation Accuracy: 71.2600, Validation MAE: 4.300589942878546
# SNR [30dB], Validation Loss: 0.4089, Validation Accuracy: 83.9233, Validation MAE: 3.213362674407716
# SNR [40dB], Validation Loss: 0.3358, Validation Accuracy: 86.7900, Validation MAE: 3.0013109841745482
#
#
# Epoch [16/50], Training Loss: 1.0883, Training Accuracy: 63.8282, Training MAE: 3.264102707024253
# SNR [0dB], Validation Loss: 2.9192, Validation Accuracy: 17.0567, Validation MAE: 20.17487592471205
# SNR [10dB], Validation Loss: 1.5974, Validation Accuracy: 43.9333, Validation MAE: 8.1033804663358
# SNR [20dB], Validation Loss: 0.7352, Validation Accuracy: 72.5233, Validation MAE: 3.3802322314823487
# SNR [30dB], Validation Loss: 0.3608, Validation Accuracy: 86.2467, Validation MAE: 2.173986328307894
# SNR [40dB], Validation Loss: 0.2849, Validation Accuracy: 89.4833, Validation MAE: 1.9654930236913568
#
#
# Epoch [17/50], Training Loss: 1.0680, Training Accuracy: 64.4905, Training MAE: 3.2044282088249707
# SNR [0dB], Validation Loss: 2.9465, Validation Accuracy: 16.9700, Validation MAE: 19.933982582638823
# SNR [10dB], Validation Loss: 1.6023, Validation Accuracy: 43.8867, Validation MAE: 7.80925180260324
# SNR [20dB], Validation Loss: 0.7610, Validation Accuracy: 71.2733, Validation MAE: 3.5455098792021724
# SNR [30dB], Validation Loss: 0.3943, Validation Accuracy: 84.4033, Validation MAE: 2.389409120704186
# SNR [40dB], Validation Loss: 0.3146, Validation Accuracy: 87.8200, Validation MAE: 2.152636014608109
#
#
# Epoch [18/50], Training Loss: 1.0475, Training Accuracy: 65.0501, Training MAE: 3.141161427296195
# SNR [0dB], Validation Loss: 2.9836, Validation Accuracy: 16.7633, Validation MAE: 20.56264631519805
# SNR [10dB], Validation Loss: 1.6199, Validation Accuracy: 43.6767, Validation MAE: 8.185410618971813
# SNR [20dB], Validation Loss: 0.7487, Validation Accuracy: 71.7333, Validation MAE: 3.9055623185691544
# SNR [30dB], Validation Loss: 0.3770, Validation Accuracy: 85.4467, Validation MAE: 2.6372319505571684
# SNR [40dB], Validation Loss: 0.2866, Validation Accuracy: 88.4733, Validation MAE: 2.4908699316415395
#
#
# Epoch [19/50], Training Loss: 1.0221, Training Accuracy: 65.7467, Training MAE: 3.065696855545785
# SNR [0dB], Validation Loss: 3.0513, Validation Accuracy: 16.4300, Validation MAE: 21.288322876673845
# SNR [10dB], Validation Loss: 1.6423, Validation Accuracy: 43.5033, Validation MAE: 8.29239629178762
# SNR [20dB], Validation Loss: 0.7591, Validation Accuracy: 71.5700, Validation MAE: 3.4330461653712896
# SNR [30dB], Validation Loss: 0.3774, Validation Accuracy: 85.2733, Validation MAE: 2.120704185785186
# SNR [40dB], Validation Loss: 0.2842, Validation Accuracy: 88.5500, Validation MAE: 2.0024346848955896
#
#
# Epoch [20/50], Training Loss: 0.9939, Training Accuracy: 66.4916, Training MAE: 2.9668882656792186
# SNR [0dB], Validation Loss: 3.1481, Validation Accuracy: 16.4033, Validation MAE: 20.770530948590693
# SNR [10dB], Validation Loss: 1.6683, Validation Accuracy: 43.7200, Validation MAE: 8.390532821425227
# SNR [20dB], Validation Loss: 0.7697, Validation Accuracy: 72.3433, Validation MAE: 3.513765333832756
# SNR [30dB], Validation Loss: 0.3548, Validation Accuracy: 86.4100, Validation MAE: 2.646034272871992
# SNR [40dB], Validation Loss: 0.2595, Validation Accuracy: 89.7000, Validation MAE: 2.376486562412211
#
#
# Epoch [21/50], Training Loss: 0.9608, Training Accuracy: 67.5147, Training MAE: 2.871984765657172
# SNR [0dB], Validation Loss: 3.2546, Validation Accuracy: 16.0967, Validation MAE: 21.00814683022755
# SNR [10dB], Validation Loss: 1.6969, Validation Accuracy: 43.0200, Validation MAE: 8.185551081561943
# SNR [20dB], Validation Loss: 0.7708, Validation Accuracy: 71.6267, Validation MAE: 3.4108062552673473
# SNR [30dB], Validation Loss: 0.3654, Validation Accuracy: 85.8833, Validation MAE: 2.181337203858039
# SNR [40dB], Validation Loss: 0.2667, Validation Accuracy: 89.5767, Validation MAE: 2.0269219964416143
#
#
# Epoch [22/50], Training Loss: 0.9222, Training Accuracy: 68.5885, Training MAE: 2.7662902727988947
# SNR [0dB], Validation Loss: 3.4672, Validation Accuracy: 16.3500, Validation MAE: 21.913428223616442
# SNR [10dB], Validation Loss: 1.7549, Validation Accuracy: 43.8233, Validation MAE: 8.601741736117614
# SNR [20dB], Validation Loss: 0.8076, Validation Accuracy: 72.1000, Validation MAE: 3.459078565408746
# SNR [30dB], Validation Loss: 0.3878, Validation Accuracy: 85.3267, Validation MAE: 2.6185504260698567
# SNR [40dB], Validation Loss: 0.2831, Validation Accuracy: 88.6033, Validation MAE: 2.252270811873771
#
#
# Epoch [23/50], Training Loss: 0.8801, Training Accuracy: 69.7566, Training MAE: 2.6097322758920187
# SNR [0dB], Validation Loss: 3.5274, Validation Accuracy: 15.4700, Validation MAE: 21.788884727034368
# SNR [10dB], Validation Loss: 1.7650, Validation Accuracy: 42.4200, Validation MAE: 8.649452195898492
# SNR [20dB], Validation Loss: 0.7972, Validation Accuracy: 71.2267, Validation MAE: 3.6988482067609327
# SNR [30dB], Validation Loss: 0.3809, Validation Accuracy: 85.1967, Validation MAE: 2.529028935293567
# SNR [40dB], Validation Loss: 0.2818, Validation Accuracy: 88.8567, Validation MAE: 1.9753254050004683
#
#
# Epoch [24/50], Training Loss: 0.8325, Training Accuracy: 71.1684, Training MAE: 2.4652772289336045
# SNR [0dB], Validation Loss: 3.7880, Validation Accuracy: 15.0267, Validation MAE: 22.586571776383558
# SNR [10dB], Validation Loss: 1.8344, Validation Accuracy: 42.0267, Validation MAE: 8.77998876299279
# SNR [20dB], Validation Loss: 0.8069, Validation Accuracy: 71.1933, Validation MAE: 3.6512313887068077
# SNR [30dB], Validation Loss: 0.3869, Validation Accuracy: 84.9333, Validation MAE: 2.379998127165465
# SNR [40dB], Validation Loss: 0.2822, Validation Accuracy: 88.6900, Validation MAE: 1.9026594250397977
#
#
# Epoch [25/50], Training Loss: 0.7828, Training Accuracy: 72.5644, Training MAE: 2.304503831463843
# SNR [0dB], Validation Loss: 3.9347, Validation Accuracy: 15.3000, Validation MAE: 23.023878640322128
# SNR [10dB], Validation Loss: 1.8668, Validation Accuracy: 42.6867, Validation MAE: 8.790617098979306
# SNR [20dB], Validation Loss: 0.8405, Validation Accuracy: 71.9533, Validation MAE: 3.939366981927147
# SNR [30dB], Validation Loss: 0.4157, Validation Accuracy: 84.8633, Validation MAE: 2.634703623934825
# SNR [40dB], Validation Loss: 0.3132, Validation Accuracy: 87.9867, Validation MAE: 2.530339919468115
#
#
# Epoch [26/50], Training Loss: 0.7297, Training Accuracy: 74.2542, Training MAE: 2.1261500423037534
# SNR [0dB], Validation Loss: 4.3470, Validation Accuracy: 15.3767, Validation MAE: 21.839170334300963
# SNR [10dB], Validation Loss: 1.9908, Validation Accuracy: 43.1500, Validation MAE: 8.304616537128945
# SNR [20dB], Validation Loss: 0.8557, Validation Accuracy: 72.9100, Validation MAE: 3.605253300870868
# SNR [30dB], Validation Loss: 0.3798, Validation Accuracy: 86.5767, Validation MAE: 2.1262758685270158
# SNR [40dB], Validation Loss: 0.2574, Validation Accuracy: 89.8200, Validation MAE: 1.8601929019571122
#
#
# Epoch [27/50], Training Loss: 0.6757, Training Accuracy: 75.9579, Training MAE: 1.9501264952941755
# SNR [0dB], Validation Loss: 4.7287, Validation Accuracy: 14.9933, Validation MAE: 23.21589100103006
# SNR [10dB], Validation Loss: 2.0674, Validation Accuracy: 41.1900, Validation MAE: 9.137138308830416
# SNR [20dB], Validation Loss: 0.8587, Validation Accuracy: 70.6533, Validation MAE: 4.073883322408466
# SNR [30dB], Validation Loss: 0.3779, Validation Accuracy: 85.7433, Validation MAE: 2.3504073415113775
# SNR [40dB], Validation Loss: 0.2588, Validation Accuracy: 89.9933, Validation MAE: 2.0337578424946154
#
#
# Epoch [28/50], Training Loss: 0.6249, Training Accuracy: 77.6372, Training MAE: 1.804117398947273
# SNR [0dB], Validation Loss: 5.1665, Validation Accuracy: 14.8667, Validation MAE: 23.03450697630864
# SNR [10dB], Validation Loss: 2.2033, Validation Accuracy: 42.0867, Validation MAE: 8.72530199456878
# SNR [20dB], Validation Loss: 0.8968, Validation Accuracy: 71.2533, Validation MAE: 3.754096825545463
# SNR [30dB], Validation Loss: 0.3859, Validation Accuracy: 85.9033, Validation MAE: 2.3886131660267815
# SNR [40dB], Validation Loss: 0.2789, Validation Accuracy: 89.1300, Validation MAE: 1.9153946998782658
#
#
# Epoch [29/50], Training Loss: 0.5751, Training Accuracy: 79.3306, Training MAE: 1.649787316527748
# SNR [0dB], Validation Loss: 5.5100, Validation Accuracy: 15.3900, Validation MAE: 22.306629834254142
# SNR [10dB], Validation Loss: 2.3033, Validation Accuracy: 41.9467, Validation MAE: 8.764350594624965
# SNR [20dB], Validation Loss: 0.9082, Validation Accuracy: 71.7767, Validation MAE: 3.934684895589475
# SNR [30dB], Validation Loss: 0.3851, Validation Accuracy: 86.0833, Validation MAE: 2.4508380934544434
# SNR [40dB], Validation Loss: 0.2694, Validation Accuracy: 89.6133, Validation MAE: 1.8938102818615976
#
#
# Epoch [30/50], Training Loss: 0.5278, Training Accuracy: 80.9426, Training MAE: 1.496365704093356
# SNR [0dB], Validation Loss: 6.0614, Validation Accuracy: 14.4800, Validation MAE: 23.627118644067796
# SNR [10dB], Validation Loss: 2.4676, Validation Accuracy: 40.5100, Validation MAE: 9.065268283547148
# SNR [20dB], Validation Loss: 0.9557, Validation Accuracy: 69.5800, Validation MAE: 4.122811124637138
# SNR [30dB], Validation Loss: 0.4132, Validation Accuracy: 84.8200, Validation MAE: 2.434450791272591
# SNR [40dB], Validation Loss: 0.2952, Validation Accuracy: 88.6767, Validation MAE: 2.174829103848675
#
#
# Epoch [31/50], Training Loss: 0.4859, Training Accuracy: 82.4287, Training MAE: 1.3682073774085477
# SNR [0dB], Validation Loss: 6.3128, Validation Accuracy: 15.1067, Validation MAE: 23.069622623841184
# SNR [10dB], Validation Loss: 2.5767, Validation Accuracy: 42.1700, Validation MAE: 8.897977338702125
# SNR [20dB], Validation Loss: 0.9911, Validation Accuracy: 72.6600, Validation MAE: 3.525470549676936
# SNR [30dB], Validation Loss: 0.3747, Validation Accuracy: 87.5333, Validation MAE: 2.2556887349002714
# SNR [40dB], Validation Loss: 0.2338, Validation Accuracy: 91.1600, Validation MAE: 1.8446483753160408
#
#
# Epoch [32/50], Training Loss: 0.4467, Training Accuracy: 83.8426, Training MAE: 1.2707065849931074
# SNR [0dB], Validation Loss: 6.7319, Validation Accuracy: 14.8767, Validation MAE: 23.176795580110497
# SNR [10dB], Validation Loss: 2.7022, Validation Accuracy: 41.5300, Validation MAE: 8.82765240191029
# SNR [20dB], Validation Loss: 1.0322, Validation Accuracy: 70.4267, Validation MAE: 3.748384680213503
# SNR [30dB], Validation Loss: 0.4614, Validation Accuracy: 85.0300, Validation MAE: 2.3461934638074724
# SNR [40dB], Validation Loss: 0.3266, Validation Accuracy: 88.2867, Validation MAE: 1.9145987452008615
#
#
# Epoch [33/50], Training Loss: 0.4133, Training Accuracy: 85.0971, Training MAE: 1.1871980605996069
# SNR [0dB], Validation Loss: 7.1014, Validation Accuracy: 14.5900, Validation MAE: 23.961840996347973
# SNR [10dB], Validation Loss: 2.8433, Validation Accuracy: 41.0333, Validation MAE: 9.178293847738553
# SNR [20dB], Validation Loss: 1.0566, Validation Accuracy: 71.7533, Validation MAE: 3.7421106845210224
# SNR [30dB], Validation Loss: 0.4159, Validation Accuracy: 86.6367, Validation MAE: 2.415347879014889
# SNR [40dB], Validation Loss: 0.2671, Validation Accuracy: 89.9967, Validation MAE: 1.9382432812061055
#
#
# Epoch [34/50], Training Loss: 0.3811, Training Accuracy: 86.2404, Training MAE: 1.0969109524708802
# SNR [0dB], Validation Loss: 7.3770, Validation Accuracy: 14.4467, Validation MAE: 22.797172019852045
# SNR [10dB], Validation Loss: 2.9254, Validation Accuracy: 41.1533, Validation MAE: 9.323719449386648
# SNR [20dB], Validation Loss: 1.0582, Validation Accuracy: 70.9000, Validation MAE: 3.9357149545837626
# SNR [30dB], Validation Loss: 0.4037, Validation Accuracy: 86.5167, Validation MAE: 2.6079689109467177
# SNR [40dB], Validation Loss: 0.2606, Validation Accuracy: 90.3300, Validation MAE: 1.9941473920779098
#
#
# Epoch [35/50], Training Loss: 0.3520, Training Accuracy: 87.3247, Training MAE: 1.0218340611353711
# SNR [0dB], Validation Loss: 7.7915, Validation Accuracy: 15.2900, Validation MAE: 22.43660455098792
# SNR [10dB], Validation Loss: 3.0954, Validation Accuracy: 41.9567, Validation MAE: 8.72829852982489
# SNR [20dB], Validation Loss: 1.1017, Validation Accuracy: 72.0667, Validation MAE: 3.6018353778443672
# SNR [30dB], Validation Loss: 0.4154, Validation Accuracy: 86.9233, Validation MAE: 2.287620563723195
# SNR [40dB], Validation Loss: 0.2633, Validation Accuracy: 90.7200, Validation MAE: 1.8811218278865063
#
#
# Epoch [36/50], Training Loss: 0.3277, Training Accuracy: 88.2171, Training MAE: 0.9476282028350587
# SNR [0dB], Validation Loss: 7.9839, Validation Accuracy: 14.7667, Validation MAE: 23.620985110965446
# SNR [10dB], Validation Loss: 3.1605, Validation Accuracy: 41.1333, Validation MAE: 9.287433280269688
# SNR [20dB], Validation Loss: 1.1360, Validation Accuracy: 71.5867, Validation MAE: 4.150622717482911
# SNR [30dB], Validation Loss: 0.4359, Validation Accuracy: 86.4333, Validation MAE: 2.493585541717389
# SNR [40dB], Validation Loss: 0.2851, Validation Accuracy: 89.8300, Validation MAE: 2.0014514467646785
#
#
# Epoch [37/50], Training Loss: 0.3047, Training Accuracy: 89.0649, Training MAE: 0.8806792892969424
# SNR [0dB], Validation Loss: 8.4006, Validation Accuracy: 14.7367, Validation MAE: 23.225348815432156
# SNR [10dB], Validation Loss: 3.3655, Validation Accuracy: 40.9500, Validation MAE: 9.1775915347879
# SNR [20dB], Validation Loss: 1.1993, Validation Accuracy: 70.1300, Validation MAE: 4.206058619720948
# SNR [30dB], Validation Loss: 0.4837, Validation Accuracy: 84.9000, Validation MAE: 2.6591909354808503
# SNR [40dB], Validation Loss: 0.3221, Validation Accuracy: 88.8667, Validation MAE: 2.1888753628616913
#
#
# Epoch [38/50], Training Loss: 0.2869, Training Accuracy: 89.7239, Training MAE: 0.8442980613483458
# SNR [0dB], Validation Loss: 8.5326, Validation Accuracy: 14.7433, Validation MAE: 24.319786496863003
# SNR [10dB], Validation Loss: 3.4249, Validation Accuracy: 40.6567, Validation MAE: 9.437634609982208
# SNR [20dB], Validation Loss: 1.1972, Validation Accuracy: 70.4167, Validation MAE: 4.060164809439086
# SNR [30dB], Validation Loss: 0.4551, Validation Accuracy: 85.8233, Validation MAE: 2.5933139807098042
# SNR [40dB], Validation Loss: 0.2931, Validation Accuracy: 89.8800, Validation MAE: 2.032540500046821
#
#
# Epoch [39/50], Training Loss: 0.2682, Training Accuracy: 90.4269, Training MAE: 0.795313060254355
# SNR [0dB], Validation Loss: 8.7158, Validation Accuracy: 14.7400, Validation MAE: 23.423869276149453
# SNR [10dB], Validation Loss: 3.4981, Validation Accuracy: 40.9967, Validation MAE: 9.06465961232325
# SNR [20dB], Validation Loss: 1.2389, Validation Accuracy: 70.4733, Validation MAE: 3.799840809064519
# SNR [30dB], Validation Loss: 0.4609, Validation Accuracy: 86.1667, Validation MAE: 2.258778911883135
# SNR [40dB], Validation Loss: 0.2908, Validation Accuracy: 90.1800, Validation MAE: 1.8434778537316228
#
#
# Epoch [40/50], Training Loss: 0.2522, Training Accuracy: 91.0239, Training MAE: 0.7381435099719555
# SNR [0dB], Validation Loss: 9.1318, Validation Accuracy: 14.7367, Validation MAE: 23.933514374005057
# SNR [10dB], Validation Loss: 3.7036, Validation Accuracy: 41.8933, Validation MAE: 8.839217155164341
# SNR [20dB], Validation Loss: 1.3034, Validation Accuracy: 71.8300, Validation MAE: 3.7428129974716735
# SNR [30dB], Validation Loss: 0.4743, Validation Accuracy: 86.3500, Validation MAE: 2.393576177544714
# SNR [40dB], Validation Loss: 0.3011, Validation Accuracy: 89.9733, Validation MAE: 2.071729562693136
#
#
# Epoch [41/50], Training Loss: 0.2387, Training Accuracy: 91.5289, Training MAE: 0.7020834078605948
# SNR [0dB], Validation Loss: 9.0198, Validation Accuracy: 14.5300, Validation MAE: 24.15404064050941
# SNR [10dB], Validation Loss: 3.6776, Validation Accuracy: 40.6233, Validation MAE: 9.384399288322877
# SNR [20dB], Validation Loss: 1.3481, Validation Accuracy: 70.1067, Validation MAE: 4.108624403033992
# SNR [30dB], Validation Loss: 0.5845, Validation Accuracy: 83.8600, Validation MAE: 2.9344976121359676
# SNR [40dB], Validation Loss: 0.4247, Validation Accuracy: 87.0267, Validation MAE: 2.5842775540780973
#
#
# Epoch [42/50], Training Loss: 0.2259, Training Accuracy: 91.9859, Training MAE: 0.6692096061549674
# SNR [0dB], Validation Loss: 9.6046, Validation Accuracy: 14.8267, Validation MAE: 23.32437494147392
# SNR [10dB], Validation Loss: 3.8334, Validation Accuracy: 40.4833, Validation MAE: 9.14734525704654
# SNR [20dB], Validation Loss: 1.3197, Validation Accuracy: 70.4000, Validation MAE: 4.063723195055717
# SNR [30dB], Validation Loss: 0.4962, Validation Accuracy: 85.5900, Validation MAE: 2.477385522989044
# SNR [40dB], Validation Loss: 0.3322, Validation Accuracy: 89.1700, Validation MAE: 2.0897087742297966
#
#
# Epoch [43/50], Training Loss: 0.2135, Training Accuracy: 92.4758, Training MAE: 0.627165415579262
# SNR [0dB], Validation Loss: 9.5351, Validation Accuracy: 14.5100, Validation MAE: 23.268189905421856
# SNR [10dB], Validation Loss: 3.8721, Validation Accuracy: 40.4267, Validation MAE: 9.4094952710928
# SNR [20dB], Validation Loss: 1.3609, Validation Accuracy: 70.0533, Validation MAE: 4.164575334769173
# SNR [30dB], Validation Loss: 0.5446, Validation Accuracy: 84.3867, Validation MAE: 2.7452476823672627
# SNR [40dB], Validation Loss: 0.3815, Validation Accuracy: 87.9567, Validation MAE: 2.3766738458657177
#
#
# Epoch [44/50], Training Loss: 0.2013, Training Accuracy: 92.8876, Training MAE: 0.588645289890942
# SNR [0dB], Validation Loss: 9.5707, Validation Accuracy: 14.5300, Validation MAE: 23.58483940443862
# SNR [10dB], Validation Loss: 3.9272, Validation Accuracy: 40.3367, Validation MAE: 9.167712332615414
# SNR [20dB], Validation Loss: 1.3936, Validation Accuracy: 70.1067, Validation MAE: 4.308315385335706
# SNR [30dB], Validation Loss: 0.5452, Validation Accuracy: 84.9900, Validation MAE: 2.6700533757842493
# SNR [40dB], Validation Loss: 0.3706, Validation Accuracy: 88.6433, Validation MAE: 2.3706807753534975
#
#
# Epoch [45/50], Training Loss: 0.1936, Training Accuracy: 93.1787, Training MAE: 0.5771072219204157
# SNR [0dB], Validation Loss: 9.9678, Validation Accuracy: 14.5633, Validation MAE: 23.142803633299
# SNR [10dB], Validation Loss: 4.0863, Validation Accuracy: 40.0833, Validation MAE: 9.108109373536848
# SNR [20dB], Validation Loss: 1.4774, Validation Accuracy: 70.3500, Validation MAE: 3.937868714299092
# SNR [30dB], Validation Loss: 0.5327, Validation Accuracy: 85.6500, Validation MAE: 2.4762618222680026
# SNR [40dB], Validation Loss: 0.3476, Validation Accuracy: 89.4933, Validation MAE: 1.9499953179136624
#
#
# Epoch [46/50], Training Loss: 0.1840, Training Accuracy: 93.5586, Training MAE: 0.5477000817789373
# SNR [0dB], Validation Loss: 10.1740, Validation Accuracy: 14.6667, Validation MAE: 22.81070324936792
# SNR [10dB], Validation Loss: 4.1523, Validation Accuracy: 41.2667, Validation MAE: 9.186627961419608
# SNR [20dB], Validation Loss: 1.4373, Validation Accuracy: 71.7167, Validation MAE: 3.7216499672253955
# SNR [30dB], Validation Loss: 0.4965, Validation Accuracy: 86.9367, Validation MAE: 2.455567000655492
# SNR [40dB], Validation Loss: 0.3074, Validation Accuracy: 90.4367, Validation MAE: 2.0116583949808033
#
#
# Epoch [47/50], Training Loss: 0.1762, Training Accuracy: 93.8304, Training MAE: 0.5226564261356499
# SNR [0dB], Validation Loss: 10.2989, Validation Accuracy: 14.4133, Validation MAE: 23.48927802228673
# SNR [10dB], Validation Loss: 4.2535, Validation Accuracy: 40.2567, Validation MAE: 9.457439835190561
# SNR [20dB], Validation Loss: 1.5237, Validation Accuracy: 69.6000, Validation MAE: 4.066204700814683
# SNR [30dB], Validation Loss: 0.5904, Validation Accuracy: 84.8367, Validation MAE: 2.6542747448262944
# SNR [40dB], Validation Loss: 0.3975, Validation Accuracy: 88.6733, Validation MAE: 2.150294971439273
#
#
# Epoch [48/50], Training Loss: 0.1691, Training Accuracy: 94.0961, Training MAE: 0.49113451428885185
# SNR [0dB], Validation Loss: 10.1971, Validation Accuracy: 14.4833, Validation MAE: 23.58483940443862
# SNR [10dB], Validation Loss: 4.2404, Validation Accuracy: 40.1533, Validation MAE: 9.369837999812717
# SNR [20dB], Validation Loss: 1.4899, Validation Accuracy: 70.2667, Validation MAE: 3.9330461653712896
# SNR [30dB], Validation Loss: 0.5425, Validation Accuracy: 85.6800, Validation MAE: 2.576973499391329
# SNR [40dB], Validation Loss: 0.3426, Validation Accuracy: 89.5700, Validation MAE: 2.0753815900365202
#
#
# Epoch [49/50], Training Loss: 0.1615, Training Accuracy: 94.3827, Training MAE: 0.46884788202535566
# SNR [0dB], Validation Loss: 10.1858, Validation Accuracy: 14.2000, Validation MAE: 23.186534319692854
# SNR [10dB], Validation Loss: 4.2687, Validation Accuracy: 40.2467, Validation MAE: 9.31711770765053
# SNR [20dB], Validation Loss: 1.4970, Validation Accuracy: 70.5400, Validation MAE: 4.137278771420545
# SNR [30dB], Validation Loss: 0.5518, Validation Accuracy: 86.1233, Validation MAE: 2.5344133345818896
# SNR [40dB], Validation Loss: 0.3471, Validation Accuracy: 89.8500, Validation MAE: 2.2208071916846146
#
#
# Epoch [50/50], Training Loss: 0.1552, Training Accuracy: 94.6281, Training MAE: 0.45191722939948636
# SNR [0dB], Validation Loss: 10.3697, Validation Accuracy: 14.8600, Validation MAE: 23.668648749882948
# SNR [10dB], Validation Loss: 4.3491, Validation Accuracy: 41.3200, Validation MAE: 9.269219964416143
# SNR [20dB], Validation Loss: 1.5092, Validation Accuracy: 71.4267, Validation MAE: 3.9819739675999624
# SNR [30dB], Validation Loss: 0.5287, Validation Accuracy: 86.7833, Validation MAE: 2.6167244123981646
# SNR [40dB], Validation Loss: 0.3167, Validation Accuracy: 90.6667, Validation MAE: 2.0656896713175392
#
#
# Training Complete

# %% [markdown]
# # DOA 6 - SNS

# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(100, 80)
        self.linear1 = nn.Linear(80, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((6, 100))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.4)
        self.dropout1 = nn.Dropout(0.3)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        # print("Input ==> ", x.size())
        out = self.relu(self.bn1(self.conv1(x)))
        # print("F.relu(self.bn1(self.conv1(x))) ==> ", x.size())
        out = self.layer1(out)
        # print("layer1 ==> ", x.size())
        out = self.layer2(out)
        # print("layer2 ==> ", x.size())
        out = self.layer3(out)
        # print("layer3 ==> ", x.size())
        out = self.layer4(out)
        out = self.dropout(out)
#         print("layer4 ==>", out.size())
        out = self.adp_pool(out)
        
        out = self.linear(out)
        out = self.dropout1(out)
        out = F.relu(out)
        out = self.linear1(out)
        out = self.flat(out)
#         print("Out ===>", out.size())
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 6, 181])

# %%
train_dataset_list = []
test_dataset_list = []

# %%
df1  = sio.loadmat("../SNS_dataset/100/DOA6/SNR_SNS_00_6.mat")
df2  = sio.loadmat("../SNS_dataset/100/DOA6/SNR_SNS_10_6.mat")
df3  = sio.loadmat("../SNS_dataset/100/DOA6/SNR_SNS_20_6.mat")
df4  = sio.loadmat("../SNS_dataset/100/DOA6/SNR_SNS_30_6.mat")
df5  = sio.loadmat("../SNS_dataset/100/DOA6/SNR_SNS_40_6.mat")
df = [df1, df2, df3, df4, df5]

# %%
from sklearn.model_selection import train_test_split
new_train_dataset_list = []
new_test_dataset_list = []
train_dataset_list_label = []
test_dataset_list_label = []
def create_dataset(df):
    data = np.transpose(df['SNS_data'], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    new_train_dataset_list.extend(X_train)
    new_test_dataset_list.append(X_test.tolist())
    train_dataset_list_label.extend(y_train)
    test_dataset_list_label.append(y_test.tolist())
    
for file in df:
    create_dataset(file)

# %%
del df
del df1
del df2
del df3
del df4
del df5

# %%
for idx, data in enumerate(new_train_dataset_list):
    new = np.zeros((3, 8, 10))
    for j in range(0, data.shape[0]):
        for k in range(0, data.shape[1]):
            new[0][j][k] = data[j][k].real
            new[1][j][k] = data[j][k].imag
            new[2][j][k] = cmath.phase(data[j][k])
    new_train_dataset_list[idx] = new
    
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new = np.zeros((3, 8, 10))
        for j in range(0, 8):
            for k in range(0, 10):
                new[0][j][k] = ndata[j][k].real
                new[1][j][k] = ndata[j][k].imag
                new[2][j][k] = cmath.phase(ndata[j][k])
        new_test_dataset_list[idx][i] = new

# %%
# new_train_dataset_list.shape

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample

    dataset = DOA_dataset(train, test)

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
doa2_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

# %%
del new_train_dataset_list
del train_dataset_list_label

# %%
test_dataset_list = []
for idx, data in enumerate(new_test_dataset_list):
    print(type(data))
    f = get_data(data, test_dataset_list_label[idx], 128, False)
    test_dataset_list.append(f)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
del new_test_dataset_list
del new

# %%
# Saved_dataloader_dir = "./saved_dataloader/"
# doa = 6
# np.savez(Saved_dataloader_dir+ "/SNS_DOA_{}_trainloader.pth".format(doa), doa2_train_loader, test_dataset_list)

# %%
# model = torch.hub.load('pytorch/vision:v0.9.0', 'squeezenet1_0', pretrained=False)

# %%
num_epochs = 60
doa = 6
weights_dir = "./doa_weights/"
Saved_dataloader_dir = "./saved_dataloader/"

# torch.save( doa2_train_loader, Saved_dataloader_dir+ "/SNS_DOA_{}_trainloader.pth".format(doa))
steps = 20


autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()

# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-5)
#     exp_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma = 0.1)
    criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa2_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            # nn.utils.clip_grad_value_(classification_model.parameters(), clip_value=3.0)
            optimizer.step()
#             exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa2_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(128*len(doa2_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa2_train_loader), (100*(train_correct/train_total)), training_mae/(64*len(doa2_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(128*len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")

# 0.2599
# 0.2282
# 0.212
# 0.193
# 0.1659
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 3.9717, Training Accuracy: 7.0851, Training MAE: 1.0399039279471822
# SNR [0dB], Validation Loss: 4.4392, Validation Accuracy: 3.8122, Validation MAE: 1.1461516908184286
# SNR [10dB], Validation Loss: 3.6329, Validation Accuracy: 9.5300, Validation MAE: 0.7729440519945687
# SNR [20dB], Validation Loss: 3.1929, Validation Accuracy: 14.8244, Validation MAE: 0.6663684275213035
# SNR [30dB], Validation Loss: 3.0564, Validation Accuracy: 17.3144, Validation MAE: 0.6429898193885195
# SNR [40dB], Validation Loss: 3.0361, Validation Accuracy: 17.6933, Validation MAE: 0.6413357260745388
#
#
# Epoch [2/60], Training Loss: 3.3967, Training Accuracy: 14.3716, Training MAE: 0.8169389563493483
# SNR [0dB], Validation Loss: 4.3947, Validation Accuracy: 4.1489, Validation MAE: 1.0789864307285326
# SNR [10dB], Validation Loss: 3.5596, Validation Accuracy: 11.1144, Validation MAE: 0.7293593150107688
# SNR [20dB], Validation Loss: 3.0229, Validation Accuracy: 19.6722, Validation MAE: 0.6329028496347973
# SNR [30dB], Validation Loss: 2.8126, Validation Accuracy: 24.4700, Validation MAE: 0.6116995827090551
# SNR [40dB], Validation Loss: 2.7709, Validation Accuracy: 26.0367, Validation MAE: 0.6098977110450416
#
#
# Epoch [3/60], Training Loss: 3.2881, Training Accuracy: 17.6338, Training MAE: 0.8022339173982818
# SNR [0dB], Validation Loss: 4.3828, Validation Accuracy: 4.1400, Validation MAE: 1.0563218407622437
# SNR [10dB], Validation Loss: 3.5377, Validation Accuracy: 11.6633, Validation MAE: 0.7311048553235322
# SNR [20dB], Validation Loss: 2.9751, Validation Accuracy: 21.4967, Validation MAE: 0.640633413123888
# SNR [30dB], Validation Loss: 2.7272, Validation Accuracy: 27.6544, Validation MAE: 0.628662635195243
# SNR [40dB], Validation Loss: 2.6784, Validation Accuracy: 29.4478, Validation MAE: 0.6328223762758686

# %%
max(acc_res[0]), max(acc_res[10]), max(acc_res[20]), max(acc_res[30]), max(acc_res[40])
# Out:
# (7.274444444444445,
#  22.40111111111111,
#  46.23111111111111,
#  64.3288888888889,
#  70.13555555555556)

# %%
min(mae_res[0]), min(mae_res[10]), min(mae_res[20]), min(mae_res[30]), min(mae_res[40])
# Out:
# (0.7315145378780785,
#  0.2529270355370353,
#  0.09337835939694727,
#  0.04619975536098886,
#  0.03926441497331211)

# %%
import matplotlib.pyplot as plt
ep = range(0, len(acc_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - 5")
plt.legend(fontsize=14)
plt.savefig("DOA3_resnet34")
plt.show()
