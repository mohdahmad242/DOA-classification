# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath
import mat73

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "NS" # Sub-Nyquist or Nyquist sample
no_samples = 100
no_doa = 6

# %%
root_dataset_path =  ("../../datasets/100/DOA6")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.10, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, label, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(label))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, label)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
df1  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_0_6_100000.mat")

# %%
transp = np.transpose(df1['NS_data'], (2, 0, 1))
new = np.zeros((100000, 3, 8, 100))
for i in range(0, transp.shape[0]):
    for j in range(0, transp.shape[1]):
        for k in range(0, transp.shape[2]):
            new[i][0][j][k] = transp[i][j][k].real
            new[i][1][j][k] = transp[i][j][k].imag
            new[i][2][j][k] = cmath.phase(transp[i][j][k])

# %%
new.shape
# Out:
# (100000, 3, 8, 100)

# %%
new[0][2][7]
# Out:
# array([-3.05304301,  2.45123622,  2.53728555, -2.7911906 , -1.70906938,
#        -2.4472191 , -2.37130292, -1.85577411, -1.31098267, -0.42307692,
#        -1.36889332, -0.93089771,  0.12307016,  0.32595651,  0.365734  ,
#         0.28411599,  0.69692479,  2.25330789,  1.85328587,  1.46270947,
#         1.88636534,  1.82296085,  2.10865795,  2.13710762, -3.01677972,
#         1.72734545, -3.13457304, -2.41932838, -0.19189779, -2.0530364 ,
#        -2.45581969,  2.39257057, -0.41355023,  1.28737994,  2.82503939,
#         2.87568951, -2.65489372,  2.64606909, -2.76529496, -2.34578336,
#         0.10139584, -2.02494842, -1.42504432,  2.5582724 ,  2.38160463,
#        -0.1769003 , -0.18980297,  2.37701519, -1.92797034, -2.91080342,
#        -1.8599997 , -1.39792287, -1.58818982, -2.89937329, -0.0860637 ,
#        -1.10468397, -0.32905554,  0.70894542,  0.25246965,  0.09626797,
#         1.25474429,  3.10958563,  2.02844804,  2.38962328, -1.04506998,
#        -1.09488967,  0.42714803, -2.29407103, -0.85700904, -0.3878711 ,
#         0.43892455,  0.99868423,  1.73238132,  2.33067783,  2.42485745,
#         1.62804833,  2.90920788,  2.78983692,  3.07202676, -2.59302352,
#        -3.01287853,  1.08371973, -1.74029097,  0.14646229,  0.92323896,
#        -2.72004288,  2.47462991, -2.8406263 ,  3.00836275, -2.87823647,
#        -2.16174484,  0.52932128, -2.18237764, -1.30625909, -1.0960805 ,
#        -1.12900684, -0.40204234,  1.41683298,  1.79610136,  0.70571571])

# %%
a = (np.max(new[:,2,:,:]) - np.min(new[:,2,:,:]))
k = new[2]/a

# %%
k[0][0]
# Out:
# array([-0.00165588, -0.02217933,  0.01070128,  0.01137881,  0.01729746,
#         0.03578723,  0.00942878,  0.03594103,  0.03025375,  0.01906789,
#         0.01641902,  0.00066365,  0.01072174, -0.02023822, -0.0344483 ,
#        -0.00538524, -0.0243263 , -0.0301473 , -0.02696455, -0.03162282,
#        -0.004271  ,  0.00913837,  0.02158793,  0.02292515,  0.02968018,
#         0.02802117,  0.00272398,  0.02471635,  0.03475526, -0.00347539,
#        -0.00660656, -0.02521838,  0.00474822, -0.01698643,  0.00248033,
#        -0.00901578,  0.00352659,  0.00996662,  0.03033465,  0.02186368,
#         0.00591488, -0.02672437, -0.01046898, -0.01621644, -0.00379269,
#        -0.00037182, -0.01537781,  0.00711982, -0.03281743,  0.00111348,
#         0.00450632,  0.00784687,  0.00064737, -0.00151409, -0.02631006,
#         0.00022832, -0.0109346 , -0.0132783 ,  0.01486429,  0.02303386,
#         0.02221512,  0.02868811,  0.01884316, -0.00714312,  0.02949113,
#         0.02417609, -0.0096582 , -0.00340862, -0.01812632,  0.01339713,
#        -0.01170932, -0.00979488, -0.04159387, -0.00150092,  0.02097773,
#         0.02632997,  0.01889445,  0.00939358,  0.01164736, -0.01105368,
#        -0.01163106, -0.01061463, -0.02512404, -0.01460868, -0.03710965,
#        -0.02060224, -0.0197507 ,  0.00733098,  0.00555852,  0.01667944,
#         0.02153327,  0.02523377,  0.04556343,  0.0152604 ,  0.00036901,
#        -0.00259772,  0.00774188, -0.00047972, -0.0207114 , -0.0243501 ])

# %%
np.max(new[:,0,:,:]), np.min(new[:,0,:,:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-7634ec7d5653> in <module>
# ----> 1 np.max(new[:,0,:,:]), np.min(new[:,0,:,:])
#
# IndexError: too many indices for array: array is 3-dimensional, but 4 were indexed

# %%
df1  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_0_6_100000.mat")
# df2  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_10_6_100000.mat")
# df3  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_20_6_100000.mat")
# df4  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_30_6_100000.mat")
# df5  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_40_6_100000.mat")
df = [df1]

new_train_dataset_list = []
new_test_dataset_list = []
train_dataset_list_label = []
test_dataset_list_label = []

# dataset_len = 0
# if dataset_type == "SNS":
#     dataset_len = ss//10
# if dataset_type == "NS":
#     dataset_len = ss
dataset_len = 100
for file in df:
    X_train, X_test, y_train, y_test = create_dataset(file, "NS"+"_data")
    new_train_dataset_list.extend(X_train)
    new_test_dataset_list.append(X_test.tolist())
    train_dataset_list_label.extend(y_train)
    test_dataset_list_label.append(y_test.tolist())

# Deleteing all unused memory
del df

# Dividing into different channels
logging.info('Dividing your dataset into 3 channel')

for idx, data in enumerate(new_train_dataset_list):
    new = np.zeros((3, 8, dataset_len))
    for j in range(0, data.shape[0]):
        for k in range(0, data.shape[1]):
            new[0][j][k] = data[j][k].real
            new[1][j][k] = data[j][k].imag
            new[2][j][k] = cmath.phase(data[j][k])
    new_train_dataset_list[idx] = new
# Out:
# 2021-08-18 23:29:26,095 - Dividing your dataset into 3 channel

# %%
# new_train_dataset_list[1][2]

# %%
for idx, data in enumerate(new_train_dataset_list):
    new_train_dataset_list[idx][0] = new_train_dataset_list[idx][0]/(np.max(new_train_dataset_list[idx][0])) 
    new_train_dataset_list[idx][1] = new_train_dataset_list[idx][1]/(np.max(new_train_dataset_list[idx][1])) 
    new_train_dataset_list[idx][2] = new_train_dataset_list[idx][2]/(np.max(new_train_dataset_list[idx][2]))
#     print(new_train_dataset_list[idx])

# %%
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, 8):
            for k in range(0, dataset_len):
                new[0][j][k] = ndata[j][k].real
                new[1][j][k] = ndata[j][k].imag
                new[2][j][k] = cmath.phase(ndata[j][k])
        new_test_dataset_list[idx][i] = new

# %%
np.max(new_test_dataset_list[0][2][2])
# Out:
# 3.133351058316604

# %%
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new_test_dataset_list[idx][i][0] = new_test_dataset_list[idx][i][0]/(np.max(new_test_dataset_list[idx][i][0]))
        new_test_dataset_list[idx][i][1] = new_test_dataset_list[idx][i][1]/(np.max(new_test_dataset_list[idx][i][1]))
        new_test_dataset_list[idx][i][2] = new_test_dataset_list[idx][i][2]/(np.max(new_test_dataset_list[idx][i][2]))

# %%
np.max(new_test_dataset_list[0][2][2])
# Out:
# 1.0

# %%
np.min(new_test_dataset_list[0][2][2])
# Out:
# -0.9974660488668081

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
#     df1  = sio.loadmat(root_path + "/SNR_{}_00_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df1  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_0_6_100000.mat")
    df2  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_10_6_100000.mat")
    df3  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_20_6_100000.mat")
    df4  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_30_6_100000.mat")
    df5  = sio.loadmat("../../datasets/100/DOA6/SNR_NS_40_6_100000.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new
    print("Max bfore train", np.max(new_train_dataset_list[0][2]))
    for idx, data in enumerate(new_train_dataset_list):
        data[0] = data[0]/(np.max(data[0])) 
        data[1] = data[1]/(np.max(data[1])) 
        data[2] = data[2]/(np.max(data[2]))
        
    print("Max after train", np.max(new_train_dataset_list[0][2]))
    
    
    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new
            
    print("Max after test", np.min(new_test_dataset_list[0][2][2]))        
    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new_test_dataset_list[idx][i][0] = new_test_dataset_list[idx][i][0]/(np.max(new_test_dataset_list[idx][i][0]))
            new_test_dataset_list[idx][i][1] = new_test_dataset_list[idx][i][1]/(np.max(new_test_dataset_list[idx][i][1]))
            new_test_dataset_list[idx][i][2] = new_test_dataset_list[idx][i][2]/(np.max(new_test_dataset_list[idx][i][2]))
    print("Max after test", np.min(new_test_dataset_list[0][2][2]))
    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "NS", 100)
# Out:
# 2021-08-18 23:03:26,722 - Data prepration started
# 2021-08-18 23:04:11,379 - Dividing your dataset into 3 channel
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-077200871d63> in <module>
# ----> 1 doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "NS", 100)
#
# <ipython-input-34-24eaad24d09e> in create_dataloader(root_path, dataset_type, ss)
#      48
#      49     for idx, data in enumerate(new_train_dataset_list):
# ---> 50         data[0] = data[0]/(max(data[0]))
#      51         data[1] = data[1]/(max(data[1]))
#      52         data[2] = data[2]/(max(data[2]))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 6, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 70

weights_dir = "../doa_weights"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

# model = nn.Sequential( pre_trained, autoencoder)
# model = ConvAutoencoder()
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-4)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
#         criterion = None
#         if (i+1)>=25 :
#           print("Criterion is changed to focal loss")
#           criterion = focal_criterion.cuda()
#         else:
#           criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/70], Training Loss: 5.0998, Training Accuracy: 0.8550, Training MAE: 0.3137833774089813
# SNR [0dB], Validation Loss: 4.9722, Validation Accuracy: 1.0650, Validation MAE: 0.2572462260723114
# SNR [10dB], Validation Loss: 4.8438, Validation Accuracy: 1.2100, Validation MAE: 0.2533252239227295
# SNR [20dB], Validation Loss: 4.8234, Validation Accuracy: 1.3017, Validation MAE: 0.25709661841392517
# SNR [30dB], Validation Loss: 4.8191, Validation Accuracy: 1.2983, Validation MAE: 0.2551726698875427
# SNR [40dB], Validation Loss: 4.8198, Validation Accuracy: 1.2267, Validation MAE: 0.2559303939342499
#
#
# Epoch [2/70], Training Loss: 3.9749, Training Accuracy: 4.9456, Training MAE: 0.13658051192760468
# SNR [0dB], Validation Loss: 5.4619, Validation Accuracy: 1.0333, Validation MAE: 0.23451276123523712
# SNR [10dB], Validation Loss: 4.8107, Validation Accuracy: 1.8283, Validation MAE: 0.21182562410831451
# SNR [20dB], Validation Loss: 4.6217, Validation Accuracy: 1.9783, Validation MAE: 0.2038138210773468
# SNR [30dB], Validation Loss: 4.5892, Validation Accuracy: 2.2083, Validation MAE: 0.2003745138645172
# SNR [40dB], Validation Loss: 4.5903, Validation Accuracy: 2.0583, Validation MAE: 0.2005101442337036
#
#
# Epoch [3/70], Training Loss: 3.1971, Training Accuracy: 10.5708, Training MAE: 0.07284167408943176
# SNR [0dB], Validation Loss: 4.8409, Validation Accuracy: 2.7317, Validation MAE: 0.21528282761573792
# SNR [10dB], Validation Loss: 4.1226, Validation Accuracy: 5.4633, Validation MAE: 0.17832042276859283
# SNR [20dB], Validation Loss: 3.8878, Validation Accuracy: 6.5700, Validation MAE: 0.16519173979759216
# SNR [30dB], Validation Loss: 3.8393, Validation Accuracy: 6.8867, Validation MAE: 0.1605285406112671
# SNR [40dB], Validation Loss: 3.8345, Validation Accuracy: 6.7667, Validation MAE: 0.1608213633298874
#
#
# Epoch [4/70], Training Loss: 2.8219, Training Accuracy: 14.7745, Training MAE: 0.056036338210105896
# SNR [0dB], Validation Loss: 4.4591, Validation Accuracy: 4.1550, Validation MAE: 0.18588942289352417
# SNR [10dB], Validation Loss: 3.6853, Validation Accuracy: 8.6350, Validation MAE: 0.12830142676830292
# SNR [20dB], Validation Loss: 3.4054, Validation Accuracy: 10.8100, Validation MAE: 0.10881469398736954
# SNR [30dB], Validation Loss: 3.3537, Validation Accuracy: 11.1317, Validation MAE: 0.1035948097705841
# SNR [40dB], Validation Loss: 3.3478, Validation Accuracy: 11.2167, Validation MAE: 0.10366220027208328
#
#
# Epoch [5/70], Training Loss: 2.6038, Training Accuracy: 18.0509, Training MAE: 0.047268759459257126
# SNR [0dB], Validation Loss: 4.3342, Validation Accuracy: 4.9400, Validation MAE: 0.1765756756067276
# SNR [10dB], Validation Loss: 3.4729, Validation Accuracy: 11.1167, Validation MAE: 0.11038202792406082
# SNR [20dB], Validation Loss: 3.1577, Validation Accuracy: 14.3000, Validation MAE: 0.09002551436424255
# SNR [30dB], Validation Loss: 3.0966, Validation Accuracy: 15.3367, Validation MAE: 0.08588561415672302
# SNR [40dB], Validation Loss: 3.0916, Validation Accuracy: 15.1250, Validation MAE: 0.08400754630565643
#
#
# Epoch [6/70], Training Loss: 2.4569, Training Accuracy: 20.5849, Training MAE: 0.042072564363479614
# SNR [0dB], Validation Loss: 3.9896, Validation Accuracy: 6.7717, Validation MAE: 0.14053378999233246
# SNR [10dB], Validation Loss: 3.1557, Validation Accuracy: 13.7267, Validation MAE: 0.07541011273860931
# SNR [20dB], Validation Loss: 2.8280, Validation Accuracy: 18.0717, Validation MAE: 0.054268792271614075
# SNR [30dB], Validation Loss: 2.7656, Validation Accuracy: 18.9800, Validation MAE: 0.051198866218328476
# SNR [40dB], Validation Loss: 2.7566, Validation Accuracy: 18.9767, Validation MAE: 0.049512770026922226
#
#
# Epoch [7/70], Training Loss: 2.3491, Training Accuracy: 22.6079, Training MAE: 0.03860437124967575
# SNR [0dB], Validation Loss: 3.8554, Validation Accuracy: 8.3433, Validation MAE: 0.12422206252813339
# SNR [10dB], Validation Loss: 3.0148, Validation Accuracy: 16.6767, Validation MAE: 0.06320353597402573
# SNR [20dB], Validation Loss: 2.6881, Validation Accuracy: 20.8883, Validation MAE: 0.04344417154788971
# SNR [30dB], Validation Loss: 2.6238, Validation Accuracy: 22.1750, Validation MAE: 0.040369775146245956
# SNR [40dB], Validation Loss: 2.6160, Validation Accuracy: 22.2933, Validation MAE: 0.03877200931310654
#
#
# Epoch [8/70], Training Loss: 2.2611, Training Accuracy: 24.4411, Training MAE: 0.03604364022612572
# SNR [0dB], Validation Loss: 3.8170, Validation Accuracy: 8.8483, Validation MAE: 0.12075099349021912
# SNR [10dB], Validation Loss: 2.9652, Validation Accuracy: 18.2133, Validation MAE: 0.06194479763507843
# SNR [20dB], Validation Loss: 2.6237, Validation Accuracy: 23.6767, Validation MAE: 0.04313366487622261
# SNR [30dB], Validation Loss: 2.5555, Validation Accuracy: 24.7033, Validation MAE: 0.039551399648189545
# SNR [40dB], Validation Loss: 2.5461, Validation Accuracy: 25.1317, Validation MAE: 0.03803369030356407
#
#
# Epoch [9/70], Training Loss: 2.1916, Training Accuracy: 25.9282, Training MAE: 0.034032344818115234
# SNR [0dB], Validation Loss: 3.6740, Validation Accuracy: 10.1733, Validation MAE: 0.1035684123635292
# SNR [10dB], Validation Loss: 2.8260, Validation Accuracy: 20.9033, Validation MAE: 0.05054458975791931
# SNR [20dB], Validation Loss: 2.4864, Validation Accuracy: 27.5117, Validation MAE: 0.03375919163227081
# SNR [30dB], Validation Loss: 2.4174, Validation Accuracy: 28.9117, Validation MAE: 0.03119109384715557
# SNR [40dB], Validation Loss: 2.4089, Validation Accuracy: 29.1067, Validation MAE: 0.030182309448719025
#
#
# Epoch [10/70], Training Loss: 2.1307, Training Accuracy: 27.3783, Training MAE: 0.032476574182510376
# SNR [0dB], Validation Loss: 3.5945, Validation Accuracy: 11.8983, Validation MAE: 0.09449252486228943
# SNR [10dB], Validation Loss: 2.7299, Validation Accuracy: 24.5267, Validation MAE: 0.04219364374876022
# SNR [20dB], Validation Loss: 2.3636, Validation Accuracy: 32.2500, Validation MAE: 0.02539067715406418
# SNR [30dB], Validation Loss: 2.2861, Validation Accuracy: 34.4550, Validation MAE: 0.02345871366560459
# SNR [40dB], Validation Loss: 2.2760, Validation Accuracy: 34.3983, Validation MAE: 0.021949106827378273
#
#
# Epoch [11/70], Training Loss: 2.0790, Training Accuracy: 28.6683, Training MAE: 0.031108075752854347
# SNR [0dB], Validation Loss: 3.5729, Validation Accuracy: 11.1400, Validation MAE: 0.09810936450958252
# SNR [10dB], Validation Loss: 2.6861, Validation Accuracy: 22.8817, Validation MAE: 0.04549160599708557
# SNR [20dB], Validation Loss: 2.3178, Validation Accuracy: 30.0033, Validation MAE: 0.028900351375341415
# SNR [30dB], Validation Loss: 2.2385, Validation Accuracy: 32.2100, Validation MAE: 0.025792982429265976
# SNR [40dB], Validation Loss: 2.2295, Validation Accuracy: 32.2967, Validation MAE: 0.025289684534072876
#
#
# Epoch [12/70], Training Loss: 2.0325, Training Accuracy: 29.8218, Training MAE: 0.029978588223457336
# SNR [0dB], Validation Loss: 3.5629, Validation Accuracy: 11.5533, Validation MAE: 0.09389934688806534
# SNR [10dB], Validation Loss: 2.6748, Validation Accuracy: 23.7150, Validation MAE: 0.0419621504843235
# SNR [20dB], Validation Loss: 2.3067, Validation Accuracy: 31.3933, Validation MAE: 0.026109691709280014
# SNR [30dB], Validation Loss: 2.2303, Validation Accuracy: 33.1767, Validation MAE: 0.023630641400814056
# SNR [40dB], Validation Loss: 2.2186, Validation Accuracy: 33.4033, Validation MAE: 0.022942038252949715
#
#
# Epoch [13/70], Training Loss: 1.9914, Training Accuracy: 30.8641, Training MAE: 0.029017414897680283
# SNR [0dB], Validation Loss: 3.5478, Validation Accuracy: 11.7683, Validation MAE: 0.09702667593955994
# SNR [10dB], Validation Loss: 2.6499, Validation Accuracy: 24.8833, Validation MAE: 0.043828096240758896
# SNR [20dB], Validation Loss: 2.2658, Validation Accuracy: 33.2767, Validation MAE: 0.025918640196323395
# SNR [30dB], Validation Loss: 2.1799, Validation Accuracy: 35.3217, Validation MAE: 0.022555116564035416
# SNR [40dB], Validation Loss: 2.1666, Validation Accuracy: 35.9383, Validation MAE: 0.021276528015732765
#
#
# Epoch [14/70], Training Loss: 1.9550, Training Accuracy: 31.8591, Training MAE: 0.02815266326069832
# SNR [0dB], Validation Loss: 3.5195, Validation Accuracy: 12.9800, Validation MAE: 0.09065719693899155
# SNR [10dB], Validation Loss: 2.6350, Validation Accuracy: 26.2400, Validation MAE: 0.03951452672481537
# SNR [20dB], Validation Loss: 2.2562, Validation Accuracy: 34.1967, Validation MAE: 0.024069469422101974
# SNR [30dB], Validation Loss: 2.1711, Validation Accuracy: 36.7267, Validation MAE: 0.02118874527513981
# SNR [40dB], Validation Loss: 2.1587, Validation Accuracy: 37.1183, Validation MAE: 0.020536653697490692
#
#
# Epoch [15/70], Training Loss: 1.9211, Training Accuracy: 32.7649, Training MAE: 0.027453280985355377
# SNR [0dB], Validation Loss: 3.4978, Validation Accuracy: 12.3733, Validation MAE: 0.09171288460493088
# SNR [10dB], Validation Loss: 2.5731, Validation Accuracy: 25.5950, Validation MAE: 0.03889148309826851
# SNR [20dB], Validation Loss: 2.1809, Validation Accuracy: 34.9267, Validation MAE: 0.022165650501847267
# SNR [30dB], Validation Loss: 2.0928, Validation Accuracy: 36.8267, Validation MAE: 0.018018176779150963
# SNR [40dB], Validation Loss: 2.0809, Validation Accuracy: 37.2967, Validation MAE: 0.01813974604010582
#
#
# Epoch [16/70], Training Loss: 1.8920, Training Accuracy: 33.5970, Training MAE: 0.02674504742026329
# SNR [0dB], Validation Loss: 3.4190, Validation Accuracy: 13.3233, Validation MAE: 0.0858772024512291
# SNR [10dB], Validation Loss: 2.5308, Validation Accuracy: 27.1083, Validation MAE: 0.03692729398608208
# SNR [20dB], Validation Loss: 2.1588, Validation Accuracy: 35.6517, Validation MAE: 0.021731378510594368
# SNR [30dB], Validation Loss: 2.0746, Validation Accuracy: 37.9267, Validation MAE: 0.019183123484253883
# SNR [40dB], Validation Loss: 2.0625, Validation Accuracy: 38.1167, Validation MAE: 0.018325965851545334
#
#
# Epoch [17/70], Training Loss: 1.8654, Training Accuracy: 34.3482, Training MAE: 0.026157455518841743
# SNR [0dB], Validation Loss: 3.4477, Validation Accuracy: 12.7383, Validation MAE: 0.09030760824680328
# SNR [10dB], Validation Loss: 2.5210, Validation Accuracy: 26.3933, Validation MAE: 0.038941845297813416
# SNR [20dB], Validation Loss: 2.1236, Validation Accuracy: 35.9183, Validation MAE: 0.0218766201287508
# SNR [30dB], Validation Loss: 2.0311, Validation Accuracy: 38.3867, Validation MAE: 0.019135409966111183
# SNR [40dB], Validation Loss: 2.0181, Validation Accuracy: 38.8717, Validation MAE: 0.018141107633709908
#
#
# Epoch [18/70], Training Loss: 1.8367, Training Accuracy: 35.1845, Training MAE: 0.025632493197917938
# SNR [0dB], Validation Loss: 3.4037, Validation Accuracy: 13.5033, Validation MAE: 0.08470626920461655
# SNR [10dB], Validation Loss: 2.4916, Validation Accuracy: 28.0467, Validation MAE: 0.03497285768389702
# SNR [20dB], Validation Loss: 2.1031, Validation Accuracy: 37.6550, Validation MAE: 0.019735312089323997
# SNR [30dB], Validation Loss: 2.0118, Validation Accuracy: 40.0617, Validation MAE: 0.01637798547744751
# SNR [40dB], Validation Loss: 2.0005, Validation Accuracy: 40.5350, Validation MAE: 0.01576058939099312
#
#
# Epoch [19/70], Training Loss: 1.8126, Training Accuracy: 35.8974, Training MAE: 0.025150129571557045
# SNR [0dB], Validation Loss: 3.3995, Validation Accuracy: 13.2267, Validation MAE: 0.0885687842965126
# SNR [10dB], Validation Loss: 2.4576, Validation Accuracy: 27.8233, Validation MAE: 0.03619652986526489
# SNR [20dB], Validation Loss: 2.0644, Validation Accuracy: 37.5950, Validation MAE: 0.020183976739645004
# SNR [30dB], Validation Loss: 1.9727, Validation Accuracy: 40.1733, Validation MAE: 0.01680050790309906
# SNR [40dB], Validation Loss: 1.9643, Validation Accuracy: 40.3017, Validation MAE: 0.016576319932937622
#
#
# Epoch [20/70], Training Loss: 1.7900, Training Accuracy: 36.5465, Training MAE: 0.024571755900979042
# SNR [0dB], Validation Loss: 3.3979, Validation Accuracy: 13.4533, Validation MAE: 0.08737652003765106
# SNR [10dB], Validation Loss: 2.4516, Validation Accuracy: 27.6883, Validation MAE: 0.03647845983505249
# SNR [20dB], Validation Loss: 2.0464, Validation Accuracy: 37.8733, Validation MAE: 0.020436851307749748
# SNR [30dB], Validation Loss: 1.9528, Validation Accuracy: 40.3150, Validation MAE: 0.017718495801091194
# SNR [40dB], Validation Loss: 1.9425, Validation Accuracy: 40.7333, Validation MAE: 0.017073875293135643
#
#
# Epoch [21/70], Training Loss: 1.7693, Training Accuracy: 37.1809, Training MAE: 0.024258755147457123
# SNR [0dB], Validation Loss: 3.4538, Validation Accuracy: 13.0167, Validation MAE: 0.09424509853124619
# SNR [10dB], Validation Loss: 2.4762, Validation Accuracy: 27.9800, Validation MAE: 0.03816809877753258
# SNR [20dB], Validation Loss: 2.0476, Validation Accuracy: 37.8667, Validation MAE: 0.02076203189790249
# SNR [30dB], Validation Loss: 1.9496, Validation Accuracy: 41.0617, Validation MAE: 0.017300618812441826
# SNR [40dB], Validation Loss: 1.9370, Validation Accuracy: 41.3600, Validation MAE: 0.01710301637649536
#
#
# Epoch [22/70], Training Loss: 1.7483, Training Accuracy: 37.8258, Training MAE: 0.023828668519854546
# SNR [0dB], Validation Loss: 3.3588, Validation Accuracy: 13.5350, Validation MAE: 0.08341763913631439
# SNR [10dB], Validation Loss: 2.4190, Validation Accuracy: 28.0150, Validation MAE: 0.03434498608112335
# SNR [20dB], Validation Loss: 2.0157, Validation Accuracy: 38.0800, Validation MAE: 0.019255151972174644
# SNR [30dB], Validation Loss: 1.9152, Validation Accuracy: 41.4333, Validation MAE: 0.016014471650123596
# SNR [40dB], Validation Loss: 1.9040, Validation Accuracy: 41.9750, Validation MAE: 0.015630550682544708
#
#
# Epoch [23/70], Training Loss: 1.7300, Training Accuracy: 38.3413, Training MAE: 0.023433683440089226
# SNR [0dB], Validation Loss: 3.3756, Validation Accuracy: 13.7250, Validation MAE: 0.0858997106552124
# SNR [10dB], Validation Loss: 2.4176, Validation Accuracy: 28.3383, Validation MAE: 0.03403838723897934
# SNR [20dB], Validation Loss: 2.0060, Validation Accuracy: 38.1350, Validation MAE: 0.01813218928873539
# SNR [30dB], Validation Loss: 1.9052, Validation Accuracy: 40.8400, Validation MAE: 0.015073259361088276
# SNR [40dB], Validation Loss: 1.8900, Validation Accuracy: 41.6817, Validation MAE: 0.014488918706774712
#
#
# Epoch [24/70], Training Loss: 1.7103, Training Accuracy: 38.9384, Training MAE: 0.02300163172185421
# SNR [0dB], Validation Loss: 3.3647, Validation Accuracy: 13.7117, Validation MAE: 0.08288612961769104
# SNR [10dB], Validation Loss: 2.4153, Validation Accuracy: 27.9850, Validation MAE: 0.03448795527219772
# SNR [20dB], Validation Loss: 2.0094, Validation Accuracy: 37.4450, Validation MAE: 0.01851828396320343
# SNR [30dB], Validation Loss: 1.9073, Validation Accuracy: 40.7400, Validation MAE: 0.01556471735239029
# SNR [40dB], Validation Loss: 1.8961, Validation Accuracy: 40.8600, Validation MAE: 0.01548504177480936
#
#
# Epoch [25/70], Training Loss: 1.6946, Training Accuracy: 39.4257, Training MAE: 0.022654658183455467
# SNR [0dB], Validation Loss: 3.3461, Validation Accuracy: 13.7933, Validation MAE: 0.0798548012971878
# SNR [10dB], Validation Loss: 2.3956, Validation Accuracy: 27.9667, Validation MAE: 0.03186739608645439
# SNR [20dB], Validation Loss: 1.9901, Validation Accuracy: 37.2617, Validation MAE: 0.01736508682370186
# SNR [30dB], Validation Loss: 1.8883, Validation Accuracy: 40.6200, Validation MAE: 0.014627879485487938
# SNR [40dB], Validation Loss: 1.8754, Validation Accuracy: 40.9417, Validation MAE: 0.014719122089445591
#
#
# Epoch [26/70], Training Loss: 1.6779, Training Accuracy: 39.8843, Training MAE: 0.022232787683606148
# SNR [0dB], Validation Loss: 3.3262, Validation Accuracy: 13.7483, Validation MAE: 0.08125723898410797
# SNR [10dB], Validation Loss: 2.3739, Validation Accuracy: 28.4550, Validation MAE: 0.034005239605903625
# SNR [20dB], Validation Loss: 1.9591, Validation Accuracy: 37.6300, Validation MAE: 0.018874697387218475
# SNR [30dB], Validation Loss: 1.8549, Validation Accuracy: 40.7017, Validation MAE: 0.015634015202522278
# SNR [40dB], Validation Loss: 1.8408, Validation Accuracy: 41.3217, Validation MAE: 0.015656597912311554
#
#
# Epoch [27/70], Training Loss: 1.6624, Training Accuracy: 40.3719, Training MAE: 0.021999232470989227
# SNR [0dB], Validation Loss: 3.3324, Validation Accuracy: 13.8633, Validation MAE: 0.08467267453670502
# SNR [10dB], Validation Loss: 2.3614, Validation Accuracy: 28.2900, Validation MAE: 0.03355857729911804
# SNR [20dB], Validation Loss: 1.9373, Validation Accuracy: 37.9783, Validation MAE: 0.017666682600975037
# SNR [30dB], Validation Loss: 1.8283, Validation Accuracy: 41.1633, Validation MAE: 0.01451350562274456
# SNR [40dB], Validation Loss: 1.8174, Validation Accuracy: 41.4400, Validation MAE: 0.014189785346388817
#
#
# Epoch [28/70], Training Loss: 1.6464, Training Accuracy: 40.8367, Training MAE: 0.02160472795367241
# SNR [0dB], Validation Loss: 3.2986, Validation Accuracy: 13.9217, Validation MAE: 0.0804627314209938
# SNR [10dB], Validation Loss: 2.3448, Validation Accuracy: 28.4300, Validation MAE: 0.033009205013513565
# SNR [20dB], Validation Loss: 1.9375, Validation Accuracy: 37.8250, Validation MAE: 0.01795252598822117
# SNR [30dB], Validation Loss: 1.8346, Validation Accuracy: 40.7500, Validation MAE: 0.014611033722758293
# SNR [40dB], Validation Loss: 1.8220, Validation Accuracy: 41.0700, Validation MAE: 0.014529717154800892
#
#
# Epoch [29/70], Training Loss: 1.6334, Training Accuracy: 41.2168, Training MAE: 0.02139885351061821
# SNR [0dB], Validation Loss: 3.3141, Validation Accuracy: 13.9750, Validation MAE: 0.0842176303267479
# SNR [10dB], Validation Loss: 2.3638, Validation Accuracy: 28.2583, Validation MAE: 0.03445008024573326
# SNR [20dB], Validation Loss: 1.9549, Validation Accuracy: 37.2050, Validation MAE: 0.019519958645105362
# SNR [30dB], Validation Loss: 1.8508, Validation Accuracy: 40.3233, Validation MAE: 0.016214892268180847
# SNR [40dB], Validation Loss: 1.8381, Validation Accuracy: 40.4450, Validation MAE: 0.015962474048137665
#
#
# Epoch [30/70], Training Loss: 1.6210, Training Accuracy: 41.5714, Training MAE: 0.021148664876818657
# SNR [0dB], Validation Loss: 3.3556, Validation Accuracy: 13.5800, Validation MAE: 0.08208287507295609
# SNR [10dB], Validation Loss: 2.4037, Validation Accuracy: 28.4200, Validation MAE: 0.03499007225036621
# SNR [20dB], Validation Loss: 2.0039, Validation Accuracy: 37.5117, Validation MAE: 0.02177080698311329
# SNR [30dB], Validation Loss: 1.9093, Validation Accuracy: 40.7750, Validation MAE: 0.01906966045498848
# SNR [40dB], Validation Loss: 1.8961, Validation Accuracy: 41.0283, Validation MAE: 0.019528519362211227
#
#
# Epoch [31/70], Training Loss: 1.6047, Training Accuracy: 42.0194, Training MAE: 0.020730994641780853
# SNR [0dB], Validation Loss: 3.2950, Validation Accuracy: 13.6533, Validation MAE: 0.08080628514289856
# SNR [10dB], Validation Loss: 2.3383, Validation Accuracy: 27.7017, Validation MAE: 0.031796183437108994
# SNR [20dB], Validation Loss: 1.9251, Validation Accuracy: 36.4383, Validation MAE: 0.017657574266195297
# SNR [30dB], Validation Loss: 1.8217, Validation Accuracy: 39.4350, Validation MAE: 0.014924011193215847
# SNR [40dB], Validation Loss: 1.8076, Validation Accuracy: 40.0817, Validation MAE: 0.014701091684401035
#
#
# Epoch [32/70], Training Loss: 1.5924, Training Accuracy: 42.4373, Training MAE: 0.02048969455063343
# SNR [0dB], Validation Loss: 3.2838, Validation Accuracy: 14.0700, Validation MAE: 0.08099398016929626
# SNR [10dB], Validation Loss: 2.3143, Validation Accuracy: 28.3250, Validation MAE: 0.03151371330022812
# SNR [20dB], Validation Loss: 1.8977, Validation Accuracy: 37.4217, Validation MAE: 0.017046740278601646
# SNR [30dB], Validation Loss: 1.7923, Validation Accuracy: 40.7350, Validation MAE: 0.014145435765385628
# SNR [40dB], Validation Loss: 1.7790, Validation Accuracy: 41.0933, Validation MAE: 0.013986173085868359
#
#
# Epoch [33/70], Training Loss: 1.5791, Training Accuracy: 42.7998, Training MAE: 0.020264148712158203
# SNR [0dB], Validation Loss: 3.3045, Validation Accuracy: 13.7517, Validation MAE: 0.08045488595962524
# SNR [10dB], Validation Loss: 2.3268, Validation Accuracy: 28.2533, Validation MAE: 0.032219260931015015
# SNR [20dB], Validation Loss: 1.8965, Validation Accuracy: 37.9933, Validation MAE: 0.017277302220463753
# SNR [30dB], Validation Loss: 1.7847, Validation Accuracy: 41.3017, Validation MAE: 0.014836229383945465
# SNR [40dB], Validation Loss: 1.7721, Validation Accuracy: 41.8433, Validation MAE: 0.014348686672747135
#
#
# Epoch [34/70], Training Loss: 1.5678, Training Accuracy: 43.1407, Training MAE: 0.019947458058595657
# SNR [0dB], Validation Loss: 3.3163, Validation Accuracy: 13.3967, Validation MAE: 0.08322396874427795
# SNR [10dB], Validation Loss: 2.3370, Validation Accuracy: 27.5567, Validation MAE: 0.03364727646112442
# SNR [20dB], Validation Loss: 1.9109, Validation Accuracy: 37.4783, Validation MAE: 0.018661344423890114
# SNR [30dB], Validation Loss: 1.7995, Validation Accuracy: 40.7350, Validation MAE: 0.015848372131586075
# SNR [40dB], Validation Loss: 1.7836, Validation Accuracy: 41.1417, Validation MAE: 0.015276050195097923
#
#
# Epoch [35/70], Training Loss: 1.5580, Training Accuracy: 43.4349, Training MAE: 0.019680572673678398
# SNR [0dB], Validation Loss: 3.2924, Validation Accuracy: 13.9433, Validation MAE: 0.0782281830906868
# SNR [10dB], Validation Loss: 2.3098, Validation Accuracy: 28.2783, Validation MAE: 0.03149040788412094
# SNR [20dB], Validation Loss: 1.8852, Validation Accuracy: 37.9650, Validation MAE: 0.018121350556612015
# SNR [30dB], Validation Loss: 1.7757, Validation Accuracy: 41.5950, Validation MAE: 0.01585502177476883
# SNR [40dB], Validation Loss: 1.7624, Validation Accuracy: 41.7850, Validation MAE: 0.015460090711712837
#
#
# Epoch [36/70], Training Loss: 1.5450, Training Accuracy: 43.8243, Training MAE: 0.0194160845130682
# SNR [0dB], Validation Loss: 3.3022, Validation Accuracy: 13.5767, Validation MAE: 0.08257079124450684
# SNR [10dB], Validation Loss: 2.3058, Validation Accuracy: 28.5200, Validation MAE: 0.03181758522987366
# SNR [20dB], Validation Loss: 1.8743, Validation Accuracy: 39.0183, Validation MAE: 0.017952430993318558
# SNR [30dB], Validation Loss: 1.7601, Validation Accuracy: 42.7483, Validation MAE: 0.014305432327091694
# SNR [40dB], Validation Loss: 1.7465, Validation Accuracy: 42.9450, Validation MAE: 0.014385111629962921
# Epoch    36: reducing learning rate of group 0 to 5.0000e-05.
#
#
# Epoch [37/70], Training Loss: 1.3370, Training Accuracy: 50.7891, Training MAE: 0.015509754419326782
# SNR [0dB], Validation Loss: 3.2095, Validation Accuracy: 14.0700, Validation MAE: 0.08461648970842361
# SNR [10dB], Validation Loss: 2.1449, Validation Accuracy: 29.5383, Validation MAE: 0.03247431665658951
# SNR [20dB], Validation Loss: 1.6749, Validation Accuracy: 41.0900, Validation MAE: 0.017276307567954063
# SNR [30dB], Validation Loss: 1.5425, Validation Accuracy: 45.6500, Validation MAE: 0.014121401123702526
# SNR [40dB], Validation Loss: 1.5255, Validation Accuracy: 46.2383, Validation MAE: 0.013662902638316154
#
#
# Epoch [38/70], Training Loss: 1.2937, Training Accuracy: 52.0992, Training MAE: 0.014655391685664654
# SNR [0dB], Validation Loss: 3.2153, Validation Accuracy: 14.1983, Validation MAE: 0.0854150727391243
# SNR [10dB], Validation Loss: 2.1395, Validation Accuracy: 29.9033, Validation MAE: 0.03271007537841797
# SNR [20dB], Validation Loss: 1.6638, Validation Accuracy: 41.6550, Validation MAE: 0.017354799434542656
# SNR [30dB], Validation Loss: 1.5308, Validation Accuracy: 46.2983, Validation MAE: 0.014020957984030247
# SNR [40dB], Validation Loss: 1.5141, Validation Accuracy: 46.6383, Validation MAE: 0.013730382546782494
#
#
# Epoch [39/70], Training Loss: 1.2763, Training Accuracy: 52.6522, Training MAE: 0.014215073548257351
# SNR [0dB], Validation Loss: 3.2245, Validation Accuracy: 14.0100, Validation MAE: 0.08627195656299591
# SNR [10dB], Validation Loss: 2.1441, Validation Accuracy: 29.4817, Validation MAE: 0.0334290973842144
# SNR [20dB], Validation Loss: 1.6697, Validation Accuracy: 41.0783, Validation MAE: 0.017695272341370583
# SNR [30dB], Validation Loss: 1.5348, Validation Accuracy: 45.8917, Validation MAE: 0.014724770560860634
# SNR [40dB], Validation Loss: 1.5169, Validation Accuracy: 46.2500, Validation MAE: 0.014302699826657772
#
#
# Epoch [40/70], Training Loss: 1.2638, Training Accuracy: 53.0080, Training MAE: 0.013970553874969482
# SNR [0dB], Validation Loss: 3.2217, Validation Accuracy: 14.1350, Validation MAE: 0.08541565388441086
# SNR [10dB], Validation Loss: 2.1390, Validation Accuracy: 29.6667, Validation MAE: 0.03258349746465683
# SNR [20dB], Validation Loss: 1.6621, Validation Accuracy: 41.4467, Validation MAE: 0.017095180228352547
# SNR [30dB], Validation Loss: 1.5255, Validation Accuracy: 46.4283, Validation MAE: 0.014168022200465202
# SNR [40dB], Validation Loss: 1.5083, Validation Accuracy: 46.7833, Validation MAE: 0.014090710319578648
#
#
# Epoch [41/70], Training Loss: 1.2549, Training Accuracy: 53.3014, Training MAE: 0.013816781342029572
# SNR [0dB], Validation Loss: 3.2270, Validation Accuracy: 14.0833, Validation MAE: 0.08669111877679825
# SNR [10dB], Validation Loss: 2.1367, Validation Accuracy: 29.8117, Validation MAE: 0.03333248198032379
# SNR [20dB], Validation Loss: 1.6548, Validation Accuracy: 41.6717, Validation MAE: 0.017496857792139053
# SNR [30dB], Validation Loss: 1.5165, Validation Accuracy: 46.8083, Validation MAE: 0.014162556268274784
# SNR [40dB], Validation Loss: 1.4989, Validation Accuracy: 47.1683, Validation MAE: 0.01413797214627266
# Epoch    41: reducing learning rate of group 0 to 2.5000e-06.
#
#
# Epoch [42/70], Training Loss: 1.2380, Training Accuracy: 53.7991, Training MAE: 0.013453192077577114
# SNR [0dB], Validation Loss: 3.2258, Validation Accuracy: 14.1283, Validation MAE: 0.08565293252468109
# SNR [10dB], Validation Loss: 2.1267, Validation Accuracy: 29.8083, Validation MAE: 0.032947931438684464
# SNR [20dB], Validation Loss: 1.6427, Validation Accuracy: 41.6933, Validation MAE: 0.017346328124403954
# SNR [30dB], Validation Loss: 1.5048, Validation Accuracy: 46.7583, Validation MAE: 0.014086978510022163
# SNR [40dB], Validation Loss: 1.4875, Validation Accuracy: 47.0400, Validation MAE: 0.014158186502754688
#
#
# Epoch [43/70], Training Loss: 1.2365, Training Accuracy: 53.8855, Training MAE: 0.013388378545641899
# SNR [0dB], Validation Loss: 3.2281, Validation Accuracy: 14.0317, Validation MAE: 0.08682999014854431
# SNR [10dB], Validation Loss: 2.1321, Validation Accuracy: 29.7333, Validation MAE: 0.033134058117866516
# SNR [20dB], Validation Loss: 1.6483, Validation Accuracy: 41.5533, Validation MAE: 0.0174065213650465
# SNR [30dB], Validation Loss: 1.5102, Validation Accuracy: 46.3767, Validation MAE: 0.014240597374737263
# SNR [40dB], Validation Loss: 1.4927, Validation Accuracy: 46.8517, Validation MAE: 0.014096269384026527
#
#
# Epoch [44/70], Training Loss: 1.2362, Training Accuracy: 53.9104, Training MAE: 0.013362501747906208
# SNR [0dB], Validation Loss: 3.2247, Validation Accuracy: 14.2583, Validation MAE: 0.08583177626132965
# SNR [10dB], Validation Loss: 2.1301, Validation Accuracy: 29.6067, Validation MAE: 0.03319806605577469
# SNR [20dB], Validation Loss: 1.6486, Validation Accuracy: 41.3000, Validation MAE: 0.01767478697001934
# SNR [30dB], Validation Loss: 1.5076, Validation Accuracy: 46.1767, Validation MAE: 0.014440477825701237
# SNR [40dB], Validation Loss: 1.4898, Validation Accuracy: 46.5567, Validation MAE: 0.014367809519171715
#
#
# Epoch [45/70], Training Loss: 1.2355, Training Accuracy: 53.9423, Training MAE: 0.013356481678783894
# SNR [0dB], Validation Loss: 3.2298, Validation Accuracy: 14.0983, Validation MAE: 0.0864180400967598
# SNR [10dB], Validation Loss: 2.1291, Validation Accuracy: 29.7800, Validation MAE: 0.03341726213693619
# SNR [20dB], Validation Loss: 1.6440, Validation Accuracy: 41.6450, Validation MAE: 0.017538834363222122
# SNR [30dB], Validation Loss: 1.5046, Validation Accuracy: 46.4883, Validation MAE: 0.014200806617736816
# SNR [40dB], Validation Loss: 1.4870, Validation Accuracy: 46.8900, Validation MAE: 0.014271188527345657
# Epoch    45: reducing learning rate of group 0 to 1.2500e-07.
#
#
# Epoch [46/70], Training Loss: 1.2342, Training Accuracy: 53.9577, Training MAE: 0.013328170403838158
# SNR [0dB], Validation Loss: 3.2264, Validation Accuracy: 14.0817, Validation MAE: 0.08626551926136017
# SNR [10dB], Validation Loss: 2.1329, Validation Accuracy: 29.5917, Validation MAE: 0.0333145372569561
# SNR [20dB], Validation Loss: 1.6500, Validation Accuracy: 41.3050, Validation MAE: 0.017540106549859047
# SNR [30dB], Validation Loss: 1.5113, Validation Accuracy: 46.1933, Validation MAE: 0.014367354102432728
# SNR [40dB], Validation Loss: 1.4936, Validation Accuracy: 46.6333, Validation MAE: 0.014289222657680511
#
#
# Epoch [47/70], Training Loss: 1.2344, Training Accuracy: 53.9415, Training MAE: 0.013292421586811543
# SNR [0dB], Validation Loss: 3.2245, Validation Accuracy: 14.1433, Validation MAE: 0.0856148824095726
# SNR [10dB], Validation Loss: 2.1266, Validation Accuracy: 29.6533, Validation MAE: 0.032955121248960495
# SNR [20dB], Validation Loss: 1.6447, Validation Accuracy: 41.3650, Validation MAE: 0.017658306285738945
# SNR [30dB], Validation Loss: 1.5069, Validation Accuracy: 46.3833, Validation MAE: 0.014270010404288769
# SNR [40dB], Validation Loss: 1.4895, Validation Accuracy: 46.7550, Validation MAE: 0.014232496730983257
#
#
# Epoch [48/70], Training Loss: 1.2338, Training Accuracy: 54.0022, Training MAE: 0.01336322445422411
# SNR [0dB], Validation Loss: 3.2294, Validation Accuracy: 14.1283, Validation MAE: 0.08709652721881866
# SNR [10dB], Validation Loss: 2.1355, Validation Accuracy: 29.6483, Validation MAE: 0.03356487303972244
# SNR [20dB], Validation Loss: 1.6529, Validation Accuracy: 41.5517, Validation MAE: 0.017537375912070274
# SNR [30dB], Validation Loss: 1.5134, Validation Accuracy: 46.5983, Validation MAE: 0.014399683102965355
# SNR [40dB], Validation Loss: 1.4955, Validation Accuracy: 46.9083, Validation MAE: 0.014236042276024818
#
#
# Epoch [49/70], Training Loss: 1.2337, Training Accuracy: 54.0024, Training MAE: 0.013376411981880665
# SNR [0dB], Validation Loss: 3.2259, Validation Accuracy: 14.0917, Validation MAE: 0.08563282340765
# SNR [10dB], Validation Loss: 2.1252, Validation Accuracy: 29.5967, Validation MAE: 0.03302651643753052
# SNR [20dB], Validation Loss: 1.6412, Validation Accuracy: 41.5450, Validation MAE: 0.0173613540828228
# SNR [30dB], Validation Loss: 1.5024, Validation Accuracy: 46.4850, Validation MAE: 0.014018317684531212
# SNR [40dB], Validation Loss: 1.4848, Validation Accuracy: 46.8683, Validation MAE: 0.014048279263079166
# Epoch    49: reducing learning rate of group 0 to 6.2500e-09.
#
#
# Epoch [50/70], Training Loss: 1.2335, Training Accuracy: 54.0091, Training MAE: 0.013338202610611916
# SNR [0dB], Validation Loss: 3.2282, Validation Accuracy: 14.1500, Validation MAE: 0.08595834672451019
# SNR [10dB], Validation Loss: 2.1214, Validation Accuracy: 29.8017, Validation MAE: 0.033203717321157455
# SNR [20dB], Validation Loss: 1.6328, Validation Accuracy: 41.9367, Validation MAE: 0.017347419634461403
# SNR [30dB], Validation Loss: 1.4940, Validation Accuracy: 46.9400, Validation MAE: 0.01411902904510498
# SNR [40dB], Validation Loss: 1.4767, Validation Accuracy: 47.2900, Validation MAE: 0.014077963307499886
#
#
# Epoch [51/70], Training Loss: 1.2338, Training Accuracy: 53.9257, Training MAE: 0.013330288231372833
# SNR [0dB], Validation Loss: 3.2207, Validation Accuracy: 14.2617, Validation MAE: 0.08575885742902756
# SNR [10dB], Validation Loss: 2.1199, Validation Accuracy: 29.9500, Validation MAE: 0.033046089112758636
# SNR [20dB], Validation Loss: 1.6354, Validation Accuracy: 41.9000, Validation MAE: 0.017281679436564445
# SNR [30dB], Validation Loss: 1.4948, Validation Accuracy: 46.9667, Validation MAE: 0.014138699509203434
# SNR [40dB], Validation Loss: 1.4770, Validation Accuracy: 47.4300, Validation MAE: 0.01391742005944252
#
#
# Epoch [52/70], Training Loss: 1.2341, Training Accuracy: 53.9832, Training MAE: 0.013357697054743767
# SNR [0dB], Validation Loss: 3.2284, Validation Accuracy: 14.1850, Validation MAE: 0.08655507862567902
# SNR [10dB], Validation Loss: 2.1262, Validation Accuracy: 29.9500, Validation MAE: 0.033436745405197144
# SNR [20dB], Validation Loss: 1.6404, Validation Accuracy: 41.8983, Validation MAE: 0.017395958304405212
# SNR [30dB], Validation Loss: 1.5009, Validation Accuracy: 46.9800, Validation MAE: 0.014198347926139832
# SNR [40dB], Validation Loss: 1.4832, Validation Accuracy: 47.2583, Validation MAE: 0.014101638458669186
#
#
# Epoch [53/70], Training Loss: 1.2341, Training Accuracy: 54.0068, Training MAE: 0.013317761942744255
# SNR [0dB], Validation Loss: 3.2257, Validation Accuracy: 14.1750, Validation MAE: 0.0852862223982811
# SNR [10dB], Validation Loss: 2.1289, Validation Accuracy: 29.5833, Validation MAE: 0.03300347179174423
# SNR [20dB], Validation Loss: 1.6447, Validation Accuracy: 41.3067, Validation MAE: 0.017483286559581757
# SNR [30dB], Validation Loss: 1.5053, Validation Accuracy: 46.3017, Validation MAE: 0.01412986870855093
# SNR [40dB], Validation Loss: 1.4877, Validation Accuracy: 46.7517, Validation MAE: 0.014134512282907963
#
#
# Epoch [54/70], Training Loss: 1.2335, Training Accuracy: 54.0139, Training MAE: 0.013364487327635288
# SNR [0dB], Validation Loss: 3.2246, Validation Accuracy: 14.1783, Validation MAE: 0.08621607720851898
# SNR [10dB], Validation Loss: 2.1265, Validation Accuracy: 29.7500, Validation MAE: 0.03327483683824539
# SNR [20dB], Validation Loss: 1.6429, Validation Accuracy: 41.5750, Validation MAE: 0.01745314709842205
# SNR [30dB], Validation Loss: 1.5034, Validation Accuracy: 46.7167, Validation MAE: 0.014194793999195099
# SNR [40dB], Validation Loss: 1.4862, Validation Accuracy: 46.9633, Validation MAE: 0.0142166493460536
#
#
# Epoch [55/70], Training Loss: 1.2339, Training Accuracy: 54.0144, Training MAE: 0.013362257741391659
# SNR [0dB], Validation Loss: 3.2341, Validation Accuracy: 14.0467, Validation MAE: 0.08775071799755096
# SNR [10dB], Validation Loss: 2.1335, Validation Accuracy: 29.7200, Validation MAE: 0.03365975245833397
# SNR [20dB], Validation Loss: 1.6469, Validation Accuracy: 41.5633, Validation MAE: 0.017696185037493706
# SNR [30dB], Validation Loss: 1.5073, Validation Accuracy: 46.6350, Validation MAE: 0.014233040623366833
# SNR [40dB], Validation Loss: 1.4898, Validation Accuracy: 46.9083, Validation MAE: 0.014269283972680569
#
#
# Epoch [56/70], Training Loss: 1.2342, Training Accuracy: 53.9654, Training MAE: 0.013309895992279053
# SNR [0dB], Validation Loss: 3.2262, Validation Accuracy: 14.1800, Validation MAE: 0.08673383295536041
# SNR [10dB], Validation Loss: 2.1239, Validation Accuracy: 29.8833, Validation MAE: 0.03354327753186226
# SNR [20dB], Validation Loss: 1.6374, Validation Accuracy: 42.1067, Validation MAE: 0.017448410391807556
# SNR [30dB], Validation Loss: 1.4984, Validation Accuracy: 47.2000, Validation MAE: 0.01404135674238205
# SNR [40dB], Validation Loss: 1.4813, Validation Accuracy: 47.4517, Validation MAE: 0.01413742359727621
#
#
# Epoch [57/70], Training Loss: 1.2339, Training Accuracy: 54.0055, Training MAE: 0.01339404284954071
# SNR [0dB], Validation Loss: 3.2320, Validation Accuracy: 14.1350, Validation MAE: 0.08664422482252121
# SNR [10dB], Validation Loss: 2.1297, Validation Accuracy: 29.7450, Validation MAE: 0.03346315026283264
# SNR [20dB], Validation Loss: 1.6433, Validation Accuracy: 41.5650, Validation MAE: 0.01747162826359272
# SNR [30dB], Validation Loss: 1.5041, Validation Accuracy: 46.5800, Validation MAE: 0.014179135672748089
# SNR [40dB], Validation Loss: 1.4866, Validation Accuracy: 46.9300, Validation MAE: 0.01412130706012249
#
#
# Epoch [58/70], Training Loss: 1.2345, Training Accuracy: 53.9741, Training MAE: 0.013312011957168579
# SNR [0dB], Validation Loss: 3.2296, Validation Accuracy: 14.0817, Validation MAE: 0.08774089068174362
# SNR [10dB], Validation Loss: 2.1289, Validation Accuracy: 29.8017, Validation MAE: 0.03402353823184967
# SNR [20dB], Validation Loss: 1.6430, Validation Accuracy: 41.9233, Validation MAE: 0.017998240888118744
# SNR [30dB], Validation Loss: 1.5043, Validation Accuracy: 46.9167, Validation MAE: 0.014580436050891876
# SNR [40dB], Validation Loss: 1.4870, Validation Accuracy: 47.0750, Validation MAE: 0.01442918460816145
#
#
# Epoch [59/70], Training Loss: 1.2336, Training Accuracy: 54.0253, Training MAE: 0.0133625203743577
# SNR [0dB], Validation Loss: 3.2203, Validation Accuracy: 14.2417, Validation MAE: 0.08503217250108719
# SNR [10dB], Validation Loss: 2.1184, Validation Accuracy: 29.8883, Validation MAE: 0.0328027680516243
# SNR [20dB], Validation Loss: 1.6315, Validation Accuracy: 41.8567, Validation MAE: 0.017144719138741493
# SNR [30dB], Validation Loss: 1.4915, Validation Accuracy: 46.9017, Validation MAE: 0.014062302187085152
# SNR [40dB], Validation Loss: 1.4741, Validation Accuracy: 47.2083, Validation MAE: 0.013967234641313553
#
#
# Epoch [60/70], Training Loss: 1.2335, Training Accuracy: 54.0319, Training MAE: 0.01331425178796053
# SNR [0dB], Validation Loss: 3.2308, Validation Accuracy: 14.1250, Validation MAE: 0.08652292191982269
# SNR [10dB], Validation Loss: 2.1285, Validation Accuracy: 29.8183, Validation MAE: 0.03357861191034317
# SNR [20dB], Validation Loss: 1.6435, Validation Accuracy: 41.6483, Validation MAE: 0.017627252265810966
# SNR [30dB], Validation Loss: 1.5047, Validation Accuracy: 46.6350, Validation MAE: 0.014258810319006443
# SNR [40dB], Validation Loss: 1.4871, Validation Accuracy: 46.9567, Validation MAE: 0.014166017062962055

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-1 ====
# = MAE =_= Acc =
# 0.0672   28.42
# 0.0301   64.16
# 0.0145   86.54
# 0.0068   96.48
# 0.0032   98.93

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-004af10bd35a> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 ep = range(0, len(loss_res["training"]))
#       3 plt.figure(figsize=(10, 8))
#       4 plt.plot(ep, loss_res["training"], label='Train')
#       5 plt.plot(ep, loss_res[0], label='0 dB')
#
# NameError: name 'loss_res' is not defined

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
