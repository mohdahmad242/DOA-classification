# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 300
no_doa = 4

# %%
root_dataset_path =  ("../../SNS_dataset/300/DOA4")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.10, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, label, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(label))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, label)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_{}_0_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df1  = sio.loadmat("../../SNS_dataset/100/DOA5/SNR_SNS_00_5.mat")
#     df2  = sio.loadmat("../../SNS_dataset/100/DOA5/SNR_SNS_10_5.mat")
#     df3  = sio.loadmat("../../SNS_dataset/100/DOA5/SNR_SNS_20_5.mat")
#     df4  = sio.loadmat("../../SNS_dataset/100/DOA5/SNR_SNS_30_5.mat")
#     df5  = sio.loadmat("../../SNS_dataset/100/DOA5/SNR_SNS_40_5.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 300)
# Out:
# 2021-07-04 05:24:08,930 - Data prepration started
# 2021-07-04 05:24:24,255 - Dividing your dataset into 3 channel
# 2021-07-04 05:29:06,147 - Creating Train dataloader
# 2021-07-04 05:29:07,507 - Creating Validation dataloader
# 2021-07-04 05:29:07,640 - Your dataset is ready !!

# %%
for j,(features, labels) in enumerate(doa_train_loader, 0):
    features, labels = Variable(features.cuda()), Variable(labels.cuda())
    print(features.size())
    print(labels.size())
    break
# Out:
# torch.Size([64, 3, 8, 30])
# torch.Size([64, 4])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 4, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 40

weights_dir = "../doa_weights"

autoencoder = ResNet34()
cross_criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

# model = nn.Sequential( pre_trained, autoencoder)
# model = ConvAutoencoder()
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-5)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/40], Training Loss: 5.2111, Training Accuracy: 0.5697, Training MAE: 0.33462953567504883
# SNR [0dB], Validation Loss: 4.9466, Validation Accuracy: 1.2550, Validation MAE: 0.264752596616745
# SNR [10dB], Validation Loss: 4.8166, Validation Accuracy: 1.6275, Validation MAE: 0.2430834174156189
# SNR [20dB], Validation Loss: 4.7914, Validation Accuracy: 1.7775, Validation MAE: 0.2399471253156662
# SNR [30dB], Validation Loss: 4.7874, Validation Accuracy: 1.7125, Validation MAE: 0.24172036349773407
# SNR [40dB], Validation Loss: 4.7866, Validation Accuracy: 1.7850, Validation MAE: 0.23855334520339966
#
#
# Epoch [2/40], Training Loss: 2.8374, Training Accuracy: 15.4833, Training MAE: 0.06119022145867348
# SNR [0dB], Validation Loss: 4.3163, Validation Accuracy: 6.7125, Validation MAE: 0.26788273453712463
# SNR [10dB], Validation Loss: 2.9924, Validation Accuracy: 20.1425, Validation MAE: 0.0864947959780693
# SNR [20dB], Validation Loss: 0.6400, Validation Accuracy: 64.7600, Validation MAE: 0.011526292189955711
# SNR [30dB], Validation Loss: 0.1269, Validation Accuracy: 83.7925, Validation MAE: 0.005420506000518799
# SNR [40dB], Validation Loss: 0.0454, Validation Accuracy: 91.2150, Validation MAE: 0.0033283305820077658
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# KeyboardInterrupt:

# %%
# SNS DOA-4 300 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
# Out:
# === Metrics ===
# ==== DOA-4 ====
# = MAE =_= Acc =
# 0.0920   13.68
# 0.0301   36.79
# 0.0113   64.72
# 0.0054   83.70
# 0.0030   90.92

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, mae_res["training"], label='Train')
plt.plot(ep, mae_res[0], label='0 dB')
plt.plot(ep, mae_res[10], label='10 dB')
plt.plot(ep, mae_res[20], label='20 dB')
plt.plot(ep, mae_res[30], label='30 dB')
plt.plot(ep, mae_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/70], Training Loss: 4.4888, Training Accuracy: 3.8742, Training MAE: 0.23209838569164276
# SNR [0dB], Validation Loss: 4.2826, Validation Accuracy: 4.7600, Validation MAE: 0.13758325576782227
# SNR [10dB], Validation Loss: 3.2036, Validation Accuracy: 11.4880, Validation MAE: 0.05360035225749016
# SNR [20dB], Validation Loss: 2.7689, Validation Accuracy: 15.2700, Validation MAE: 0.028226839378476143
# SNR [30dB], Validation Loss: 2.6758, Validation Accuracy: 16.8360, Validation MAE: 0.022958336398005486
# SNR [40dB], Validation Loss: 2.6600, Validation Accuracy: 16.7100, Validation MAE: 0.022248931229114532
#
#
# Epoch [2/70], Training Loss: 2.6276, Training Accuracy: 19.1396, Training MAE: 0.04788878560066223
# SNR [0dB], Validation Loss: 4.1357, Validation Accuracy: 5.9280, Validation MAE: 0.12402670085430145
# SNR [10dB], Validation Loss: 2.9308, Validation Accuracy: 16.4680, Validation MAE: 0.04712754487991333
# SNR [20dB], Validation Loss: 2.2477, Validation Accuracy: 26.3620, Validation MAE: 0.022079892456531525
# SNR [30dB], Validation Loss: 2.0480, Validation Accuracy: 31.1220, Validation MAE: 0.015768585726618767
# SNR [40dB], Validation Loss: 2.0165, Validation Accuracy: 31.7440, Validation MAE: 0.015063224360346794
#
#
# Epoch [3/70], Training Loss: 2.3577, Training Accuracy: 26.1360, Training MAE: 0.04331317916512489
# SNR [0dB], Validation Loss: 4.1035, Validation Accuracy: 6.0100, Validation MAE: 0.12491399794816971
# SNR [10dB], Validation Loss: 2.8256, Validation Accuracy: 18.5580, Validation MAE: 0.04539937153458595
# SNR [20dB], Validation Loss: 1.9508, Validation Accuracy: 34.1160, Validation MAE: 0.018796661868691444
# SNR [30dB], Validation Loss: 1.6456, Validation Accuracy: 42.0760, Validation MAE: 0.012171411886811256
# SNR [40dB], Validation Loss: 1.5936, Validation Accuracy: 44.2340, Validation MAE: 0.011015629395842552
#
#
# Epoch [4/70], Training Loss: 2.2312, Training Accuracy: 30.4617, Training MAE: 0.041378941386938095
# SNR [0dB], Validation Loss: 4.0651, Validation Accuracy: 6.2640, Validation MAE: 0.12236510217189789
# SNR [10dB], Validation Loss: 2.7976, Validation Accuracy: 18.3120, Validation MAE: 0.04539575055241585
# SNR [20dB], Validation Loss: 1.9464, Validation Accuracy: 33.6240, Validation MAE: 0.01883283071219921
# SNR [30dB], Validation Loss: 1.6130, Validation Accuracy: 41.9640, Validation MAE: 0.012273694388568401
# SNR [40dB], Validation Loss: 1.5477, Validation Accuracy: 44.4860, Validation MAE: 0.010695131495594978
#
#
# Epoch [5/70], Training Loss: 2.1496, Training Accuracy: 33.3915, Training MAE: 0.040300991386175156
# SNR [30dB], Validation Loss: 0.5218, Validation Accuracy: 71.4400, Validation MAE: 0.009543279185891151
# SNR [40dB], Validation Loss: 0.3377, Validation Accuracy: 80.6580, Validation MAE: 0.007774692960083485
#
#
# Criterion is changed to focal loss
# Epoch [33/70], Training Loss: 1.1072, Training Accuracy: 49.6511, Training MAE: 0.03417046740651131
# SNR [0dB], Validation Loss: 3.8331, Validation Accuracy: 6.9180, Validation MAE: 0.1142193078994751
# SNR [10dB], Validation Loss: 2.4088, Validation Accuracy: 22.2300, Validation MAE: 0.04215842857956886
# SNR [20dB], Validation Loss: 1.2704, Validation Accuracy: 48.3640, Validation MAE: 0.017742063850164413
# SNR [30dB], Validation Loss: 0.5231, Validation Accuracy: 71.7860, Validation MAE: 0.009443842805922031
# SNR [40dB], Validation Loss: 0.3378, Validation Accuracy: 80.7480, Validation MAE: 0.007791520562022924
# Epoch    33: reducing learning rate of group 0 to 1.2500e-07.
#
#
# Criterion is changed to focal loss
# Epoch [34/70], Training Loss: 1.1064, Training Accuracy: 49.6781, Training MAE: 0.03412841632962227
# SNR [0dB], Validation Loss: 3.8480, Validation Accuracy: 6.8440, Validation MAE: 0.11478378623723984
# SNR [10dB], Validation Loss: 2.4361, Validation Accuracy: 22.0420, Validation MAE: 0.04270775243639946
# SNR [20dB], Validation Loss: 1.2975, Validation Accuracy: 48.1500, Validation MAE: 0.01792301796376705
# SNR [30dB], Validation Loss: 0.5582, Validation Accuracy: 71.4620, Validation MAE: 0.009481105953454971
# SNR [40dB], Validation Loss: 0.3614, Validation Accuracy: 80.7480, Validation MAE: 0.007709675934165716
#
#
# Criterion is changed to focal loss
# Epoch [35/70], Training Loss: 1.1066, Training Accuracy: 49.6914, Training MAE: 0.03417908772826195
# SNR [0dB], Validation Loss: 3.7859, Validation Accuracy: 7.0540, Validation MAE: 0.11528985947370529
# SNR [10dB], Validation Loss: 2.3438, Validation Accuracy: 22.0800, Validation MAE: 0.04230835288763046
# SNR [20dB], Validation Loss: 1.2136, Validation Accuracy: 48.2040, Validation MAE: 0.017656389623880386
# SNR [30dB], Validation Loss: 0.5011, Validation Accuracy: 71.5220, Validation MAE: 0.009435431100428104
# SNR [40dB], Validation Loss: 0.3146, Validation Accuracy: 80.7300, Validation MAE: 0.007600291632115841
#
#
# Criterion is changed to focal loss
# Epoch [36/70], Training Loss: 1.1066, Training Accuracy: 49.6816, Training MAE: 0.03411044925451279
# SNR [0dB], Validation Loss: 3.8039, Validation Accuracy: 6.9200, Validation MAE: 0.1148504838347435
# SNR [10dB], Validation Loss: 2.3735, Validation Accuracy: 22.1580, Validation MAE: 0.04223480820655823
# SNR [20dB], Validation Loss: 1.2286, Validation Accuracy: 48.3500, Validation MAE: 0.01759410835802555
# SNR [30dB], Validation Loss: 0.4849, Validation Accuracy: 71.7700, Validation MAE: 0.009396310895681381
# SNR [40dB], Validation Loss: 0.3054, Validation Accuracy: 80.8200, Validation MAE: 0.007493095472455025
#
#
# Criterion is changed to focal loss
# Epoch [37/70], Training Loss: 1.1064, Training Accuracy: 49.6651, Training MAE: 0.03415835648775101
# SNR [20dB], Validation Loss: 1.2104, Validation Accuracy: 48.4500, Validation MAE: 0.017613666132092476
# SNR [30dB], Validation Loss: 0.5021, Validation Accuracy: 71.5600, Validation MAE: 0.009379043243825436
# SNR [40dB], Validation Loss: 0.3180, Validation Accuracy: 80.9160, Validation MAE: 0.0076201786287128925
#
#
# Criterion is changed to focal loss
# Epoch [42/70], Training Loss: 1.1067, Training Accuracy: 49.6621, Training MAE: 0.03411925956606865
# SNR [0dB], Validation Loss: 3.7880, Validation Accuracy: 6.9440, Validation MAE: 0.11494390666484833
# SNR [10dB], Validation Loss: 2.3442, Validation Accuracy: 22.0260, Validation MAE: 0.04237610846757889
# SNR [20dB], Validation Loss: 1.2040, Validation Accuracy: 48.4140, Validation MAE: 0.017565475776791573
# SNR [30dB], Validation Loss: 0.4944, Validation Accuracy: 71.4980, Validation MAE: 0.009363306686282158
# SNR [40dB], Validation Loss: 0.3103, Validation Accuracy: 80.8760, Validation MAE: 0.007662577088922262
#
#
# Criterion is changed to focal loss
# Epoch [43/70], Training Loss: 1.1063, Training Accuracy: 49.7090, Training MAE: 0.03412391617894173
# SNR [0dB], Validation Loss: 3.7741, Validation Accuracy: 7.0900, Validation MAE: 0.1149166002869606
# SNR [10dB], Validation Loss: 2.3303, Validation Accuracy: 22.1600, Validation MAE: 0.04218772053718567
# SNR [20dB], Validation Loss: 1.1868, Validation Accuracy: 48.5240, Validation MAE: 0.017441341653466225
# SNR [30dB], Validation Loss: 0.4594, Validation Accuracy: 71.8760, Validation MAE: 0.00930375512689352
# SNR [40dB], Validation Loss: 0.2826, Validation Accuracy: 81.0820, Validation MAE: 0.007576687727123499
#
#
# Criterion is changed to focal loss
# Epoch [44/70], Training Loss: 1.1063, Training Accuracy: 49.6782, Training MAE: 0.034131839871406555
# SNR [0dB], Validation Loss: 3.7881, Validation Accuracy: 7.0680, Validation MAE: 0.11486860364675522
# SNR [10dB], Validation Loss: 2.3477, Validation Accuracy: 22.1020, Validation MAE: 0.04225514456629753
# SNR [20dB], Validation Loss: 1.2100, Validation Accuracy: 48.4860, Validation MAE: 0.01749510131776333
# SNR [30dB], Validation Loss: 0.4992, Validation Accuracy: 71.5760, Validation MAE: 0.00934659130871296
# SNR [40dB], Validation Loss: 0.3181, Validation Accuracy: 80.8180, Validation MAE: 0.0076144989579916
#
#
# Criterion is changed to focal loss
# Epoch [45/70], Training Loss: 1.1068, Training Accuracy: 49.6796, Training MAE: 0.03417366370558739
# SNR [0dB], Validation Loss: 3.7896, Validation Accuracy: 7.0540, Validation MAE: 0.1145496591925621
# SNR [10dB], Validation Loss: 2.3464, Validation Accuracy: 22.1200, Validation MAE: 0.042263224720954895
# SNR [20dB], Validation Loss: 1.2061, Validation Accuracy: 48.4920, Validation MAE: 0.017658580094575882
# SNR [30dB], Validation Loss: 0.4969, Validation Accuracy: 71.6320, Validation MAE: 0.009391609579324722
# SNR [40dB], Validation Loss: 0.3140, Validation Accuracy: 80.8480, Validation MAE: 0.007685305550694466
#
#
# Criterion is changed to focal loss
# Epoch [46/70], Training Loss: 1.1066, Training Accuracy: 49.6801, Training MAE: 0.034116387367248535
# SNR [0dB], Validation Loss: 3.7803, Validation Accuracy: 7.0380, Validation MAE: 0.1149132028222084
# SNR [10dB], Validation Loss: 2.3335, Validation Accuracy: 22.2220, Validation MAE: 0.04221395030617714
# SNR [20dB], Validation Loss: 1.1918, Validation Accuracy: 48.4200, Validation MAE: 0.017534662038087845
# SNR [30dB], Validation Loss: 0.4806, Validation Accuracy: 71.7800, Validation MAE: 0.009382541291415691
# SNR [40dB], Validation Loss: 0.3027, Validation Accuracy: 80.8900, Validation MAE: 0.007552868686616421
#
#
# Criterion is changed to focal loss
# Epoch [47/70], Training Loss: 1.1070, Training Accuracy: 49.7002, Training MAE: 0.03412952274084091
# SNR [0dB], Validation Loss: 3.7820, Validation Accuracy: 7.1000, Validation MAE: 0.11470022052526474
# SNR [10dB], Validation Loss: 2.3362, Validation Accuracy: 22.1920, Validation MAE: 0.042289018630981445
# SNR [20dB], Validation Loss: 1.2010, Validation Accuracy: 48.4320, Validation MAE: 0.01751706935465336
# SNR [30dB], Validation Loss: 0.5033, Validation Accuracy: 71.4880, Validation MAE: 0.009394451975822449
# SNR [40dB], Validation Loss: 0.3221, Validation Accuracy: 80.6960, Validation MAE: 0.007676128763705492
#
#
# Criterion is changed to focal loss
# Epoch [48/70], Training Loss: 1.1067, Training Accuracy: 49.6789, Training MAE: 0.034132953733205795
# SNR [0dB], Validation Loss: 3.7930, Validation Accuracy: 6.9980, Validation MAE: 0.1151624247431755
# SNR [10dB], Validation Loss: 2.3532, Validation Accuracy: 22.0700, Validation MAE: 0.04247894138097763
# SNR [20dB], Validation Loss: 1.2122, Validation Accuracy: 48.3080, Validation MAE: 0.01746855117380619
# SNR [30dB], Validation Loss: 0.5055, Validation Accuracy: 71.4820, Validation MAE: 0.009398277848958969
# SNR [40dB], Validation Loss: 0.3213, Validation Accuracy: 80.7140, Validation MAE: 0.0075588771142065525
#
#
# Criterion is changed to focal loss
# Epoch [49/70], Training Loss: 1.1064, Training Accuracy: 49.6949, Training MAE: 0.034155119210481644
# SNR [0dB], Validation Loss: 3.8025, Validation Accuracy: 6.9860, Validation MAE: 0.11497776955366135
# SNR [10dB], Validation Loss: 2.3673, Validation Accuracy: 22.0840, Validation MAE: 0.04231032729148865
# SNR [20dB], Validation Loss: 1.2323, Validation Accuracy: 48.2300, Validation MAE: 0.01756700873374939
# SNR [30dB], Validation Loss: 0.5142, Validation Accuracy: 71.5240, Validation MAE: 0.009415539912879467
# SNR [40dB], Validation Loss: 0.3284, Validation Accuracy: 80.7080, Validation MAE: 0.0076187592931091785
#
#
# Criterion is changed to focal loss
# Epoch [50/70], Training Loss: 1.1061, Training Accuracy: 49.6796, Training MAE: 0.03412910923361778
# SNR [0dB], Validation Loss: 3.7919, Validation Accuracy: 7.0380, Validation MAE: 0.11464166641235352
# SNR [10dB], Validation Loss: 2.3543, Validation Accuracy: 22.1380, Validation MAE: 0.04221383482217789
# SNR [20dB], Validation Loss: 1.2206, Validation Accuracy: 48.2920, Validation MAE: 0.017442217096686363
# SNR [30dB], Validation Loss: 0.4963, Validation Accuracy: 71.6380, Validation MAE: 0.009406688623130322
# SNR [40dB], Validation Loss: 0.3145, Validation Accuracy: 80.7620, Validation MAE: 0.007618757430464029
#
#
# Criterion is changed to focal loss
# Epoch [51/70], Training Loss: 1.1068, Training Accuracy: 49.7062, Training MAE: 0.03413926064968109
# SNR [0dB], Validation Loss: 3.7868, Validation Accuracy: 7.0460, Validation MAE: 0.1150975450873375
# SNR [10dB], Validation Loss: 2.3424, Validation Accuracy: 22.1180, Validation MAE: 0.04238845780491829
# SNR [20dB], Validation Loss: 1.2032, Validation Accuracy: 48.4500, Validation MAE: 0.017645027488470078
# SNR [30dB], Validation Loss: 0.5024, Validation Accuracy: 71.5000, Validation MAE: 0.009453678503632545
# SNR [40dB], Validation Loss: 0.3201, Validation Accuracy: 80.6900, Validation MAE: 0.007690768223255873
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-9-7033499e61c1> in forward(self, input, target)
#       6
#       7     def forward(self, input, target):
# ----> 8         ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
#       9         pt = torch.exp(-ce_loss)
#      10         focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2691     if size_average is not None or reduce is not None:
#    2692         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2693     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    2694
#    2695
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2403         else:
#    2404             input = input.view(n, c, 0, 0)
# -> 2405         if target.numel() > 0:
#    2406             target = target.view(n, 1, -1)
#    2407         else:
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-5 ====
# = MAE =_= Acc =
# 0.1141   6.86
# 0.0419   20.99
# 0.0164   43.58
# 0.0088   59.60
# 0.0072   64.21

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
