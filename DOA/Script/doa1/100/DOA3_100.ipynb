# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 100
no_doa = 3

# %%
root_dataset_path =  ("../../SNS_dataset/100/DOA3")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.10, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, label, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(label))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, label)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
#     df1  = sio.loadmat(root_path + "/SNR_{}_00_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df1  = sio.loadmat("../../SNS_dataset/100/DOA3/SNR_SNS_00_3.mat")
    df2  = sio.loadmat("../../SNS_dataset/100/DOA3/SNR_SNS_10_3.mat")
    df3  = sio.loadmat("../../SNS_dataset/100/DOA3/SNR_SNS_20_3.mat")
    df4  = sio.loadmat("../../SNS_dataset/100/DOA3/SNR_SNS_30_3.mat")
    df5  = sio.loadmat("../../SNS_dataset/100/DOA3/SNR_SNS_40_3.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 100)
# Out:
# 2021-06-30 15:16:01,115 - Data prepration started
# 2021-06-30 15:16:06,810 - Dividing your dataset into 3 channel
# 2021-06-30 15:17:55,454 - Creating Train dataloader
# 2021-06-30 15:17:56,268 - Creating Validation dataloader
# 2021-06-30 15:17:56,369 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 3, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 32

weights_dir = "../doa_weights"

autoencoder = ResNet34()
cross_criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

# model = nn.Sequential( pre_trained, autoencoder)
# model = ConvAutoencoder()
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-2)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/32], Training Loss: 3.5407, Training Accuracy: 12.7634, Training MAE: 0.145576611161232
# SNR [0dB], Validation Loss: 4.1180, Validation Accuracy: 8.4133, Validation MAE: 0.14597883820533752
# SNR [10dB], Validation Loss: 2.9648, Validation Accuracy: 22.9700, Validation MAE: 0.05075875669717789
# SNR [20dB], Validation Loss: 2.5263, Validation Accuracy: 32.6133, Validation MAE: 0.02915358915925026
# SNR [30dB], Validation Loss: 2.4188, Validation Accuracy: 36.0600, Validation MAE: 0.023717058822512627
# SNR [40dB], Validation Loss: 2.4078, Validation Accuracy: 35.8933, Validation MAE: 0.022878572344779968
#
#
# Epoch [2/32], Training Loss: 2.0192, Training Accuracy: 34.6290, Training MAE: 0.036900877952575684
# SNR [0dB], Validation Loss: 3.8983, Validation Accuracy: 10.1800, Validation MAE: 0.12578566372394562
# SNR [10dB], Validation Loss: 2.4864, Validation Accuracy: 34.8433, Validation MAE: 0.032959576696157455

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/70], Training Loss: 3.3827, Training Accuracy: 13.3798, Training MAE: 0.11590491235256195
# SNR [0dB], Validation Loss: 3.8123, Validation Accuracy: 10.4100, Validation MAE: 0.10387708991765976
# SNR [10dB], Validation Loss: 2.7477, Validation Accuracy: 24.4467, Validation MAE: 0.040590133517980576
# SNR [20dB], Validation Loss: 2.3198, Validation Accuracy: 34.0933, Validation MAE: 0.026915669441223145
# SNR [30dB], Validation Loss: 2.2101, Validation Accuracy: 37.7933, Validation MAE: 0.022700265049934387
# SNR [40dB], Validation Loss: 2.1987, Validation Accuracy: 38.3967, Validation MAE: 0.022509584203362465
#
#
# Epoch [2/70], Training Loss: 1.9794, Training Accuracy: 35.8398, Training MAE: 0.036185313016176224
# SNR [0dB], Validation Loss: 3.6614, Validation Accuracy: 11.1733, Validation MAE: 0.09575498849153519
# SNR [10dB], Validation Loss: 2.4498, Validation Accuracy: 28.6867, Validation MAE: 0.035551365464925766
# SNR [20dB], Validation Loss: 1.6745, Validation Accuracy: 45.1133, Validation MAE: 0.019580695778131485
# SNR [30dB], Validation Loss: 1.4307, Validation Accuracy: 51.9700, Validation MAE: 0.014229398220777512
# SNR [40dB], Validation Loss: 1.3930, Validation Accuracy: 53.0800, Validation MAE: 0.013786295428872108
#
#
# Epoch [3/70], Training Loss: 1.7426, Training Accuracy: 44.4763, Training MAE: 0.03352104872465134
# SNR [0dB], Validation Loss: 3.6768, Validation Accuracy: 11.7133, Validation MAE: 0.09300985187292099
# SNR [10dB], Validation Loss: 2.4002, Validation Accuracy: 31.6333, Validation MAE: 0.03528036177158356
# SNR [20dB], Validation Loss: 1.4435, Validation Accuracy: 54.2333, Validation MAE: 0.019287843257188797
# SNR [30dB], Validation Loss: 1.0877, Validation Accuracy: 65.7700, Validation MAE: 0.01408151350915432
# SNR [40dB], Validation Loss: 1.0257, Validation Accuracy: 68.3567, Validation MAE: 0.013492165133357048
#
#
# Epoch [4/70], Training Loss: 1.6462, Training Accuracy: 47.8376, Training MAE: 0.0322461798787117
# SNR [0dB], Validation Loss: 3.5615, Validation Accuracy: 11.7700, Validation MAE: 0.09111014753580093
# SNR [10dB], Validation Loss: 2.2775, Validation Accuracy: 33.4000, Validation MAE: 0.03314497694373131
# SNR [20dB], Validation Loss: 1.3033, Validation Accuracy: 59.1767, Validation MAE: 0.014091713353991508
# SNR [30dB], Validation Loss: 0.9202, Validation Accuracy: 74.2733, Validation MAE: 0.009304992854595184
# SNR [0dB], Validation Loss: 3.4004, Validation Accuracy: 12.1267, Validation MAE: 0.09195318818092346
# SNR [10dB], Validation Loss: 2.0987, Validation Accuracy: 35.6200, Validation MAE: 0.03197430074214935
# SNR [20dB], Validation Loss: 1.1028, Validation Accuracy: 65.8600, Validation MAE: 0.01320004090666771
# SNR [30dB], Validation Loss: 0.4822, Validation Accuracy: 85.6133, Validation MAE: 0.005828461144119501
# SNR [40dB], Validation Loss: 0.2846, Validation Accuracy: 92.8133, Validation MAE: 0.003715478116646409
#
#
# Criterion is changed to focal loss
# Epoch [25/70], Training Loss: 0.6258, Training Accuracy: 60.4742, Training MAE: 0.02606581151485443
# SNR [0dB], Validation Loss: 3.1801, Validation Accuracy: 12.1933, Validation MAE: 0.09198541939258575
# SNR [10dB], Validation Loss: 1.6205, Validation Accuracy: 35.3067, Validation MAE: 0.03214640915393829
# SNR [20dB], Validation Loss: 0.4973, Validation Accuracy: 66.0733, Validation MAE: 0.01327015832066536
# SNR [30dB], Validation Loss: 0.0737, Validation Accuracy: 85.7100, Validation MAE: 0.005823178216814995
# SNR [40dB], Validation Loss: 0.0186, Validation Accuracy: 92.9133, Validation MAE: 0.0033687162213027477
#
#
# Criterion is changed to focal loss
# Epoch [26/70], Training Loss: 0.6219, Training Accuracy: 60.5824, Training MAE: 0.025856545194983482
# SNR [0dB], Validation Loss: 3.1709, Validation Accuracy: 12.1400, Validation MAE: 0.09248115867376328
# SNR [10dB], Validation Loss: 1.6063, Validation Accuracy: 35.2733, Validation MAE: 0.03222271427512169
# SNR [20dB], Validation Loss: 0.4881, Validation Accuracy: 66.0833, Validation MAE: 0.01341895293444395
# SNR [30dB], Validation Loss: 0.0699, Validation Accuracy: 85.7467, Validation MAE: 0.0061346059665083885
# SNR [40dB], Validation Loss: 0.0171, Validation Accuracy: 92.7800, Validation MAE: 0.003739152802154422
#
#
# Criterion is changed to focal loss
# Epoch [27/70], Training Loss: 0.6188, Training Accuracy: 60.6289, Training MAE: 0.025832923129200935
# SNR [0dB], Validation Loss: 3.1833, Validation Accuracy: 12.1167, Validation MAE: 0.09298491477966309
# SNR [10dB], Validation Loss: 1.6154, Validation Accuracy: 35.2933, Validation MAE: 0.03219813108444214
# SNR [20dB], Validation Loss: 0.4968, Validation Accuracy: 65.8767, Validation MAE: 0.013476326130330563
# SNR [30dB], Validation Loss: 0.0744, Validation Accuracy: 85.7667, Validation MAE: 0.006080698221921921
# SNR [40dB], Validation Loss: 0.0181, Validation Accuracy: 93.0167, Validation MAE: 0.0038735594134777784
#
#
# Criterion is changed to focal loss
# Epoch [28/70], Training Loss: 0.6158, Training Accuracy: 60.7261, Training MAE: 0.02574448473751545
# SNR [0dB], Validation Loss: 3.1842, Validation Accuracy: 12.1667, Validation MAE: 0.09235803782939911
# SNR [10dB], Validation Loss: 1.6187, Validation Accuracy: 35.3333, Validation MAE: 0.03200472518801689
# SNR [20dB], Validation Loss: 0.4975, Validation Accuracy: 65.9933, Validation MAE: 0.013332267291843891
# SNR [30dB], Validation Loss: 0.0721, Validation Accuracy: 85.8233, Validation MAE: 0.006057933438569307
# SNR [40dB], Validation Loss: 0.0172, Validation Accuracy: 93.0500, Validation MAE: 0.003882483346387744
#
#
# Criterion is changed to focal loss
# Epoch [29/70], Training Loss: 0.6133, Training Accuracy: 60.7605, Training MAE: 0.025797011330723763
# SNR [0dB], Validation Loss: 3.1923, Validation Accuracy: 12.0167, Validation MAE: 0.0928836464881897
# SNR [10dB], Validation Loss: 1.6205, Validation Accuracy: 35.5333, Validation MAE: 0.031828612089157104
# SNR [20dB], Validation Loss: 0.4888, Validation Accuracy: 65.9033, Validation MAE: 0.013341915793716908
# SNR [30dB], Validation Loss: 0.0649, Validation Accuracy: 85.8267, Validation MAE: 0.006137886084616184
# SNR [40dB], Validation Loss: 0.0143, Validation Accuracy: 92.8367, Validation MAE: 0.003901788266375661
#
#
# Criterion is changed to focal loss
# Epoch [30/70], Training Loss: 0.6099, Training Accuracy: 60.8336, Training MAE: 0.025661831721663475
# SNR [0dB], Validation Loss: 3.1948, Validation Accuracy: 11.9633, Validation MAE: 0.09382685273885727
# SNR [10dB], Validation Loss: 1.6222, Validation Accuracy: 35.3067, Validation MAE: 0.03263412415981293
# SNR [20dB], Validation Loss: 0.4803, Validation Accuracy: 66.0167, Validation MAE: 0.013397830538451672
# SNR [30dB], Validation Loss: 0.0592, Validation Accuracy: 85.8000, Validation MAE: 0.006256447173655033
# SNR [40dB], Validation Loss: 0.0124, Validation Accuracy: 93.0633, Validation MAE: 0.004231794271618128
# Epoch    30: reducing learning rate of group 0 to 2.5000e-06.
#
#
# Criterion is changed to focal loss
# Epoch [31/70], Training Loss: 0.6033, Training Accuracy: 61.0224, Training MAE: 0.02557268552482128
# SNR [0dB], Validation Loss: 3.1895, Validation Accuracy: 12.0533, Validation MAE: 0.09342510998249054
# SNR [10dB], Validation Loss: 1.6215, Validation Accuracy: 35.4667, Validation MAE: 0.03231760859489441
# SNR [20dB], Validation Loss: 0.4936, Validation Accuracy: 66.1200, Validation MAE: 0.013402197510004044
# SNR [30dB], Validation Loss: 0.0635, Validation Accuracy: 86.1200, Validation MAE: 0.006202902644872665
# SNR [40dB], Validation Loss: 0.0133, Validation Accuracy: 93.3733, Validation MAE: 0.004160766489803791
#
#
# Criterion is changed to focal loss
# Epoch [32/70], Training Loss: 0.6014, Training Accuracy: 61.0838, Training MAE: 0.025434762239456177
# SNR [0dB], Validation Loss: 3.1741, Validation Accuracy: 12.0267, Validation MAE: 0.09309928864240646
# SNR [10dB], Validation Loss: 1.5892, Validation Accuracy: 35.4533, Validation MAE: 0.03204387426376343
# SNR [20dB], Validation Loss: 0.4736, Validation Accuracy: 66.0967, Validation MAE: 0.013211878016591072
# SNR [30dB], Validation Loss: 0.0643, Validation Accuracy: 86.1000, Validation MAE: 0.006257358472794294
# SNR [40dB], Validation Loss: 0.0137, Validation Accuracy: 93.2667, Validation MAE: 0.004123248625546694
#
#
# Criterion is changed to focal loss
# Epoch [33/70], Training Loss: 0.6011, Training Accuracy: 61.1179, Training MAE: 0.025486452504992485
# SNR [0dB], Validation Loss: 3.1792, Validation Accuracy: 12.0267, Validation MAE: 0.09347482025623322
# SNR [10dB], Validation Loss: 1.6003, Validation Accuracy: 35.3700, Validation MAE: 0.03213092312216759
# SNR [20dB], Validation Loss: 0.4742, Validation Accuracy: 66.0233, Validation MAE: 0.01325613260269165
# SNR [30dB], Validation Loss: 0.0600, Validation Accuracy: 86.0167, Validation MAE: 0.006182870361953974
# SNR [40dB], Validation Loss: 0.0123, Validation Accuracy: 93.2867, Validation MAE: 0.003925281576812267
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-3 ====
# = MAE =_= Acc =
# 0.0890   12.59
# 0.0316   34.71
# 0.0129   65.92
# 0.0058   85.71
# 0.0033   92.81

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, acc_res["training"], label='Train')
plt.plot(ep, acc_res[0], label='0 dB')
plt.plot(ep, acc_res[10], label='10 dB')
plt.plot(ep, acc_res[20], label='20 dB')
plt.plot(ep, acc_res[30], label='30 dB')
plt.plot(ep, acc_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('ACC', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, mae_res["training"], label='Train')
plt.plot(ep, mae_res[0], label='0 dB')
plt.plot(ep, mae_res[10], label='10 dB')
plt.plot(ep, mae_res[20], label='20 dB')
plt.plot(ep, mae_res[30], label='30 dB')
plt.plot(ep, mae_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
