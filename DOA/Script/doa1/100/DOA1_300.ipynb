# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 300
no_doa = 1

# %%
root_dataset_path =  ("../../SNS_dataset/300/DOA1")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.10, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, label, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(label))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, label)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_{}_0_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df1  = sio.loadmat("../../SNS_dataset/200/DOA1/SNR_SNS_00_1.mat")
#     df2  = sio.loadmat("../../SNS_dataset/200/DOA1/SNR_SNS_10_1.mat")
#     df3  = sio.loadmat("../../SNS_dataset/200/DOA1/SNR_SNS_20_1.mat")
#     df4  = sio.loadmat("../../SNS_dataset/200/DOA1/SNR_SNS_30_1.mat")
#     df5  = sio.loadmat("../../SNS_dataset/200/DOA1/SNR_SNS_40_1.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 300)
# Out:
# 2021-07-02 15:09:39,011 - Data prepration started
# 2021-07-02 15:11:38,588 - Dividing your dataset into 3 channel
# 2021-07-02 15:16:13,203 - Creating Train dataloader
# 2021-07-02 15:16:14,573 - Creating Validation dataloader
# 2021-07-02 15:16:14,692 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 1, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 70

weights_dir = "../doa_weights"

autoencoder = ResNet34()
cross_criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

# model = nn.Sequential( pre_trained, autoencoder)
# model = ConvAutoencoder()
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-3)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/70], Training Loss: 2.4871, Training Accuracy: 29.9609, Training MAE: 0.08971923589706421
# SNR [20dB], Validation Loss: 0.0945, Validation Accuracy: 91.5900, Validation MAE: 0.014538822695612907
# SNR [30dB], Validation Loss: 0.0272, Validation Accuracy: 96.1700, Validation MAE: 0.006986393593251705
# SNR [40dB], Validation Loss: 0.0189, Validation Accuracy: 96.8700, Validation MAE: 0.006335123907774687
#
#
# Criterion is changed to focal loss
# Epoch [29/70], Training Loss: 0.0241, Training Accuracy: 88.7607, Training MAE: 0.014467615634202957
# SNR [0dB], Validation Loss: 1.9033, Validation Accuracy: 36.8700, Validation MAE: 0.08787601441144943
# SNR [10dB], Validation Loss: 0.5890, Validation Accuracy: 73.1400, Validation MAE: 0.03417525067925453
# SNR [20dB], Validation Loss: 0.1190, Validation Accuracy: 91.4200, Validation MAE: 0.015004327520728111
# SNR [30dB], Validation Loss: 0.0366, Validation Accuracy: 96.2500, Validation MAE: 0.00810753833502531
# SNR [40dB], Validation Loss: 0.0233, Validation Accuracy: 97.6200, Validation MAE: 0.007049225736409426
#
#
# Criterion is changed to focal loss
# Epoch [30/70], Training Loss: 0.0224, Training Accuracy: 89.0607, Training MAE: 0.014294239692389965
# SNR [0dB], Validation Loss: 1.8724, Validation Accuracy: 36.6200, Validation MAE: 0.08399134129285812
# SNR [10dB], Validation Loss: 0.5768, Validation Accuracy: 73.4500, Validation MAE: 0.03708738461136818
# SNR [20dB], Validation Loss: 0.1370, Validation Accuracy: 91.2100, Validation MAE: 0.01687180995941162
# SNR [30dB], Validation Loss: 0.0478, Validation Accuracy: 96.6600, Validation MAE: 0.006582628469914198
# SNR [40dB], Validation Loss: 0.0313, Validation Accuracy: 97.7800, Validation MAE: 0.00492932228371501
#
#
# Criterion is changed to focal loss
# Epoch [31/70], Training Loss: 0.0212, Training Accuracy: 89.3593, Training MAE: 0.013869153335690498
# SNR [0dB], Validation Loss: 1.9039, Validation Accuracy: 36.0700, Validation MAE: 0.08904960751533508
# SNR [10dB], Validation Loss: 0.5803, Validation Accuracy: 72.3100, Validation MAE: 0.038734134286642075
# SNR [20dB], Validation Loss: 0.1162, Validation Accuracy: 91.2700, Validation MAE: 0.017374467104673386
# SNR [30dB], Validation Loss: 0.0403, Validation Accuracy: 96.2800, Validation MAE: 0.008496551774442196
# SNR [40dB], Validation Loss: 0.0285, Validation Accuracy: 97.3000, Validation MAE: 0.00729181244969368
#
#
# Criterion is changed to focal loss
# Epoch [32/70], Training Loss: 0.0202, Training Accuracy: 89.5133, Training MAE: 0.013829206116497517
# SNR [0dB], Validation Loss: 2.0101, Validation Accuracy: 35.0400, Validation MAE: 0.0957682803273201
# SNR [10dB], Validation Loss: 0.6903, Validation Accuracy: 71.3100, Validation MAE: 0.03954986110329628
# SNR [20dB], Validation Loss: 0.1692, Validation Accuracy: 90.6100, Validation MAE: 0.016615016385912895
# SNR [30dB], Validation Loss: 0.0585, Validation Accuracy: 96.1900, Validation MAE: 0.011137142777442932
# SNR [40dB], Validation Loss: 0.0388, Validation Accuracy: 97.6000, Validation MAE: 0.010071727447211742
#
#
# Criterion is changed to focal loss
# Epoch [33/70], Training Loss: 0.0197, Training Accuracy: 89.7042, Training MAE: 0.01346864365041256
# SNR [0dB], Validation Loss: 1.7963, Validation Accuracy: 38.0800, Validation MAE: 0.07476703077554703
# SNR [10dB], Validation Loss: 0.5183, Validation Accuracy: 74.1200, Validation MAE: 0.03334914147853851
# SNR [20dB], Validation Loss: 0.1038, Validation Accuracy: 91.5700, Validation MAE: 0.015060603618621826
# SNR [30dB], Validation Loss: 0.0343, Validation Accuracy: 96.4500, Validation MAE: 0.00948219746351242
# SNR [40dB], Validation Loss: 0.0226, Validation Accuracy: 97.7100, Validation MAE: 0.007627281825989485
#
#
# Criterion is changed to focal loss
# Epoch [34/70], Training Loss: 0.0176, Training Accuracy: 90.1496, Training MAE: 0.013225477188825607
# SNR [0dB], Validation Loss: 1.8008, Validation Accuracy: 37.6800, Validation MAE: 0.07268428057432175
# SNR [10dB], Validation Loss: 0.5400, Validation Accuracy: 74.4700, Validation MAE: 0.032601166516542435
# SNR [20dB], Validation Loss: 0.1248, Validation Accuracy: 91.5700, Validation MAE: 0.014634436927735806
# SNR [30dB], Validation Loss: 0.0510, Validation Accuracy: 96.6000, Validation MAE: 0.006980383303016424
# SNR [40dB], Validation Loss: 0.0368, Validation Accuracy: 97.5500, Validation MAE: 0.00606194045394659
#
#
# Criterion is changed to focal loss
# Epoch [35/70], Training Loss: 0.0166, Training Accuracy: 90.3478, Training MAE: 0.012674105353653431
# SNR [0dB], Validation Loss: 1.7959, Validation Accuracy: 38.1600, Validation MAE: 0.07142545282840729
# SNR [10dB], Validation Loss: 0.5612, Validation Accuracy: 72.0800, Validation MAE: 0.029816333204507828
# SNR [20dB], Validation Loss: 0.1314, Validation Accuracy: 89.5600, Validation MAE: 0.01625823974609375
# SNR [30dB], Validation Loss: 0.0521, Validation Accuracy: 93.7200, Validation MAE: 0.012666423805058002
# SNR [40dB], Validation Loss: 0.0402, Validation Accuracy: 94.3900, Validation MAE: 0.011127308011054993
#
#
# Criterion is changed to focal loss
# Epoch [36/70], Training Loss: 0.0157, Training Accuracy: 90.5796, Training MAE: 0.012617033906280994
# SNR [0dB], Validation Loss: 1.8629, Validation Accuracy: 37.9800, Validation MAE: 0.07434140890836716
# SNR [10dB], Validation Loss: 0.5807, Validation Accuracy: 73.6000, Validation MAE: 0.032324157655239105
# SNR [20dB], Validation Loss: 0.1287, Validation Accuracy: 91.0600, Validation MAE: 0.01612820476293564
# SNR [30dB], Validation Loss: 0.0453, Validation Accuracy: 95.6200, Validation MAE: 0.011274280957877636
# SNR [40dB], Validation Loss: 0.0321, Validation Accuracy: 96.5000, Validation MAE: 0.01050499640405178
#
#
# Criterion is changed to focal loss
# Epoch [37/70], Training Loss: 0.0145, Training Accuracy: 90.8251, Training MAE: 0.01259196549654007
# SNR [0dB], Validation Loss: 1.7841, Validation Accuracy: 38.2500, Validation MAE: 0.0749768391251564
# SNR [10dB], Validation Loss: 0.5195, Validation Accuracy: 73.2700, Validation MAE: 0.03154285252094269
# SNR [20dB], Validation Loss: 0.1033, Validation Accuracy: 91.5800, Validation MAE: 0.014295689761638641
# SNR [30dB], Validation Loss: 0.0286, Validation Accuracy: 96.8700, Validation MAE: 0.007467196322977543
# SNR [40dB], Validation Loss: 0.0168, Validation Accuracy: 97.8300, Validation MAE: 0.007191280834376812
#
#
# Criterion is changed to focal loss
# Epoch [38/70], Training Loss: 0.0141, Training Accuracy: 90.9273, Training MAE: 0.012128196656703949
# SNR [0dB], Validation Loss: 1.7311, Validation Accuracy: 38.7000, Validation MAE: 0.06448659300804138
# SNR [10dB], Validation Loss: 0.5040, Validation Accuracy: 74.4100, Validation MAE: 0.028460796922445297
# SNR [20dB], Validation Loss: 0.0993, Validation Accuracy: 91.7400, Validation MAE: 0.013143401592969894
# SNR [30dB], Validation Loss: 0.0308, Validation Accuracy: 96.5200, Validation MAE: 0.007387426681816578
# SNR [40dB], Validation Loss: 0.0204, Validation Accuracy: 97.7800, Validation MAE: 0.006498487666249275
#
#
# Criterion is changed to focal loss
# Epoch [39/70], Training Loss: 0.0134, Training Accuracy: 91.1840, Training MAE: 0.012083732523024082
# SNR [0dB], Validation Loss: 1.7444, Validation Accuracy: 38.5400, Validation MAE: 0.0712757483124733
# SNR [10dB], Validation Loss: 0.4692, Validation Accuracy: 74.0000, Validation MAE: 0.030251242220401764
# SNR [20dB], Validation Loss: 0.0958, Validation Accuracy: 91.0500, Validation MAE: 0.016171367838978767
# SNR [30dB], Validation Loss: 0.0320, Validation Accuracy: 95.9100, Validation MAE: 0.011644171550869942
# SNR [40dB], Validation Loss: 0.0215, Validation Accuracy: 96.7300, Validation MAE: 0.009922022931277752
#
#
# Criterion is changed to focal loss
# Epoch [40/70], Training Loss: 0.0124, Training Accuracy: 91.3493, Training MAE: 0.011802694760262966
# SNR [0dB], Validation Loss: 1.6315, Validation Accuracy: 39.4800, Validation MAE: 0.06276881694793701
# SNR [10dB], Validation Loss: 0.4164, Validation Accuracy: 74.4200, Validation MAE: 0.02858864702284336
# SNR [20dB], Validation Loss: 0.0768, Validation Accuracy: 91.9800, Validation MAE: 0.013093682937324047
# SNR [30dB], Validation Loss: 0.0233, Validation Accuracy: 97.2300, Validation MAE: 0.006624152418226004
# SNR [40dB], Validation Loss: 0.0154, Validation Accuracy: 98.1500, Validation MAE: 0.005647794343531132
#
#
# Criterion is changed to focal loss
# Epoch [41/70], Training Loss: 0.0120, Training Accuracy: 91.5944, Training MAE: 0.011410016566514969
# SNR [0dB], Validation Loss: 1.6503, Validation Accuracy: 39.7700, Validation MAE: 0.06484883278608322
# SNR [10dB], Validation Loss: 0.4326, Validation Accuracy: 74.8900, Validation MAE: 0.02889133431017399
# SNR [20dB], Validation Loss: 0.0809, Validation Accuracy: 92.0000, Validation MAE: 0.015305375680327415
# SNR [30dB], Validation Loss: 0.0258, Validation Accuracy: 96.9200, Validation MAE: 0.008863164111971855
# SNR [40dB], Validation Loss: 0.0176, Validation Accuracy: 97.6700, Validation MAE: 0.009709485806524754
#
#
# Criterion is changed to focal loss
# Epoch [42/70], Training Loss: 0.0113, Training Accuracy: 91.6927, Training MAE: 0.011360015720129013
# SNR [0dB], Validation Loss: 1.6302, Validation Accuracy: 39.8400, Validation MAE: 0.06179901212453842
# SNR [10dB], Validation Loss: 0.4391, Validation Accuracy: 74.7200, Validation MAE: 0.028248807415366173
# SNR [20dB], Validation Loss: 0.0897, Validation Accuracy: 91.8600, Validation MAE: 0.013436800800263882
# SNR [30dB], Validation Loss: 0.0300, Validation Accuracy: 96.0300, Validation MAE: 0.008804702199995518
# SNR [40dB], Validation Loss: 0.0198, Validation Accuracy: 97.1500, Validation MAE: 0.0070836469531059265
#
#
# Criterion is changed to focal loss
# Epoch [43/70], Training Loss: 0.0108, Training Accuracy: 91.8622, Training MAE: 0.011383463628590107
# SNR [0dB], Validation Loss: 1.6493, Validation Accuracy: 39.5900, Validation MAE: 0.05881967395544052
# SNR [10dB], Validation Loss: 0.4688, Validation Accuracy: 74.7200, Validation MAE: 0.028183789923787117
# SNR [20dB], Validation Loss: 0.1078, Validation Accuracy: 92.2700, Validation MAE: 0.01321388315409422
# SNR [30dB], Validation Loss: 0.0337, Validation Accuracy: 97.1700, Validation MAE: 0.006530723534524441
# SNR [40dB], Validation Loss: 0.0196, Validation Accuracy: 97.7800, Validation MAE: 0.004861572757363319
#
#
# Criterion is changed to focal loss
# Epoch [44/70], Training Loss: 0.0105, Training Accuracy: 92.0613, Training MAE: 0.011174437589943409
# SNR [0dB], Validation Loss: 1.6285, Validation Accuracy: 40.4500, Validation MAE: 0.059228356927633286
# SNR [10dB], Validation Loss: 0.4426, Validation Accuracy: 75.5500, Validation MAE: 0.027050625532865524
# SNR [20dB], Validation Loss: 0.0880, Validation Accuracy: 92.4000, Validation MAE: 0.012727616354823112
# SNR [30dB], Validation Loss: 0.0274, Validation Accuracy: 97.0700, Validation MAE: 0.00645368592813611
# SNR [40dB], Validation Loss: 0.0186, Validation Accuracy: 97.6300, Validation MAE: 0.005968512035906315
#
#
# Criterion is changed to focal loss
# Epoch [45/70], Training Loss: 0.0105, Training Accuracy: 92.0780, Training MAE: 0.01111243013292551
# SNR [0dB], Validation Loss: 1.8653, Validation Accuracy: 39.1700, Validation MAE: 0.058745913207530975
# SNR [10dB], Validation Loss: 0.7040, Validation Accuracy: 73.1100, Validation MAE: 0.028577720746397972
# SNR [20dB], Validation Loss: 0.3008, Validation Accuracy: 89.7700, Validation MAE: 0.01472895871847868
# SNR [30dB], Validation Loss: 0.2311, Validation Accuracy: 94.4500, Validation MAE: 0.011166646145284176
# SNR [40dB], Validation Loss: 0.2206, Validation Accuracy: 95.7600, Validation MAE: 0.010091942735016346
#
#
# Criterion is changed to focal loss
# Epoch [46/70], Training Loss: 0.0100, Training Accuracy: 92.2282, Training MAE: 0.011298021301627159
# SNR [0dB], Validation Loss: 1.6070, Validation Accuracy: 40.9300, Validation MAE: 0.05778157711029053
# SNR [10dB], Validation Loss: 0.4183, Validation Accuracy: 76.0700, Validation MAE: 0.02676323615014553
# SNR [20dB], Validation Loss: 0.0810, Validation Accuracy: 92.8900, Validation MAE: 0.01333517674356699
# SNR [30dB], Validation Loss: 0.0248, Validation Accuracy: 97.3700, Validation MAE: 0.007306564599275589
# SNR [40dB], Validation Loss: 0.0162, Validation Accuracy: 98.4700, Validation MAE: 0.006005664821714163
#
#
# Criterion is changed to focal loss
# Epoch [47/70], Training Loss: 0.0091, Training Accuracy: 92.4382, Training MAE: 0.01087683904916048
# SNR [0dB], Validation Loss: 1.7150, Validation Accuracy: 40.6200, Validation MAE: 0.05611461028456688
# SNR [10dB], Validation Loss: 0.5181, Validation Accuracy: 74.5300, Validation MAE: 0.029060162603855133
# SNR [20dB], Validation Loss: 0.1067, Validation Accuracy: 90.8400, Validation MAE: 0.014560678042471409
# SNR [30dB], Validation Loss: 0.0404, Validation Accuracy: 94.9500, Validation MAE: 0.007314213551580906
# SNR [40dB], Validation Loss: 0.0304, Validation Accuracy: 96.0600, Validation MAE: 0.006511600688099861
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-1 ====
# = MAE =_= Acc =
# 0.0561   40.62
# 0.0268   76.07
# 0.0127   92.40
# 0.0065   97.07
# 0.0049   97.78

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
