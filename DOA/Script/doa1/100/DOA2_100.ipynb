# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 100
no_doa = 2

# %%
root_dataset_path =  ("../../SNS_dataset/100/DOA2")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.10, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, label, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(label))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, label)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
#     df1  = sio.loadmat(root_path + "/SNR_{}_00_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df2  = sio.loadmat(root_path + "/SNR_{}_10_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df3  = sio.loadmat(root_path + "/SNR_{}_20_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df4  = sio.loadmat(root_path + "/SNR_{}_30_{}_{}.mat".format(nq_type, no_doa, no_samples))
#     df5  = sio.loadmat(root_path + "/SNR_{}_40_{}_{}.mat".format(nq_type, no_doa, no_samples))
    df1  = sio.loadmat("../../SNS_dataset/100/DOA2/SNR_SNS_00_2.mat")
    df2  = sio.loadmat("../../SNS_dataset/100/DOA2/SNR_SNS_10_2.mat")
    df3  = sio.loadmat("../../SNS_dataset/100/DOA2/SNR_SNS_20_2.mat")
    df4  = sio.loadmat("../../SNS_dataset/100/DOA2/SNR_SNS_30_2.mat")
    df5  = sio.loadmat("../../SNS_dataset/100/DOA2/SNR_SNS_40_2.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 100)
# Out:
# 2021-06-30 15:12:47,639 - Data prepration started
# 2021-06-30 15:12:52,730 - Dividing your dataset into 3 channel
# 2021-06-30 15:14:33,514 - Creating Train dataloader
# 2021-06-30 15:14:34,225 - Creating Validation dataloader
# 2021-06-30 15:14:34,313 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((no_doa, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 2, 181])

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
num_epochs = 70

weights_dir = "../doa_weights"

autoencoder = ResNet34()
cross_criterion = nn.CrossEntropyLoss()
focal_criterion = FocalLoss()
# if ('{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_{}_model.pth".format(no_doa, no_samples))
#     autoencoder = torch.load(os.path.join(weights_dir, '{}_DOA_{}_{}_model.pth'.format(nq_type, no_doa, no_samples)))

# model = nn.Sequential( pre_trained, autoencoder)
# model = ConvAutoencoder()
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    classification_model = autoencoder.cuda()
    optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-5)
  
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=25 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/70], Training Loss: 3.0782, Training Accuracy: 18.4394, Training MAE: 0.10191911458969116
# SNR [0dB], Validation Loss: 3.8997, Validation Accuracy: 11.7000, Validation MAE: 0.1259525865316391
# SNR [10dB], Validation Loss: 2.7939, Validation Accuracy: 29.7050, Validation MAE: 0.05634654313325882
#
#
# Criterion is changed to focal loss
# Epoch [29/70], Training Loss: 0.4175, Training Accuracy: 66.5418, Training MAE: 0.02390780672430992
# SNR [0dB], Validation Loss: 3.1510, Validation Accuracy: 15.7350, Validation MAE: 0.1063527762889862
# SNR [10dB], Validation Loss: 1.7105, Validation Accuracy: 44.1700, Validation MAE: 0.04734214395284653
# SNR [20dB], Validation Loss: 0.5810, Validation Accuracy: 74.4100, Validation MAE: 0.02152794785797596
# SNR [30dB], Validation Loss: 0.0974, Validation Accuracy: 90.3900, Validation MAE: 0.013791939243674278
# SNR [40dB], Validation Loss: 0.0322, Validation Accuracy: 94.5350, Validation MAE: 0.011457586660981178
# Epoch    29: reducing learning rate of group 0 to 2.5000e-06.
#
#
# Criterion is changed to focal loss
# Epoch [30/70], Training Loss: 0.4111, Training Accuracy: 66.8241, Training MAE: 0.023693181574344635
# SNR [0dB], Validation Loss: 3.0913, Validation Accuracy: 15.8800, Validation MAE: 0.1029571071267128
# SNR [10dB], Validation Loss: 1.6321, Validation Accuracy: 44.2200, Validation MAE: 0.045878153294324875
# SNR [20dB], Validation Loss: 0.5288, Validation Accuracy: 74.5950, Validation MAE: 0.021128827705979347
# SNR [30dB], Validation Loss: 0.0926, Validation Accuracy: 90.4450, Validation MAE: 0.013684851117432117
# SNR [40dB], Validation Loss: 0.0311, Validation Accuracy: 94.7950, Validation MAE: 0.0111789396032691
#
#
# Criterion is changed to focal loss
# Epoch [31/70], Training Loss: 0.4109, Training Accuracy: 66.8356, Training MAE: 0.0236379262059927
# SNR [0dB], Validation Loss: 3.1116, Validation Accuracy: 15.6950, Validation MAE: 0.10549771040678024
# SNR [10dB], Validation Loss: 1.6502, Validation Accuracy: 44.4000, Validation MAE: 0.04683757573366165
# SNR [20dB], Validation Loss: 0.5404, Validation Accuracy: 74.4500, Validation MAE: 0.021251486614346504
# SNR [30dB], Validation Loss: 0.0957, Validation Accuracy: 90.5050, Validation MAE: 0.013749322853982449
# SNR [40dB], Validation Loss: 0.0326, Validation Accuracy: 94.7650, Validation MAE: 0.011225380934774876
#
#
# Criterion is changed to focal loss
# Epoch [32/70], Training Loss: 0.4103, Training Accuracy: 66.8648, Training MAE: 0.023655887693166733
# SNR [0dB], Validation Loss: 3.1051, Validation Accuracy: 15.8200, Validation MAE: 0.10413479804992676
# SNR [10dB], Validation Loss: 1.6527, Validation Accuracy: 44.2350, Validation MAE: 0.04649117961525917
# SNR [20dB], Validation Loss: 0.5459, Validation Accuracy: 74.3500, Validation MAE: 0.02178146317601204
# SNR [30dB], Validation Loss: 0.1007, Validation Accuracy: 90.5050, Validation MAE: 0.013985353522002697
# SNR [40dB], Validation Loss: 0.0348, Validation Accuracy: 94.8550, Validation MAE: 0.01151167694479227
#
#
# Criterion is changed to focal loss
# Epoch [33/70], Training Loss: 0.4099, Training Accuracy: 66.8259, Training MAE: 0.023814648389816284
# SNR [0dB], Validation Loss: 3.1021, Validation Accuracy: 15.8650, Validation MAE: 0.10389521718025208
# SNR [30dB], Validation Loss: 0.0875, Validation Accuracy: 90.5350, Validation MAE: 0.013753693550825119
# SNR [40dB], Validation Loss: 0.0280, Validation Accuracy: 94.9500, Validation MAE: 0.011227566748857498
#
#
# Criterion is changed to focal loss
# Epoch [38/70], Training Loss: 0.4096, Training Accuracy: 66.8156, Training MAE: 0.023819036781787872
# SNR [0dB], Validation Loss: 3.1198, Validation Accuracy: 15.7750, Validation MAE: 0.1066838726401329
# SNR [10dB], Validation Loss: 1.6540, Validation Accuracy: 44.3700, Validation MAE: 0.047470539808273315
# SNR [20dB], Validation Loss: 0.5370, Validation Accuracy: 74.6250, Validation MAE: 0.02157876081764698
# SNR [30dB], Validation Loss: 0.0923, Validation Accuracy: 90.4650, Validation MAE: 0.01369823794811964
# SNR [40dB], Validation Loss: 0.0314, Validation Accuracy: 94.9000, Validation MAE: 0.01127592008560896
#
#
# Criterion is changed to focal loss
# Epoch [39/70], Training Loss: 0.4095, Training Accuracy: 66.8682, Training MAE: 0.023614957928657532
# SNR [0dB], Validation Loss: 3.1177, Validation Accuracy: 15.7850, Validation MAE: 0.10532369464635849
# SNR [10dB], Validation Loss: 1.6672, Validation Accuracy: 44.2350, Validation MAE: 0.047348156571388245
# SNR [20dB], Validation Loss: 0.5473, Validation Accuracy: 74.5700, Validation MAE: 0.02176971547305584
# SNR [30dB], Validation Loss: 0.0885, Validation Accuracy: 90.5750, Validation MAE: 0.01348843239247799
# SNR [40dB], Validation Loss: 0.0279, Validation Accuracy: 94.8950, Validation MAE: 0.011006288230419159
#
#
# Criterion is changed to focal loss
# Epoch [40/70], Training Loss: 0.4098, Training Accuracy: 66.8306, Training MAE: 0.023662779480218887
# SNR [0dB], Validation Loss: 3.1024, Validation Accuracy: 15.7850, Validation MAE: 0.10416730493307114
# SNR [10dB], Validation Loss: 1.6424, Validation Accuracy: 44.3250, Validation MAE: 0.04658843204379082
# SNR [20dB], Validation Loss: 0.5330, Validation Accuracy: 74.5550, Validation MAE: 0.021532593294978142
# SNR [30dB], Validation Loss: 0.0921, Validation Accuracy: 90.4500, Validation MAE: 0.013611637987196445
# SNR [40dB], Validation Loss: 0.0306, Validation Accuracy: 94.8950, Validation MAE: 0.011072398163378239
# Epoch    40: reducing learning rate of group 0 to 6.2500e-09.
#
#
# Criterion is changed to focal loss
# Epoch [41/70], Training Loss: 0.4095, Training Accuracy: 66.8917, Training MAE: 0.023701775819063187
# SNR [0dB], Validation Loss: 3.1097, Validation Accuracy: 15.8300, Validation MAE: 0.10424980521202087
# SNR [10dB], Validation Loss: 1.6534, Validation Accuracy: 44.2700, Validation MAE: 0.04685314744710922
# SNR [20dB], Validation Loss: 0.5385, Validation Accuracy: 74.4500, Validation MAE: 0.0217492263764143
# SNR [30dB], Validation Loss: 0.0891, Validation Accuracy: 90.5400, Validation MAE: 0.013735117390751839
# SNR [40dB], Validation Loss: 0.0280, Validation Accuracy: 94.8550, Validation MAE: 0.011201067827641964
#
#
# Criterion is changed to focal loss
# Epoch [42/70], Training Loss: 0.4097, Training Accuracy: 66.8644, Training MAE: 0.023723509162664413
# SNR [0dB], Validation Loss: 3.1144, Validation Accuracy: 15.8200, Validation MAE: 0.10475602000951767
# SNR [10dB], Validation Loss: 1.6599, Validation Accuracy: 44.3700, Validation MAE: 0.0464521124958992
# SNR [20dB], Validation Loss: 0.5386, Validation Accuracy: 74.5300, Validation MAE: 0.021005894988775253
# SNR [30dB], Validation Loss: 0.0845, Validation Accuracy: 90.5850, Validation MAE: 0.013274529948830605
# SNR [40dB], Validation Loss: 0.0266, Validation Accuracy: 94.8850, Validation MAE: 0.010993994772434235
#
#
# Criterion is changed to focal loss
# Epoch [43/70], Training Loss: 0.4099, Training Accuracy: 66.8622, Training MAE: 0.02375120483338833
# SNR [0dB], Validation Loss: 3.1202, Validation Accuracy: 15.8300, Validation MAE: 0.10588207840919495
# SNR [10dB], Validation Loss: 1.6646, Validation Accuracy: 44.3100, Validation MAE: 0.04715965688228607
# SNR [20dB], Validation Loss: 0.5358, Validation Accuracy: 74.6300, Validation MAE: 0.021266238763928413
# SNR [30dB], Validation Loss: 0.0779, Validation Accuracy: 90.6750, Validation MAE: 0.012947529554367065
# SNR [40dB], Validation Loss: 0.0232, Validation Accuracy: 94.8800, Validation MAE: 0.010963398031890392
#
#
# Criterion is changed to focal loss
# Epoch [44/70], Training Loss: 0.4098, Training Accuracy: 66.8289, Training MAE: 0.023785848170518875
# SNR [0dB], Validation Loss: 3.1063, Validation Accuracy: 15.8050, Validation MAE: 0.10484835505485535
# SNR [10dB], Validation Loss: 1.6462, Validation Accuracy: 44.3850, Validation MAE: 0.04689248651266098
# SNR [20dB], Validation Loss: 0.5380, Validation Accuracy: 74.4400, Validation MAE: 0.021563462913036346
# SNR [30dB], Validation Loss: 0.0938, Validation Accuracy: 90.4950, Validation MAE: 0.01379712950438261
# SNR [40dB], Validation Loss: 0.0310, Validation Accuracy: 94.9200, Validation MAE: 0.011372080072760582
#
#
# Criterion is changed to focal loss
# Epoch [45/70], Training Loss: 0.4094, Training Accuracy: 66.8414, Training MAE: 0.02379804477095604
# SNR [0dB], Validation Loss: 3.1070, Validation Accuracy: 15.8500, Validation MAE: 0.10472186654806137
# SNR [10dB], Validation Loss: 1.6508, Validation Accuracy: 44.2800, Validation MAE: 0.04687773436307907
# SNR [20dB], Validation Loss: 0.5374, Validation Accuracy: 74.5800, Validation MAE: 0.02190767414867878
# SNR [30dB], Validation Loss: 0.0891, Validation Accuracy: 90.6050, Validation MAE: 0.0136777488514781
# SNR [40dB], Validation Loss: 0.0284, Validation Accuracy: 94.8750, Validation MAE: 0.011140967719256878
#
#
# Criterion is changed to focal loss
# Epoch [46/70], Training Loss: 0.4096, Training Accuracy: 66.8320, Training MAE: 0.023803256452083588
# SNR [0dB], Validation Loss: 3.0943, Validation Accuracy: 15.9500, Validation MAE: 0.10379277169704437
# SNR [40dB], Validation Loss: 0.0395, Validation Accuracy: 94.8350, Validation MAE: 0.01154200080782175
#
#
# Criterion is changed to focal loss
# Epoch [51/70], Training Loss: 0.4096, Training Accuracy: 66.8341, Training MAE: 0.023734373971819878
# SNR [0dB], Validation Loss: 3.0956, Validation Accuracy: 15.7800, Validation MAE: 0.10406813770532608
# SNR [10dB], Validation Loss: 1.6268, Validation Accuracy: 44.3900, Validation MAE: 0.04642260819673538
# SNR [20dB], Validation Loss: 0.5159, Validation Accuracy: 74.5500, Validation MAE: 0.02117745392024517
# SNR [30dB], Validation Loss: 0.0835, Validation Accuracy: 90.5650, Validation MAE: 0.013476958498358727
# SNR [40dB], Validation Loss: 0.0267, Validation Accuracy: 94.8600, Validation MAE: 0.010951378382742405
#
#
# Criterion is changed to focal loss
# Epoch [52/70], Training Loss: 0.4097, Training Accuracy: 66.8528, Training MAE: 0.023754389956593513
# SNR [0dB], Validation Loss: 3.0845, Validation Accuracy: 15.8750, Validation MAE: 0.1028994619846344
# SNR [10dB], Validation Loss: 1.6183, Validation Accuracy: 44.3450, Validation MAE: 0.04617346450686455
# SNR [20dB], Validation Loss: 0.5171, Validation Accuracy: 74.4550, Validation MAE: 0.021440530195832253
# SNR [30dB], Validation Loss: 0.0878, Validation Accuracy: 90.5000, Validation MAE: 0.013693593442440033
# SNR [40dB], Validation Loss: 0.0287, Validation Accuracy: 94.8350, Validation MAE: 0.011258162558078766
#
#
# Criterion is changed to focal loss
# Epoch [53/70], Training Loss: 0.4095, Training Accuracy: 66.8479, Training MAE: 0.023809591308236122
# SNR [0dB], Validation Loss: 3.0988, Validation Accuracy: 15.8300, Validation MAE: 0.10409218072891235
# SNR [10dB], Validation Loss: 1.6338, Validation Accuracy: 44.3900, Validation MAE: 0.04671928659081459
# SNR [20dB], Validation Loss: 0.5230, Validation Accuracy: 74.6000, Validation MAE: 0.021297382190823555
# SNR [30dB], Validation Loss: 0.0875, Validation Accuracy: 90.5000, Validation MAE: 0.013550718314945698
# SNR [40dB], Validation Loss: 0.0283, Validation Accuracy: 94.9150, Validation MAE: 0.010993448086082935
#
#
# Criterion is changed to focal loss
# Epoch [54/70], Training Loss: 0.4100, Training Accuracy: 66.8509, Training MAE: 0.023791776970028877
# SNR [0dB], Validation Loss: 3.1027, Validation Accuracy: 15.8850, Validation MAE: 0.1043986901640892
# SNR [10dB], Validation Loss: 1.6348, Validation Accuracy: 44.3600, Validation MAE: 0.04654882103204727
# SNR [20dB], Validation Loss: 0.5204, Validation Accuracy: 74.6200, Validation MAE: 0.02139381505548954
# SNR [30dB], Validation Loss: 0.0843, Validation Accuracy: 90.5600, Validation MAE: 0.01363513246178627
# SNR [40dB], Validation Loss: 0.0266, Validation Accuracy: 94.9400, Validation MAE: 0.01099454052746296
#
#
# Criterion is changed to focal loss
# Epoch [55/70], Training Loss: 0.4095, Training Accuracy: 66.8612, Training MAE: 0.023721208795905113
# SNR [0dB], Validation Loss: 3.0769, Validation Accuracy: 15.9500, Validation MAE: 0.10276314616203308
# SNR [10dB], Validation Loss: 1.6086, Validation Accuracy: 44.3600, Validation MAE: 0.045982785522937775
# SNR [20dB], Validation Loss: 0.5156, Validation Accuracy: 74.5750, Validation MAE: 0.021630939096212387
# SNR [30dB], Validation Loss: 0.0950, Validation Accuracy: 90.5100, Validation MAE: 0.013973606750369072
# SNR [40dB], Validation Loss: 0.0334, Validation Accuracy: 94.9100, Validation MAE: 0.011487910524010658
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adamw.py in step(self, closure)
#     119                     group['lr'],
#     120                     group['weight_decay'],
# --> 121                     group['eps'])
#     122
#     123         return loss
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/_functional.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#     126
#     127         # Decay the first and second moment running average coefficient
# --> 128         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     129         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     130         if amsgrad:
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(no_doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-2 ====
# = MAE =_= Acc =
# 0.0956   15.94
# 0.0397   43.21
# 0.0176   71.44
# 0.0121   83.27
# 0.0104   94.39

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
