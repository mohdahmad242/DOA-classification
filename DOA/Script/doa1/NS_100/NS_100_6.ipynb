# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((4, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 4, 181])

# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import mat73

# %%
train_dataset_list = []
test_dataset_list = []

# %%
df1  = sio.loadmat("../../datasets/100/DOA4/SNR_NS_0_4_100000.mat")
df2  = sio.loadmat("../../datasets/100/DOA4/SNR_NS_10_4_100000.mat")
df3  = sio.loadmat("../../datasets/100/DOA4/SNR_NS_20_4_100000.mat")
df4  = sio.loadmat("../../datasets/100/DOA4/SNR_NS_30_4_100000.mat")
df5  = sio.loadmat("../../datasets/100/DOA4/SNR_NS_40_4_100000.mat")
df = [df1, df2, df3, df4, df5]

# %%
new_train_dataset_list = []
new_test_dataset_list = []
train_dataset_list_label = []
test_dataset_list_label = []
def create_dataset(df):
    data = np.transpose(df['NS_data'], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    new_train_dataset_list.extend(X_train)
    new_test_dataset_list.append(X_test.tolist())
    train_dataset_list_label.extend(y_train)
    test_dataset_list_label.append(y_test.tolist())
    
for file in df:
    create_dataset(file)

# %%
del df
del df1
del df2
del df3
del df4
del df5

# %%
for idx, data in enumerate(new_train_dataset_list):
    new = np.zeros((3, 8, 100))
    for j in range(0, data.shape[0]):
        for k in range(0, data.shape[1]):
            new[0][j][k] = data[j][k].real
            new[1][j][k] = data[j][k].imag
            new[2][j][k] = cmath.phase(data[j][k])
    new_train_dataset_list[idx] = new
    
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new = np.zeros((3, 8, 100))
        for j in range(0, 8):
            for k in range(0, 100):
                new[0][j][k] = ndata[j][k].real
                new[1][j][k] = ndata[j][k].imag
                new[2][j][k] = cmath.phase(ndata[j][k])
        new_test_dataset_list[idx][i] = new

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample

    dataset = DOA_dataset(train, test)

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
doa2_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

# %%
del new_train_dataset_list
del train_dataset_list_label

# %%
test_dataset_list = []
for idx, data in enumerate(new_test_dataset_list):
    print(type(data))
    f = get_data(data, test_dataset_list_label[idx], 128, False)
    test_dataset_list.append(f)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
del new_test_dataset_list
del new

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
focal_criterion = FocalLoss().cuda()

# %%
num_epochs = 100
doa = 4
weights_dir = "../doa_weights/NS"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
if ("{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
    print("Pre-trained available for DOA_{}_model.pth".format(doa))
    autoencoder = torch.load(os.path.join(weights_dir, "{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-2)
	criterion = criterion.cuda()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# Pre-trained available for DOA_4_model.pth
# GeForce GTX 1080 Ti

# %%
if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
# 	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-4)
	criterion = criterion.cuda()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
nq_type = "NS" # Sub-Nyquist or Nyquist sample
no_samples = 100
no_doa = 4

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
#         criterion = None
#         if (i+1)>=1 :
#           print("Criterion is changed to focal loss")
#           criterion = focal_criterion.cuda()
#         else:
#           criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa2_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa2_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa2_train_loader)*181*no_doa))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa2_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa2_train_loader)*181*no_doa)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181*no_doa))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181*no_doa)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/100], Training Loss: 1.6895, Training Accuracy: 41.1167, Training MAE: 0.0054453895427286625
# SNR [0dB], Validation Loss: 3.2507, Validation Accuracy: 20.0717, Validation MAE: 0.016305342316627502
# SNR [10dB], Validation Loss: 2.3673, Validation Accuracy: 39.3450, Validation MAE: 0.006682572886347771
# SNR [20dB], Validation Loss: 2.0712, Validation Accuracy: 47.1467, Validation MAE: 0.004630441777408123
# SNR [30dB], Validation Loss: 2.0264, Validation Accuracy: 48.1167, Validation MAE: 0.0043409280478954315
# SNR [40dB], Validation Loss: 2.0196, Validation Accuracy: 48.2383, Validation MAE: 0.0042029195465147495
#
#
# Epoch [2/100], Training Loss: 1.5545, Training Accuracy: 44.9942, Training MAE: 0.0050596692599356174
# SNR [0dB], Validation Loss: 3.2330, Validation Accuracy: 21.2683, Validation MAE: 0.01720021292567253
# SNR [10dB], Validation Loss: 2.2330, Validation Accuracy: 44.6883, Validation MAE: 0.006521184928715229
# SNR [20dB], Validation Loss: 1.8445, Validation Accuracy: 57.0833, Validation MAE: 0.004155687056481838
# SNR [30dB], Validation Loss: 1.7881, Validation Accuracy: 58.6417, Validation MAE: 0.003970232326537371
# SNR [40dB], Validation Loss: 1.7808, Validation Accuracy: 58.9583, Validation MAE: 0.0038994448259472847
#
#
# Epoch [3/100], Training Loss: 1.4241, Training Accuracy: 49.6319, Training MAE: 0.004644313827157021
# SNR [0dB], Validation Loss: 3.1735, Validation Accuracy: 21.7217, Validation MAE: 0.015489917248487473
# SNR [10dB], Validation Loss: 2.1871, Validation Accuracy: 45.9017, Validation MAE: 0.006143074482679367
# SNR [20dB], Validation Loss: 1.7864, Validation Accuracy: 58.9067, Validation MAE: 0.0044871442951262
# SNR [30dB], Validation Loss: 1.7309, Validation Accuracy: 60.9033, Validation MAE: 0.0042372955940663815
# SNR [40dB], Validation Loss: 1.7186, Validation Accuracy: 61.1583, Validation MAE: 0.00425025075674057
#
#
# Epoch [4/100], Training Loss: 1.3360, Training Accuracy: 52.6717, Training MAE: 0.004373758565634489
# SNR [0dB], Validation Loss: 3.0993, Validation Accuracy: 21.4767, Validation MAE: 0.012891534715890884
# SNR [10dB], Validation Loss: 2.0449, Validation Accuracy: 46.7250, Validation MAE: 0.004848177079111338
# SNR [20dB], Validation Loss: 1.5418, Validation Accuracy: 62.8567, Validation MAE: 0.0029380398336797953
# SNR [30dB], Validation Loss: 1.4636, Validation Accuracy: 66.4233, Validation MAE: 0.002636340679600835
# SNR [40dB], Validation Loss: 1.4509, Validation Accuracy: 67.1283, Validation MAE: 0.002565667498856783
#
#
# Epoch [5/100], Training Loss: 1.2808, Training Accuracy: 54.7575, Training MAE: 0.004234661813825369
# SNR [0dB], Validation Loss: 3.0038, Validation Accuracy: 23.2200, Validation MAE: 0.01217983290553093
# SNR [10dB], Validation Loss: 1.9314, Validation Accuracy: 49.9183, Validation MAE: 0.004553557839244604
# SNR [20dB], Validation Loss: 1.4252, Validation Accuracy: 66.7783, Validation MAE: 0.0027853536885231733
# SNR [30dB], Validation Loss: 1.3445, Validation Accuracy: 70.4200, Validation MAE: 0.002439623000100255
# SNR [40dB], Validation Loss: 1.3313, Validation Accuracy: 71.2167, Validation MAE: 0.002332294825464487
#
#
# Epoch [6/100], Training Loss: 1.2257, Training Accuracy: 56.5941, Training MAE: 0.004033138509839773
# SNR [0dB], Validation Loss: 2.9673, Validation Accuracy: 23.0550, Validation MAE: 0.011887583881616592
# SNR [10dB], Validation Loss: 1.8981, Validation Accuracy: 49.4267, Validation MAE: 0.004357365425676107
# SNR [20dB], Validation Loss: 1.3880, Validation Accuracy: 66.4467, Validation MAE: 0.0027685731183737516
# SNR [30dB], Validation Loss: 1.2971, Validation Accuracy: 71.0583, Validation MAE: 0.002548726974055171
# SNR [40dB], Validation Loss: 1.2855, Validation Accuracy: 71.6567, Validation MAE: 0.002320436993613839
#
#
# Epoch [7/100], Training Loss: 1.1845, Training Accuracy: 58.0072, Training MAE: 0.003908265382051468
# SNR [0dB], Validation Loss: 3.0171, Validation Accuracy: 23.5417, Validation MAE: 0.011772612109780312
# SNR [10dB], Validation Loss: 1.9636, Validation Accuracy: 50.4100, Validation MAE: 0.004542812705039978
# SNR [20dB], Validation Loss: 1.4308, Validation Accuracy: 66.0683, Validation MAE: 0.0029806997627019882
# SNR [30dB], Validation Loss: 1.3421, Validation Accuracy: 68.7100, Validation MAE: 0.0028858387377113104
# SNR [40dB], Validation Loss: 1.3290, Validation Accuracy: 69.4150, Validation MAE: 0.002769883954897523
#
#
# Epoch [8/100], Training Loss: 1.1521, Training Accuracy: 59.0874, Training MAE: 0.00380470952950418
# SNR [0dB], Validation Loss: 2.9517, Validation Accuracy: 23.0600, Validation MAE: 0.01156392227858305
# SNR [10dB], Validation Loss: 1.8423, Validation Accuracy: 50.8100, Validation MAE: 0.004251378588378429
# SNR [20dB], Validation Loss: 1.2623, Validation Accuracy: 69.6650, Validation MAE: 0.002342933090403676
# SNR [30dB], Validation Loss: 1.1587, Validation Accuracy: 74.6800, Validation MAE: 0.0020796875469386578
# SNR [40dB], Validation Loss: 1.1438, Validation Accuracy: 75.1583, Validation MAE: 0.001893768203444779
#
#
# Epoch [9/100], Training Loss: 1.1259, Training Accuracy: 59.9558, Training MAE: 0.0037143344525247812
# SNR [0dB], Validation Loss: 2.9868, Validation Accuracy: 23.3600, Validation MAE: 0.011105719953775406
# SNR [10dB], Validation Loss: 1.9134, Validation Accuracy: 50.6367, Validation MAE: 0.003996721468865871
# SNR [20dB], Validation Loss: 1.3420, Validation Accuracy: 69.5267, Validation MAE: 0.002015171805396676
# SNR [30dB], Validation Loss: 1.2243, Validation Accuracy: 74.6750, Validation MAE: 0.0016238243551924825
# SNR [40dB], Validation Loss: 1.2084, Validation Accuracy: 75.2533, Validation MAE: 0.0016510298009961843
#
#
# Epoch [10/100], Training Loss: 1.1886, Training Accuracy: 58.4224, Training MAE: 0.00409193430095911
# SNR [0dB], Validation Loss: 2.9005, Validation Accuracy: 23.9700, Validation MAE: 0.011779067106544971
# SNR [10dB], Validation Loss: 1.8582, Validation Accuracy: 51.7600, Validation MAE: 0.004459778778254986
# SNR [20dB], Validation Loss: 1.3006, Validation Accuracy: 69.8767, Validation MAE: 0.002532022539526224
# SNR [30dB], Validation Loss: 1.1967, Validation Accuracy: 73.9017, Validation MAE: 0.0022021732293069363
# SNR [40dB], Validation Loss: 1.1814, Validation Accuracy: 74.8350, Validation MAE: 0.0021577682346105576
#
#
# Epoch [11/100], Training Loss: 1.0907, Training Accuracy: 61.1758, Training MAE: 0.0035987182054668665
# SNR [0dB], Validation Loss: 2.9501, Validation Accuracy: 23.6450, Validation MAE: 0.01200478058308363
# SNR [10dB], Validation Loss: 1.8801, Validation Accuracy: 50.7783, Validation MAE: 0.004435186740010977
# SNR [20dB], Validation Loss: 1.3180, Validation Accuracy: 69.7333, Validation MAE: 0.0025740424171090126
# SNR [30dB], Validation Loss: 1.2066, Validation Accuracy: 74.6500, Validation MAE: 0.002286906586959958
# SNR [40dB], Validation Loss: 1.1928, Validation Accuracy: 75.4533, Validation MAE: 0.00217652996070683
#
#
# Epoch [12/100], Training Loss: 1.0747, Training Accuracy: 61.6535, Training MAE: 0.0035208198241889477
# SNR [0dB], Validation Loss: 2.9106, Validation Accuracy: 23.9833, Validation MAE: 0.011231215670704842
# SNR [10dB], Validation Loss: 1.8722, Validation Accuracy: 51.6350, Validation MAE: 0.004332065582275391
# SNR [20dB], Validation Loss: 1.3485, Validation Accuracy: 68.8433, Validation MAE: 0.0023886566050350666
# SNR [30dB], Validation Loss: 1.2517, Validation Accuracy: 72.8050, Validation MAE: 0.0020882608368992805
# SNR [40dB], Validation Loss: 1.2345, Validation Accuracy: 73.8833, Validation MAE: 0.0019523019436746836
#
#
# Epoch [13/100], Training Loss: 1.0551, Training Accuracy: 62.2769, Training MAE: 0.00342890084721148
# SNR [0dB], Validation Loss: 2.9355, Validation Accuracy: 23.8883, Validation MAE: 0.01132929977029562
# SNR [10dB], Validation Loss: 1.9237, Validation Accuracy: 50.8283, Validation MAE: 0.004034519661217928
# SNR [20dB], Validation Loss: 1.3758, Validation Accuracy: 68.0233, Validation MAE: 0.0019769470673054457
# SNR [30dB], Validation Loss: 1.2542, Validation Accuracy: 72.4567, Validation MAE: 0.0017652319511398673
# SNR [40dB], Validation Loss: 1.2398, Validation Accuracy: 72.7033, Validation MAE: 0.001735671772621572
#
#
# Epoch [14/100], Training Loss: 1.0362, Training Accuracy: 62.9100, Training MAE: 0.0033421642147004604
# SNR [0dB], Validation Loss: 2.9058, Validation Accuracy: 24.3383, Validation MAE: 0.011291212402284145
# SNR [10dB], Validation Loss: 1.8710, Validation Accuracy: 52.6067, Validation MAE: 0.004185833968222141
# SNR [20dB], Validation Loss: 1.3463, Validation Accuracy: 71.0050, Validation MAE: 0.0023361355997622013
# SNR [30dB], Validation Loss: 1.2384, Validation Accuracy: 75.8283, Validation MAE: 0.0019824872724711895
# SNR [40dB], Validation Loss: 1.2242, Validation Accuracy: 76.3317, Validation MAE: 0.0018417348619550467
# Epoch    14: reducing learning rate of group 0 to 5.0000e-05.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
