# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((5, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.9)
        self.dropout1 = nn.Dropout(0.8)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 5, 181])

# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import mat73

# %%
train_dataset_list = []
test_dataset_list = []

# %%
df1  = sio.loadmat("../../datasets/100/DOA5/SNR_NS_0_5_100000.mat")
df2  = sio.loadmat("../../datasets/100/DOA5/SNR_NS_10_5_100000.mat")
df3  = sio.loadmat("../../datasets/100/DOA5/SNR_NS_20_5_100000.mat")
df4  = sio.loadmat("../../datasets/100/DOA5/SNR_NS_30_5_100000.mat")
df5  = sio.loadmat("../../datasets/100/DOA5/SNR_NS_40_5_100000.mat")
df = [df1, df2, df3, df4, df5]

# %%
new_train_dataset_list = []
new_test_dataset_list = []
train_dataset_list_label = []
test_dataset_list_label = []
def create_dataset(df):
    data = np.transpose(df['NS_data'], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    new_train_dataset_list.extend(X_train)
    new_test_dataset_list.append(X_test.tolist())
    train_dataset_list_label.extend(y_train)
    test_dataset_list_label.append(y_test.tolist())
    
for file in df:
    create_dataset(file)

# %%
del df
del df1
del df2
del df3
del df4
del df5

# %%
for idx, data in enumerate(new_train_dataset_list):
    new = np.zeros((3, 8, 100))
    for j in range(0, data.shape[0]):
        for k in range(0, data.shape[1]):
            new[0][j][k] = data[j][k].real
            new[1][j][k] = data[j][k].imag
            new[2][j][k] = cmath.phase(data[j][k])
    new_train_dataset_list[idx] = new
    
for idx, data in enumerate(new_test_dataset_list):
    for i, ndata in enumerate(data):
        new = np.zeros((3, 8, 100))
        for j in range(0, 8):
            for k in range(0, 100):
                new[0][j][k] = ndata[j][k].real
                new[1][j][k] = ndata[j][k].imag
                new[2][j][k] = cmath.phase(ndata[j][k])
        new_test_dataset_list[idx][i] = new

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample

    dataset = DOA_dataset(train, test)

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
doa2_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

# %%
del new_train_dataset_list
del train_dataset_list_label

# %%
test_dataset_list = []
for idx, data in enumerate(new_test_dataset_list):
    print(type(data))
    f = get_data(data, test_dataset_list_label[idx], 128, False)
    test_dataset_list.append(f)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
del new_test_dataset_list
del new

# %%
class FocalLoss(nn.modules.loss._WeightedLoss):
    def __init__(self, weight=None, gamma=2,reduction='mean'):
        super(FocalLoss, self).__init__(weight,reduction=reduction)
        self.gamma = gamma
        self.weight = weight #weight parameter will act as the alpha parameter to balance class weights

    def forward(self, input, target):
        ce_loss = F.cross_entropy(input, target,reduction=self.reduction,weight=self.weight)
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# %%
focal_criterion = FocalLoss().cuda()

# %%
num_epochs = 100
doa = 5
weights_dir = "../doa_weights/NS"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
if ("{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
    print("Pre-trained available for DOA_{}_model.pth".format(doa))
    autoencoder = torch.load(os.path.join(weights_dir, "{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-3)
	criterion = criterion.cuda()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# Pre-trained available for DOA_5_model.pth
# GeForce GTX 1080 Ti

# %%
if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.001, weight_decay=1e-2)
	criterion = criterion.cuda()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, "min", factor=0.05, patience=3, verbose=True)
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
nq_type = "NS" # Sub-Nyquist or Nyquist sample
no_samples = 100
no_doa = 5

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        criterion = None
        if (i+1)>=1 :
          print("Criterion is changed to focal loss")
          criterion = focal_criterion.cuda()
        else:
          criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa2_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa2_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa2_train_loader)*181*no_doa))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa2_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa2_train_loader)*181*no_doa)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181*no_doa))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181*no_doa)))

                total_valdation_loss+=validation_loss

        scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Criterion is changed to focal loss
# Epoch [1/100], Training Loss: 0.7096, Training Accuracy: 52.9930, Training MAE: 0.0031671738252043724
# SNR [0dB], Validation Loss: 3.0641, Validation Accuracy: 15.6240, Validation MAE: 0.012481465004384518
# SNR [10dB], Validation Loss: 1.7175, Validation Accuracy: 37.1640, Validation MAE: 0.004342781845480204
# SNR [20dB], Validation Loss: 0.9631, Validation Accuracy: 56.8107, Validation MAE: 0.002140406286343932
# SNR [30dB], Validation Loss: 0.7881, Validation Accuracy: 62.8587, Validation MAE: 0.001645294832997024
# SNR [40dB], Validation Loss: 0.7695, Validation Accuracy: 63.5933, Validation MAE: 0.001543693826533854
#
#
# Criterion is changed to focal loss
# Epoch [2/100], Training Loss: 0.7260, Training Accuracy: 52.5166, Training MAE: 0.0032147266902029514
# SNR [0dB], Validation Loss: 3.0581, Validation Accuracy: 15.8413, Validation MAE: 0.012769381515681744
# SNR [10dB], Validation Loss: 1.7263, Validation Accuracy: 37.3867, Validation MAE: 0.0045450530014932156
# SNR [20dB], Validation Loss: 0.9920, Validation Accuracy: 57.0373, Validation MAE: 0.002299708779901266
# SNR [30dB], Validation Loss: 0.8201, Validation Accuracy: 62.8973, Validation MAE: 0.0016405542846769094
# SNR [40dB], Validation Loss: 0.8029, Validation Accuracy: 63.8027, Validation MAE: 0.0016577023779973388
#
#
# Criterion is changed to focal loss
# Epoch [3/100], Training Loss: 0.7320, Training Accuracy: 52.2936, Training MAE: 0.003237696597352624
# SNR [0dB], Validation Loss: 3.0536, Validation Accuracy: 15.4893, Validation MAE: 0.012929155491292477
# SNR [10dB], Validation Loss: 1.7175, Validation Accuracy: 36.8573, Validation MAE: 0.0044998060911893845
# SNR [20dB], Validation Loss: 0.9768, Validation Accuracy: 55.5173, Validation MAE: 0.0022909685503691435
# SNR [30dB], Validation Loss: 0.8053, Validation Accuracy: 61.0347, Validation MAE: 0.0018344999989494681
# SNR [40dB], Validation Loss: 0.7883, Validation Accuracy: 61.6333, Validation MAE: 0.0018166055670008063
#
#
# Criterion is changed to focal loss
# Epoch [4/100], Training Loss: 0.7359, Training Accuracy: 52.1710, Training MAE: 0.0032336153090000153
# SNR [0dB], Validation Loss: 3.0898, Validation Accuracy: 15.4467, Validation MAE: 0.01310759037733078
# SNR [10dB], Validation Loss: 1.7698, Validation Accuracy: 36.0427, Validation MAE: 0.004670659080147743
# SNR [20dB], Validation Loss: 1.0300, Validation Accuracy: 53.6640, Validation MAE: 0.002291125478222966
# SNR [30dB], Validation Loss: 0.8545, Validation Accuracy: 59.1320, Validation MAE: 0.0016947052208706737
# SNR [40dB], Validation Loss: 0.8375, Validation Accuracy: 59.7893, Validation MAE: 0.0015765076968818903
#
#
# Criterion is changed to focal loss
# Epoch [5/100], Training Loss: 0.7408, Training Accuracy: 51.9949, Training MAE: 0.003238830016925931
# SNR [0dB], Validation Loss: 3.0749, Validation Accuracy: 15.4240, Validation MAE: 0.012797756120562553
# SNR [10dB], Validation Loss: 1.7682, Validation Accuracy: 36.2293, Validation MAE: 0.004485360346734524
# SNR [20dB], Validation Loss: 1.0437, Validation Accuracy: 54.0973, Validation MAE: 0.002239583060145378
# SNR [30dB], Validation Loss: 0.8813, Validation Accuracy: 59.0253, Validation MAE: 0.0017387312836945057
# SNR [40dB], Validation Loss: 0.8638, Validation Accuracy: 59.4133, Validation MAE: 0.0016182413091883063
#
#
# Criterion is changed to focal loss
# Epoch [6/100], Training Loss: 0.7444, Training Accuracy: 51.8063, Training MAE: 0.0032386519014835358
# SNR [0dB], Validation Loss: 3.0751, Validation Accuracy: 15.1747, Validation MAE: 0.012849410995841026
# SNR [10dB], Validation Loss: 1.7269, Validation Accuracy: 36.9027, Validation MAE: 0.004451894201338291
# SNR [20dB], Validation Loss: 0.9799, Validation Accuracy: 56.4933, Validation MAE: 0.0021429324988275766
# SNR [30dB], Validation Loss: 0.8073, Validation Accuracy: 62.5813, Validation MAE: 0.0015324465930461884
# SNR [40dB], Validation Loss: 0.7917, Validation Accuracy: 62.9280, Validation MAE: 0.0015478782588616014
#
#
# Criterion is changed to focal loss
# Epoch [7/100], Training Loss: 0.7492, Training Accuracy: 51.6978, Training MAE: 0.0032587472815066576
# SNR [0dB], Validation Loss: 3.0722, Validation Accuracy: 15.3520, Validation MAE: 0.01251684408634901
# SNR [10dB], Validation Loss: 1.7584, Validation Accuracy: 36.3587, Validation MAE: 0.00426995474845171
# SNR [20dB], Validation Loss: 1.0353, Validation Accuracy: 55.4160, Validation MAE: 0.0021772286854684353
# SNR [30dB], Validation Loss: 0.8628, Validation Accuracy: 61.3600, Validation MAE: 0.0017922684783115983
# SNR [40dB], Validation Loss: 0.8465, Validation Accuracy: 61.7733, Validation MAE: 0.001716984435915947
# Epoch     7: reducing learning rate of group 0 to 5.0000e-05.
#
#
# Criterion is changed to focal loss
# Epoch [8/100], Training Loss: 0.4665, Training Accuracy: 61.5639, Training MAE: 0.0024185050278902054
# SNR [0dB], Validation Loss: 2.8666, Validation Accuracy: 14.9560, Validation MAE: 0.013006439432501793
# SNR [10dB], Validation Loss: 1.4320, Validation Accuracy: 37.0747, Validation MAE: 0.0045009818859398365
# SNR [20dB], Validation Loss: 0.6195, Validation Accuracy: 61.5240, Validation MAE: 0.0019754208624362946
# SNR [30dB], Validation Loss: 0.4280, Validation Accuracy: 70.8387, Validation MAE: 0.001239080331288278
# SNR [40dB], Validation Loss: 0.4090, Validation Accuracy: 72.1707, Validation MAE: 0.0012034180108457804
#
#
# Criterion is changed to focal loss
# Epoch [9/100], Training Loss: 0.4158, Training Accuracy: 63.1616, Training MAE: 0.00221651210449636
# SNR [0dB], Validation Loss: 2.8806, Validation Accuracy: 14.9613, Validation MAE: 0.013086989521980286
# SNR [10dB], Validation Loss: 1.4234, Validation Accuracy: 37.3640, Validation MAE: 0.004518155008554459
# SNR [20dB], Validation Loss: 0.5893, Validation Accuracy: 62.5787, Validation MAE: 0.0018385436851531267
# SNR [30dB], Validation Loss: 0.3932, Validation Accuracy: 72.0987, Validation MAE: 0.0011197112035006285
# SNR [40dB], Validation Loss: 0.3730, Validation Accuracy: 73.4413, Validation MAE: 0.001072544022463262
#
#
# Criterion is changed to focal loss
# Epoch [10/100], Training Loss: 0.3964, Training Accuracy: 63.7685, Training MAE: 0.0021197607275098562
# SNR [0dB], Validation Loss: 2.8759, Validation Accuracy: 14.9907, Validation MAE: 0.013275861740112305
# SNR [10dB], Validation Loss: 1.4305, Validation Accuracy: 37.0533, Validation MAE: 0.004655236843973398
# SNR [20dB], Validation Loss: 0.5955, Validation Accuracy: 62.0667, Validation MAE: 0.0019416759023442864
# SNR [30dB], Validation Loss: 0.3940, Validation Accuracy: 72.0120, Validation MAE: 0.0011267198715358973
# SNR [40dB], Validation Loss: 0.3718, Validation Accuracy: 73.2360, Validation MAE: 0.0011003779945895076
#
#
# Criterion is changed to focal loss
# Epoch [11/100], Training Loss: 0.3825, Training Accuracy: 64.2134, Training MAE: 0.0020556848030537367
# SNR [0dB], Validation Loss: 2.8957, Validation Accuracy: 14.9480, Validation MAE: 0.013477914966642857
# SNR [10dB], Validation Loss: 1.4249, Validation Accuracy: 37.4960, Validation MAE: 0.004655354656279087
# SNR [20dB], Validation Loss: 0.5754, Validation Accuracy: 62.9960, Validation MAE: 0.0018817601958289742
# SNR [30dB], Validation Loss: 0.3731, Validation Accuracy: 72.9773, Validation MAE: 0.0010690909111872315
# SNR [40dB], Validation Loss: 0.3514, Validation Accuracy: 74.4467, Validation MAE: 0.0010099648497998714
#
#
# Criterion is changed to focal loss
# Epoch [12/100], Training Loss: 0.3722, Training Accuracy: 64.5348, Training MAE: 0.001993762794882059
# SNR [0dB], Validation Loss: 2.9008, Validation Accuracy: 14.8773, Validation MAE: 0.013461340218782425
# SNR [10dB], Validation Loss: 1.4366, Validation Accuracy: 37.4653, Validation MAE: 0.00473230192437768
# SNR [20dB], Validation Loss: 0.5842, Validation Accuracy: 63.1320, Validation MAE: 0.0018731370801106095
# SNR [30dB], Validation Loss: 0.3776, Validation Accuracy: 73.4893, Validation MAE: 0.0011241933098062873
# SNR [40dB], Validation Loss: 0.3544, Validation Accuracy: 74.7867, Validation MAE: 0.0010334047256037593
# Epoch    12: reducing learning rate of group 0 to 2.5000e-06.
#
#
# Criterion is changed to focal loss
# Epoch [13/100], Training Loss: 0.3516, Training Accuracy: 65.3870, Training MAE: 0.0019096917239949107
# SNR [0dB], Validation Loss: 2.8983, Validation Accuracy: 14.8933, Validation MAE: 0.013502237387001514
# SNR [10dB], Validation Loss: 1.4109, Validation Accuracy: 37.8307, Validation MAE: 0.004785433411598206
# SNR [20dB], Validation Loss: 0.5519, Validation Accuracy: 63.9800, Validation MAE: 0.0018875445239245892
# SNR [30dB], Validation Loss: 0.3491, Validation Accuracy: 74.4867, Validation MAE: 0.0010700516868382692
# SNR [40dB], Validation Loss: 0.3271, Validation Accuracy: 75.8253, Validation MAE: 0.0010132037568837404
#
#
# Criterion is changed to focal loss
# Epoch [14/100], Training Loss: 0.3489, Training Accuracy: 65.4512, Training MAE: 0.0018994410056620836
# SNR [0dB], Validation Loss: 2.8862, Validation Accuracy: 14.9547, Validation MAE: 0.013409252278506756
# SNR [10dB], Validation Loss: 1.4091, Validation Accuracy: 37.3547, Validation MAE: 0.004749943036586046
# SNR [20dB], Validation Loss: 0.5600, Validation Accuracy: 63.3200, Validation MAE: 0.0018840567208826542
# SNR [30dB], Validation Loss: 0.3545, Validation Accuracy: 73.7680, Validation MAE: 0.0010753971291705966
# SNR [40dB], Validation Loss: 0.3318, Validation Accuracy: 75.2280, Validation MAE: 0.000994348432868719
#
#
# Criterion is changed to focal loss
# Epoch [15/100], Training Loss: 0.3481, Training Accuracy: 65.5086, Training MAE: 0.0018902226584032178
# SNR [0dB], Validation Loss: 2.8886, Validation Accuracy: 14.9080, Validation MAE: 0.013447378762066364
# SNR [10dB], Validation Loss: 1.4092, Validation Accuracy: 37.4600, Validation MAE: 0.004774406552314758
# SNR [20dB], Validation Loss: 0.5573, Validation Accuracy: 63.4840, Validation MAE: 0.0019218114903196692
# SNR [30dB], Validation Loss: 0.3518, Validation Accuracy: 74.1467, Validation MAE: 0.0010742509039118886
# SNR [40dB], Validation Loss: 0.3293, Validation Accuracy: 75.5800, Validation MAE: 0.0010045121889561415
#
#
# Criterion is changed to focal loss
# Epoch [16/100], Training Loss: 0.3472, Training Accuracy: 65.5488, Training MAE: 0.0018812573980540037
# SNR [0dB], Validation Loss: 2.8963, Validation Accuracy: 14.8867, Validation MAE: 0.013510852120816708
# SNR [10dB], Validation Loss: 1.3909, Validation Accuracy: 38.1240, Validation MAE: 0.004760364070534706
# SNR [20dB], Validation Loss: 0.5271, Validation Accuracy: 64.6133, Validation MAE: 0.0018440590938553214
# SNR [30dB], Validation Loss: 0.3271, Validation Accuracy: 75.0787, Validation MAE: 0.0010541866067796946
# SNR [40dB], Validation Loss: 0.3057, Validation Accuracy: 76.6120, Validation MAE: 0.000977858668193221
# Epoch    16: reducing learning rate of group 0 to 1.2500e-07.
#
#
# Criterion is changed to focal loss
# Epoch [17/100], Training Loss: 0.3460, Training Accuracy: 65.5878, Training MAE: 0.001878660754300654
# SNR [0dB], Validation Loss: 2.8888, Validation Accuracy: 14.8920, Validation MAE: 0.013444142416119576
# SNR [10dB], Validation Loss: 1.4054, Validation Accuracy: 37.5227, Validation MAE: 0.004732481669634581
# SNR [20dB], Validation Loss: 0.5524, Validation Accuracy: 63.5093, Validation MAE: 0.0018898756243288517
# SNR [30dB], Validation Loss: 0.3476, Validation Accuracy: 73.9680, Validation MAE: 0.0010744413593783975
# SNR [40dB], Validation Loss: 0.3252, Validation Accuracy: 75.4013, Validation MAE: 0.0009988452075049281
#
#
# Criterion is changed to focal loss
# Epoch [18/100], Training Loss: 0.3460, Training Accuracy: 65.5790, Training MAE: 0.0018846720922738314
# SNR [0dB], Validation Loss: 2.8909, Validation Accuracy: 14.9187, Validation MAE: 0.013455200009047985
# SNR [10dB], Validation Loss: 1.4039, Validation Accuracy: 37.6080, Validation MAE: 0.004752337466925383
# SNR [20dB], Validation Loss: 0.5487, Validation Accuracy: 63.7533, Validation MAE: 0.001876711961813271
# SNR [30dB], Validation Loss: 0.3447, Validation Accuracy: 74.1560, Validation MAE: 0.0010647892486304045
# SNR [40dB], Validation Loss: 0.3225, Validation Accuracy: 75.7387, Validation MAE: 0.0009978991001844406
#
#
# Criterion is changed to focal loss
# Epoch [19/100], Training Loss: 0.3457, Training Accuracy: 65.5802, Training MAE: 0.0018821865087375045
# SNR [0dB], Validation Loss: 2.8867, Validation Accuracy: 14.9760, Validation MAE: 0.013467756099998951
# SNR [10dB], Validation Loss: 1.4017, Validation Accuracy: 37.5773, Validation MAE: 0.004757256247103214
# SNR [20dB], Validation Loss: 0.5466, Validation Accuracy: 63.7600, Validation MAE: 0.001897630630992353
# SNR [30dB], Validation Loss: 0.3421, Validation Accuracy: 74.1973, Validation MAE: 0.0010682375868782401
# SNR [40dB], Validation Loss: 0.3196, Validation Accuracy: 75.7320, Validation MAE: 0.0009945532074198127
#
#
# Criterion is changed to focal loss
# Epoch [20/100], Training Loss: 0.3458, Training Accuracy: 65.5899, Training MAE: 0.001886134734377265
# SNR [0dB], Validation Loss: 2.8918, Validation Accuracy: 14.8973, Validation MAE: 0.013536515645682812
# SNR [10dB], Validation Loss: 1.3989, Validation Accuracy: 37.7733, Validation MAE: 0.00475339125841856
# SNR [20dB], Validation Loss: 0.5384, Validation Accuracy: 63.9867, Validation MAE: 0.0018784289713948965
# SNR [30dB], Validation Loss: 0.3355, Validation Accuracy: 74.4267, Validation MAE: 0.0010616532526910305
# SNR [40dB], Validation Loss: 0.3134, Validation Accuracy: 75.9253, Validation MAE: 0.00098525732755661
# Epoch    20: reducing learning rate of group 0 to 6.2500e-09.
#
#
# Criterion is changed to focal loss
# Epoch [21/100], Training Loss: 0.3463, Training Accuracy: 65.5640, Training MAE: 0.0018818872049450874
# SNR [0dB], Validation Loss: 2.8931, Validation Accuracy: 14.9053, Validation MAE: 0.013481376692652702
# SNR [10dB], Validation Loss: 1.4060, Validation Accuracy: 37.5120, Validation MAE: 0.004791574086993933
# SNR [20dB], Validation Loss: 0.5479, Validation Accuracy: 63.6547, Validation MAE: 0.0018973613623529673
# SNR [30dB], Validation Loss: 0.3436, Validation Accuracy: 74.1253, Validation MAE: 0.001065442687831819
# SNR [40dB], Validation Loss: 0.3211, Validation Accuracy: 75.6760, Validation MAE: 0.0010039320914074779
#
#
# Criterion is changed to focal loss
# Epoch [22/100], Training Loss: 0.3460, Training Accuracy: 65.5649, Training MAE: 0.0018940854351967573
# SNR [0dB], Validation Loss: 2.8936, Validation Accuracy: 14.8307, Validation MAE: 0.01348729059100151
# SNR [10dB], Validation Loss: 1.4154, Validation Accuracy: 37.2987, Validation MAE: 0.004799241665750742
# SNR [20dB], Validation Loss: 0.5606, Validation Accuracy: 63.2440, Validation MAE: 0.0019252253696322441
# SNR [30dB], Validation Loss: 0.3538, Validation Accuracy: 73.7813, Validation MAE: 0.001081976224668324
# SNR [40dB], Validation Loss: 0.3310, Validation Accuracy: 75.2453, Validation MAE: 0.0010231287451460958
#
#
# Criterion is changed to focal loss
# Epoch [23/100], Training Loss: 0.3460, Training Accuracy: 65.5682, Training MAE: 0.001878452836535871
# SNR [0dB], Validation Loss: 2.8941, Validation Accuracy: 14.8867, Validation MAE: 0.013495458289980888
# SNR [10dB], Validation Loss: 1.4046, Validation Accuracy: 37.6960, Validation MAE: 0.0047890180721879005
# SNR [20dB], Validation Loss: 0.5458, Validation Accuracy: 63.9280, Validation MAE: 0.0018974452978000045
# SNR [30dB], Validation Loss: 0.3417, Validation Accuracy: 74.3947, Validation MAE: 0.0010685109300538898
# SNR [40dB], Validation Loss: 0.3195, Validation Accuracy: 75.8720, Validation MAE: 0.0009961724281311035
#
#
# Criterion is changed to focal loss
# Epoch [24/100], Training Loss: 0.3454, Training Accuracy: 65.6042, Training MAE: 0.0018877199618145823
# SNR [0dB], Validation Loss: 2.8960, Validation Accuracy: 14.8893, Validation MAE: 0.01347687840461731
# SNR [10dB], Validation Loss: 1.4015, Validation Accuracy: 37.7747, Validation MAE: 0.004762393422424793
# SNR [20dB], Validation Loss: 0.5422, Validation Accuracy: 63.9560, Validation MAE: 0.001861329423263669
# SNR [30dB], Validation Loss: 0.3393, Validation Accuracy: 74.3907, Validation MAE: 0.0010572834871709347
# SNR [40dB], Validation Loss: 0.3173, Validation Accuracy: 75.8360, Validation MAE: 0.001001283759251237
#
#
# Criterion is changed to focal loss
# Epoch [25/100], Training Loss: 0.3456, Training Accuracy: 65.5709, Training MAE: 0.001892846659757197
# SNR [0dB], Validation Loss: 2.9014, Validation Accuracy: 14.8307, Validation MAE: 0.01357799582183361
# SNR [10dB], Validation Loss: 1.4043, Validation Accuracy: 37.8307, Validation MAE: 0.0048363665118813515
# SNR [20dB], Validation Loss: 0.5415, Validation Accuracy: 64.1013, Validation MAE: 0.001907510799355805
# SNR [30dB], Validation Loss: 0.3380, Validation Accuracy: 74.6493, Validation MAE: 0.0010700031416490674
# SNR [40dB], Validation Loss: 0.3159, Validation Accuracy: 76.1600, Validation MAE: 0.0010056390892714262
#
#
# Criterion is changed to focal loss
# Epoch [26/100], Training Loss: 0.3459, Training Accuracy: 65.5756, Training MAE: 0.0018860150594264269
# SNR [0dB], Validation Loss: 2.8954, Validation Accuracy: 14.8893, Validation MAE: 0.013550844974815845
# SNR [10dB], Validation Loss: 1.4016, Validation Accuracy: 37.7653, Validation MAE: 0.004809678066521883
# SNR [20dB], Validation Loss: 0.5405, Validation Accuracy: 64.1787, Validation MAE: 0.0019111987203359604
# SNR [30dB], Validation Loss: 0.3377, Validation Accuracy: 74.7160, Validation MAE: 0.0010698081459850073
# SNR [40dB], Validation Loss: 0.3159, Validation Accuracy: 76.2587, Validation MAE: 0.001006638747639954
#
#
# Criterion is changed to focal loss
# Epoch [27/100], Training Loss: 0.3455, Training Accuracy: 65.6021, Training MAE: 0.001880205818451941
# SNR [0dB], Validation Loss: 2.8984, Validation Accuracy: 14.8773, Validation MAE: 0.013484211638569832
# SNR [10dB], Validation Loss: 1.4062, Validation Accuracy: 37.6720, Validation MAE: 0.0047964476980268955
# SNR [20dB], Validation Loss: 0.5436, Validation Accuracy: 64.0453, Validation MAE: 0.0018922361778095365
# SNR [30dB], Validation Loss: 0.3391, Validation Accuracy: 74.6253, Validation MAE: 0.001055605709552765
# SNR [40dB], Validation Loss: 0.3169, Validation Accuracy: 76.1253, Validation MAE: 0.0009944943012669683
#
#
# Criterion is changed to focal loss
# Epoch [28/100], Training Loss: 0.3454, Training Accuracy: 65.5840, Training MAE: 0.001873208675533533
# SNR [0dB], Validation Loss: 2.8914, Validation Accuracy: 14.8320, Validation MAE: 0.013405348174273968
# SNR [10dB], Validation Loss: 1.4167, Validation Accuracy: 37.1267, Validation MAE: 0.004774128086864948
# SNR [20dB], Validation Loss: 0.5640, Validation Accuracy: 62.9947, Validation MAE: 0.0019070626003667712
# SNR [30dB], Validation Loss: 0.3561, Validation Accuracy: 73.5653, Validation MAE: 0.0010649360483512282
# SNR [40dB], Validation Loss: 0.3331, Validation Accuracy: 74.9747, Validation MAE: 0.0010130131850019097
#
#
# Criterion is changed to focal loss
# Epoch [29/100], Training Loss: 0.3457, Training Accuracy: 65.5810, Training MAE: 0.00188452226575464
# SNR [0dB], Validation Loss: 2.8974, Validation Accuracy: 14.8080, Validation MAE: 0.013503413647413254
# SNR [10dB], Validation Loss: 1.4085, Validation Accuracy: 37.5027, Validation MAE: 0.004786721430718899
# SNR [20dB], Validation Loss: 0.5498, Validation Accuracy: 63.6920, Validation MAE: 0.0018825402949005365
# SNR [30dB], Validation Loss: 0.3449, Validation Accuracy: 74.2147, Validation MAE: 0.0010600438108667731
# SNR [40dB], Validation Loss: 0.3226, Validation Accuracy: 75.6667, Validation MAE: 0.0009885251056402922
#
#
# Criterion is changed to focal loss
# Epoch [30/100], Training Loss: 0.3454, Training Accuracy: 65.6064, Training MAE: 0.001879939460195601
# SNR [0dB], Validation Loss: 2.8864, Validation Accuracy: 14.8627, Validation MAE: 0.0134255550801754
# SNR [10dB], Validation Loss: 1.4071, Validation Accuracy: 37.2667, Validation MAE: 0.004759239032864571
# SNR [20dB], Validation Loss: 0.5552, Validation Accuracy: 63.3253, Validation MAE: 0.0018933333922177553
# SNR [30dB], Validation Loss: 0.3495, Validation Accuracy: 73.8893, Validation MAE: 0.001072071143426001
# SNR [40dB], Validation Loss: 0.3269, Validation Accuracy: 75.3320, Validation MAE: 0.0009919778676703572
#
#
# Criterion is changed to focal loss
# Epoch [31/100], Training Loss: 0.3454, Training Accuracy: 65.6002, Training MAE: 0.001877125701867044
# SNR [0dB], Validation Loss: 2.8875, Validation Accuracy: 14.9240, Validation MAE: 0.013445351272821426
# SNR [10dB], Validation Loss: 1.3943, Validation Accuracy: 37.8000, Validation MAE: 0.004751194734126329
# SNR [20dB], Validation Loss: 0.5377, Validation Accuracy: 64.0227, Validation MAE: 0.0018721857341006398
# SNR [30dB], Validation Loss: 0.3353, Validation Accuracy: 74.5853, Validation MAE: 0.001058156369253993
# SNR [40dB], Validation Loss: 0.3134, Validation Accuracy: 76.0533, Validation MAE: 0.0009870618814602494
#
#
# Criterion is changed to focal loss
# Epoch [32/100], Training Loss: 0.3457, Training Accuracy: 65.5944, Training MAE: 0.0018798810197040439
# SNR [0dB], Validation Loss: 2.8885, Validation Accuracy: 14.9507, Validation MAE: 0.01347399689257145
# SNR [10dB], Validation Loss: 1.4018, Validation Accuracy: 37.5360, Validation MAE: 0.004800830967724323
# SNR [20dB], Validation Loss: 0.5463, Validation Accuracy: 63.6920, Validation MAE: 0.0018933911342173815
# SNR [30dB], Validation Loss: 0.3417, Validation Accuracy: 74.2160, Validation MAE: 0.0010668036993592978
# SNR [40dB], Validation Loss: 0.3193, Validation Accuracy: 75.7613, Validation MAE: 0.000993187539279461
#
#
# Criterion is changed to focal loss
# Epoch [33/100], Training Loss: 0.3456, Training Accuracy: 65.5833, Training MAE: 0.0018835325026884675
# SNR [0dB], Validation Loss: 2.8936, Validation Accuracy: 14.9013, Validation MAE: 0.013505088165402412
# SNR [10dB], Validation Loss: 1.4051, Validation Accuracy: 37.6893, Validation MAE: 0.004795830696821213
# SNR [20dB], Validation Loss: 0.5468, Validation Accuracy: 63.9307, Validation MAE: 0.0019074772717431188
# SNR [30dB], Validation Loss: 0.3425, Validation Accuracy: 74.3893, Validation MAE: 0.0010736460098996758
# SNR [40dB], Validation Loss: 0.3204, Validation Accuracy: 75.8853, Validation MAE: 0.0010040242923423648
#
#
# Criterion is changed to focal loss
# Epoch [34/100], Training Loss: 0.3458, Training Accuracy: 65.5526, Training MAE: 0.0018823073478415608
# SNR [0dB], Validation Loss: 2.8992, Validation Accuracy: 14.7920, Validation MAE: 0.01354833971709013
# SNR [10dB], Validation Loss: 1.4022, Validation Accuracy: 37.8520, Validation MAE: 0.004777498077601194
# SNR [20dB], Validation Loss: 0.5386, Validation Accuracy: 64.1480, Validation MAE: 0.0018781066173687577
# SNR [30dB], Validation Loss: 0.3362, Validation Accuracy: 74.6293, Validation MAE: 0.0010672961361706257
# SNR [40dB], Validation Loss: 0.3144, Validation Accuracy: 76.1213, Validation MAE: 0.00100658496376127
#
#
# Criterion is changed to focal loss
# Epoch [35/100], Training Loss: 0.3455, Training Accuracy: 65.6016, Training MAE: 0.0018877576803788543
# SNR [0dB], Validation Loss: 2.8951, Validation Accuracy: 14.8693, Validation MAE: 0.013480117544531822
# SNR [10dB], Validation Loss: 1.4101, Validation Accuracy: 37.4427, Validation MAE: 0.004772031679749489
# SNR [20dB], Validation Loss: 0.5530, Validation Accuracy: 63.5627, Validation MAE: 0.0018961277091875672
# SNR [30dB], Validation Loss: 0.3478, Validation Accuracy: 74.0107, Validation MAE: 0.0010711541399359703
# SNR [40dB], Validation Loss: 0.3257, Validation Accuracy: 75.3613, Validation MAE: 0.0010090580908581614
#
#
# Criterion is changed to focal loss
# Epoch [36/100], Training Loss: 0.3458, Training Accuracy: 65.5936, Training MAE: 0.0018746383721008897
# SNR [0dB], Validation Loss: 2.8912, Validation Accuracy: 14.8813, Validation MAE: 0.01349147129803896
# SNR [10dB], Validation Loss: 1.4002, Validation Accuracy: 37.7467, Validation MAE: 0.004784765653312206
# SNR [20dB], Validation Loss: 0.5405, Validation Accuracy: 64.0667, Validation MAE: 0.001901308074593544
# SNR [30dB], Validation Loss: 0.3380, Validation Accuracy: 74.6013, Validation MAE: 0.0010771091328933835
# SNR [40dB], Validation Loss: 0.3162, Validation Accuracy: 76.0987, Validation MAE: 0.0010152324102818966
#
#
# Criterion is changed to focal loss
# Epoch [37/100], Training Loss: 0.3456, Training Accuracy: 65.5839, Training MAE: 0.0018867198377847672
# SNR [0dB], Validation Loss: 2.8844, Validation Accuracy: 14.9400, Validation MAE: 0.013421116396784782
# SNR [10dB], Validation Loss: 1.4007, Validation Accuracy: 37.4467, Validation MAE: 0.0047645531594753265
# SNR [20dB], Validation Loss: 0.5488, Validation Accuracy: 63.4027, Validation MAE: 0.0018934216350317001
# SNR [30dB], Validation Loss: 0.3437, Validation Accuracy: 74.0040, Validation MAE: 0.001062579802237451
# SNR [40dB], Validation Loss: 0.3212, Validation Accuracy: 75.4840, Validation MAE: 0.0009895103285089135
#
#
# Criterion is changed to focal loss
# Epoch [38/100], Training Loss: 0.3455, Training Accuracy: 65.5919, Training MAE: 0.001871610525995493
# SNR [0dB], Validation Loss: 2.8971, Validation Accuracy: 14.8107, Validation MAE: 0.013494606129825115
# SNR [10dB], Validation Loss: 1.4080, Validation Accuracy: 37.4893, Validation MAE: 0.0047702849842607975
# SNR [20dB], Validation Loss: 0.5491, Validation Accuracy: 63.6893, Validation MAE: 0.0018798478413373232
# SNR [30dB], Validation Loss: 0.3445, Validation Accuracy: 74.2187, Validation MAE: 0.0010892583522945642
# SNR [40dB], Validation Loss: 0.3222, Validation Accuracy: 75.6947, Validation MAE: 0.0010092967422679067
#
#
# Criterion is changed to focal loss
# Epoch [39/100], Training Loss: 0.3463, Training Accuracy: 65.5723, Training MAE: 0.0018795005744323134
# SNR [0dB], Validation Loss: 2.8901, Validation Accuracy: 14.9307, Validation MAE: 0.013415739871561527
# SNR [10dB], Validation Loss: 1.4029, Validation Accuracy: 37.5867, Validation MAE: 0.0047533269971609116
# SNR [20dB], Validation Loss: 0.5470, Validation Accuracy: 63.7853, Validation MAE: 0.0018723855027928948
# SNR [30dB], Validation Loss: 0.3424, Validation Accuracy: 74.2173, Validation MAE: 0.0010481290519237518
# SNR [40dB], Validation Loss: 0.3202, Validation Accuracy: 75.7173, Validation MAE: 0.000996348331682384
#
#
# Criterion is changed to focal loss
# Epoch [40/100], Training Loss: 0.3461, Training Accuracy: 65.5675, Training MAE: 0.0018899064743891358
# SNR [0dB], Validation Loss: 2.8936, Validation Accuracy: 14.8760, Validation MAE: 0.013509199023246765
# SNR [10dB], Validation Loss: 1.4115, Validation Accuracy: 37.2120, Validation MAE: 0.004799591843038797
# SNR [20dB], Validation Loss: 0.5549, Validation Accuracy: 63.3307, Validation MAE: 0.0019117980264127254
# SNR [30dB], Validation Loss: 0.3489, Validation Accuracy: 73.9107, Validation MAE: 0.0010816839057952166
# SNR [40dB], Validation Loss: 0.3264, Validation Accuracy: 75.3413, Validation MAE: 0.0010163489496335387
#
#
# Criterion is changed to focal loss
# Epoch [41/100], Training Loss: 0.3459, Training Accuracy: 65.6021, Training MAE: 0.0018785984721034765
# SNR [0dB], Validation Loss: 2.8853, Validation Accuracy: 14.9200, Validation MAE: 0.013437229208648205
# SNR [10dB], Validation Loss: 1.4107, Validation Accuracy: 37.2133, Validation MAE: 0.004774466156959534
# SNR [20dB], Validation Loss: 0.5600, Validation Accuracy: 63.1120, Validation MAE: 0.0019192304462194443
# SNR [30dB], Validation Loss: 0.3525, Validation Accuracy: 73.7453, Validation MAE: 0.0010942670051008463
# SNR [40dB], Validation Loss: 0.3294, Validation Accuracy: 75.3307, Validation MAE: 0.0010111307492479682
#
#
# Criterion is changed to focal loss
# Epoch [42/100], Training Loss: 0.3458, Training Accuracy: 65.6038, Training MAE: 0.0018887296319007874
# SNR [0dB], Validation Loss: 2.9020, Validation Accuracy: 14.8653, Validation MAE: 0.013553610071539879
# SNR [10dB], Validation Loss: 1.4027, Validation Accuracy: 37.8120, Validation MAE: 0.004779927898198366
# SNR [20dB], Validation Loss: 0.5389, Validation Accuracy: 64.1027, Validation MAE: 0.0018862563883885741
# SNR [30dB], Validation Loss: 0.3364, Validation Accuracy: 74.5693, Validation MAE: 0.001062360592186451
# SNR [40dB], Validation Loss: 0.3146, Validation Accuracy: 76.0053, Validation MAE: 0.0009986108634620905
#
#
# Criterion is changed to focal loss
# Epoch [43/100], Training Loss: 0.3460, Training Accuracy: 65.5596, Training MAE: 0.0018806917360052466
# SNR [0dB], Validation Loss: 2.8939, Validation Accuracy: 14.8653, Validation MAE: 0.013501487672328949
# SNR [10dB], Validation Loss: 1.4075, Validation Accuracy: 37.5040, Validation MAE: 0.0047934954054653645
# SNR [20dB], Validation Loss: 0.5481, Validation Accuracy: 63.7000, Validation MAE: 0.0019051552517339587
# SNR [30dB], Validation Loss: 0.3434, Validation Accuracy: 74.2707, Validation MAE: 0.0010648724855855107
# SNR [40dB], Validation Loss: 0.3211, Validation Accuracy: 75.7333, Validation MAE: 0.0009876129915937781
#
#
# Criterion is changed to focal loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(no_doa))
plt.legend(fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-004af10bd35a> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 ep = range(0, len(loss_res["training"]))
#       3 plt.figure(figsize=(10, 8))
#       4 plt.plot(ep, loss_res["training"], label='Train')
#       5 plt.plot(ep, loss_res[0], label='0 dB')
#
# NameError: name 'loss_res' is not defined
