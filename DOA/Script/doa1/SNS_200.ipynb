# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("../SNS_dataset/200/DOA1")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_0_1_200.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_1_200.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_1_200.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_1_200.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_1_200.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 200)
# Out:
# 2021-06-21 16:12:14,836 - Data prepration started
# 2021-06-21 16:12:24,696 - Dividing your dataset into 3 channel
# 2021-06-21 16:15:39,598 - Creating Train dataloader
# 2021-06-21 16:15:40,745 - Creating Validation dataloader
# 2021-06-21 16:15:40,888 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((1, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.7)
        self.dropout1 = nn.Dropout(0.6)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 1, 181])

# %%
num_epochs = 60
doa = 1
weights_dir = "./doa_weights/"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(64*len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*64*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*128*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_200_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/DOA_{}_200_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 2.8256, Training Accuracy: 28.6426, Training MAE: 0.12493006569768748
# SNR [0dB], Validation Loss: 3.1241, Validation Accuracy: 25.2333, Validation MAE: 0.08891135640041202
# SNR [10dB], Validation Loss: 1.9271, Validation Accuracy: 55.2533, Validation MAE: 0.035622995481786685
# SNR [20dB], Validation Loss: 1.5704, Validation Accuracy: 69.0733, Validation MAE: 0.02618859151137747
# SNR [30dB], Validation Loss: 1.5205, Validation Accuracy: 72.1133, Validation MAE: 0.02713525084277554
# SNR [40dB], Validation Loss: 1.4938, Validation Accuracy: 72.8867, Validation MAE: 0.02366904380091769
#
#
# Epoch [2/60], Training Loss: 1.1347, Training Accuracy: 62.6073, Training MAE: 0.03464648028195847
# SNR [0dB], Validation Loss: 2.8077, Validation Accuracy: 30.3667, Validation MAE: 0.07033700779567376
# SNR [10dB], Validation Loss: 1.4942, Validation Accuracy: 65.0667, Validation MAE: 0.028532195196179416
# SNR [20dB], Validation Loss: 0.9753, Validation Accuracy: 82.6333, Validation MAE: 0.01978218056465961
# SNR [30dB], Validation Loss: 0.8739, Validation Accuracy: 86.3933, Validation MAE: 0.02046656990354902
# SNR [40dB], Validation Loss: 0.8318, Validation Accuracy: 87.4067, Validation MAE: 0.020021771701470174
#
#
# Epoch [3/60], Training Loss: 0.8939, Training Accuracy: 70.1362, Training MAE: 0.028747287900960133
# SNR [0dB], Validation Loss: 2.7127, Validation Accuracy: 32.1067, Validation MAE: 0.06628919784155819
# SNR [10dB], Validation Loss: 1.4325, Validation Accuracy: 65.4733, Validation MAE: 0.031056863938571027
# SNR [20dB], Validation Loss: 0.8976, Validation Accuracy: 79.7467, Validation MAE: 0.023248387606517464
# SNR [30dB], Validation Loss: 0.8005, Validation Accuracy: 80.8533, Validation MAE: 0.022820415652214626
# SNR [40dB], Validation Loss: 0.7558, Validation Accuracy: 82.2733, Validation MAE: 0.021309345444329993
#
#
# Epoch [4/60], Training Loss: 0.7988, Training Accuracy: 72.8299, Training MAE: 0.026703542408992854
# SNR [0dB], Validation Loss: 2.5604, Validation Accuracy: 33.6600, Validation MAE: 0.06052950007023129
# SNR [10dB], Validation Loss: 1.2718, Validation Accuracy: 68.8667, Validation MAE: 0.024306978064425507
# SNR [20dB], Validation Loss: 0.6755, Validation Accuracy: 86.6533, Validation MAE: 0.014090885148422137
# SNR [30dB], Validation Loss: 0.5371, Validation Accuracy: 90.9133, Validation MAE: 0.013233112299840808
# SNR [40dB], Validation Loss: 0.4959, Validation Accuracy: 92.2467, Validation MAE: 0.012198298061616257
#
#
# Epoch [5/60], Training Loss: 0.7429, Training Accuracy: 74.3758, Training MAE: 0.02573514730607868
# SNR [0dB], Validation Loss: 2.5569, Validation Accuracy: 34.6667, Validation MAE: 0.06315622366326434
# SNR [10dB], Validation Loss: 1.2837, Validation Accuracy: 70.1267, Validation MAE: 0.025273389947560634
# SNR [20dB], Validation Loss: 0.6227, Validation Accuracy: 88.8133, Validation MAE: 0.015221535841370915
# SNR [30dB], Validation Loss: 0.4675, Validation Accuracy: 92.7267, Validation MAE: 0.0142265924946156
# SNR [40dB], Validation Loss: 0.4228, Validation Accuracy: 93.8133, Validation MAE: 0.012929874051877517
#
#
# Epoch [6/60], Training Loss: 0.7007, Training Accuracy: 75.6308, Training MAE: 0.02504191378520009
# SNR [0dB], Validation Loss: 2.5155, Validation Accuracy: 34.0267, Validation MAE: 0.059050619205918156
# SNR [10dB], Validation Loss: 1.2588, Validation Accuracy: 69.5200, Validation MAE: 0.024449635382526452
# SNR [20dB], Validation Loss: 0.6152, Validation Accuracy: 88.5933, Validation MAE: 0.013850562435621314
# SNR [30dB], Validation Loss: 0.4544, Validation Accuracy: 94.4333, Validation MAE: 0.01102228965727128
# SNR [40dB], Validation Loss: 0.4122, Validation Accuracy: 95.4867, Validation MAE: 0.009337470151699598
#
#
# Epoch [7/60], Training Loss: 0.6685, Training Accuracy: 76.5534, Training MAE: 0.02430113013832537
# SNR [0dB], Validation Loss: 2.4208, Validation Accuracy: 34.5467, Validation MAE: 0.06001520214907763
# SNR [10dB], Validation Loss: 1.2153, Validation Accuracy: 69.6067, Validation MAE: 0.022725676561475793
# SNR [20dB], Validation Loss: 0.6320, Validation Accuracy: 87.5800, Validation MAE: 0.01334467763835565
# SNR [30dB], Validation Loss: 0.4783, Validation Accuracy: 93.1667, Validation MAE: 0.010137814285045416
# SNR [40dB], Validation Loss: 0.4350, Validation Accuracy: 94.2067, Validation MAE: 0.008269734993913288
#
#
# Epoch [8/60], Training Loss: 0.6421, Training Accuracy: 77.3033, Training MAE: 0.02325062072542826
# SNR [0dB], Validation Loss: 2.3674, Validation Accuracy: 35.2733, Validation MAE: 0.061001366583949806
# SNR [10dB], Validation Loss: 1.1661, Validation Accuracy: 70.0667, Validation MAE: 0.02389656393388894
# SNR [20dB], Validation Loss: 0.5769, Validation Accuracy: 87.6467, Validation MAE: 0.014482278303211912
# SNR [30dB], Validation Loss: 0.4220, Validation Accuracy: 91.4267, Validation MAE: 0.012899147860286543
# SNR [40dB], Validation Loss: 0.3790, Validation Accuracy: 92.5533, Validation MAE: 0.012364731599400693
#
#
# Epoch [9/60], Training Loss: 0.6156, Training Accuracy: 78.1925, Training MAE: 0.02274844563863693
# SNR [0dB], Validation Loss: 2.4043, Validation Accuracy: 34.1200, Validation MAE: 0.06855305974342167
# SNR [10dB], Validation Loss: 1.1699, Validation Accuracy: 71.2200, Validation MAE: 0.030415637583107034
# SNR [20dB], Validation Loss: 0.5367, Validation Accuracy: 88.5600, Validation MAE: 0.01732006156943534
# SNR [30dB], Validation Loss: 0.3693, Validation Accuracy: 92.1133, Validation MAE: 0.0178665488341605
# SNR [40dB], Validation Loss: 0.3174, Validation Accuracy: 93.4667, Validation MAE: 0.014246710834347785
#
#
# Epoch [10/60], Training Loss: 0.5935, Training Accuracy: 78.8939, Training MAE: 0.022188412265675892
# SNR [0dB], Validation Loss: 2.3575, Validation Accuracy: 34.5000, Validation MAE: 0.06436551877516622
# SNR [10dB], Validation Loss: 1.0950, Validation Accuracy: 70.7800, Validation MAE: 0.025255100547804103
# SNR [20dB], Validation Loss: 0.4285, Validation Accuracy: 89.8133, Validation MAE: 0.012885979492461841
# SNR [30dB], Validation Loss: 0.2468, Validation Accuracy: 95.0400, Validation MAE: 0.00954743246090458
# SNR [40dB], Validation Loss: 0.2030, Validation Accuracy: 96.2467, Validation MAE: 0.008335942621031931
#
#
# Epoch [11/60], Training Loss: 0.5676, Training Accuracy: 79.7261, Training MAE: 0.021743419520124856
# SNR [0dB], Validation Loss: 2.3632, Validation Accuracy: 34.5333, Validation MAE: 0.06106976893903924
# SNR [10dB], Validation Loss: 1.1511, Validation Accuracy: 71.1667, Validation MAE: 0.023903513905796422
# SNR [20dB], Validation Loss: 0.5215, Validation Accuracy: 89.6333, Validation MAE: 0.01286183748478322
# SNR [30dB], Validation Loss: 0.3437, Validation Accuracy: 95.0733, Validation MAE: 0.009590595444329993
# SNR [40dB], Validation Loss: 0.2908, Validation Accuracy: 96.2333, Validation MAE: 0.008467626299278958
#
#
# Epoch [12/60], Training Loss: 0.5399, Training Accuracy: 80.6772, Training MAE: 0.02114678112944782
# SNR [0dB], Validation Loss: 2.2687, Validation Accuracy: 34.3867, Validation MAE: 0.061204378921247304
# SNR [10dB], Validation Loss: 1.0466, Validation Accuracy: 70.6933, Validation MAE: 0.025257661063770014
# SNR [20dB], Validation Loss: 0.4539, Validation Accuracy: 88.3333, Validation MAE: 0.016306097246933233
# SNR [30dB], Validation Loss: 0.2953, Validation Accuracy: 92.3200, Validation MAE: 0.01419111105908793
# SNR [40dB], Validation Loss: 0.2509, Validation Accuracy: 92.9067, Validation MAE: 0.013475263952617287
#
#
# Epoch [13/60], Training Loss: 0.5103, Training Accuracy: 81.7612, Training MAE: 0.020630983152540597
# SNR [0dB], Validation Loss: 2.3171, Validation Accuracy: 33.8733, Validation MAE: 0.06337935434029404
# SNR [10dB], Validation Loss: 1.0890, Validation Accuracy: 70.8533, Validation MAE: 0.02407067901957112
# SNR [20dB], Validation Loss: 0.4303, Validation Accuracy: 89.7400, Validation MAE: 0.013375769617941754
# SNR [30dB], Validation Loss: 0.2330, Validation Accuracy: 95.1933, Validation MAE: 0.010703688313512502
# SNR [40dB], Validation Loss: 0.1853, Validation Accuracy: 96.3467, Validation MAE: 0.010770993304616536
#
#
# Epoch [14/60], Training Loss: 0.4802, Training Accuracy: 82.7734, Training MAE: 0.020092904990844585
# SNR [0dB], Validation Loss: 2.2942, Validation Accuracy: 33.7533, Validation MAE: 0.06454731540874614
# SNR [10dB], Validation Loss: 1.1095, Validation Accuracy: 70.7400, Validation MAE: 0.02637514338889409
# SNR [20dB], Validation Loss: 0.4908, Validation Accuracy: 89.4067, Validation MAE: 0.012504462613540594
# SNR [30dB], Validation Loss: 0.2893, Validation Accuracy: 95.5267, Validation MAE: 0.010533596895776758
# SNR [40dB], Validation Loss: 0.2323, Validation Accuracy: 96.9733, Validation MAE: 0.008754038299466242
#
#
# Epoch [15/60], Training Loss: 0.4486, Training Accuracy: 83.8995, Training MAE: 0.01952331739628509
# SNR [0dB], Validation Loss: 2.2447, Validation Accuracy: 33.6333, Validation MAE: 0.06032392721696788
# SNR [10dB], Validation Loss: 0.9759, Validation Accuracy: 71.5467, Validation MAE: 0.023633196577394888
# SNR [20dB], Validation Loss: 0.3595, Validation Accuracy: 90.6467, Validation MAE: 0.011744355159659143
# SNR [30dB], Validation Loss: 0.1789, Validation Accuracy: 96.2267, Validation MAE: 0.009618395331959921
# SNR [40dB], Validation Loss: 0.1321, Validation Accuracy: 97.5933, Validation MAE: 0.006562968208633767
#
#
# Epoch [16/60], Training Loss: 0.4173, Training Accuracy: 85.0205, Training MAE: 0.018746968646970393
# SNR [0dB], Validation Loss: 2.2845, Validation Accuracy: 33.2200, Validation MAE: 0.0640370411555389
# SNR [10dB], Validation Loss: 1.0197, Validation Accuracy: 70.9200, Validation MAE: 0.024385988271373723
# SNR [20dB], Validation Loss: 0.3999, Validation Accuracy: 90.3333, Validation MAE: 0.012087098511096545
# SNR [30dB], Validation Loss: 0.2129, Validation Accuracy: 96.0867, Validation MAE: 0.008330821589100102
# SNR [40dB], Validation Loss: 0.1630, Validation Accuracy: 97.4067, Validation MAE: 0.005077137372413147
#
#
# Epoch [17/60], Training Loss: 0.3891, Training Accuracy: 86.0360, Training MAE: 0.018290042873627
# SNR [0dB], Validation Loss: 2.2747, Validation Accuracy: 33.1933, Validation MAE: 0.0643450346474389
# SNR [10dB], Validation Loss: 0.9559, Validation Accuracy: 70.7533, Validation MAE: 0.025492496956643882
# SNR [20dB], Validation Loss: 0.3468, Validation Accuracy: 89.9933, Validation MAE: 0.012876834792583575
# SNR [30dB], Validation Loss: 0.1630, Validation Accuracy: 95.5667, Validation MAE: 0.00879976179885757
# SNR [40dB], Validation Loss: 0.1156, Validation Accuracy: 97.1400, Validation MAE: 0.006624420591815713
#
#
# Epoch [18/60], Training Loss: 0.3625, Training Accuracy: 86.9871, Training MAE: 0.017750053867611297
# SNR [0dB], Validation Loss: 2.2534, Validation Accuracy: 33.6133, Validation MAE: 0.0663572344086525
# SNR [10dB], Validation Loss: 0.9531, Validation Accuracy: 70.8000, Validation MAE: 0.02564905421855979
# SNR [20dB], Validation Loss: 0.3777, Validation Accuracy: 89.8933, Validation MAE: 0.01236875526734713
# SNR [30dB], Validation Loss: 0.1993, Validation Accuracy: 95.5000, Validation MAE: 0.009561698192714674
# SNR [40dB], Validation Loss: 0.1485, Validation Accuracy: 96.8933, Validation MAE: 0.0073589228860380185
#
#
# Epoch [19/60], Training Loss: 0.3386, Training Accuracy: 87.8214, Training MAE: 0.016935540227666572
# SNR [0dB], Validation Loss: 2.3030, Validation Accuracy: 33.1933, Validation MAE: 0.0717921124403034
# SNR [10dB], Validation Loss: 0.9303, Validation Accuracy: 70.7600, Validation MAE: 0.028321135522989045
# SNR [20dB], Validation Loss: 0.3617, Validation Accuracy: 90.0600, Validation MAE: 0.01516630185410619
# SNR [30dB], Validation Loss: 0.1943, Validation Accuracy: 95.3400, Validation MAE: 0.012181837601835378
# SNR [40dB], Validation Loss: 0.1448, Validation Accuracy: 96.9200, Validation MAE: 0.010089164481693043
#
#
# Epoch [20/60], Training Loss: 0.3160, Training Accuracy: 88.6322, Training MAE: 0.016466512440298463
# SNR [0dB], Validation Loss: 2.3530, Validation Accuracy: 32.4133, Validation MAE: 0.06709722352280176
# SNR [10dB], Validation Loss: 0.9650, Validation Accuracy: 69.9267, Validation MAE: 0.02666887114898399
# SNR [20dB], Validation Loss: 0.3605, Validation Accuracy: 89.5933, Validation MAE: 0.012700890766925743
# SNR [30dB], Validation Loss: 0.1753, Validation Accuracy: 95.8733, Validation MAE: 0.008469089451259482
# SNR [40dB], Validation Loss: 0.1266, Validation Accuracy: 97.5333, Validation MAE: 0.007819084183912351
#
#
# Epoch [21/60], Training Loss: 0.2961, Training Accuracy: 89.3558, Training MAE: 0.01594522891031022
# SNR [0dB], Validation Loss: 2.3860, Validation Accuracy: 32.6667, Validation MAE: 0.0707807086337672
# SNR [10dB], Validation Loss: 0.9418, Validation Accuracy: 70.6933, Validation MAE: 0.027393862955332898
# SNR [20dB], Validation Loss: 0.3450, Validation Accuracy: 90.0867, Validation MAE: 0.012842816509036426
# SNR [30dB], Validation Loss: 0.1638, Validation Accuracy: 96.0467, Validation MAE: 0.008539686534319692
# SNR [40dB], Validation Loss: 0.1165, Validation Accuracy: 97.4533, Validation MAE: 0.006383732091019758
#
#
# Epoch [22/60], Training Loss: 0.2784, Training Accuracy: 89.9925, Training MAE: 0.01528221792714104
# SNR [0dB], Validation Loss: 2.4191, Validation Accuracy: 32.8400, Validation MAE: 0.06853367297967974
# SNR [10dB], Validation Loss: 0.9393, Validation Accuracy: 70.9267, Validation MAE: 0.025251808455847926
# SNR [20dB], Validation Loss: 0.3266, Validation Accuracy: 90.4800, Validation MAE: 0.013781794292536755
# SNR [30dB], Validation Loss: 0.1461, Validation Accuracy: 96.2733, Validation MAE: 0.009421967178574773
# SNR [40dB], Validation Loss: 0.1025, Validation Accuracy: 97.5667, Validation MAE: 0.009910294152074164
#
#
# Epoch [23/60], Training Loss: 0.2603, Training Accuracy: 90.5459, Training MAE: 0.014437715730424011
# SNR [0dB], Validation Loss: 2.4442, Validation Accuracy: 32.2800, Validation MAE: 0.07068926163498455
# SNR [10dB], Validation Loss: 0.9868, Validation Accuracy: 69.3400, Validation MAE: 0.02731521853637981
# SNR [20dB], Validation Loss: 0.3952, Validation Accuracy: 89.1533, Validation MAE: 0.013771552228673097
# SNR [30dB], Validation Loss: 0.2124, Validation Accuracy: 94.5000, Validation MAE: 0.012126969402565784
# SNR [40dB], Validation Loss: 0.1606, Validation Accuracy: 95.9800, Validation MAE: 0.011291509621687424
#
#
# Epoch [24/60], Training Loss: 0.2464, Training Accuracy: 91.1007, Training MAE: 0.014034501581087185
# SNR [0dB], Validation Loss: 2.4605, Validation Accuracy: 33.1267, Validation MAE: 0.06743996687423916
# SNR [10dB], Validation Loss: 0.9237, Validation Accuracy: 70.3800, Validation MAE: 0.027067945851671504
# SNR [20dB], Validation Loss: 0.3115, Validation Accuracy: 89.9867, Validation MAE: 0.013714489301432719
# SNR [30dB], Validation Loss: 0.1413, Validation Accuracy: 95.3667, Validation MAE: 0.009763613166026782
# SNR [40dB], Validation Loss: 0.0953, Validation Accuracy: 96.9200, Validation MAE: 0.006421042466523082
#
#
# Epoch [25/60], Training Loss: 0.2310, Training Accuracy: 91.6188, Training MAE: 0.013387102325999297
# SNR [0dB], Validation Loss: 2.5112, Validation Accuracy: 32.7067, Validation MAE: 0.0724644307753535
# SNR [10dB], Validation Loss: 0.9516, Validation Accuracy: 69.8733, Validation MAE: 0.027686859139432533
# SNR [20dB], Validation Loss: 0.3484, Validation Accuracy: 89.4867, Validation MAE: 0.012901708376252458
# SNR [30dB], Validation Loss: 0.1684, Validation Accuracy: 95.5267, Validation MAE: 0.009778976261822269
# SNR [40dB], Validation Loss: 0.1165, Validation Accuracy: 97.2667, Validation MAE: 0.006211811733308362
#
#
# Epoch [26/60], Training Loss: 0.2183, Training Accuracy: 92.0814, Training MAE: 0.013065820501472104
# SNR [0dB], Validation Loss: 2.5641, Validation Accuracy: 32.4800, Validation MAE: 0.07144168754096826
# SNR [10dB], Validation Loss: 0.9579, Validation Accuracy: 70.3267, Validation MAE: 0.028094712754003184
# SNR [20dB], Validation Loss: 0.3386, Validation Accuracy: 90.1933, Validation MAE: 0.012622612135967787
# SNR [30dB], Validation Loss: 0.1562, Validation Accuracy: 95.9933, Validation MAE: 0.009643268915628804
# SNR [40dB], Validation Loss: 0.1051, Validation Accuracy: 97.8933, Validation MAE: 0.005500719870774417
#
#
# Epoch [27/60], Training Loss: 0.2084, Training Accuracy: 92.4139, Training MAE: 0.012404746360504516
# SNR [0dB], Validation Loss: 2.6041, Validation Accuracy: 32.3067, Validation MAE: 0.07427837344320629
# SNR [10dB], Validation Loss: 0.9781, Validation Accuracy: 69.7533, Validation MAE: 0.02928718161812904
# SNR [20dB], Validation Loss: 0.3662, Validation Accuracy: 89.8000, Validation MAE: 0.013125204841277273
# SNR [30dB], Validation Loss: 0.1793, Validation Accuracy: 95.9533, Validation MAE: 0.008835609022380373
# SNR [40dB], Validation Loss: 0.1275, Validation Accuracy: 97.6867, Validation MAE: 0.0068607196366701
#
#
# Epoch [28/60], Training Loss: 0.1977, Training Accuracy: 92.8179, Training MAE: 0.01193115594486286
# SNR [0dB], Validation Loss: 2.5930, Validation Accuracy: 32.7867, Validation MAE: 0.07089849236819927
# SNR [10dB], Validation Loss: 0.9394, Validation Accuracy: 71.2000, Validation MAE: 0.02576354586103568
# SNR [20dB], Validation Loss: 0.3190, Validation Accuracy: 90.3733, Validation MAE: 0.012898782072291413
# SNR [30dB], Validation Loss: 0.1342, Validation Accuracy: 96.5067, Validation MAE: 0.008209014186721602
# SNR [40dB], Validation Loss: 0.0894, Validation Accuracy: 98.0267, Validation MAE: 0.005110789867965165
#
#
# Epoch [29/60], Training Loss: 0.1877, Training Accuracy: 93.1271, Training MAE: 0.01159111664854441
# SNR [0dB], Validation Loss: 2.6885, Validation Accuracy: 32.1933, Validation MAE: 0.07241834148796704
# SNR [10dB], Validation Loss: 0.9686, Validation Accuracy: 70.1400, Validation MAE: 0.026552550566532447
# SNR [20dB], Validation Loss: 0.3302, Validation Accuracy: 90.0267, Validation MAE: 0.013598900294971438
# SNR [30dB], Validation Loss: 0.1451, Validation Accuracy: 96.0600, Validation MAE: 0.00915347879014889
# SNR [40dB], Validation Loss: 0.0962, Validation Accuracy: 97.6933, Validation MAE: 0.006148896198145894
#
#
# Epoch [30/60], Training Loss: 0.1791, Training Accuracy: 93.4649, Training MAE: 0.01090646242869301
# SNR [0dB], Validation Loss: 2.6893, Validation Accuracy: 32.6467, Validation MAE: 0.07319490940162937
# SNR [10dB], Validation Loss: 0.9666, Validation Accuracy: 69.8800, Validation MAE: 0.029099166588631896
# SNR [20dB], Validation Loss: 0.3290, Validation Accuracy: 89.5867, Validation MAE: 0.015383945711208914
# SNR [30dB], Validation Loss: 0.1445, Validation Accuracy: 95.3067, Validation MAE: 0.011181407435153104
# SNR [40dB], Validation Loss: 0.0966, Validation Accuracy: 96.6733, Validation MAE: 0.008305582217436089
#
#
# Epoch [31/60], Training Loss: 0.1720, Training Accuracy: 93.7426, Training MAE: 0.010698557367134185
# SNR [0dB], Validation Loss: 2.6800, Validation Accuracy: 33.1400, Validation MAE: 0.07016691637793801
# SNR [10dB], Validation Loss: 0.9708, Validation Accuracy: 70.3200, Validation MAE: 0.028489032212754003
# SNR [20dB], Validation Loss: 0.3339, Validation Accuracy: 90.1333, Validation MAE: 0.013342117122389736
# SNR [30dB], Validation Loss: 0.1478, Validation Accuracy: 96.3200, Validation MAE: 0.00838715294035022
# SNR [40dB], Validation Loss: 0.0957, Validation Accuracy: 98.2133, Validation MAE: 0.005121397719823954
#
#
# Epoch [32/60], Training Loss: 0.1644, Training Accuracy: 93.9936, Training MAE: 0.010561639522104855
# SNR [0dB], Validation Loss: 2.7204, Validation Accuracy: 32.6733, Validation MAE: 0.07298055763648281
# SNR [10dB], Validation Loss: 0.9723, Validation Accuracy: 70.3200, Validation MAE: 0.028471840176982864
# SNR [20dB], Validation Loss: 0.3231, Validation Accuracy: 90.0333, Validation MAE: 0.013364795978087835
# SNR [30dB], Validation Loss: 0.1369, Validation Accuracy: 96.1533, Validation MAE: 0.009606690116115741
# SNR [40dB], Validation Loss: 0.0928, Validation Accuracy: 97.7667, Validation MAE: 0.006846453904860005
#
#
# Epoch [33/60], Training Loss: 0.1581, Training Accuracy: 94.2092, Training MAE: 0.010202868751877047
# SNR [0dB], Validation Loss: 2.7452, Validation Accuracy: 32.6933, Validation MAE: 0.07429373653900177
# SNR [10dB], Validation Loss: 0.9950, Validation Accuracy: 70.1133, Validation MAE: 0.031176476612978742
# SNR [20dB], Validation Loss: 0.3571, Validation Accuracy: 88.9600, Validation MAE: 0.015658652495552018
# SNR [30dB], Validation Loss: 0.1908, Validation Accuracy: 93.9200, Validation MAE: 0.012342784319692855
# SNR [40dB], Validation Loss: 0.1431, Validation Accuracy: 95.1133, Validation MAE: 0.010324366162562038
#
#
# Epoch [34/60], Training Loss: 0.1517, Training Accuracy: 94.4409, Training MAE: 0.009813069509600914
# SNR [0dB], Validation Loss: 2.7651, Validation Accuracy: 32.6467, Validation MAE: 0.07134365635827325
# SNR [10dB], Validation Loss: 0.9774, Validation Accuracy: 70.4800, Validation MAE: 0.02813202312950651
# SNR [20dB], Validation Loss: 0.3275, Validation Accuracy: 90.1000, Validation MAE: 0.01315227315291694
# SNR [30dB], Validation Loss: 0.1368, Validation Accuracy: 96.2867, Validation MAE: 0.008352403080812811
# SNR [40dB], Validation Loss: 0.0886, Validation Accuracy: 97.9867, Validation MAE: 0.0065326078050379245
#
#
# Epoch [35/60], Training Loss: 0.1469, Training Accuracy: 94.6541, Training MAE: 0.00915026650948694
# SNR [0dB], Validation Loss: 2.8580, Validation Accuracy: 32.0733, Validation MAE: 0.07243443615975279
# SNR [10dB], Validation Loss: 1.0055, Validation Accuracy: 69.9200, Validation MAE: 0.028249806863938572
# SNR [20dB], Validation Loss: 0.3508, Validation Accuracy: 89.8333, Validation MAE: 0.013289809439086057
# SNR [30dB], Validation Loss: 0.1592, Validation Accuracy: 95.8667, Validation MAE: 0.009627905819833318
# SNR [40dB], Validation Loss: 0.1090, Validation Accuracy: 97.5400, Validation MAE: 0.0071731025845116585
#
#
# Epoch [36/60], Training Loss: 0.1422, Training Accuracy: 94.7758, Training MAE: 0.009193929952138939
# SNR [0dB], Validation Loss: 2.7988, Validation Accuracy: 32.6000, Validation MAE: 0.07359947092424385
# SNR [10dB], Validation Loss: 0.9990, Validation Accuracy: 70.5333, Validation MAE: 0.030526837133626743
# SNR [20dB], Validation Loss: 0.3324, Validation Accuracy: 90.0333, Validation MAE: 0.013224699175952804
# SNR [30dB], Validation Loss: 0.1358, Validation Accuracy: 96.2133, Validation MAE: 0.0085791916377938
# SNR [40dB], Validation Loss: 0.0874, Validation Accuracy: 97.6800, Validation MAE: 0.006880106400412023
#
#
# Epoch [37/60], Training Loss: 0.1368, Training Accuracy: 94.9779, Training MAE: 0.008809239293656268
# SNR [0dB], Validation Loss: 2.9209, Validation Accuracy: 32.1267, Validation MAE: 0.07119002540031838
# SNR [10dB], Validation Loss: 1.0105, Validation Accuracy: 70.0333, Validation MAE: 0.028566945055716827
# SNR [20dB], Validation Loss: 0.3247, Validation Accuracy: 89.9933, Validation MAE: 0.013399911625620377
# SNR [30dB], Validation Loss: 0.1332, Validation Accuracy: 96.3600, Validation MAE: 0.009083979071074071
# SNR [40dB], Validation Loss: 0.0831, Validation Accuracy: 98.0733, Validation MAE: 0.006928390415769267
#
#
# Epoch [38/60], Training Loss: 0.1324, Training Accuracy: 95.1393, Training MAE: 0.008723680264321505
# SNR [0dB], Validation Loss: 2.8884, Validation Accuracy: 31.7000, Validation MAE: 0.07717614594063114
# SNR [10dB], Validation Loss: 1.0199, Validation Accuracy: 69.7867, Validation MAE: 0.0304785531182695
# SNR [20dB], Validation Loss: 0.3257, Validation Accuracy: 90.0133, Validation MAE: 0.014105150880232231
# SNR [30dB], Validation Loss: 0.1281, Validation Accuracy: 95.9933, Validation MAE: 0.008373252996535257
# SNR [40dB], Validation Loss: 0.0785, Validation Accuracy: 97.8533, Validation MAE: 0.005941860192901957
#
#
# Epoch [39/60], Training Loss: 0.1273, Training Accuracy: 95.3388, Training MAE: 0.008411731679396616
# SNR [0dB], Validation Loss: 2.8968, Validation Accuracy: 32.7267, Validation MAE: 0.07225922371008521
# SNR [10dB], Validation Loss: 1.0070, Validation Accuracy: 70.3667, Validation MAE: 0.029300349985953742
# SNR [20dB], Validation Loss: 0.3375, Validation Accuracy: 89.8000, Validation MAE: 0.014650174992976871
# SNR [30dB], Validation Loss: 0.1656, Validation Accuracy: 95.7800, Validation MAE: 0.01067332790991666
# SNR [40dB], Validation Loss: 0.1192, Validation Accuracy: 97.2333, Validation MAE: 0.009522558877235696
#
#
# Epoch [40/60], Training Loss: 0.1254, Training Accuracy: 95.3652, Training MAE: 0.00836687233417719
# SNR [0dB], Validation Loss: 2.8933, Validation Accuracy: 32.3733, Validation MAE: 0.07204487194493867
# SNR [10dB], Validation Loss: 1.0032, Validation Accuracy: 70.4600, Validation MAE: 0.028949559298623466
# SNR [20dB], Validation Loss: 0.3307, Validation Accuracy: 89.8267, Validation MAE: 0.015368948403408559
# SNR [30dB], Validation Loss: 0.1507, Validation Accuracy: 95.6600, Validation MAE: 0.011803978602865436
# SNR [40dB], Validation Loss: 0.1005, Validation Accuracy: 97.3200, Validation MAE: 0.00812634609982208
#
#
# Epoch [41/60], Training Loss: 0.1211, Training Accuracy: 95.5195, Training MAE: 0.008186966991425274
# SNR [0dB], Validation Loss: 2.9388, Validation Accuracy: 32.3400, Validation MAE: 0.07282838983050847
# SNR [10dB], Validation Loss: 1.0234, Validation Accuracy: 70.0800, Validation MAE: 0.02964199597340575
# SNR [20dB], Validation Loss: 0.3302, Validation Accuracy: 90.0467, Validation MAE: 0.013192144044386178
# SNR [30dB], Validation Loss: 0.1501, Validation Accuracy: 96.0733, Validation MAE: 0.00935649112744639
# SNR [40dB], Validation Loss: 0.1041, Validation Accuracy: 97.5867, Validation MAE: 0.006206324913381403
#
#
# Epoch [42/60], Training Loss: 0.1164, Training Accuracy: 95.7096, Training MAE: 0.007724802644878916
# SNR [0dB], Validation Loss: 2.9147, Validation Accuracy: 32.7333, Validation MAE: 0.07404170861035678
# SNR [10dB], Validation Loss: 1.0089, Validation Accuracy: 70.4867, Validation MAE: 0.030616455192433747
# SNR [20dB], Validation Loss: 0.3284, Validation Accuracy: 89.8533, Validation MAE: 0.014204645214907764
# SNR [30dB], Validation Loss: 0.1359, Validation Accuracy: 96.2400, Validation MAE: 0.009179083949808034
# SNR [40dB], Validation Loss: 0.0869, Validation Accuracy: 98.0733, Validation MAE: 0.006376782119112277
#
#
# Epoch [43/60], Training Loss: 0.1130, Training Accuracy: 95.8595, Training MAE: 0.007687937648343914
# SNR [0dB], Validation Loss: 2.9957, Validation Accuracy: 32.3067, Validation MAE: 0.07312577547054967
# SNR [10dB], Validation Loss: 1.0370, Validation Accuracy: 69.9467, Validation MAE: 0.02926633170240659
# SNR [20dB], Validation Loss: 0.3183, Validation Accuracy: 90.2200, Validation MAE: 0.014239029286450043
# SNR [30dB], Validation Loss: 0.1211, Validation Accuracy: 96.2867, Validation MAE: 0.009877373232512407
# SNR [40dB], Validation Loss: 0.0773, Validation Accuracy: 97.6800, Validation MAE: 0.00911287632268939
#
#
# Epoch [44/60], Training Loss: 0.1104, Training Accuracy: 95.9226, Training MAE: 0.007534511148307725
# SNR [0dB], Validation Loss: 3.0095, Validation Accuracy: 32.6667, Validation MAE: 0.07316125690607735
# SNR [10dB], Validation Loss: 1.0435, Validation Accuracy: 70.2133, Validation MAE: 0.030198725301994567
# SNR [20dB], Validation Loss: 0.3295, Validation Accuracy: 90.0000, Validation MAE: 0.015562816040827793
# SNR [30dB], Validation Loss: 0.1296, Validation Accuracy: 95.9667, Validation MAE: 0.01020402191216406
# SNR [40dB], Validation Loss: 0.0868, Validation Accuracy: 97.3600, Validation MAE: 0.00950756156943534
#
#
# Epoch [45/60], Training Loss: 0.1071, Training Accuracy: 96.0704, Training MAE: 0.007315803966819215
# SNR [0dB], Validation Loss: 3.0912, Validation Accuracy: 32.3800, Validation MAE: 0.07411157411742672
# SNR [10dB], Validation Loss: 1.0741, Validation Accuracy: 70.0800, Validation MAE: 0.029804405843243748
# SNR [20dB], Validation Loss: 0.3318, Validation Accuracy: 89.7067, Validation MAE: 0.015558060796891095
# SNR [30dB], Validation Loss: 0.1450, Validation Accuracy: 95.1200, Validation MAE: 0.012367657903361738
# SNR [40dB], Validation Loss: 0.0975, Validation Accuracy: 96.4667, Validation MAE: 0.010514575920029965
#
#
# Epoch [46/60], Training Loss: 0.1050, Training Accuracy: 96.1165, Training MAE: 0.007260987432831872
# SNR [0dB], Validation Loss: 3.1152, Validation Accuracy: 32.4200, Validation MAE: 0.07420594742017043
# SNR [10dB], Validation Loss: 1.0671, Validation Accuracy: 70.1667, Validation MAE: 0.03072875210693885
# SNR [20dB], Validation Loss: 0.3347, Validation Accuracy: 89.3067, Validation MAE: 0.016097598089708773
# SNR [30dB], Validation Loss: 0.1445, Validation Accuracy: 95.4000, Validation MAE: 0.010948766270250024
# SNR [40dB], Validation Loss: 0.0969, Validation Accuracy: 96.9733, Validation MAE: 0.008634791413053657
#
#
# Epoch [47/60], Training Loss: 0.1024, Training Accuracy: 96.2115, Training MAE: 0.007157658851218073
# SNR [0dB], Validation Loss: 3.1040, Validation Accuracy: 32.0000, Validation MAE: 0.07548766855510816
# SNR [10dB], Validation Loss: 1.0836, Validation Accuracy: 69.8000, Validation MAE: 0.029558230522520837
# SNR [20dB], Validation Loss: 0.3394, Validation Accuracy: 89.8467, Validation MAE: 0.013905430634890907
# SNR [30dB], Validation Loss: 0.1397, Validation Accuracy: 96.1867, Validation MAE: 0.008778180307144863
# SNR [40dB], Validation Loss: 0.0895, Validation Accuracy: 97.9467, Validation MAE: 0.00629777191216406
#
#
# Epoch [48/60], Training Loss: 0.0991, Training Accuracy: 96.3772, Training MAE: 0.006874125951210503
# SNR [0dB], Validation Loss: 3.0479, Validation Accuracy: 32.0200, Validation MAE: 0.07306432308736772
# SNR [10dB], Validation Loss: 1.0690, Validation Accuracy: 69.9867, Validation MAE: 0.029267063278396854
# SNR [20dB], Validation Loss: 0.3323, Validation Accuracy: 89.8333, Validation MAE: 0.015049249695664388
# SNR [30dB], Validation Loss: 0.1360, Validation Accuracy: 96.1733, Validation MAE: 0.008647228204888098
# SNR [40dB], Validation Loss: 0.0857, Validation Accuracy: 97.6533, Validation MAE: 0.007155910548740519
#
#
# Epoch [49/60], Training Loss: 0.0967, Training Accuracy: 96.4346, Training MAE: 0.006811172080188283
# SNR [0dB], Validation Loss: 3.0892, Validation Accuracy: 32.1200, Validation MAE: 0.07308224669912913
# SNR [10dB], Validation Loss: 1.0675, Validation Accuracy: 70.1467, Validation MAE: 0.0314076546259013
# SNR [20dB], Validation Loss: 0.3179, Validation Accuracy: 90.1333, Validation MAE: 0.015000234104316884
# SNR [30dB], Validation Loss: 0.1259, Validation Accuracy: 96.2267, Validation MAE: 0.00902545299185317
# SNR [40dB], Validation Loss: 0.0765, Validation Accuracy: 98.0533, Validation MAE: 0.0064386002902893525
#
#
# Epoch [50/60], Training Loss: 0.0943, Training Accuracy: 96.5362, Training MAE: 0.0065248964036402025
# SNR [0dB], Validation Loss: 3.1101, Validation Accuracy: 32.1333, Validation MAE: 0.0731404069903549
# SNR [10dB], Validation Loss: 1.0869, Validation Accuracy: 70.0333, Validation MAE: 0.029052711513250305
# SNR [20dB], Validation Loss: 0.3221, Validation Accuracy: 90.1600, Validation MAE: 0.0140283354012548
# SNR [30dB], Validation Loss: 0.1341, Validation Accuracy: 96.2600, Validation MAE: 0.008959611152729656
# SNR [40dB], Validation Loss: 0.0867, Validation Accuracy: 98.0933, Validation MAE: 0.00622205379717202
#
#
# Epoch [51/60], Training Loss: 0.0927, Training Accuracy: 96.5748, Training MAE: 0.0066212445539637
# SNR [0dB], Validation Loss: 3.0984, Validation Accuracy: 32.0533, Validation MAE: 0.07428020238318195
# SNR [10dB], Validation Loss: 1.0811, Validation Accuracy: 69.9733, Validation MAE: 0.03103930611480476
# SNR [20dB], Validation Loss: 0.3263, Validation Accuracy: 89.9800, Validation MAE: 0.015748270554359022
# SNR [30dB], Validation Loss: 0.1262, Validation Accuracy: 96.2333, Validation MAE: 0.009503903689484033
# SNR [40dB], Validation Loss: 0.0761, Validation Accuracy: 98.0000, Validation MAE: 0.006244001076879857
#
#
# Epoch [52/60], Training Loss: 0.0903, Training Accuracy: 96.6760, Training MAE: 0.006367102259444719
# SNR [0dB], Validation Loss: 3.1314, Validation Accuracy: 32.2000, Validation MAE: 0.07334159038767675
# SNR [10dB], Validation Loss: 1.1041, Validation Accuracy: 69.3733, Validation MAE: 0.029928407973593033
# SNR [20dB], Validation Loss: 0.3270, Validation Accuracy: 90.0200, Validation MAE: 0.015070099611386834
# SNR [30dB], Validation Loss: 0.1292, Validation Accuracy: 96.2267, Validation MAE: 0.008743064659612323
# SNR [40dB], Validation Loss: 0.0791, Validation Accuracy: 98.1800, Validation MAE: 0.005442193791553516
#
#
# Epoch [53/60], Training Loss: 0.0889, Training Accuracy: 96.7080, Training MAE: 0.006279775374140718
# SNR [0dB], Validation Loss: 3.1359, Validation Accuracy: 31.9600, Validation MAE: 0.0730602994194213
# SNR [10dB], Validation Loss: 1.0820, Validation Accuracy: 69.9600, Validation MAE: 0.03109307695008896
# SNR [20dB], Validation Loss: 0.3171, Validation Accuracy: 90.5067, Validation MAE: 0.013301148866935106
# SNR [30dB], Validation Loss: 0.1224, Validation Accuracy: 96.4133, Validation MAE: 0.008252908746137278
# SNR [40dB], Validation Loss: 0.0752, Validation Accuracy: 98.0200, Validation MAE: 0.006553457720760371
#
#
# Epoch [54/60], Training Loss: 0.0870, Training Accuracy: 96.7969, Training MAE: 0.0061792155669493296
# SNR [0dB], Validation Loss: 3.1245, Validation Accuracy: 32.2467, Validation MAE: 0.07409182156568968
# SNR [10dB], Validation Loss: 1.0817, Validation Accuracy: 70.3400, Validation MAE: 0.028849333387957674
# SNR [20dB], Validation Loss: 0.3162, Validation Accuracy: 90.1533, Validation MAE: 0.014091982512407529
# SNR [30dB], Validation Loss: 0.1150, Validation Accuracy: 96.4667, Validation MAE: 0.008877308853825264
# SNR [40dB], Validation Loss: 0.0638, Validation Accuracy: 98.3333, Validation MAE: 0.004927164294409589
#
#
# Epoch [55/60], Training Loss: 0.0842, Training Accuracy: 96.9021, Training MAE: 0.0060348753266373885
# SNR [0dB], Validation Loss: 3.1682, Validation Accuracy: 32.0400, Validation MAE: 0.07229946038954958
# SNR [10dB], Validation Loss: 1.1113, Validation Accuracy: 69.8667, Validation MAE: 0.030893356704747636
# SNR [20dB], Validation Loss: 0.3300, Validation Accuracy: 90.1467, Validation MAE: 0.01599078799513063
# SNR [30dB], Validation Loss: 0.1335, Validation Accuracy: 96.3200, Validation MAE: 0.008634425625058527
# SNR [40dB], Validation Loss: 0.0850, Validation Accuracy: 98.0333, Validation MAE: 0.006428724014420826
#
#
# Epoch [56/60], Training Loss: 0.0828, Training Accuracy: 96.9348, Training MAE: 0.006067008708666488
# SNR [0dB], Validation Loss: 3.1259, Validation Accuracy: 32.0800, Validation MAE: 0.0738760066485626
# SNR [10dB], Validation Loss: 1.1009, Validation Accuracy: 69.9733, Validation MAE: 0.029678208984923682
# SNR [20dB], Validation Loss: 0.3354, Validation Accuracy: 89.4133, Validation MAE: 0.014626764561288511
# SNR [30dB], Validation Loss: 0.1379, Validation Accuracy: 94.9867, Validation MAE: 0.011397588140275307
# SNR [40dB], Validation Loss: 0.0899, Validation Accuracy: 96.5133, Validation MAE: 0.008056846380747261
#
#
# Epoch [57/60], Training Loss: 0.0818, Training Accuracy: 96.9927, Training MAE: 0.005883736640208449
# SNR [0dB], Validation Loss: 3.2302, Validation Accuracy: 32.2533, Validation MAE: 0.07307273621125573
# SNR [10dB], Validation Loss: 1.1092, Validation Accuracy: 70.6000, Validation MAE: 0.029224997658956833
# SNR [20dB], Validation Loss: 0.3206, Validation Accuracy: 90.1667, Validation MAE: 0.015479416377938008
# SNR [30dB], Validation Loss: 0.1224, Validation Accuracy: 96.2933, Validation MAE: 0.009957480803446016
# SNR [40dB], Validation Loss: 0.0752, Validation Accuracy: 97.9333, Validation MAE: 0.008101838304148328
#
#
# Epoch [58/60], Training Loss: 0.0803, Training Accuracy: 97.0212, Training MAE: 0.0059826065850763005
# SNR [0dB], Validation Loss: 3.2042, Validation Accuracy: 32.3933, Validation MAE: 0.07343815841839124
# SNR [10dB], Validation Loss: 1.1186, Validation Accuracy: 70.2800, Validation MAE: 0.028445137653338327
# SNR [20dB], Validation Loss: 0.3434, Validation Accuracy: 89.7400, Validation MAE: 0.014828679534600618
# SNR [30dB], Validation Loss: 0.1560, Validation Accuracy: 94.9333, Validation MAE: 0.009862741712707183
# SNR [40dB], Validation Loss: 0.1091, Validation Accuracy: 96.3133, Validation MAE: 0.008379105604457347
#
#
# Epoch [59/60], Training Loss: 0.0783, Training Accuracy: 97.0845, Training MAE: 0.00577214073215027
# SNR [0dB], Validation Loss: 3.1754, Validation Accuracy: 31.7000, Validation MAE: 0.07492362346661673
# SNR [10dB], Validation Loss: 1.1224, Validation Accuracy: 69.9733, Validation MAE: 0.03066912866373256
# SNR [20dB], Validation Loss: 0.3308, Validation Accuracy: 89.9267, Validation MAE: 0.01581191766551175
# SNR [30dB], Validation Loss: 0.1338, Validation Accuracy: 95.8667, Validation MAE: 0.01114336548365952
# SNR [40dB], Validation Loss: 0.0856, Validation Accuracy: 97.4333, Validation MAE: 0.009090563254986422
#
#
# Epoch [60/60], Training Loss: 0.0770, Training Accuracy: 97.1652, Training MAE: 0.00576935895878691
# SNR [0dB], Validation Loss: 3.1419, Validation Accuracy: 32.0667, Validation MAE: 0.07348680822174361
# SNR [10dB], Validation Loss: 1.0901, Validation Accuracy: 70.3733, Validation MAE: 0.03084946214533196
# SNR [20dB], Validation Loss: 0.3251, Validation Accuracy: 90.0733, Validation MAE: 0.014105882456222492
# SNR [30dB], Validation Loss: 0.1267, Validation Accuracy: 96.2533, Validation MAE: 0.008778546095139995
# SNR [40dB], Validation Loss: 0.0803, Validation Accuracy: 97.8600, Validation MAE: 0.006676728275119393
#
#
# Training Complete

# %%
max(acc_res[0]), max(acc_res[10]), max(acc_res[20]), max(acc_res[30]), max(acc_res[40])
# Out:
# (35.27333333333333,
#  71.54666666666667,
#  90.64666666666666,
#  96.50666666666666,
#  98.33333333333333)

# %%
# SNS DOA1 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-1 ====
# = MAE =_= Acc =
# 0.0591   34.03
# 0.0227   69.61
# 0.0117   90.65
# 0.0082   96.51
# 0.0049   98.33

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()
