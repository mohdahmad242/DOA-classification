# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("../SNS_dataset/200/DOA2")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_0_2_200.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_2_200.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_2_200.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_2_200.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_2_200.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 200)
# Out:
# 2021-06-21 16:43:22,049 - Data prepration started
# 2021-06-21 16:43:32,364 - Dividing your dataset into 3 channel
# 2021-06-21 16:47:03,498 - Creating Train dataloader
# 2021-06-21 16:47:04,785 - Creating Validation dataloader
# 2021-06-21 16:47:04,936 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((2, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.7)
        self.dropout1 = nn.Dropout(0.6)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 2, 181])

# %%
num_epochs = 60
doa = 2
weights_dir = "./doa_weights/"

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()  

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(64*len(doa_train_loader)*181))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*64*181)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.abs(pred.reshape(-1).cuda() - labels.reshape(-1)).sum().item()

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(128*len(test_dataset_list[val_data])*181))
                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*128*181)))

                total_valdation_loss+=validation_loss
            torch.save( classification_model, weights_dir+ "/SNS_DOA_{}_200_model.pth".format(doa))
            if best_valid_loss > total_valdation_loss:
                best_valid_loss = total_valdation_loss 
                # Saving Best Pre-Trained Model as .pth file
                torch.save( classification_model, weights_dir+ "/DOA_{}_200_best_model.pth".format(doa))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")  

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 4.0094, Training Accuracy: 7.4495, Training MAE: 0.31156503817320996
# SNR [0dB], Validation Loss: 3.5257, Validation Accuracy: 13.6667, Validation MAE: 0.1594327213456316
# SNR [10dB], Validation Loss: 2.8133, Validation Accuracy: 24.4200, Validation MAE: 0.07101261822268003
# SNR [20dB], Validation Loss: 2.5984, Validation Accuracy: 28.7200, Validation MAE: 0.04967254658675906
# SNR [30dB], Validation Loss: 2.5559, Validation Accuracy: 30.1467, Validation MAE: 0.043655699854855325
# SNR [40dB], Validation Loss: 2.5493, Validation Accuracy: 29.8000, Validation MAE: 0.0444889649077629
#
#
# Epoch [2/60], Training Loss: 1.9918, Training Accuracy: 33.9041, Training MAE: 0.06915730361615978
# SNR [0dB], Validation Loss: 3.2855, Validation Accuracy: 18.4433, Validation MAE: 0.13372258053188502
# SNR [10dB], Validation Loss: 2.2576, Validation Accuracy: 39.5833, Validation MAE: 0.054525090130162
# SNR [20dB], Validation Loss: 1.8561, Validation Accuracy: 52.7267, Validation MAE: 0.03499786379810844
# SNR [30dB], Validation Loss: 1.7583, Validation Accuracy: 56.7367, Validation MAE: 0.028914809439086055
# SNR [40dB], Validation Loss: 1.7414, Validation Accuracy: 57.7733, Validation MAE: 0.029260479094484503
#
#
# Epoch [3/60], Training Loss: 1.5752, Training Accuracy: 47.1320, Training MAE: 0.058095048880177635
# SNR [0dB], Validation Loss: 3.1670, Validation Accuracy: 20.3500, Validation MAE: 0.12617600840434498
# SNR [10dB], Validation Loss: 2.0506, Validation Accuracy: 46.0433, Validation MAE: 0.05096853345350688
# SNR [20dB], Validation Loss: 1.5263, Validation Accuracy: 64.1300, Validation MAE: 0.030243717225395636
# SNR [30dB], Validation Loss: 1.3789, Validation Accuracy: 69.7300, Validation MAE: 0.02260130864313138
# SNR [40dB], Validation Loss: 1.3531, Validation Accuracy: 70.7900, Validation MAE: 0.021930819248056933
#
#
# Epoch [4/60], Training Loss: 1.3882, Training Accuracy: 53.5240, Training MAE: 0.05422779895276372
# SNR [0dB], Validation Loss: 3.1273, Validation Accuracy: 20.9500, Validation MAE: 0.12453142557823767
# SNR [10dB], Validation Loss: 1.9024, Validation Accuracy: 49.7100, Validation MAE: 0.04891426807285326
# SNR [20dB], Validation Loss: 1.2348, Validation Accuracy: 69.3667, Validation MAE: 0.028160188805131568
# SNR [30dB], Validation Loss: 1.0321, Validation Accuracy: 76.4033, Validation MAE: 0.0210514649077629
# SNR [40dB], Validation Loss: 1.0019, Validation Accuracy: 77.1533, Validation MAE: 0.01943724248525143
#
#
# Epoch [5/60], Training Loss: 1.2845, Training Accuracy: 56.9574, Training MAE: 0.051545532482377594
# SNR [0dB], Validation Loss: 3.0154, Validation Accuracy: 21.6200, Validation MAE: 0.12199614898398727
# SNR [10dB], Validation Loss: 1.8399, Validation Accuracy: 49.7133, Validation MAE: 0.048917194376814306
# SNR [20dB], Validation Loss: 1.1662, Validation Accuracy: 70.3633, Validation MAE: 0.026511582311077815
# SNR [30dB], Validation Loss: 0.9520, Validation Accuracy: 77.5333, Validation MAE: 0.019721093969472796
# SNR [40dB], Validation Loss: 0.9123, Validation Accuracy: 78.8833, Validation MAE: 0.015794725629740613
#
#
# Epoch [6/60], Training Loss: 1.2154, Training Accuracy: 59.1587, Training MAE: 0.04986951403095287
# SNR [0dB], Validation Loss: 3.0491, Validation Accuracy: 21.2033, Validation MAE: 0.13105013343946062
# SNR [10dB], Validation Loss: 1.8142, Validation Accuracy: 51.0800, Validation MAE: 0.051215440350220055
# SNR [20dB], Validation Loss: 1.0615, Validation Accuracy: 73.1700, Validation MAE: 0.02766271713175391
# SNR [30dB], Validation Loss: 0.8243, Validation Accuracy: 80.9933, Validation MAE: 0.018530454045322595
# SNR [40dB], Validation Loss: 0.7855, Validation Accuracy: 82.1133, Validation MAE: 0.016268421083434778
#
#
# Epoch [7/60], Training Loss: 1.1619, Training Accuracy: 60.8212, Training MAE: 0.04862069277491824
# SNR [0dB], Validation Loss: 2.9941, Validation Accuracy: 21.3800, Validation MAE: 0.12851485684521022
# SNR [10dB], Validation Loss: 1.8597, Validation Accuracy: 51.1100, Validation MAE: 0.053222519079501825
# SNR [20dB], Validation Loss: 1.1187, Validation Accuracy: 74.2400, Validation MAE: 0.03199620751006649
# SNR [30dB], Validation Loss: 0.8676, Validation Accuracy: 83.0300, Validation MAE: 0.02520754810843712
# SNR [40dB], Validation Loss: 0.8190, Validation Accuracy: 84.6200, Validation MAE: 0.023427989512126605
#
#
# Epoch [8/60], Training Loss: 1.1217, Training Accuracy: 62.0944, Training MAE: 0.04758357227119992
# SNR [0dB], Validation Loss: 2.9861, Validation Accuracy: 21.1300, Validation MAE: 0.13779745879764022
# SNR [10dB], Validation Loss: 1.8208, Validation Accuracy: 50.8000, Validation MAE: 0.057344583996628895
# SNR [20dB], Validation Loss: 1.0505, Validation Accuracy: 73.7400, Validation MAE: 0.03564786906545557
# SNR [30dB], Validation Loss: 0.7933, Validation Accuracy: 82.0733, Validation MAE: 0.030034486492180917
# SNR [40dB], Validation Loss: 0.7567, Validation Accuracy: 82.5533, Validation MAE: 0.028966751334394605
#
#
# Epoch [9/60], Training Loss: 1.0894, Training Accuracy: 63.0855, Training MAE: 0.04673350652775617
# SNR [0dB], Validation Loss: 2.9490, Validation Accuracy: 21.2500, Validation MAE: 0.1395598253581796
# SNR [10dB], Validation Loss: 1.6975, Validation Accuracy: 51.8333, Validation MAE: 0.05802019442363517
# SNR [20dB], Validation Loss: 0.8737, Validation Accuracy: 75.6400, Validation MAE: 0.03025725138121547
# SNR [30dB], Validation Loss: 0.5972, Validation Accuracy: 84.8900, Validation MAE: 0.019744504401161156
# SNR [40dB], Validation Loss: 0.5492, Validation Accuracy: 86.1667, Validation MAE: 0.017860330438243283
#
#
# Epoch [10/60], Training Loss: 1.0668, Training Accuracy: 63.7921, Training MAE: 0.0459101146111424
# SNR [0dB], Validation Loss: 3.0053, Validation Accuracy: 20.8567, Validation MAE: 0.15296120013578052
# SNR [10dB], Validation Loss: 1.8022, Validation Accuracy: 49.3933, Validation MAE: 0.058086036262758683
# SNR [20dB], Validation Loss: 1.0264, Validation Accuracy: 71.5167, Validation MAE: 0.03040137185129694
# SNR [30dB], Validation Loss: 0.7581, Validation Accuracy: 79.3333, Validation MAE: 0.021169980218185225
# SNR [40dB], Validation Loss: 0.7130, Validation Accuracy: 80.3700, Validation MAE: 0.020503880279052346
#
#
# Epoch [11/60], Training Loss: 1.0474, Training Accuracy: 64.3786, Training MAE: 0.04555992314194178
# SNR [0dB], Validation Loss: 2.9454, Validation Accuracy: 21.4967, Validation MAE: 0.1493713567515685
# SNR [10dB], Validation Loss: 1.6892, Validation Accuracy: 52.3767, Validation MAE: 0.05973391118082218
# SNR [20dB], Validation Loss: 0.8764, Validation Accuracy: 75.8400, Validation MAE: 0.03539474377282517
# SNR [30dB], Validation Loss: 0.5951, Validation Accuracy: 84.7767, Validation MAE: 0.02912111386833973
# SNR [40dB], Validation Loss: 0.5489, Validation Accuracy: 86.0633, Validation MAE: 0.026006429089802417
#
#
# Epoch [12/60], Training Loss: 1.0268, Training Accuracy: 65.0342, Training MAE: 0.04456035657862883
# SNR [0dB], Validation Loss: 2.8757, Validation Accuracy: 21.5833, Validation MAE: 0.14729404672722166
# SNR [10dB], Validation Loss: 1.6022, Validation Accuracy: 52.6000, Validation MAE: 0.059032695594156755
# SNR [20dB], Validation Loss: 0.7961, Validation Accuracy: 76.7767, Validation MAE: 0.032504287035302934
# SNR [30dB], Validation Loss: 0.5271, Validation Accuracy: 85.3033, Validation MAE: 0.025905471603146362
# SNR [40dB], Validation Loss: 0.4840, Validation Accuracy: 86.5633, Validation MAE: 0.0240238581561944
#
#
# Epoch [13/60], Training Loss: 1.0120, Training Accuracy: 65.4539, Training MAE: 0.04429997479245371
# SNR [0dB], Validation Loss: 2.9091, Validation Accuracy: 21.3467, Validation MAE: 0.14494934567843432
# SNR [10dB], Validation Loss: 1.6596, Validation Accuracy: 52.7467, Validation MAE: 0.05924485263133252
# SNR [20dB], Validation Loss: 0.8251, Validation Accuracy: 76.6967, Validation MAE: 0.03375528197864969
# SNR [30dB], Validation Loss: 0.5395, Validation Accuracy: 85.5933, Validation MAE: 0.027331313208165557
# SNR [40dB], Validation Loss: 0.4950, Validation Accuracy: 87.0133, Validation MAE: 0.025820974576271187
#
#
# Epoch [14/60], Training Loss: 0.9963, Training Accuracy: 65.9511, Training MAE: 0.04352764271589265
# SNR [0dB], Validation Loss: 2.8863, Validation Accuracy: 21.3433, Validation MAE: 0.13625310188219872
# SNR [10dB], Validation Loss: 1.6726, Validation Accuracy: 52.3500, Validation MAE: 0.0539709213175391
# SNR [20dB], Validation Loss: 0.8440, Validation Accuracy: 77.0167, Validation MAE: 0.0275826095608203
# SNR [30dB], Validation Loss: 0.5493, Validation Accuracy: 86.4067, Validation MAE: 0.017594768353778444
# SNR [40dB], Validation Loss: 0.5052, Validation Accuracy: 87.5433, Validation MAE: 0.016491551760464462
#
#
# Epoch [15/60], Training Loss: 0.9806, Training Accuracy: 66.4036, Training MAE: 0.04306026579402523
# SNR [0dB], Validation Loss: 2.8909, Validation Accuracy: 21.5600, Validation MAE: 0.1486822121687424
# SNR [10dB], Validation Loss: 1.6375, Validation Accuracy: 51.5800, Validation MAE: 0.05444937201516996
# SNR [20dB], Validation Loss: 0.8271, Validation Accuracy: 75.3233, Validation MAE: 0.025778908956831163
# SNR [30dB], Validation Loss: 0.5353, Validation Accuracy: 84.2367, Validation MAE: 0.01666383790617099
# SNR [40dB], Validation Loss: 0.4849, Validation Accuracy: 85.6867, Validation MAE: 0.013910551666822736
#
#
# Epoch [16/60], Training Loss: 0.9657, Training Accuracy: 66.8744, Training MAE: 0.042341567347825036
# SNR [0dB], Validation Loss: 2.8969, Validation Accuracy: 21.2000, Validation MAE: 0.15119224939132878
# SNR [10dB], Validation Loss: 1.6408, Validation Accuracy: 52.3033, Validation MAE: 0.057456515123138874
# SNR [20dB], Validation Loss: 0.8113, Validation Accuracy: 77.1400, Validation MAE: 0.027513109841745483
# SNR [30dB], Validation Loss: 0.5075, Validation Accuracy: 86.9400, Validation MAE: 0.01581520975746793
# SNR [40dB], Validation Loss: 0.4570, Validation Accuracy: 88.4567, Validation MAE: 0.01322177287199176
#
#
# Epoch [17/60], Training Loss: 0.9492, Training Accuracy: 67.3838, Training MAE: 0.04155358454635984
# SNR [0dB], Validation Loss: 2.9288, Validation Accuracy: 21.2500, Validation MAE: 0.15807747682367262
# SNR [10dB], Validation Loss: 1.6689, Validation Accuracy: 52.4800, Validation MAE: 0.05762770390486001
# SNR [20dB], Validation Loss: 0.8533, Validation Accuracy: 76.8000, Validation MAE: 0.026992227736679465
# SNR [30dB], Validation Loss: 0.5470, Validation Accuracy: 86.8933, Validation MAE: 0.016491551760464462
# SNR [40dB], Validation Loss: 0.4907, Validation Accuracy: 88.7000, Validation MAE: 0.014675048576645753
#
#
# Epoch [18/60], Training Loss: 0.9332, Training Accuracy: 67.8499, Training MAE: 0.04127462727356677
# SNR [0dB], Validation Loss: 2.8391, Validation Accuracy: 21.5633, Validation MAE: 0.1434291307706714
# SNR [10dB], Validation Loss: 1.5766, Validation Accuracy: 53.1267, Validation MAE: 0.054225143974154885
# SNR [20dB], Validation Loss: 0.7584, Validation Accuracy: 77.7933, Validation MAE: 0.02844074819739676
# SNR [30dB], Validation Loss: 0.4605, Validation Accuracy: 87.9100, Validation MAE: 0.019773767440771608
# SNR [40dB], Validation Loss: 0.4124, Validation Accuracy: 89.4833, Validation MAE: 0.01860288006835846
#
#
# Epoch [19/60], Training Loss: 0.9153, Training Accuracy: 68.3745, Training MAE: 0.04045714987508538
# SNR [0dB], Validation Loss: 2.8285, Validation Accuracy: 21.4933, Validation MAE: 0.14921882315759902
# SNR [10dB], Validation Loss: 1.5655, Validation Accuracy: 53.1967, Validation MAE: 0.05755418051783875
# SNR [20dB], Validation Loss: 0.7399, Validation Accuracy: 78.0400, Validation MAE: 0.026676552696881732
# SNR [30dB], Validation Loss: 0.4313, Validation Accuracy: 88.2700, Validation MAE: 0.014807463830883041
# SNR [40dB], Validation Loss: 0.3770, Validation Accuracy: 90.3267, Validation MAE: 0.012087098511096545
#
#
# Epoch [20/60], Training Loss: 0.8930, Training Accuracy: 68.9854, Training MAE: 0.039367162678522256
# SNR [0dB], Validation Loss: 2.8144, Validation Accuracy: 21.2467, Validation MAE: 0.13873716815713083
# SNR [10dB], Validation Loss: 1.6104, Validation Accuracy: 52.1367, Validation MAE: 0.057330684052813934
# SNR [20dB], Validation Loss: 0.8424, Validation Accuracy: 75.9100, Validation MAE: 0.03360896678059743
# SNR [30dB], Validation Loss: 0.5501, Validation Accuracy: 85.4467, Validation MAE: 0.027091356283359864
# SNR [40dB], Validation Loss: 0.5000, Validation Accuracy: 86.8100, Validation MAE: 0.02589413217529731
#
#
# Epoch [21/60], Training Loss: 0.8710, Training Accuracy: 69.6491, Training MAE: 0.038870564137398596
# SNR [0dB], Validation Loss: 2.7968, Validation Accuracy: 21.5000, Validation MAE: 0.14526611808221743
# SNR [10dB], Validation Loss: 1.5674, Validation Accuracy: 52.5067, Validation MAE: 0.05912011892499298
# SNR [20dB], Validation Loss: 0.7865, Validation Accuracy: 77.9200, Validation MAE: 0.03412911730967319
# SNR [30dB], Validation Loss: 0.4848, Validation Accuracy: 88.0133, Validation MAE: 0.025448968185223336
# SNR [40dB], Validation Loss: 0.4353, Validation Accuracy: 89.5900, Validation MAE: 0.024064826411649032
#
#
# Epoch [22/60], Training Loss: 0.8480, Training Accuracy: 70.2944, Training MAE: 0.03772475948839496
# SNR [0dB], Validation Loss: 2.7854, Validation Accuracy: 21.3100, Validation MAE: 0.13523365073976965
# SNR [10dB], Validation Loss: 1.5180, Validation Accuracy: 52.7667, Validation MAE: 0.05161049138496114
# SNR [20dB], Validation Loss: 0.7378, Validation Accuracy: 77.5300, Validation MAE: 0.025865966499672256
# SNR [30dB], Validation Loss: 0.4462, Validation Accuracy: 87.2500, Validation MAE: 0.015702912842962824
# SNR [40dB], Validation Loss: 0.3957, Validation Accuracy: 89.0367, Validation MAE: 0.012542504565034179
#
#
# Epoch [23/60], Training Loss: 0.8184, Training Accuracy: 71.2156, Training MAE: 0.036229751289702926
# SNR [0dB], Validation Loss: 2.8427, Validation Accuracy: 21.2700, Validation MAE: 0.15098411602209943
# SNR [10dB], Validation Loss: 1.5184, Validation Accuracy: 53.1700, Validation MAE: 0.058487671481412117
# SNR [20dB], Validation Loss: 0.6826, Validation Accuracy: 78.7367, Validation MAE: 0.02797692901957112
# SNR [30dB], Validation Loss: 0.3694, Validation Accuracy: 89.5733, Validation MAE: 0.01808602163123888
# SNR [40dB], Validation Loss: 0.3184, Validation Accuracy: 91.3200, Validation MAE: 0.016538006835846053
#
#
# Epoch [24/60], Training Loss: 0.7911, Training Accuracy: 71.9958, Training MAE: 0.0353255579561422
# SNR [0dB], Validation Loss: 2.8498, Validation Accuracy: 21.0433, Validation MAE: 0.15091644524300027
# SNR [10dB], Validation Loss: 1.5179, Validation Accuracy: 52.9333, Validation MAE: 0.059613201142429066
# SNR [20dB], Validation Loss: 0.6947, Validation Accuracy: 77.7800, Validation MAE: 0.031061984970502856
# SNR [30dB], Validation Loss: 0.3876, Validation Accuracy: 87.8967, Validation MAE: 0.021378845163404814
# SNR [40dB], Validation Loss: 0.3360, Validation Accuracy: 89.5800, Validation MAE: 0.020010066485625994
#
#
# Epoch [25/60], Training Loss: 0.7614, Training Accuracy: 72.9006, Training MAE: 0.034105347369139144
# SNR [0dB], Validation Loss: 2.8981, Validation Accuracy: 20.4367, Validation MAE: 0.14844298681992696
# SNR [10dB], Validation Loss: 1.5619, Validation Accuracy: 52.2200, Validation MAE: 0.06392145214907763
# SNR [20dB], Validation Loss: 0.7717, Validation Accuracy: 77.8567, Validation MAE: 0.033006513952617285
# SNR [30dB], Validation Loss: 0.4630, Validation Accuracy: 88.4333, Validation MAE: 0.021885095748665605
# SNR [40dB], Validation Loss: 0.4106, Validation Accuracy: 90.2133, Validation MAE: 0.019767183256859257
#
#
# Epoch [26/60], Training Loss: 0.7303, Training Accuracy: 73.8336, Training MAE: 0.032712211870674475
# SNR [0dB], Validation Loss: 2.9102, Validation Accuracy: 20.7900, Validation MAE: 0.1434038913990074
# SNR [10dB], Validation Loss: 1.4999, Validation Accuracy: 52.5267, Validation MAE: 0.06081774101039423
# SNR [20dB], Validation Loss: 0.6749, Validation Accuracy: 78.1933, Validation MAE: 0.0313813178902519
# SNR [30dB], Validation Loss: 0.3593, Validation Accuracy: 89.4800, Validation MAE: 0.019553197279707838
# SNR [40dB], Validation Loss: 0.3060, Validation Accuracy: 91.4267, Validation MAE: 0.018025666612042326
#
#
# Epoch [27/60], Training Loss: 0.7000, Training Accuracy: 74.8002, Training MAE: 0.031210405225865438
# SNR [0dB], Validation Loss: 2.9716, Validation Accuracy: 20.7900, Validation MAE: 0.15175336817585916
# SNR [10dB], Validation Loss: 1.5168, Validation Accuracy: 52.6133, Validation MAE: 0.06708881039891376
# SNR [20dB], Validation Loss: 0.6992, Validation Accuracy: 78.3567, Validation MAE: 0.032368213901114336
# SNR [30dB], Validation Loss: 0.3878, Validation Accuracy: 88.5800, Validation MAE: 0.01749344507912726
# SNR [40dB], Validation Loss: 0.3368, Validation Accuracy: 90.4267, Validation MAE: 0.014561288510160128
#
#
# Epoch [28/60], Training Loss: 0.6685, Training Accuracy: 75.7998, Training MAE: 0.029932531336806928
# SNR [0dB], Validation Loss: 3.0046, Validation Accuracy: 20.3133, Validation MAE: 0.15054334148796703
# SNR [10dB], Validation Loss: 1.5225, Validation Accuracy: 52.2133, Validation MAE: 0.06563407154227924
# SNR [20dB], Validation Loss: 0.7028, Validation Accuracy: 78.2433, Validation MAE: 0.03447149487311546
# SNR [30dB], Validation Loss: 0.3930, Validation Accuracy: 88.6467, Validation MAE: 0.022598748127165464
# SNR [40dB], Validation Loss: 0.3405, Validation Accuracy: 90.8033, Validation MAE: 0.020031647977338703
#
#
# Epoch [29/60], Training Loss: 0.6396, Training Accuracy: 76.6998, Training MAE: 0.028719418171562726
# SNR [0dB], Validation Loss: 3.0909, Validation Accuracy: 19.6600, Validation MAE: 0.15508533102350408
# SNR [10dB], Validation Loss: 1.5295, Validation Accuracy: 52.1633, Validation MAE: 0.06866316192995599
# SNR [20dB], Validation Loss: 0.6931, Validation Accuracy: 77.7967, Validation MAE: 0.03538815958891282
# SNR [30dB], Validation Loss: 0.3821, Validation Accuracy: 88.4000, Validation MAE: 0.021565031252926303
# SNR [40dB], Validation Loss: 0.3304, Validation Accuracy: 90.0600, Validation MAE: 0.019285440467272215
#
#
# Epoch [30/60], Training Loss: 0.6109, Training Accuracy: 77.6236, Training MAE: 0.027212489944019282
# SNR [0dB], Validation Loss: 3.1542, Validation Accuracy: 19.6900, Validation MAE: 0.15173178668414647
# SNR [10dB], Validation Loss: 1.5101, Validation Accuracy: 52.0233, Validation MAE: 0.06225199573930143
# SNR [20dB], Validation Loss: 0.6714, Validation Accuracy: 78.4000, Validation MAE: 0.030203846333926396
# SNR [30dB], Validation Loss: 0.3495, Validation Accuracy: 89.5133, Validation MAE: 0.017927635429347315
# SNR [40dB], Validation Loss: 0.2929, Validation Accuracy: 91.6600, Validation MAE: 0.01517727549396011
#
#
# Epoch [31/60], Training Loss: 0.5854, Training Accuracy: 78.5012, Training MAE: 0.02621901988401201
# SNR [0dB], Validation Loss: 3.2193, Validation Accuracy: 19.6867, Validation MAE: 0.16094781522146268
# SNR [10dB], Validation Loss: 1.5592, Validation Accuracy: 51.3333, Validation MAE: 0.07979591956175672
# SNR [20dB], Validation Loss: 0.7241, Validation Accuracy: 77.5433, Validation MAE: 0.038990805552954394
# SNR [30dB], Validation Loss: 0.4135, Validation Accuracy: 87.8467, Validation MAE: 0.021875219472797077
# SNR [40dB], Validation Loss: 0.3609, Validation Accuracy: 89.7567, Validation MAE: 0.01875321893435715
#
#
# Epoch [32/60], Training Loss: 0.5588, Training Accuracy: 79.4149, Training MAE: 0.02522059722750268
# SNR [0dB], Validation Loss: 3.3422, Validation Accuracy: 19.2133, Validation MAE: 0.15922751428036333
# SNR [10dB], Validation Loss: 1.5683, Validation Accuracy: 51.2567, Validation MAE: 0.07890705473358929
# SNR [20dB], Validation Loss: 0.6897, Validation Accuracy: 77.9667, Validation MAE: 0.042924855440584324
# SNR [30dB], Validation Loss: 0.3697, Validation Accuracy: 88.6500, Validation MAE: 0.025026483050847457
# SNR [40dB], Validation Loss: 0.3135, Validation Accuracy: 90.7500, Validation MAE: 0.020800900131098417
#
#
# Epoch [33/60], Training Loss: 0.5355, Training Accuracy: 80.1640, Training MAE: 0.024510803055853434
# SNR [0dB], Validation Loss: 3.4104, Validation Accuracy: 19.3767, Validation MAE: 0.16210553422605112
# SNR [10dB], Validation Loss: 1.5904, Validation Accuracy: 50.7000, Validation MAE: 0.08577289540219121
# SNR [20dB], Validation Loss: 0.7116, Validation Accuracy: 77.8100, Validation MAE: 0.04629449445172769
# SNR [30dB], Validation Loss: 0.3783, Validation Accuracy: 89.0967, Validation MAE: 0.025569312435621314
# SNR [40dB], Validation Loss: 0.3189, Validation Accuracy: 91.1167, Validation MAE: 0.02095343372506789
#
#
# Epoch [34/60], Training Loss: 0.5127, Training Accuracy: 80.9961, Training MAE: 0.023269456190865217
# SNR [0dB], Validation Loss: 3.4694, Validation Accuracy: 19.0200, Validation MAE: 0.16012625538439929
# SNR [10dB], Validation Loss: 1.6046, Validation Accuracy: 50.7967, Validation MAE: 0.08971462683771889
# SNR [20dB], Validation Loss: 0.7004, Validation Accuracy: 78.1267, Validation MAE: 0.04239263390766926
# SNR [30dB], Validation Loss: 0.3627, Validation Accuracy: 89.2933, Validation MAE: 0.020777123911414928
# SNR [40dB], Validation Loss: 0.3070, Validation Accuracy: 91.0100, Validation MAE: 0.016528130559977525
#
#
# Epoch [35/60], Training Loss: 0.4928, Training Accuracy: 81.7572, Training MAE: 0.022667371243930014
# SNR [0dB], Validation Loss: 3.5136, Validation Accuracy: 19.4500, Validation MAE: 0.15479270062739958
# SNR [10dB], Validation Loss: 1.5877, Validation Accuracy: 50.9033, Validation MAE: 0.0787962209710647
# SNR [20dB], Validation Loss: 0.7129, Validation Accuracy: 77.2967, Validation MAE: 0.04154693206292724
# SNR [30dB], Validation Loss: 0.3869, Validation Accuracy: 88.6733, Validation MAE: 0.023551991642475886
# SNR [40dB], Validation Loss: 0.3316, Validation Accuracy: 90.4700, Validation MAE: 0.01846973323813091
#
#
# Epoch [36/60], Training Loss: 0.4728, Training Accuracy: 82.3960, Training MAE: 0.021920413100103908
# SNR [0dB], Validation Loss: 3.6741, Validation Accuracy: 19.3067, Validation MAE: 0.15809320570746324
# SNR [10dB], Validation Loss: 1.6091, Validation Accuracy: 51.0867, Validation MAE: 0.08261614500421388
# SNR [20dB], Validation Loss: 0.6958, Validation Accuracy: 77.3200, Validation MAE: 0.04270574843150108
# SNR [30dB], Validation Loss: 0.3698, Validation Accuracy: 88.1300, Validation MAE: 0.02350261026313325
# SNR [40dB], Validation Loss: 0.3129, Validation Accuracy: 90.0900, Validation MAE: 0.017686946928551363
#
#
# Epoch [37/60], Training Loss: 0.4538, Training Accuracy: 83.1314, Training MAE: 0.02106172905881012
# SNR [0dB], Validation Loss: 3.6940, Validation Accuracy: 19.1933, Validation MAE: 0.15524115670942973
# SNR [10dB], Validation Loss: 1.6325, Validation Accuracy: 50.5267, Validation MAE: 0.08074587098511096
# SNR [20dB], Validation Loss: 0.7100, Validation Accuracy: 77.7000, Validation MAE: 0.04569313898773293
# SNR [30dB], Validation Loss: 0.3757, Validation Accuracy: 89.0933, Validation MAE: 0.0275467623372975
# SNR [40dB], Validation Loss: 0.3183, Validation Accuracy: 90.8933, Validation MAE: 0.02288442855136249
#
#
# Epoch [38/60], Training Loss: 0.4384, Training Accuracy: 83.6768, Training MAE: 0.02051313475388533
# SNR [0dB], Validation Loss: 3.7684, Validation Accuracy: 19.3133, Validation MAE: 0.15324980686393858
# SNR [10dB], Validation Loss: 1.6376, Validation Accuracy: 50.7667, Validation MAE: 0.0785895507538159
# SNR [20dB], Validation Loss: 0.7165, Validation Accuracy: 77.1600, Validation MAE: 0.04556950264537878
# SNR [30dB], Validation Loss: 0.3838, Validation Accuracy: 87.8967, Validation MAE: 0.027700759083247494
# SNR [40dB], Validation Loss: 0.3244, Validation Accuracy: 89.8200, Validation MAE: 0.02255046411180822
#
#
# Epoch [39/60], Training Loss: 0.4207, Training Accuracy: 84.2985, Training MAE: 0.01994686188926816
# SNR [0dB], Validation Loss: 3.8330, Validation Accuracy: 19.0067, Validation MAE: 0.15879625023410432
# SNR [10dB], Validation Loss: 1.6511, Validation Accuracy: 50.5233, Validation MAE: 0.07991589802415956
# SNR [20dB], Validation Loss: 0.7176, Validation Accuracy: 77.4533, Validation MAE: 0.041282101554452666
# SNR [30dB], Validation Loss: 0.3731, Validation Accuracy: 88.5433, Validation MAE: 0.022036531978649687
# SNR [40dB], Validation Loss: 0.3130, Validation Accuracy: 90.6000, Validation MAE: 0.018389625667197304
#
#
# Epoch [40/60], Training Loss: 0.4061, Training Accuracy: 84.8453, Training MAE: 0.019384670692109373
# SNR [0dB], Validation Loss: 3.9155, Validation Accuracy: 18.9567, Validation MAE: 0.15651300156849893
# SNR [10dB], Validation Loss: 1.6713, Validation Accuracy: 50.8600, Validation MAE: 0.08222840972937541
# SNR [20dB], Validation Loss: 0.7196, Validation Accuracy: 77.3333, Validation MAE: 0.047753622764303776
# SNR [30dB], Validation Loss: 0.3755, Validation Accuracy: 88.8367, Validation MAE: 0.028171162444985486
# SNR [40dB], Validation Loss: 0.3160, Validation Accuracy: 90.6533, Validation MAE: 0.024907601952430004
#
#
# Epoch [41/60], Training Loss: 0.3909, Training Accuracy: 85.3819, Training MAE: 0.01847527778216853
# SNR [0dB], Validation Loss: 4.0599, Validation Accuracy: 18.8033, Validation MAE: 0.1566798008942785
# SNR [10dB], Validation Loss: 1.7101, Validation Accuracy: 50.1367, Validation MAE: 0.09076041471579736
# SNR [20dB], Validation Loss: 0.7218, Validation Accuracy: 77.3400, Validation MAE: 0.056129802064800075
# SNR [30dB], Validation Loss: 0.3778, Validation Accuracy: 88.6667, Validation MAE: 0.03267072057308737
# SNR [40dB], Validation Loss: 0.3162, Validation Accuracy: 90.5500, Validation MAE: 0.030189946390111435
#
#
# Epoch [42/60], Training Loss: 0.3783, Training Accuracy: 85.8695, Training MAE: 0.017799085872875764
# SNR [0dB], Validation Loss: 4.1218, Validation Accuracy: 19.4067, Validation MAE: 0.15547306629834254
# SNR [10dB], Validation Loss: 1.7190, Validation Accuracy: 50.4433, Validation MAE: 0.07731587695477105
# SNR [20dB], Validation Loss: 0.7107, Validation Accuracy: 77.1500, Validation MAE: 0.0453094273808409
# SNR [30dB], Validation Loss: 0.3801, Validation Accuracy: 87.9033, Validation MAE: 0.027231818873490028
# SNR [40dB], Validation Loss: 0.3243, Validation Accuracy: 89.8000, Validation MAE: 0.023665385920966384
#
#
# Epoch [43/60], Training Loss: 0.3644, Training Accuracy: 86.3366, Training MAE: 0.017417124991992654
# SNR [0dB], Validation Loss: 4.1330, Validation Accuracy: 18.9767, Validation MAE: 0.15851203296188782
# SNR [10dB], Validation Loss: 1.7448, Validation Accuracy: 49.7000, Validation MAE: 0.08435363798108438
# SNR [20dB], Validation Loss: 0.7482, Validation Accuracy: 76.1967, Validation MAE: 0.049095698918438055
# SNR [30dB], Validation Loss: 0.3976, Validation Accuracy: 87.7000, Validation MAE: 0.026918338561663077
# SNR [40dB], Validation Loss: 0.3329, Validation Accuracy: 89.8200, Validation MAE: 0.023858887770390486
#
#
# Epoch [44/60], Training Loss: 0.3524, Training Accuracy: 86.8224, Training MAE: 0.016947512252281784
# SNR [0dB], Validation Loss: 4.1528, Validation Accuracy: 19.1033, Validation MAE: 0.1612953138168368
# SNR [10dB], Validation Loss: 1.7273, Validation Accuracy: 50.8067, Validation MAE: 0.08647155047289072
# SNR [20dB], Validation Loss: 0.7054, Validation Accuracy: 77.6167, Validation MAE: 0.050563240354902145
# SNR [30dB], Validation Loss: 0.3505, Validation Accuracy: 88.6967, Validation MAE: 0.030162878078471768
# SNR [40dB], Validation Loss: 0.2878, Validation Accuracy: 90.7067, Validation MAE: 0.026881759762150015
#
#
# Epoch [45/60], Training Loss: 0.3404, Training Accuracy: 87.2414, Training MAE: 0.016680384015753467
# SNR [0dB], Validation Loss: 4.2994, Validation Accuracy: 19.1800, Validation MAE: 0.15799078506882666
# SNR [10dB], Validation Loss: 1.7696, Validation Accuracy: 50.6933, Validation MAE: 0.08197894231669632
# SNR [20dB], Validation Loss: 0.7182, Validation Accuracy: 77.3967, Validation MAE: 0.053151190420451355
# SNR [30dB], Validation Loss: 0.3615, Validation Accuracy: 88.7100, Validation MAE: 0.031665169374473265
# SNR [40dB], Validation Loss: 0.2986, Validation Accuracy: 90.8033, Validation MAE: 0.026586568850079595
#
#
# Epoch [46/60], Training Loss: 0.3305, Training Accuracy: 87.6395, Training MAE: 0.01622145640550373
# SNR [0dB], Validation Loss: 4.3107, Validation Accuracy: 18.7167, Validation MAE: 0.15321578858039142
# SNR [10dB], Validation Loss: 1.7773, Validation Accuracy: 49.8467, Validation MAE: 0.0781919392031089
# SNR [20dB], Validation Loss: 0.7277, Validation Accuracy: 76.9567, Validation MAE: 0.05302353041015076
# SNR [30dB], Validation Loss: 0.3758, Validation Accuracy: 88.6200, Validation MAE: 0.03280350161531979
# SNR [40dB], Validation Loss: 0.3105, Validation Accuracy: 90.7167, Validation MAE: 0.02991048436183163
#
#
# Epoch [47/60], Training Loss: 0.3201, Training Accuracy: 88.0147, Training MAE: 0.015714939672435008
# SNR [0dB], Validation Loss: 4.4221, Validation Accuracy: 18.6200, Validation MAE: 0.15818318955426539
# SNR [10dB], Validation Loss: 1.8086, Validation Accuracy: 49.8567, Validation MAE: 0.07978165382994662
# SNR [20dB], Validation Loss: 0.7435, Validation Accuracy: 76.8267, Validation MAE: 0.054761023387021254
# SNR [30dB], Validation Loss: 0.3880, Validation Accuracy: 88.1833, Validation MAE: 0.03407388332240847
# SNR [40dB], Validation Loss: 0.3216, Validation Accuracy: 90.6233, Validation MAE: 0.030409419187189812
#
#
# Epoch [48/60], Training Loss: 0.3094, Training Accuracy: 88.3891, Training MAE: 0.015248641662666458
# SNR [0dB], Validation Loss: 4.4003, Validation Accuracy: 19.1567, Validation MAE: 0.15330979609514
# SNR [10dB], Validation Loss: 1.8055, Validation Accuracy: 50.3200, Validation MAE: 0.0784677433514374
# SNR [20dB], Validation Loss: 0.7242, Validation Accuracy: 77.3467, Validation MAE: 0.05483162047008147
# SNR [30dB], Validation Loss: 0.3621, Validation Accuracy: 89.2067, Validation MAE: 0.0344528396853638
# SNR [40dB], Validation Loss: 0.2970, Validation Accuracy: 91.4333, Validation MAE: 0.029849763554639946
#
#
# Epoch [49/60], Training Loss: 0.3007, Training Accuracy: 88.7516, Training MAE: 0.01502262907636389
# SNR [0dB], Validation Loss: 4.4205, Validation Accuracy: 18.7767, Validation MAE: 0.15468259844086524
# SNR [10dB], Validation Loss: 1.8265, Validation Accuracy: 49.5833, Validation MAE: 0.08153048623466616
# SNR [20dB], Validation Loss: 0.7325, Validation Accuracy: 77.1833, Validation MAE: 0.05305645132971252
# SNR [30dB], Validation Loss: 0.3546, Validation Accuracy: 88.9533, Validation MAE: 0.030801909705964976
# SNR [40dB], Validation Loss: 0.2838, Validation Accuracy: 91.3467, Validation MAE: 0.027700027507257235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a90cb20edcf7> in <module>
#      79         print("\n")
#      80
# ---> 81 train()
#      82 print("Training Complete")
#
# <ipython-input-10-a90cb20edcf7> in train()
#      15             auto_outputs = torch.transpose(enn, 2, 3)
#      16             auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, doa))
# ---> 17             losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
#      18             losss.backward()
#      19             optimizer.step()
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))
# Out:
# === Metrics ===
# ==== DOA-2 ====
# = MAE =_= Acc =
# 0.1220   21.62
# 0.0489   49.71
# 0.0258   75.32
# 0.0148   88.27
# 0.0121   90.33

# %%
loss_res[0].index(min(loss_res[0]))
# min(loss_res[0])
# Out:
# 21

# %%
acc_res[0][29]
# Out:
# 19.689999999999998

# %%
mae_res[0][21]
# Out:
# 0.13523365073976965

# %%
import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()
