# %%
import scipy.io as sio
import numpy as np
import torch
import os
from os import listdir
from os.path import isfile, join
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np 
import math
import pandas as pd
import cmath
import scipy.io as sio
import numpy as np
import torch
from torch import nn, optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np 
import math
import pandas as pd
import cmath

#from unet import UNet
# from auto import encoder, decoder

from collections import OrderedDict
from torch.utils.data.sampler import SubsetRandomSampler
from torch.autograd import Variable
#==========================================================================
# For Plotting loss graph
# Bokeh
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

from functools import partial
from threading import Thread
from tornado import gen
# from AttRCNN_UNet import Att_R2U
import logging
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
import sys
# from dataloader import norm
import csv
from sklearn.model_selection import train_test_split
from sys import getsizeof
# import wandb
# import logging
# logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)

# %%
root_dataset_path =  ("../../SNS_dataset/1000/DOA7")

# %%
def create_dataset(df, dataset_type):
  
    data = np.transpose(df[dataset_type], (2, 0, 1))
    label = df['DOA']
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.15, random_state=42)
    
    return X_train, X_test, y_train, y_test

def get_data(train, test, batch_size, train_bool=True):
    class DOA_dataset(Dataset):
        def __init__(self, train, test):
            self.x = torch.from_numpy(np.array(train))
            self.y = torch.from_numpy(np.asarray(test))
            self.n_sample = len(self.y)
        def __getitem__(self, index):
            return self.x[index], self.y[index]
        def __len__(self):
            return self.n_sample


    dataset = DOA_dataset(train, test)
    

    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_bool)
    return loader

# %%
def create_dataloader(root_path, dataset_type, ss):
    # Loading all dataset 
    logging.info('Data prepration started')
    df1  = sio.loadmat(root_path + "/SNR_SNS_0_7_1000.mat")
    df2  = sio.loadmat(root_path + "/SNR_SNS_10_7_1000.mat")
    df3  = sio.loadmat(root_path + "/SNR_SNS_20_7_1000.mat")
    df4  = sio.loadmat(root_path + "/SNR_SNS_30_7_1000.mat")
    df5  = sio.loadmat(root_path + "/SNR_SNS_40_7_1000.mat")
    df = [df1, df2, df3, df4, df5]

    new_train_dataset_list = []
    new_test_dataset_list = []
    train_dataset_list_label = []
    test_dataset_list_label = []

    dataset_len = 0
    if dataset_type == "SNS":
        dataset_len = ss//10
    if dataset_type == "NS":
        dataset_len = ss

    for file in df:
        X_train, X_test, y_train, y_test = create_dataset(file, dataset_type+"_data")
        new_train_dataset_list.extend(X_train)
        new_test_dataset_list.append(X_test.tolist())
        train_dataset_list_label.extend(y_train)
        test_dataset_list_label.append(y_test.tolist())

    # Deleteing all unused memory
    del df

    # Dividing into different channels
    logging.info('Dividing your dataset into 3 channel')

    for idx, data in enumerate(new_train_dataset_list):
        new = np.zeros((3, 8, dataset_len))
        for j in range(0, data.shape[0]):
            for k in range(0, data.shape[1]):
                new[0][j][k] = data[j][k].real
                new[1][j][k] = data[j][k].imag
                new[2][j][k] = cmath.phase(data[j][k])
        new_train_dataset_list[idx] = new

    for idx, data in enumerate(new_test_dataset_list):
        for i, ndata in enumerate(data):
            new = np.zeros((3, 8, dataset_len))
            for j in range(0, 8):
                for k in range(0, dataset_len):
                    new[0][j][k] = ndata[j][k].real
                    new[1][j][k] = ndata[j][k].imag
                    new[2][j][k] = cmath.phase(ndata[j][k])
            new_test_dataset_list[idx][i] = new

    # Generaring train loader
    logging.info('Creating Train dataloader')
    doa_train_loader = get_data(new_train_dataset_list, train_dataset_list_label, 64, True)

    # Deleteing all unused memory
    del new_train_dataset_list
    del train_dataset_list_label

    test_dataset_list = []
    logging.info('Creating Validation dataloader')
    for idx, data in enumerate(new_test_dataset_list):
        f = get_data(data, test_dataset_list_label[idx], 128, False)
        test_dataset_list.append(f)

    # Deleteing all unused memory
    del new_test_dataset_list
    del new
    logging.info('Your dataset is ready !!')
    return doa_train_loader ,test_dataset_list

# %%
doa_train_loader , test_dataset_list = create_dataloader(root_dataset_path, "SNS", 1000)
# Out:
# 2021-08-03 20:22:46,839 - Data prepration started
# 2021-08-03 20:23:31,695 - Dividing your dataset into 3 channel
# 2021-08-03 20:39:07,144 - Creating Train dataloader
# 2021-08-03 20:39:10,760 - Creating Validation dataloader
# 2021-08-03 20:39:11,056 - Your dataset is ready !!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=(3,3), stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=(3,3), stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.relu2 = nn.ReLU(inplace=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu2(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=181):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=(1,3), stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=1)
        self.linear = nn.Linear(25, num_classes)
        self.adp_pool = nn.AdaptiveMaxPool2d((7, 25))
        #self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.flat = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(0.7)
        self.dropout1 = nn.Dropout(0.6)
        self.relu = nn.ReLU(inplace=True)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.dropout(out)
        out = self.layer4(out)
        out = self.dropout1(out)
        out = self.adp_pool(out)
        out = self.linear(out)
        out = self.dropout1(out)
        out = self.flat(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [2, 3, 5, 2])

def ResNet101():
    return ResNet(BasicBlock, [3, 4, 23, 3])


if __name__ == "__main__":
    image = torch.rand(1, 3, 10, 100)
    model = ResNet34()
    print(model(image).size())
# Out:
# torch.Size([1, 1, 7, 181])

# %%
nq_type = "SNS" # Sub-Nyquist or Nyquist sample
no_samples = 1000
no_doa = 7

# %%
num_epochs = 60
doa = 7
weights_dir = root_dataset_path

autoencoder = ResNet34()
criterion = nn.CrossEntropyLoss()
# if ('SNS_DOA_{}_model.pth'.format(doa) in [f for f in listdir(weights_dir) if isfile(join(weights_dir, f))]):
#     print("Pre-trained available for DOA_{}_model.pth".format(doa))
#     autoencoder = torch.load(os.path.join(weights_dir, 'SNS_DOA_{}_model.pth'.format(doa)))

if torch.cuda.is_available():
	print(torch.cuda.get_device_name(0))
	classification_model = autoencoder.cuda()
	optimizer = optim.AdamW(classification_model.parameters(), lr=0.0001, weight_decay=1e-5)
	criterion = criterion.cuda()
# Out:
# GeForce GTX 1080 Ti

# %%
acc_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
loss_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}
mae_res = {
    "training": [],
    0: [],
    10: [],
    20: [],
    30: [],
    40: []
}

# %%
# %%time
def train():
    print("Training Starts !!!!!!!")
    best_valid_loss = float('Inf')
    for i in range(num_epochs):
        training_loss = 0
        train_correct = 0
        train_total = 0
        epoch_loss = 0.0
        training_mae = 0.0
        classification_model.train()
#         criterion = None
#         if (i+1)>=25 :
#           print("Criterion is changed to focal loss")
#           criterion = cross_criterion.cuda()
#         else:
#           criterion = cross_criterion.cuda()
        for j,(features, labels) in enumerate(doa_train_loader, 0):
            features, labels = Variable(features.cuda()), Variable(labels.cuda())
            optimizer.zero_grad()
            enn = classification_model(features.float())
            auto_outputs = torch.transpose(enn, 2, 3)
            auto_outputs = torch.reshape(auto_outputs.cuda(), (auto_outputs.shape[0], 181, no_doa))
            losss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())
            losss.backward()
            optimizer.step()
#           exp_scheduler.step()
            training_loss += losss.item()

            _, pred = torch.max(auto_outputs, 1)

            train_total+= labels.reshape(-1).size(0)

            train_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()

            epoch_loss += auto_outputs.shape[0] * losss.item()
            training_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

        loss_res['training'].append(training_loss/len(doa_train_loader))
        acc_res['training'].append((100*(train_correct/train_total)))
        mae_res['training'].append(training_mae/(len(doa_train_loader)*181*no_doa))
        print('Epoch [{}/{}], Training Loss: {:.4f}, Training Accuracy: {:.4f}, Training MAE: {}'
                      .format(i+1, num_epochs, training_loss/len(doa_train_loader), (100*(train_correct/train_total)), training_mae/(len(doa_train_loader)*181*no_doa)))
        
        # Validation for each SNR value
        classification_model.eval()
        total_valdation_loss = 0
        zero_val = 0
        for val_data in range(0, len(test_dataset_list)):
            
            validation_loss = 0
            validation_acc = 0
            validation_mae = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for features, labels in test_dataset_list[val_data]:
                    features, labels = Variable(features.cuda()), Variable(labels.cuda())
                    enn = classification_model(features.float())
                    auto_outputs = torch.transpose(enn, 2, 3)
                    auto_outputs = torch.reshape(auto_outputs, (auto_outputs.shape[0], 181, no_doa))
                    loss = criterion(auto_outputs.cuda(), labels.type(torch.LongTensor).cuda())

                    _, pred = torch.max(auto_outputs, 1)
                    val_total+= labels.reshape(-1).size(0)
                    val_correct+=(pred.reshape(-1).cuda() == labels.reshape(-1)).sum().item()
                    validation_loss += loss.item()
                    validation_mae += torch.mean(torch.abs(pred.float().cuda() - labels.float()))

                loss_res[10*val_data].append(validation_loss/len(test_dataset_list[val_data]))
                acc_res[10*val_data].append((100*(val_correct/val_total)))
                
                mae_res[10*val_data].append(validation_mae/(len(test_dataset_list[val_data])*181*no_doa))

                print('SNR [{}dB], Validation Loss: {:.4f}, Validation Accuracy: {:.4f}, Validation MAE: {}'
                      .format(val_data*10, validation_loss/len(test_dataset_list[val_data]), (100*(val_correct/val_total)), validation_mae/(len(test_dataset_list[val_data])*181*no_doa)))

                total_valdation_loss+=validation_loss

#         scheduler.step(loss_res[0][len(loss_res[0])-1])
        # print("Odb Loss => ", loss_res[0][len(loss_res[0])-1])
        # print("Lr -> ", optimizer.state_dict()["param_groups"][0]['lr'])
        torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_model.pth".format(nq_type, no_doa, no_samples))
        if best_valid_loss > total_valdation_loss:
            best_valid_loss = total_valdation_loss 
            # Saving Best Pre-Trained Model as .pth file
            torch.save( classification_model, weights_dir+ "/{}_DOA_{}_{}_best_model.pth".format(nq_type, no_doa, no_samples))
#         if i%10 == 0:
#           ddf = pd.DataFrame(acc_res)
#           ddf.to_csv(weights_dir+"res_DOA_{}_model.csv".format(doa))
        print("\n")

train()
print("Training Complete")
# Out:
# Training Starts !!!!!!!
# Epoch [1/60], Training Loss: 5.1937, Training Accuracy: 0.5543, Training MAE: 0.050419051200151443
# SNR [0dB], Validation Loss: 5.1924, Validation Accuracy: 0.6038, Validation MAE: 0.049646347761154175
# SNR [10dB], Validation Loss: 5.1901, Validation Accuracy: 0.6143, Validation MAE: 0.04776134714484215
# SNR [20dB], Validation Loss: 5.1900, Validation Accuracy: 0.6581, Validation MAE: 0.04717373102903366
# SNR [30dB], Validation Loss: 5.1894, Validation Accuracy: 0.6790, Validation MAE: 0.04696027189493179
# SNR [40dB], Validation Loss: 5.1896, Validation Accuracy: 0.6467, Validation MAE: 0.047336261719465256
#
#
# Epoch [2/60], Training Loss: 4.1597, Training Accuracy: 3.5889, Training MAE: 0.020850863307714462
# SNR [0dB], Validation Loss: 4.1633, Validation Accuracy: 5.1352, Validation MAE: 0.017904415726661682
# SNR [10dB], Validation Loss: 3.5302, Validation Accuracy: 9.3162, Validation MAE: 0.007233374286442995
# SNR [20dB], Validation Loss: 3.3566, Validation Accuracy: 10.8257, Validation MAE: 0.004736708477139473
# SNR [30dB], Validation Loss: 3.3298, Validation Accuracy: 11.1210, Validation MAE: 0.004371271468698978
# SNR [40dB], Validation Loss: 3.3239, Validation Accuracy: 11.2914, Validation MAE: 0.0042923674918711185
#
#
# Epoch [3/60], Training Loss: 2.8779, Training Accuracy: 13.0573, Training MAE: 0.00659123295918107
# SNR [0dB], Validation Loss: 3.8894, Validation Accuracy: 8.1305, Validation MAE: 0.017097216099500656
# SNR [10dB], Validation Loss: 2.9206, Validation Accuracy: 17.3733, Validation MAE: 0.0058083184994757175
# SNR [20dB], Validation Loss: 2.6059, Validation Accuracy: 21.8143, Validation MAE: 0.0029635841492563486
# SNR [30dB], Validation Loss: 2.5515, Validation Accuracy: 22.7552, Validation MAE: 0.0024499387945979834
# SNR [40dB], Validation Loss: 2.5387, Validation Accuracy: 22.9248, Validation MAE: 0.002397810574620962
#
#
# Epoch [4/60], Training Loss: 2.4141, Training Accuracy: 20.5532, Training MAE: 0.00537262624129653
# SNR [0dB], Validation Loss: 3.8186, Validation Accuracy: 8.7495, Validation MAE: 0.019612887874245644
# SNR [10dB], Validation Loss: 2.6444, Validation Accuracy: 21.6276, Validation MAE: 0.0067836688831448555
# SNR [20dB], Validation Loss: 2.2282, Validation Accuracy: 29.1590, Validation MAE: 0.0030629276297986507
# SNR [30dB], Validation Loss: 2.1496, Validation Accuracy: 31.1686, Validation MAE: 0.0024704253301024437
# SNR [40dB], Validation Loss: 2.1330, Validation Accuracy: 31.1781, Validation MAE: 0.0023607108741998672
#
#
# Epoch [5/60], Training Loss: 2.1623, Training Accuracy: 26.5442, Training MAE: 0.004794121719896793
# SNR [0dB], Validation Loss: 3.8095, Validation Accuracy: 9.0933, Validation MAE: 0.02022269368171692
# SNR [10dB], Validation Loss: 2.4934, Validation Accuracy: 24.6305, Validation MAE: 0.007656777743250132
# SNR [20dB], Validation Loss: 1.9908, Validation Accuracy: 34.5686, Validation MAE: 0.0037017124705016613
# SNR [30dB], Validation Loss: 1.8888, Validation Accuracy: 37.6667, Validation MAE: 0.003050391562283039
# SNR [40dB], Validation Loss: 1.8692, Validation Accuracy: 37.7314, Validation MAE: 0.0028686062432825565
#
#
# Epoch [6/60], Training Loss: 2.0066, Training Accuracy: 31.2116, Training MAE: 0.0044408198446035385
# SNR [0dB], Validation Loss: 3.7381, Validation Accuracy: 10.0343, Validation MAE: 0.019689247012138367
# SNR [10dB], Validation Loss: 2.3793, Validation Accuracy: 28.4505, Validation MAE: 0.007354442495852709
# SNR [20dB], Validation Loss: 1.8237, Validation Accuracy: 41.3581, Validation MAE: 0.0035307726357132196
# SNR [30dB], Validation Loss: 1.7049, Validation Accuracy: 45.2381, Validation MAE: 0.0030177386943250895
# SNR [40dB], Validation Loss: 1.6842, Validation Accuracy: 45.9476, Validation MAE: 0.0028345559258013964
#
#
# Epoch [7/60], Training Loss: 1.8888, Training Accuracy: 35.2078, Training MAE: 0.004169606603682041
# SNR [0dB], Validation Loss: 3.6726, Validation Accuracy: 10.6276, Validation MAE: 0.01807773858308792
# SNR [10dB], Validation Loss: 2.2865, Validation Accuracy: 31.2695, Validation MAE: 0.006115623749792576
# SNR [20dB], Validation Loss: 1.6790, Validation Accuracy: 46.7629, Validation MAE: 0.0027104890905320644
# SNR [30dB], Validation Loss: 1.5463, Validation Accuracy: 51.8095, Validation MAE: 0.0022386168129742146
# SNR [40dB], Validation Loss: 1.5214, Validation Accuracy: 52.8733, Validation MAE: 0.002093949355185032
#
#
# Epoch [8/60], Training Loss: 1.7914, Training Accuracy: 38.7742, Training MAE: 0.003960259724408388
# SNR [0dB], Validation Loss: 3.5609, Validation Accuracy: 11.9533, Validation MAE: 0.016821976751089096
# SNR [10dB], Validation Loss: 2.1808, Validation Accuracy: 34.0486, Validation MAE: 0.005315713584423065
# SNR [20dB], Validation Loss: 1.5337, Validation Accuracy: 52.1762, Validation MAE: 0.0020842449739575386
# SNR [30dB], Validation Loss: 1.3794, Validation Accuracy: 59.1943, Validation MAE: 0.001530959503725171
# SNR [40dB], Validation Loss: 1.3531, Validation Accuracy: 60.3467, Validation MAE: 0.0014498691307380795
#
#
# Epoch [9/60], Training Loss: 1.7182, Training Accuracy: 41.4754, Training MAE: 0.0038024941459298134
# SNR [0dB], Validation Loss: 3.4926, Validation Accuracy: 12.3781, Validation MAE: 0.01568196713924408
# SNR [10dB], Validation Loss: 2.0823, Validation Accuracy: 35.3105, Validation MAE: 0.004691313952207565
# SNR [20dB], Validation Loss: 1.4078, Validation Accuracy: 54.3476, Validation MAE: 0.0018718565115705132
# SNR [30dB], Validation Loss: 1.2409, Validation Accuracy: 61.2638, Validation MAE: 0.0014220812590792775
# SNR [40dB], Validation Loss: 1.2140, Validation Accuracy: 62.6295, Validation MAE: 0.0012444627936929464
#
#
# Epoch [10/60], Training Loss: 1.6548, Training Accuracy: 43.8759, Training MAE: 0.00366393756121397
# SNR [0dB], Validation Loss: 3.4673, Validation Accuracy: 12.8181, Validation MAE: 0.01513273362070322
# SNR [10dB], Validation Loss: 2.0361, Validation Accuracy: 36.8190, Validation MAE: 0.00449633551761508
# SNR [20dB], Validation Loss: 1.3397, Validation Accuracy: 55.5695, Validation MAE: 0.0019138423958793283
# SNR [30dB], Validation Loss: 1.1684, Validation Accuracy: 62.4448, Validation MAE: 0.0014879032969474792
# SNR [40dB], Validation Loss: 1.1369, Validation Accuracy: 63.9467, Validation MAE: 0.0013432435225695372
#
#
# Epoch [11/60], Training Loss: 1.6064, Training Accuracy: 45.7079, Training MAE: 0.0035495886113494635
# SNR [0dB], Validation Loss: 3.4746, Validation Accuracy: 13.1143, Validation MAE: 0.015854772180318832
# SNR [10dB], Validation Loss: 2.0621, Validation Accuracy: 37.2171, Validation MAE: 0.004602538887411356
# SNR [20dB], Validation Loss: 1.3300, Validation Accuracy: 56.8352, Validation MAE: 0.0016817216528579593
# SNR [30dB], Validation Loss: 1.1338, Validation Accuracy: 63.9933, Validation MAE: 0.0012200471246615052
# SNR [40dB], Validation Loss: 1.0976, Validation Accuracy: 65.5771, Validation MAE: 0.0011070759501308203
#
#
# Epoch [12/60], Training Loss: 1.5618, Training Accuracy: 47.3907, Training MAE: 0.003434751182794571
# SNR [0dB], Validation Loss: 3.4000, Validation Accuracy: 13.4476, Validation MAE: 0.01396866887807846
# SNR [10dB], Validation Loss: 1.9848, Validation Accuracy: 38.2524, Validation MAE: 0.004000210203230381
# SNR [20dB], Validation Loss: 1.2140, Validation Accuracy: 60.2486, Validation MAE: 0.001551167224533856
# SNR [30dB], Validation Loss: 1.0129, Validation Accuracy: 69.0114, Validation MAE: 0.0010551564628258348
# SNR [40dB], Validation Loss: 0.9739, Validation Accuracy: 70.6943, Validation MAE: 0.0009538009762763977
#
#
# Epoch [13/60], Training Loss: 1.5253, Training Accuracy: 48.7450, Training MAE: 0.003354532876983285
# SNR [0dB], Validation Loss: 3.4248, Validation Accuracy: 13.5476, Validation MAE: 0.014771034941077232
# SNR [10dB], Validation Loss: 1.9916, Validation Accuracy: 39.3781, Validation MAE: 0.004054604563862085
# SNR [20dB], Validation Loss: 1.2119, Validation Accuracy: 62.5257, Validation MAE: 0.0014262745389714837
# SNR [30dB], Validation Loss: 0.9881, Validation Accuracy: 72.2086, Validation MAE: 0.0008849007426761091
# SNR [40dB], Validation Loss: 0.9451, Validation Accuracy: 74.5457, Validation MAE: 0.0008274400024674833
#
#
# Epoch [14/60], Training Loss: 1.4926, Training Accuracy: 49.9692, Training MAE: 0.0032814317382872105
# SNR [0dB], Validation Loss: 3.3966, Validation Accuracy: 14.0571, Validation MAE: 0.01378181204199791
# SNR [10dB], Validation Loss: 1.9776, Validation Accuracy: 39.3248, Validation MAE: 0.0038919367361813784
# SNR [20dB], Validation Loss: 1.1825, Validation Accuracy: 62.2819, Validation MAE: 0.0014875381020829082
# SNR [30dB], Validation Loss: 0.9532, Validation Accuracy: 71.5143, Validation MAE: 0.0009465123293921351
# SNR [40dB], Validation Loss: 0.9121, Validation Accuracy: 73.2590, Validation MAE: 0.0008989974739961326
#
#
# Epoch [15/60], Training Loss: 1.4644, Training Accuracy: 51.0690, Training MAE: 0.0032178114634007215
# SNR [0dB], Validation Loss: 3.4066, Validation Accuracy: 13.8648, Validation MAE: 0.014247657731175423
# SNR [10dB], Validation Loss: 1.9939, Validation Accuracy: 39.5105, Validation MAE: 0.003835998708382249
# SNR [20dB], Validation Loss: 1.2447, Validation Accuracy: 62.1362, Validation MAE: 0.0013388810912147164
# SNR [30dB], Validation Loss: 1.0254, Validation Accuracy: 70.9448, Validation MAE: 0.0008989825728349388
# SNR [40dB], Validation Loss: 0.9849, Validation Accuracy: 72.8629, Validation MAE: 0.0007945763063617051
#
#
# Epoch [16/60], Training Loss: 1.4382, Training Accuracy: 52.0072, Training MAE: 0.003166505601257086
# SNR [0dB], Validation Loss: 3.3436, Validation Accuracy: 14.4810, Validation MAE: 0.012884378433227539
# SNR [10dB], Validation Loss: 1.9004, Validation Accuracy: 40.8257, Validation MAE: 0.0034763922449201345
# SNR [20dB], Validation Loss: 1.0800, Validation Accuracy: 65.2895, Validation MAE: 0.0012640858767554164
# SNR [30dB], Validation Loss: 0.8342, Validation Accuracy: 75.6971, Validation MAE: 0.0007463343790732324
# SNR [40dB], Validation Loss: 0.7889, Validation Accuracy: 78.2048, Validation MAE: 0.0006743635749444366
#
#
# Epoch [17/60], Training Loss: 1.4161, Training Accuracy: 52.7818, Training MAE: 0.003108216216787696
# SNR [0dB], Validation Loss: 3.3672, Validation Accuracy: 14.2686, Validation MAE: 0.013121123425662518
# SNR [10dB], Validation Loss: 1.9393, Validation Accuracy: 40.6781, Validation MAE: 0.0035121887922286987
# SNR [20dB], Validation Loss: 1.1320, Validation Accuracy: 65.0914, Validation MAE: 0.001236769137904048
# SNR [30dB], Validation Loss: 0.8746, Validation Accuracy: 75.6933, Validation MAE: 0.0007330392836593091
# SNR [40dB], Validation Loss: 0.8289, Validation Accuracy: 77.7238, Validation MAE: 0.0006743138656020164
#
#
# Epoch [18/60], Training Loss: 1.3953, Training Accuracy: 53.5612, Training MAE: 0.0030674063600599766
# SNR [0dB], Validation Loss: 3.2830, Validation Accuracy: 14.8067, Validation MAE: 0.012391998432576656
# SNR [10dB], Validation Loss: 1.8587, Validation Accuracy: 41.2867, Validation MAE: 0.0034206779673695564
# SNR [20dB], Validation Loss: 1.0399, Validation Accuracy: 65.5829, Validation MAE: 0.001240036217495799
# SNR [30dB], Validation Loss: 0.7861, Validation Accuracy: 75.8467, Validation MAE: 0.0007513955933973193
# SNR [40dB], Validation Loss: 0.7393, Validation Accuracy: 78.1362, Validation MAE: 0.0007106810808181763
#
#
# Epoch [19/60], Training Loss: 1.3773, Training Accuracy: 54.1349, Training MAE: 0.0030225194059312344
# SNR [0dB], Validation Loss: 3.2981, Validation Accuracy: 14.6495, Validation MAE: 0.012608896009624004
# SNR [10dB], Validation Loss: 1.8770, Validation Accuracy: 41.3533, Validation MAE: 0.0034118928015232086
# SNR [20dB], Validation Loss: 1.0623, Validation Accuracy: 65.8743, Validation MAE: 0.00122394401114434
# SNR [30dB], Validation Loss: 0.7976, Validation Accuracy: 76.3571, Validation MAE: 0.0007280948921106756
# SNR [40dB], Validation Loss: 0.7498, Validation Accuracy: 78.5552, Validation MAE: 0.0006873878883197904
#
#
# Epoch [20/60], Training Loss: 1.3613, Training Accuracy: 54.6795, Training MAE: 0.002983793616294861
# SNR [0dB], Validation Loss: 3.2694, Validation Accuracy: 14.9543, Validation MAE: 0.011939368210732937
# SNR [10dB], Validation Loss: 1.8462, Validation Accuracy: 41.8724, Validation MAE: 0.0032823283690959215
# SNR [20dB], Validation Loss: 1.0247, Validation Accuracy: 67.2495, Validation MAE: 0.0011598614510148764
# SNR [30dB], Validation Loss: 0.7529, Validation Accuracy: 78.5381, Validation MAE: 0.0006903164903633296
# SNR [40dB], Validation Loss: 0.7027, Validation Accuracy: 81.2086, Validation MAE: 0.0006181169883348048
#
#
# Epoch [21/60], Training Loss: 1.3445, Training Accuracy: 55.2574, Training MAE: 0.0029334546998143196
# SNR [0dB], Validation Loss: 3.2804, Validation Accuracy: 14.8067, Validation MAE: 0.011853603646159172
# SNR [10dB], Validation Loss: 1.8681, Validation Accuracy: 41.2143, Validation MAE: 0.003248080611228943
# SNR [20dB], Validation Loss: 1.0540, Validation Accuracy: 65.7514, Validation MAE: 0.001225083600729704
# SNR [30dB], Validation Loss: 0.7837, Validation Accuracy: 76.6724, Validation MAE: 0.0007740074652247131
# SNR [40dB], Validation Loss: 0.7312, Validation Accuracy: 79.2190, Validation MAE: 0.0006831102073192596
#
#
# Epoch [22/60], Training Loss: 1.3327, Training Accuracy: 55.6434, Training MAE: 0.0029148373287171125
# SNR [0dB], Validation Loss: 3.2779, Validation Accuracy: 14.9038, Validation MAE: 0.012228943407535553
# SNR [10dB], Validation Loss: 1.8605, Validation Accuracy: 41.4838, Validation MAE: 0.0033980924636125565
# SNR [20dB], Validation Loss: 1.0367, Validation Accuracy: 66.2571, Validation MAE: 0.0012225707760080695
# SNR [30dB], Validation Loss: 0.7637, Validation Accuracy: 77.1552, Validation MAE: 0.0007733879028819501
# SNR [40dB], Validation Loss: 0.7119, Validation Accuracy: 79.9476, Validation MAE: 0.0007047118851915002
#
#
# Epoch [23/60], Training Loss: 1.3179, Training Accuracy: 56.1858, Training MAE: 0.002876182086765766
# SNR [0dB], Validation Loss: 3.2534, Validation Accuracy: 14.9400, Validation MAE: 0.011707977391779423
# SNR [10dB], Validation Loss: 1.8265, Validation Accuracy: 42.1905, Validation MAE: 0.003252882743254304
# SNR [20dB], Validation Loss: 0.9835, Validation Accuracy: 68.1048, Validation MAE: 0.0011624640319496393
# SNR [30dB], Validation Loss: 0.6970, Validation Accuracy: 79.8895, Validation MAE: 0.0006916929269209504
# SNR [40dB], Validation Loss: 0.6421, Validation Accuracy: 82.6495, Validation MAE: 0.0006225089309737086
#
#
# Epoch [24/60], Training Loss: 1.3039, Training Accuracy: 56.6135, Training MAE: 0.0028338530100882053
# SNR [0dB], Validation Loss: 3.2428, Validation Accuracy: 15.0276, Validation MAE: 0.011512544937431812
# SNR [10dB], Validation Loss: 1.8193, Validation Accuracy: 41.7095, Validation MAE: 0.0032042532693594694
# SNR [20dB], Validation Loss: 0.9901, Validation Accuracy: 67.2933, Validation MAE: 0.0011039732489734888
# SNR [30dB], Validation Loss: 0.7093, Validation Accuracy: 78.4981, Validation MAE: 0.0006575400475412607
# SNR [40dB], Validation Loss: 0.6547, Validation Accuracy: 81.1152, Validation MAE: 0.0005765663809143007
#
#
# Epoch [25/60], Training Loss: 1.2916, Training Accuracy: 57.0251, Training MAE: 0.0028054462745785713
# SNR [0dB], Validation Loss: 3.2368, Validation Accuracy: 15.3038, Validation MAE: 0.011659020557999611
# SNR [10dB], Validation Loss: 1.8052, Validation Accuracy: 42.4895, Validation MAE: 0.003270744113251567
# SNR [20dB], Validation Loss: 0.9386, Validation Accuracy: 68.2200, Validation MAE: 0.0012491687666624784
# SNR [30dB], Validation Loss: 0.6490, Validation Accuracy: 79.5610, Validation MAE: 0.0006880445289425552
# SNR [40dB], Validation Loss: 0.5979, Validation Accuracy: 81.8933, Validation MAE: 0.0006396065000444651
#
#
# Epoch [26/60], Training Loss: 1.2818, Training Accuracy: 57.3250, Training MAE: 0.002778679598122835
# SNR [0dB], Validation Loss: 3.2529, Validation Accuracy: 15.1133, Validation MAE: 0.011850783601403236
# SNR [10dB], Validation Loss: 1.8223, Validation Accuracy: 41.9438, Validation MAE: 0.003256207099184394
# SNR [20dB], Validation Loss: 0.9712, Validation Accuracy: 68.1543, Validation MAE: 0.001066296943463385
# SNR [30dB], Validation Loss: 0.6778, Validation Accuracy: 79.3876, Validation MAE: 0.0006487112841568887
# SNR [40dB], Validation Loss: 0.6221, Validation Accuracy: 81.9200, Validation MAE: 0.0005680265021510422
#
#
# Epoch [27/60], Training Loss: 1.2704, Training Accuracy: 57.6660, Training MAE: 0.002753044478595257
# SNR [0dB], Validation Loss: 3.1974, Validation Accuracy: 15.3076, Validation MAE: 0.011075410060584545
# SNR [10dB], Validation Loss: 1.7841, Validation Accuracy: 42.2362, Validation MAE: 0.0030768243595957756
# SNR [20dB], Validation Loss: 0.9352, Validation Accuracy: 67.8876, Validation MAE: 0.0010950249852612615
# SNR [30dB], Validation Loss: 0.6477, Validation Accuracy: 79.5219, Validation MAE: 0.0006114405696280301
# SNR [40dB], Validation Loss: 0.5924, Validation Accuracy: 82.3019, Validation MAE: 0.0005522228311747313
#
#
# Epoch [28/60], Training Loss: 1.2589, Training Accuracy: 58.0621, Training MAE: 0.002724007237702608
# SNR [0dB], Validation Loss: 3.2047, Validation Accuracy: 15.1524, Validation MAE: 0.011212515644729137
# SNR [10dB], Validation Loss: 1.7915, Validation Accuracy: 42.2029, Validation MAE: 0.0031879693269729614
# SNR [20dB], Validation Loss: 0.9455, Validation Accuracy: 67.8048, Validation MAE: 0.0011258306913077831
# SNR [30dB], Validation Loss: 0.6585, Validation Accuracy: 79.0410, Validation MAE: 0.0006391286151483655
# SNR [40dB], Validation Loss: 0.6033, Validation Accuracy: 81.5219, Validation MAE: 0.0005851787282153964
#
#
# Epoch [29/60], Training Loss: 1.2481, Training Accuracy: 58.3755, Training MAE: 0.002693693619221449
# SNR [0dB], Validation Loss: 3.2281, Validation Accuracy: 15.0048, Validation MAE: 0.01148443017154932
# SNR [10dB], Validation Loss: 1.8087, Validation Accuracy: 41.9629, Validation MAE: 0.003164352849125862
# SNR [20dB], Validation Loss: 0.9549, Validation Accuracy: 67.9743, Validation MAE: 0.00110355275683105
# SNR [30dB], Validation Loss: 0.6510, Validation Accuracy: 79.8276, Validation MAE: 0.0005881123361177742
# SNR [40dB], Validation Loss: 0.5929, Validation Accuracy: 82.3838, Validation MAE: 0.0005513271898962557
#
#
# Epoch [30/60], Training Loss: 1.2394, Training Accuracy: 58.6337, Training MAE: 0.00267461477778852
# SNR [0dB], Validation Loss: 3.1964, Validation Accuracy: 15.2314, Validation MAE: 0.01114619616419077
# SNR [10dB], Validation Loss: 1.7635, Validation Accuracy: 42.2629, Validation MAE: 0.0031148933339864016
# SNR [20dB], Validation Loss: 0.9013, Validation Accuracy: 68.0543, Validation MAE: 0.001190831302665174
# SNR [30dB], Validation Loss: 0.6058, Validation Accuracy: 79.3695, Validation MAE: 0.0006488532526418567
# SNR [40dB], Validation Loss: 0.5499, Validation Accuracy: 81.8914, Validation MAE: 0.0005738143809139729
#
#
# Epoch [31/60], Training Loss: 1.2294, Training Accuracy: 58.9238, Training MAE: 0.002642870182171464
# SNR [0dB], Validation Loss: 3.1834, Validation Accuracy: 15.3219, Validation MAE: 0.011264519765973091
# SNR [10dB], Validation Loss: 1.7374, Validation Accuracy: 42.8990, Validation MAE: 0.0032212091609835625
# SNR [20dB], Validation Loss: 0.8827, Validation Accuracy: 69.0552, Validation MAE: 0.0012706181732937694
# SNR [30dB], Validation Loss: 0.5870, Validation Accuracy: 80.9657, Validation MAE: 0.0007295032846741378
# SNR [40dB], Validation Loss: 0.5303, Validation Accuracy: 83.6676, Validation MAE: 0.0006302180700004101
#
#
# Epoch [32/60], Training Loss: 1.2195, Training Accuracy: 59.2152, Training MAE: 0.002609079470857978
# SNR [0dB], Validation Loss: 3.2339, Validation Accuracy: 15.0619, Validation MAE: 0.011767839081585407
# SNR [10dB], Validation Loss: 1.7973, Validation Accuracy: 42.5467, Validation MAE: 0.0032122626435011625
# SNR [20dB], Validation Loss: 0.9464, Validation Accuracy: 68.3381, Validation MAE: 0.001142759108915925
# SNR [30dB], Validation Loss: 0.6415, Validation Accuracy: 80.1467, Validation MAE: 0.0006989811081439257
# SNR [40dB], Validation Loss: 0.5779, Validation Accuracy: 82.9190, Validation MAE: 0.0006141205667518079
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in train()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adamw.py in step(self, closure)
#     119                     lr=group['lr'],
#     120                     weight_decay=group['weight_decay'],
# --> 121                     eps=group['eps'])
#     122
#     123         return loss
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/_functional.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#     130         # Decay the first and second moment running average coefficient
#     131         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 132         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     133         if amsgrad:
#     134             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
# SNS DOA-2 200 Samples
print("=== Metrics ===")
print("==== DOA-{} ====".format(doa))
print("= MAE =_= Acc =")
print("{:.4f}".format(min(mae_res[0])), "  {:.2f}".format(acc_res[0][mae_res[0].index(min(mae_res[0]))]))
print("{:.4f}".format(min(mae_res[10])), "  {:.2f}".format(acc_res[10][mae_res[10].index(min(mae_res[10]))]))
print("{:.4f}".format(min(mae_res[20])), "  {:.2f}".format(acc_res[20][mae_res[20].index(min(mae_res[20]))]))
print("{:.4f}".format(min(mae_res[30])), "  {:.2f}".format(acc_res[30][mae_res[30].index(min(mae_res[30]))]))
print("{:.4f}".format(min(mae_res[40])), "  {:.2f}".format(acc_res[40][mae_res[40].index(min(mae_res[40]))]))

import matplotlib.pyplot as plt
ep = range(0, len(loss_res["training"]))
plt.figure(figsize=(10, 8))
plt.plot(ep, loss_res["training"], label='Train')
plt.plot(ep, loss_res[0], label='0 dB')
plt.plot(ep, loss_res[10], label='10 dB')
plt.plot(ep, loss_res[20], label='20 dB')
plt.plot(ep, loss_res[30], label='30 dB')
plt.plot(ep, loss_res[40], label='40 dB')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title("DOA - {}".format(doa))
plt.legend(fontsize=14)
plt.show()
# Out:
# === Metrics ===
# ==== DOA-7 ====
# = MAE =_= Acc =
# 0.0111   15.31
# 0.0031   42.24
# 0.0011   68.15
# 0.0006   79.83
# 0.0006   82.38
