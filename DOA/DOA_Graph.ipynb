# %%
# Import required packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pylab import cm

# %% [markdown]
# # Accuracy vs SNR (DOA-3)

# %%
doa3_100_dl = [12.6,33.44,62.27,81.15,86.59]
doa3_200_dl = [16.24,41.75,68.07,84.43,87.15]
doa3_300_dl = [19.55,47.49,75.15,87.88,91.16]
doa3_100_mu = [5.47,15.44,31.91,51.42,69.83]
doa3_200_mu = [7.31,19.71,37.5,57.36,74.5]
doa3_300_mu = [8.7,22.49,41.07,60.72,76.98]

# %%
# Import required packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pylab import cm
# Use numpy.loadtxt to import our data
# wavelength, samp_1_abs, samp_2_abs = np.loadtxt('Absorbance_Data.csv', unpack=True, delimiter=',', skiprows=1)

import matplotlib.font_manager as fm
# Collect all the font names available to matplotlib
font_names = [f.name for f in fm.fontManager.ttflist]
print(font_names)

import matplotlib.font_manager as fm
# Rebuild the matplotlib font cache
fm._rebuild()
# Out:
# ['DejaVu Sans Mono', 'STIXSizeFourSym', 'cmb10', 'DejaVu Sans', 'cmss10', 'DejaVu Serif', 'DejaVu Sans', 'cmr10', 'DejaVu Sans Mono', 'DejaVu Sans', 'STIXSizeOneSym', 'DejaVu Sans Display', 'DejaVu Serif Display', 'cmex10', 'STIXSizeThreeSym', 'DejaVu Sans Mono', 'STIXSizeTwoSym', 'STIXNonUnicode', 'STIXGeneral', 'STIXGeneral', 'STIXNonUnicode', 'STIXSizeFourSym', 'STIXSizeThreeSym', 'STIXNonUnicode', 'STIXSizeOneSym', 'DejaVu Serif', 'DejaVu Serif', 'DejaVu Serif', 'cmsy10', 'cmmi10', 'STIXNonUnicode', 'DejaVu Sans', 'cmtt10', 'STIXGeneral', 'STIXGeneral', 'STIXSizeTwoSym', 'DejaVu Sans Mono', 'STIXSizeFiveSym', 'Liberation Serif', 'Liberation Serif', 'Liberation Mono', 'Liberation Serif', 'Liberation Serif', 'Liberation Mono', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Sans', 'Humor Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Sans Narrow']

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'


# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)

# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, doa3_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, doa3_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, doa3_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, doa3_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, doa3_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, doa3_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Edit the major and minor tick locations
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(100))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(50))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(0.5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(0.25))

# Add the x and y-axis labels
ax.set_xlabel('SNR(dB)', labelpad=10, weight="bold")
ax.set_ylabel('Accuracy(%)', labelpad=10, weight="bold")
ax.set_title("Accuracy vs SNR (DOA - 3)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs SNR (DOA - 3).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Accuracy vs SNR (DOA-6)

# %%
doa6_100 = [7.27, 22.4, 46.32, 64.32, 70.13]
doa6_200 = [9.84, 28.23, 54.07, 71.7, 76.68]
doa6_300 = [11.23, 32.42, 59.63, 75.82, 81.53]
doa6_100_mu = [1.61, 3.76, 7.86, 15.21, 26.15]
doa6_200_mu = [2.05, 4.69, 9.82, 18.21, 30.09]
doa6_300_mu = [2.228, 5.43, 11.09, 20.24, 32.57]

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)

# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, doa6_100, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, doa6_200, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, doa6_300, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, doa6_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, doa6_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, doa6_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('SNR(dB)', labelpad=10, weight="bold")
ax.set_ylabel('Accuracy(%)', labelpad=10, weight="bold")
ax.set_title("Accuracy vs SNR (DOA - 6)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs SNR (DOA - 6).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Accuracy vs DOA (SNR - 0dB)

# %%
SNR_0db_100_dl = [17.45,12.6,9.07,7.81,7.27,6.33]
SNR_0db_200_dl = [21.45,16.24,11.36,10.13,9.84,8.02]
SNR_0db_300_dl = [23.39,19.55,15.36,12.24,11.23,9.72]
SNR_0db_100_mu = [10.26,5.47,3.05,2.18,1.61,0.99]
SNR_0db_200_mu = [13.99,7.31,4,2.74,2.05,1.21]
SNR_0db_300_mu = [16.7,8.7,4.66,3.16,2.228,1.38]

# %%
import matplotlib.pyplot as plt
ep = [2, 3, 4, 5, 6, 7]
plt.figure(figsize=(20, 10))
plt.plot(ep, SNR_0db_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, SNR_0db_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, SNR_0db_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, SNR_0db_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, SNR_0db_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, SNR_0db_300_mu, linestyle='dotted', marker='*', label='MU-300')
plt.xlabel('DOA', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title("Accuracy vs DOA (SNR - 0dB)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs DOA (SNR - 0dB)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
plt.plot(ep, SNR_0db_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
plt.plot(ep, SNR_0db_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
plt.plot(ep, SNR_0db_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
plt.plot(ep, SNR_0db_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
plt.plot(ep, SNR_0db_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
plt.plot(ep, SNR_0db_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('DoA', labelpad=10, weight="bold")
ax.set_ylabel('Accuracy(%)', labelpad=10, weight="bold")
ax.set_title("Accuracy vs DOA (SNR - 0dB)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.99, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs DOA (SNR - 0dB).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Accuracy vs DOA (SNR - 30dB)

# %%
SNR_30db_100_dl = [86.78,81.15,70.29,67.31,64.32,57.23]
SNR_30db_200_dl = [89.78,84.43,76.1,75.56,71.7,67.5]
SNR_30db_300_dl = [93.17,87.88,83.1,81.46,75.82,71.16]
SNR_30db_100_mu = [72.98,51.42,34.29,22.26,15.21,6.87]
SNR_30db_200_mu = [77.82,57.36,39.94,26.33,18.21,8.25]
SNR_30db_300_mu = [80.45,60.72,43.12,28.9,20.24,9.23]

# %%
import matplotlib.pyplot as plt
ep = [2, 3, 4, 5, 6, 7]
plt.figure(figsize=(20, 10))
plt.plot(ep, SNR_30db_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, SNR_30db_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, SNR_30db_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, SNR_30db_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, SNR_30db_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, SNR_30db_300_mu, linestyle='dotted', marker='*', label='MU-300')
plt.xlabel('DOA', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.title("Accuracy vs DOA (SNR - 30dB)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs DOA (SNR - 30dB)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
plt.plot(ep, SNR_30db_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
plt.plot(ep, SNR_30db_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
plt.plot(ep, SNR_30db_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
plt.plot(ep, SNR_30db_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
plt.plot(ep, SNR_30db_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
plt.plot(ep, SNR_30db_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('DoA', labelpad=10, weight="bold")
ax.set_ylabel('Accuracy(%)', labelpad=10, weight="bold")
ax.set_title("Accuracy vs DOA (SNR - 30dB)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 0.45), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/Accuracy vs DOA (SNR - 30dB).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # MAE vs SNR (DOA-3)

# %%
doa3_100_dl = [0.0927,0.03273333333,0.01423333333,0.008366666667,0.006766666667]
doa3_200_dl = [0.0717,0.02583333333,0.01066666667,0.0061,0.005166666667]
doa3_300_dl = [0.06216666667,0.0228,0.009566666667,0.0048,0.004066666667]
doa3_100_mu = [0.2007,0.1679,0.1466,0.1087,0.0658]
doa3_200_mu = [0.1918,0.1635,0.1369,0.0951,0.0553]
doa3_300_mu = [0.186,0.1601,0.1302,0.0875,0.0498]

# %%
import matplotlib.pyplot as plt
ep = [0, 10, 20, 30, 40]
plt.figure(figsize=(20, 10))
plt.plot(ep, doa3_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, doa3_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, doa3_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, doa3_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, doa3_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, doa3_300_mu, linestyle='dotted', marker='*', label='MU-300')
# plt.xticks(np.arange(0, len(ep)+1, 1))
plt.yticks(np.arange(0, max(doa3_100_mu), 0.005))
plt.xlabel('SNR', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("MAE vs SNR (DOA - 3)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/MAE vs SNR (DOA - 3)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
# ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, doa3_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, doa3_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, doa3_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, doa3_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, doa3_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, doa3_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('MAE', labelpad=10, weight="bold")
ax.set_ylabel('SNR(db)', labelpad=10, weight="bold")
ax.set_title("MAE vs SNR (DOA - 3)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(1, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/MAE vs SNR (DOA - 3).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # MAE vs SNR (DOA-6)

# %%
doa6_100_dl = [0.1219166667,0.03548333333,0.01555,0.007683333333,0.006533333333]
doa6_200_dl = [0.09458333333,0.03273333333,0.01306666667,0.00695,0.005783333333]
doa6_300_dl = [0.07235,0.02321666667,0.008866666667,0.007183333333,0.005783333333]
doa6_100_mu = [0.2599,0.2282,0.212,0.193,0.1659]
doa6_200_mu = [0.25,0.2231,0.2073,0.1858,0.1566]
doa6_300_mu = [0.2456,0.2208,0.2035,0.181,0.1497]

# %%
import matplotlib.pyplot as plt
ep = [0, 10, 20, 30, 40]
plt.figure(figsize=(20, 10))
plt.plot(ep, doa6_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, doa6_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, doa6_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, doa6_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, doa6_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, doa6_300_mu, linestyle='dotted', marker='*', label='MU-300')
plt.xlabel('SNR', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("MAE vs SNR (DOA - 6)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/MAE vs SNR (DOA - 6)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
# ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, doa6_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, doa6_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, doa6_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, doa6_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, doa6_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, doa6_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('MAE', labelpad=10, weight="bold")
ax.set_ylabel('SNR(db)', labelpad=10, weight="bold")
ax.set_title("MAE vs SNR (DOA - 6)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(1, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/MAE vs SNR (DOA - 6).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # MAE vs DOA (SNR - 0dB)

# %%
SNR_0db_100_dl = [0.0789,0.0927,0.1031,0.11182,0.1219166667,0.1336142857]
SNR_0db_200_dl = [0.061,0.0717,0.09345,0.09806,0.1079166667,0.1145285714]
SNR_0db_300_dl = [0.0589,0.06883333333,0.07845,0.09162,0.09485,0.1009571429]
SNR_0db_100_mu = [0.1609,0.2007,0.2211,0.2425,0.2599,0.2809]
SNR_0db_200_mu = [0.1501,0.1918,0.2102,0.233,0.25,0.2726]
SNR_0db_300_mu = [0.1438,0.186,0.2055,0.2282,0.2456,0.2683]

# %%
import matplotlib.pyplot as plt
ep = [2, 3, 4, 5, 6, 7]
plt.figure(figsize=(20, 10))
plt.plot(ep, SNR_0db_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, SNR_0db_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, SNR_0db_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, SNR_0db_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, SNR_0db_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, SNR_0db_300_mu, linestyle='dotted', marker='*', label='MU-300')
plt.xlabel('DOA', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("MAE vs DOA (SNR - 0dB)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 0dB)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, SNR_0db_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, SNR_0db_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, SNR_0db_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, SNR_0db_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, SNR_0db_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, SNR_0db_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('DoA', labelpad=10, weight="bold")
ax.set_ylabel('MAE', labelpad=10, weight="bold")
ax.set_title("MAE vs DOA (SNR - 0dB)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 0dB).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %% [markdown]
# # MAE vs DOA (SNR - 30dB)

# %%
SNR_30db_100_dl = [0.0077,0.0083,0.008525,0.00876,0.009016666667,0.0093]
SNR_30db_200_dl = [0.004933333333,0.0061,0.006875,0.00716,0.0073,0.007714285714]
SNR_30db_300_dl = [0.004633333333,0.004966666667,0.005325,0.0067,0.007016666667,0.007285714286]
SNR_30db_100_mu = [0.0589,0.1087,0.1374,0.1719,0.193,0.218]
SNR_30db_200_mu = [0.0475,0.0951,0.1263,0.1632,0.1858,0.2133]
SNR_30db_300_mu = [0.0419,0.0875,0.1198,0.1575,0.181,0.2104]

# %%
import matplotlib.pyplot as plt
ep = [2, 3, 4, 5, 6, 7]
plt.figure(figsize=(20, 10))
plt.plot(ep, SNR_30db_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, SNR_30db_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, SNR_30db_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.plot(ep, SNR_30db_100_mu, linestyle='dotted', marker='*', label='MU-100')
plt.plot(ep, SNR_30db_200_mu, linestyle='dotted', marker='*', label='MU-200')
plt.plot(ep, SNR_30db_300_mu, linestyle='dotted', marker='*', label='MU-300')
plt.xlabel('DOA', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("MAE vs DOA (SNR - 30dB)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 30dB)")
plt.show()

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, SNR_30db_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, SNR_30db_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, SNR_30db_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)
ax.plot(ep, SNR_30db_100_mu, linestyle='-', marker='v', label='MU-100', markersize=8, linewidth=3)
ax.plot(ep, SNR_30db_200_mu, linestyle='-', marker='v', label='MU-200', markersize=8, linewidth=3)
ax.plot(ep, SNR_30db_300_mu, linestyle='-', marker='v', label='MU-300', markersize=8, linewidth=3)


ax2 = plt.axes([.6, .2, .3, .3])
ax2.xaxis.set_tick_params(which='major', size=5, width=1, direction='in', top='on')
ax2.xaxis.set_tick_params(which='minor', size=5, width=1, direction='in', top='on')
ax2.yaxis.set_tick_params(which='major', size=5, width=1, direction='in', right='on')
ax2.yaxis.set_tick_params(which='minor', size=5, width=1, direction='in', right='on')

ax2.plot(ep, SNR_30db_100_dl, linestyle='-', marker='s', label='DL-100', markersize=2, linewidth=1)
ax2.plot(ep, SNR_30db_200_dl, linestyle='-', marker='s', label='DL-200', markersize=2, linewidth=1)
ax2.plot(ep, SNR_30db_300_dl, linestyle='-', marker='s', label='DL-300', markersize=2, linewidth=1)

ax.arrow(x=4, y=0.015, dx=0.4, dy=0.02, width=0.002, facecolor='black', head_width = 0.009, 
         head_length = 0.1) 
# ax.annotate(' ', xy=(5,0.1), xytext=(2.5,0.1),
#             arrowprops={'arrowstyle': '-'}, va='center')

# Add the x and y-axis labels
ax.set_xlabel('DoA', labelpad=10, weight="bold")
ax.set_ylabel('MAE', labelpad=10, weight="bold")
ax.set_title("MAE vs DOA (SNR - 30dB)", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 1), loc=1, frameon=True, fontsize=15)


plt.setp(ax2)

plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 30dB).png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()
# Out:
#   adjustable: {'box', 'datalim'}
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float or None
#   anchor: 2-tuple of floats or {'C', 'SW', 'S', 'SE', ...}
#   animated: bool
#   aspect: {'auto', 'equal'} or num
#   autoscale_on: bool
#   autoscalex_on: bool
#   autoscaley_on: bool
#   axes_locator: Callable[[Axes, Renderer], Bbox]
#   axisbelow: bool or 'line'
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   contains: callable
#   facecolor: color
#   fc: color
#   figure: `.Figure`
#   frame_on: bool
#   gid: str
#   in_layout: bool
#   label: object
#   navigate: bool
#   navigate_mode: unknown
#   path_effects: `.AbstractPathEffect`
#   picker: None or bool or float or callable
#   position: [left, bottom, width, height] or `~matplotlib.transforms.Bbox`
#   prop_cycle: unknown
#   rasterization_zorder: float or None
#   rasterized: bool or None
# ...

# %%
import matplotlib.pyplot as plt
ep = [2, 3, 4, 5, 6, 7]
plt.figure(figsize=(20, 10))
plt.plot(ep, SNR_30db_100_dl, linestyle='dotted', marker='*', label='DL-100')
plt.plot(ep, SNR_30db_200_dl, linestyle='dotted', marker='*', label='DL-200')
plt.plot(ep, SNR_30db_300_dl, linestyle='dotted', marker='*', label='DL-300')
plt.xlabel('DOA', fontsize=14)
plt.ylabel('MAE', fontsize=14)
plt.title("MAE vs DOA (SNR - 30dB)")
plt.legend(fontsize=14)
# plt.savefig("/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 30dB) only DL")
plt.show()
# Out:
# findfont: Font family ['Avenir'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Avenir'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Avenir'] not found. Falling back to DejaVu Sans.

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['font.weight'] = 'bold'

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
ep = [2, 3, 4, 5, 6, 7]
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(8, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=7, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=7, width=2, direction='in', right='on')
# ep = [0, 10, 20, 30, 40]
# plt.figure(figsize=(8, 5))
ax.plot(ep, SNR_30db_100_dl, linestyle='--', marker='s', label='DL-100', markersize=7, linewidth=3)
ax.plot(ep, SNR_30db_200_dl, linestyle='--', marker='s', label='DL-200', markersize=7, linewidth=3)
ax.plot(ep, SNR_30db_300_dl, linestyle='--', marker='s', label='DL-300', markersize=7, linewidth=3)

# Add the x and y-axis labels
ax.set_xlabel('DoA', labelpad=10, weight="bold")
ax.set_ylabel('MAE', labelpad=10, weight="bold")
ax.set_title("MAE vs DOA (SNR - 30dB)_DL_only", weight="bold")
ax.grid(b=None, which='major', axis='both')
ax.legend(bbox_to_anchor=(0.25, 1), loc=1, frameon=True, fontsize=15)
plt.savefig('/content/drive/MyDrive/DOA/DOA_graphs/MAE vs DOA (SNR - 30dB)_DL_only.png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %%
from numpy import *
import os
import matplotlib.pyplot as plt
data = SNR_30db_100_dl
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
# ax1.semilogx(SNR_30db_100_dl,SNR_30db_200_dl)

ax2 = plt.axes([.65, .6, .2, .2])
# ax2.semilogx(data[3:8,1],data[3:8,2])
plt.setp(ax2, xticks=[], yticks=[])

plt.show()
